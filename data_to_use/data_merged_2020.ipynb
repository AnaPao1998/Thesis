# %%
# Imports
import os
import pandas as pd

# %%
# Here we read the csv file that that contains anxious tweets from 2020
anxiety1_2020_df1 = pd.read_csv("./tweets_2020/anxiety/diag_socialanxiety.csv")

# %%
#anxiety1_2020_df1

# %%
# Here we read the csv file that that contains anxious tweets from 2020
anxiety2_2020_df2 = pd.read_csv("./tweets_2020/anxiety/hate_socialanxiety.csv")

# %%
#anxiety2_2020_df2

# %%
frames = [anxiety1_2020_df1, anxiety2_2020_df2]

# %%
# Here we concatenate the df's
result_anxiety_2020 = pd.concat(frames)

# %%
#result_anxiety_2020

# %%
# Here we export the tweets deleting the duplicated ones 
result_anxiety_2020.drop_duplicates().to_csv('./merged_data/2020/anxiety_2020.csv', sep=',', index=False, encoding='utf-8-sig')

# %%
# Here we read the csv file that that contains depressed tweets from 2020
depression1_2020_df1 = pd.read_csv("./tweets_2020/depression/diag_depression.csv")

# %%
#depression1_2020_df1

# %%
# Here we read the csv file that that contains depressed tweets from 2020
depression2_2020_df2 = pd.read_csv("./tweets_2020/depression/hate_depression.csv")

# %%
#depression2_2020_df2

# %%
frames2 = [depression1_2020_df1, depression2_2020_df2]

# %%
# Here we concatenate the df's
result_depression_2020 = pd.concat(frames2)

# %%
#result_depression_2020

# %%
# Here we export the tweets deleting the duplicated ones
result_depression_2020.drop_duplicates().to_csv('./merged_data/2020/depression_2020.csv', sep=',', index=False, encoding='utf-8-sig')

# %%
result_depression_2020.drop_duplicates()
# Out:
#                                                    url  \
# 0    https://twitter.com/BrookeMedusa1/status/13447...
# 1    https://twitter.com/starkookslatte/status/1344...
# 2    https://twitter.com/Clarky_Cat_/status/1344794...
# 3    https://twitter.com/PlurryGodMomma/status/1344...
# 4    https://twitter.com/ahsofka/status/13447840910...
# ..                                                 ...
# 995  https://twitter.com/thatgalsierra/status/13405...
# 996  https://twitter.com/KaidenGamer/status/1340534...
# 997  https://twitter.com/batz_r0t/status/1340527426...
# 998  https://twitter.com/Keegan_9XX/status/13405241...
# 999  https://twitter.com/_susyyy_x/status/134051980...
#
#                           date  \
# 0    2020-12-31 23:59:05+00:00
# 1    2020-12-31 23:55:19+00:00
# 2    2020-12-31 23:54:49+00:00
# 3    2020-12-31 23:16:11+00:00
# 4    2020-12-31 23:14:46+00:00
# ..                         ...
# 995  2020-12-20 05:58:31+00:00
# 996  2020-12-20 05:47:46+00:00
# 997  2020-12-20 05:20:18+00:00
# 998  2020-12-20 05:07:15+00:00
# 999  2020-12-20 04:50:02+00:00
#
#                                                content  \
# 0    as someone who's been suffering from (diagnose...
# 1    my sister isn't even diagnosed with depression...
# 2    Diagnosed with chronic anxiety and depression ...
# 3    Mostly, thanks for being there along the way. ...
# 4    this year i had been diagnosed with depression...
# ..                                                 ...
# 995  i hate when niggas ion know say “fwm” or tell ...
# 996  I’m ready to be free of my anxiety and depress...
# 997  @faloraaa Therapy is pretty chill honestly for...
# 998  Depression is NOT a joke, however my current s...
# 999  Seasonal depression is alive and well. I love ...
#
#                                        renderedContent                   id  \
# 0    as someone who's been suffering from (diagnose...  1344795244194312193
# 1    my sister isn't even diagnosed with depression...  1344794293395804161
# 2    Diagnosed with chronic anxiety and depression ...  1344794168049217539
# 3    Mostly, thanks for being there along the way. ...  1344784448076746752
# 4    this year i had been diagnosed with depression...  1344784091011571713
# ..                                                 ...                  ...
# 995  i hate when niggas ion know say “fwm” or tell ...  1340537043332554752
# 996  I’m ready to be free of my anxiety and depress...  1340534338660786177
# 997  @faloraaa Therapy is pretty chill honestly for...  1340527426095308806
# 998  Depression is NOT a joke, however my current s...  1340524140873302017
# 999  Seasonal depression is alive and well. I love ...  1340519808996175872
#
#                                                   user outlinks tcooutlinks  \
# 0    {'username': 'BrookeMedusa1', 'displayname': '...       []          []
# 1    {'username': 'starkookslatte', 'displayname': ...       []          []
# 2    {'username': 'Clarky_Cat_', 'displayname': '-'...       []          []
# 3    {'username': 'PlurryGodMomma', 'displayname': ...       []          []
# 4    {'username': 'ahsofka', 'displayname': 'sof⁷ 🦋...       []          []
# ..                                                 ...      ...         ...
# 995  {'username': 'thatgalsierra', 'displayname': '...       []          []
# 996  {'username': 'KaidenGamer', 'displayname': 'Jo...       []          []
# 997  {'username': 'batz_r0t', 'displayname': '## ca...       []          []
# 998  {'username': 'Keegan_9XX', 'displayname': 'Kee...       []          []
# 999  {'username': '_susyyy_x', 'displayname': 'Susy...       []          []
#
#      replyCount  retweetCount  ...  quoteCount       conversationId  lang  \
# 0             1             0  ...           0  1344795244194312193    en
# 1             0             0  ...           0  1344794293395804161    en
# 2             1             0  ...           0  1344790648721911808    en
# 3             1             0  ...           0  1344784446738710528    en
# 4             1             0  ...           0  1344784091011571713    en
# ..          ...           ...  ...         ...                  ...   ...
# 995           0             0  ...           0  1340537043332554752    en
# 996           0             0  ...           0  1340534338660786177    en
# 997           1             0  ...           0  1340523717181517824    en
# 998           4             0  ...           0  1340524140873302017    en
# 999           0             0  ...           0  1340519808996175872    en
#
#                                                 source  \
# 0    <a href="http://twitter.com/download/android" ...
# 1    <a href="http://twitter.com/download/android" ...
# 2    <a href="http://twitter.com/download/android" ...
# 3    <a href="http://twitter.com/download/iphone" r...
# 4    <a href="http://twitter.com/download/iphone" r...
# ..                                                 ...
# 995  <a href="http://twitter.com/download/iphone" r...
# 996  <a href="http://twitter.com/download/iphone" r...
# 997  <a href="http://twitter.com/download/iphone" r...
# 998  <a href="http://twitter.com/download/android" ...
# 999  <a href="http://twitter.com/download/iphone" r...
#
#                                sourceUrl          sourceLabel media  \
# 0    http://twitter.com/download/android  Twitter for Android   NaN
# 1    http://twitter.com/download/android  Twitter for Android   NaN
# 2    http://twitter.com/download/android  Twitter for Android   NaN
# 3     http://twitter.com/download/iphone   Twitter for iPhone   NaN
# 4     http://twitter.com/download/iphone   Twitter for iPhone   NaN
# ..                                   ...                  ...   ...
# 995   http://twitter.com/download/iphone   Twitter for iPhone   NaN
# 996   http://twitter.com/download/iphone   Twitter for iPhone   NaN
# 997   http://twitter.com/download/iphone   Twitter for iPhone   NaN
# 998  http://twitter.com/download/android  Twitter for Android   NaN
# 999   http://twitter.com/download/iphone   Twitter for iPhone   NaN
#
#     retweetedTweet  quotedTweet  \
# 0              NaN          NaN
# 1              NaN          NaN
# 2              NaN          NaN
# 3              NaN          NaN
# 4              NaN          NaN
# ..             ...          ...
# 995            NaN          NaN
# 996            NaN          NaN
# 997            NaN          NaN
# 998            NaN          NaN
# 999            NaN          NaN
#
#                                         mentionedUsers
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 995                                                NaN
# 996                                                NaN
# 997  [{'username': 'faloraaa', 'displayname': 'falo...
# 998                                                NaN
# 999                                                NaN
#
# [4996 rows x 21 columns]
