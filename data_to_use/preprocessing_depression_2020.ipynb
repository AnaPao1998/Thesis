# %%
import pandas as pd 
pd.set_option("display.max_colwidth", 400)
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns
import string
import nltk # for text manipulation
from nltk.corpus import stopwords
import preprocessor as p
import warnings 
warnings.filterwarnings("ignore", category=DeprecationWarning)

# %matplotlib inline

# %%
# Here we read the csv file that that contains depressive tweets from 2019
depression_df = pd.read_csv("./merged_data/2020/depression_2020.csv")

# %%
#depression_df.info()

# %%
#Here we delete all the unnecesary colums
depression_df.drop(["content","id","user","outlinks","tcooutlinks","replyCount","retweetCount","likeCount","quoteCount",\
                    "conversationId","lang","source","sourceUrl","sourceLabel","media","retweetedTweet","quotedTweet",\
                    "mentionedUsers"] ,axis=1, inplace=True)

# %%
depression_df.head(10)
# Out:
#                                                              url  \
# 0   https://twitter.com/BrookeMedusa1/status/1344795244194312193
# 1  https://twitter.com/starkookslatte/status/1344794293395804161
# 2     https://twitter.com/Clarky_Cat_/status/1344794168049217539
# 3  https://twitter.com/PlurryGodMomma/status/1344784448076746752
# 4         https://twitter.com/ahsofka/status/1344784091011571713
# 5      https://twitter.com/xsaniiyahx/status/1344780162093752322
# 6         https://twitter.com/squem_1/status/1344770993001259013
# 7   https://twitter.com/phantomxbucky/status/1344770343299391488
# 8        https://twitter.com/GuuriChi/status/1344765539470737415
# 9   https://twitter.com/ThapeloKgoele/status/1344763928837050368
#
#                         date  \
# 0  2020-12-31 23:59:05+00:00
# 1  2020-12-31 23:55:19+00:00
# 2  2020-12-31 23:54:49+00:00
# 3  2020-12-31 23:16:11+00:00
# 4  2020-12-31 23:14:46+00:00
# 5  2020-12-31 22:59:10+00:00
# 6  2020-12-31 22:22:44+00:00
# 7  2020-12-31 22:20:09+00:00
# 8  2020-12-31 22:01:03+00:00
# 9  2020-12-31 21:54:39+00:00
#
#                                                                                                                                                                                                                                                                               renderedContent
# 0                                               as someone who's been suffering from (diagnosed 🙄) depression for 9 years now, new years resolutions don't mean anything. I'm trying (and failing lol) to better myself every single day... But I have a great feeling for 2021! lets do it!!
# 1  my sister isn't even diagnosed with depression. i am. she lashes out for sympathy, i cry alone. she has a boyfriend and someone to lean on, to talk to, go out with. i don't.\n\ni'm so tired of feeling alone. but truthfully, i'll never be comfortable in public being the person i am.
# 2                   Diagnosed with chronic anxiety and depression (kind of thought that would be a thing since I already have Generalised Anxiety Disorder) but also got told I have PTSD, from previous trauma in my life and specifically from my last ex and what happened with my friend.
# 3                                            Mostly, thanks for being there along the way. In the year that had been the first year in several I’d felt like getting social again I suffered some very real additional depression on top of the diagnosed I already have. You made it better.
# 4          this year i had been diagnosed with depression, achieved a first in my degree, talked to my mum for the first time in years and so much more. i’ve had many ups and downs in 2020 and it has been one of the toughest years of my life. let’s hope 2021 is better for all of us ❤️
# 5     🗓 January 1st 2021\n☁️Note from Saniyah\n🎀Dedicated to friends\n✨\n2020 was a rough year for me, most of my family got corona and I got diagnosed with depression. It was a scary year. But I met so many new friends, online and in real life! They made me stronger then ever before!
# 6                              in 2020 i reached my lowest point, later on i finally got diagnosed with depression, anxiety, ocd and a panic disorder and was put on medication for it, i’m not completely better but, allowing myself to open up and get treatment is something i’m proud of
# 7            after my reduction, i instantly saw a huge difference in my self esteem. i also had a huge mental breakdown sept 2019 and i withdrew from college to focus on my mental health. i was finally diagnosed with severe anxiety &amp; depression (already knew lmayo) &amp; with ADD
# 8                                                                                                                                                                                                      I may be using my god complex to cover my intense diagnosed depression but whos asking
# 9                                                                  -Finding Love\n-Being diagnosed with server clinical depression\n-Going broke\nNow : nursing my parents who contracted Covid19 ...\n\nSo much has happened in which I am greatful for ! \n\nThank you 2020 Jou fokon shet!

# %%
p.set_options(p.OPT.URL, p.OPT.EMOJI)
p.clean('Preprocessor is #awesome 👍 https://github.com/s/preprocessor')
# Out:
# 'Preprocessor is #awesome'

# %%
# Here we use a preprocessing library for tweet data called "Preprocessor" and we use it to delete the url's, mentions 
#and numbers
p.set_options(p.OPT.URL, p.OPT.MENTION, p.OPT.NUMBER)
depression_df['pre_proccessed'] = depression_df['renderedContent'].apply(lambda x: p.clean(x)).str.lower()
#depression_df.head(10)

# %%
# Here we use the nltk library and we download the stopwords
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Usuario\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
stopwords_english = stopwords.words('english') 
print('Stop words\n')
print(stopwords_english)
# Out:
# Stop words
#
# ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', "you're", "you've", "you'll", "you'd", 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', "she's", 'her', 'hers', 'herself', 'it', "it's", 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', "that'll", 'these', 'those', 'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such', 'no', 'nor', 'not', 'only', 'own', 'same', 'so', 'than', 'too', 'very', 's', 't', 'can', 'will', 'just', 'don', "don't", 'should', "should've", 'now', 'd', 'll', 'm', 'o', 're', 've', 'y', 'ain', 'aren', "aren't", 'couldn', "couldn't", 'didn', "didn't", 'doesn', "doesn't", 'hadn', "hadn't", 'hasn', "hasn't", 'haven', "haven't", 'isn', "isn't", 'ma', 'mightn', "mightn't", 'mustn', "mustn't", 'needn', "needn't", 'shan', "shan't", 'shouldn', "shouldn't", 'wasn', "wasn't", 'weren', "weren't", 'won', "won't", 'wouldn', "wouldn't"]

# %%
'no' in stopwords_english
# Out:
# True

# %%
# After doing some testing, I noticed that negations are important, so I removed them from the stopwords list
to_remove = ['no', 'not',"don't",'didn', "didn't", 'doesn', "doesn't", 'hadn', "hadn't", 'hasn', "hasn't"]
to_remove
            
[stopwords_english.remove(item) for item in to_remove if item in stopwords_english]
stopwords_english
# Out:
# ['i',
#  'me',
#  'my',
#  'myself',
#  'we',
#  'our',
#  'ours',
#  'ourselves',
#  'you',
#  "you're",
#  "you've",
#  "you'll",
#  "you'd",
#  'your',
#  'yours',
#  'yourself',
#  'yourselves',
#  'he',
#  'him',
#  'his',
#  'himself',
#  'she',
#  "she's",
#  'her',
#  'hers',
#  'herself',
#  'it',
#  "it's",
#  'its',
#  'itself',
#  'they',
#  'them',
#  'their',
#  'theirs',
#  'themselves',
#  'what',
#  'which',
#  'who',
#  'whom',
#  'this',
#  'that',
#  "that'll",
#  'these',
#  'those',
#  'am',
#  'is',
#  'are',
#  'was',
#  'were',
#  'be',
#  'been',
#  'being',
#  'have',
#  'has',
#  'had',
#  'having',
#  'do',
#  'does',
#  'did',
#  'doing',
#  'a',
#  'an',
#  'the',
#  'and',
#  'but',
#  'if',
#  'or',
#  'because',
#  'as',
#  'until',
#  'while',
#  'of',
#  'at',
#  'by',
#  'for',
#  'with',
#  'about',
#  'against',
#  'between',
#  'into',
#  'through',
#  'during',
#  'before',
#  'after',
#  'above',
#  'below',
#  'to',
#  'from',
#  'up',
#  'down',
#  'in',
#  'out',
#  'on',
#  'off',
#  'over',
#  'under',
#  'again',
#  'further',
#  'then',
#  'once',
#  'here',
#  'there',
#  'when',
#  'where',
#  'why',
#  'how',
#  'all',
#  'any',
#  'both',
#  'each',
#  'few',
#  'more',
#  'most',
#  'other',
#  'some',
#  'such',
#  'nor',
#  'only',
#  'own',
#  'same',
#  'so',
#  'than',
#  'too',
#  'very',
#  's',
#  't',
#  'can',
#  'will',
#  'just',
#  'don',
#  'should',
#  "should've",
#  'now',
#  'd',
#  'll',
#  'm',
#  'o',
#  're',
#  've',
#  'y',
#  'ain',
#  'aren',
#  "aren't",
#  'couldn',
#  "couldn't",
#  'haven',
#  "haven't",
#  'isn',
#  "isn't",
#  'ma',
#  'mightn',
#  "mightn't",
#  'mustn',
#  "mustn't",
#  'needn',
#  "needn't",
#  'shan',
#  "shan't",
#  'shouldn',
#  "shouldn't",
#  'wasn',
#  "wasn't",
#  'weren',
#  "weren't",
#  'won',
#  "won't",
#  'wouldn',
#  "wouldn't"]

# %%
'no' in stopwords_english
# Out:
# False

# %%
tokenized_tweet = depression_df['pre_proccessed'].apply(lambda x: x.split()) # tokenizing
#tokenized_tweet[:10]

# %%
# print(tokenized_tweet[:10])
tweets_clean_dict = {}
for num, sentence in enumerate(tokenized_tweet): #Go through every tweet in the list of tweets 
    tweets_clean = [] #create an empty list to save the cleaned tweet for each tweet 
    for word in sentence: #go through every word inside the "dirty" tweet and keep only the ones you want
        if (word not in stopwords_english): 
            tweets_clean.append(word)
    tweets_clean_dict[num] = tweets_clean #save the list of "cleaned" words (cleaned tweet) into a dict in the position num (0,1,2,... ,len(tweets))
tweets_clean_dict
# Out:
# {0: ['someone',
#   "who's",
#   'suffering',
#   '(diagnosed',
#   '🙄)',
#   'depression',
#   'years',
#   'now,',
#   'new',
#   'years',
#   'resolutions',
#   "don't",
#   'mean',
#   'anything.',
#   "i'm",
#   'trying',
#   '(and',
#   'failing',
#   'lol)',
#   'better',
#   'every',
#   'single',
#   'day...',
#   'great',
#   'feeling',
#   '!',
#   'lets',
#   'it!!'],
#  1: ['sister',
#   'even',
#   'diagnosed',
#   'depression.',
#   'am.',
#   'lashes',
#   'sympathy,',
#   'cry',
#   'alone.',
#   'boyfriend',
#   'someone',
#   'lean',
#   'on,',
#   'talk',
#   'to,',
#   'go',
#   'with.',
#   "don't.",
#   "i'm",
#   'tired',
#   'feeling',
#   'alone.',
#   'truthfully,',
#   "i'll",
#   'never',
#   'comfortable',
#   'public',
#   'person',
#   'am.'],
#  2: ['diagnosed',
#   'chronic',
#   'anxiety',
#   'depression',
#   '(kind',
#   'thought',
#   'would',
#   'thing',
#   'since',
#   'already',
#   'generalised',
#   'anxiety',
#   'disorder)',
#   'also',
#   'got',
#   'told',
#   'ptsd,',
#   'previous',
#   'trauma',
#   'life',
#   'specifically',
#   'last',
#   'ex',
#   'happened',
#   'friend.'],
#  3: ['mostly,',
#   'thanks',
#   'along',
#   'way.',
#   'year',
#   'first',
#   'year',
#   'several',
#   'i’d',
#   'felt',
#   'like',
#   'getting',
#   'social',
#   'suffered',
#   'real',
#   'additional',
#   'depression',
#   'top',
#   'diagnosed',
#   'already',
#   'have.',
#   'made',
#   'better.'],
#  4: ['year',
#   'diagnosed',
#   'depression,',
#   'achieved',
#   'first',
#   'degree,',
#   'talked',
#   'mum',
#   'first',
#   'time',
#   'years',
#   'much',
#   'more.',
#   'i’ve',
#   'many',
#   'ups',
#   'downs',
#   'one',
#   'toughest',
#   'years',
#   'life.',
#   'let’s',
#   'hope',
#   'better',
#   'us',
#   '❤️'],
#  5: ['🗓',
#   'january',
#   'st',
#   '☁️note',
#   'saniyah',
#   '🎀dedicated',
#   'friends',
#   '✨',
#   'rough',
#   'year',
#   'me,',
#   'family',
#   'got',
#   'corona',
#   'got',
#   'diagnosed',
#   'depression.',
#   'scary',
#   'year.',
#   'met',
#   'many',
#   'new',
#   'friends,',
#   'online',
#   'real',
#   'life!',
#   'made',
#   'stronger',
#   'ever',
#   'before!'],
#  6: ['reached',
#   'lowest',
#   'point,',
#   'later',
#   'finally',
#   'got',
#   'diagnosed',
#   'depression,',
#   'anxiety,',
#   'ocd',
#   'panic',
#   'disorder',
#   'put',
#   'medication',
#   'it,',
#   'i’m',
#   'not',
#   'completely',
#   'better',
#   'but,',
#   'allowing',
#   'open',
#   'get',
#   'treatment',
#   'something',
#   'i’m',
#   'proud'],
#  7: ['reduction,',
#   'instantly',
#   'saw',
#   'huge',
#   'difference',
#   'self',
#   'esteem.',
#   'also',
#   'huge',
#   'mental',
#   'breakdown',
#   'sept',
#   'withdrew',
#   'college',
#   'focus',
#   'mental',
#   'health.',
#   'finally',
#   'diagnosed',
#   'severe',
#   'anxiety',
#   '&amp;',
#   'depression',
#   '(already',
#   'knew',
#   'lmayo)',
#   '&amp;',
#   'add'],
#  8: ['may',
#   'using',
#   'god',
#   'complex',
#   'cover',
#   'intense',
#   'diagnosed',
#   'depression',
#   'whos',
#   'asking'],
#  9: ['-finding',
#   'love',
#   '-being',
#   'diagnosed',
#   'server',
#   'clinical',
#   'depression',
#   '-going',
#   'broke',
#   ':',
#   'nursing',
#   'parents',
#   'contracted',
#   'covid19',
#   '...',
#   'much',
#   'happened',
#   'greatful',
#   '!',
#   'thank',
#   'jou',
#   'fokon',
#   'shet!'],
#  10: ['real',
#   'question',
#   'depression',
#   'diagnosed',
#   'impact',
#   'ssris',
#   'people',
#   'aren’t',
#   'really',
#   'depressed?'],
#  11: ['birthday,',
#   'pat',
#   'back',
#   'tell',
#   'proud',
#   'made',
#   'yo',
#   'graduate.',
#   'years',
#   'ago',
#   'diagnosed',
#   'depression',
#   'age',
#   '.',
#   'struggled',
#   'depression',
#   'years.',
#   'year',
#   'breaking',
#   'point.',
#   'got',
#   'much',
#   'better.'],
#  12: ['hated',
#   '.',
#   'good',
#   'thing',
#   'little',
#   'squish.',
#   '(also',
#   'diagnosed',
#   'postnatal',
#   'depression',
#   'yesterday',
#   '🎵and',
#   'happy',
#   'new',
#   'year',
#   '🎵)'],
#  13: ['nothing',
#   'hits',
#   'hard',
#   'mania',
#   'caused',
#   'antidepressants',
#   'youre',
#   'wrongly',
#   'diagnosed',
#   'unipolar',
#   'depression'],
#  14: ['kept',
#   'baby',
#   'alive.',
#   'survived',
#   'diagnosed',
#   'postpartum',
#   'depression',
#   'postpartum',
#   'anxiety',
#   'top',
#   'regular',
#   'ol',
#   'depression',
#   'anxiety.',
#   'managed',
#   'deal',
#   'four',
#   'month',
#   'femoral',
#   'nerve',
#   'damage',
#   'caused',
#   'constant',
#   'pain.',
#   'posted',
#   'fire',
#   'ttt',
#   'selfies.'],
#  15: ['also',
#   'diagnosed',
#   'major',
#   'ptsd,',
#   'chronic',
#   'depression',
#   'anxiety.',
#   'dealing',
#   'whole',
#   'pete',
#   'thing',
#   'one',
#   'thing',
#   'another'],
#  16: ['same!',
#   'got',
#   'tested',
#   'diagnosed',
#   'beginning',
#   'year,',
#   'medication',
#   'bit',
#   "i'm",
#   'seriously',
#   'wondering',
#   'whether',
#   'decadeslong',
#   'depression/anxiety',
#   'symptom',
#   'rather',
#   'root',
#   'problem.',
#   'best',
#   'luck',
#   'health',
#   'journey!',
#   '🙌'],
#  17: ['got',
#   'diagnosed',
#   'adhd,',
#   'depression',
#   'got',
#   'worse,',
#   'gender',
#   'issues,',
#   'overall',
#   'world',
#   'news',
#   'general',
#   'everything',
#   'made',
#   'difficult',
#   'continue.',
#   'good',
#   'things!',
#   'met',
#   'ton',
#   'incredible',
#   'talented',
#   'people,',
#   'got',
#   'new',
#   'job,',
#   'discovered',
#   'new',
#   'things!'],
#  18: ['school',
#   'started,',
#   'mood',
#   'motivation',
#   'dropped,',
#   'got',
#   'diagnosed',
#   'w',
#   'depression',
#   'lol,',
#   'dad',
#   'mad',
#   'lot',
#   'month'],
#  19: ['-came',
#   'bi',
#   'college,',
#   'healthy',
#   'lesbian',
#   'relationship',
#   'years',
#   '(her',
#   'parents',
#   'remain',
#   'second',
#   'family',
#   'even',
#   'broke',
#   'up❤️',
#   '-debilitating',
#   'mental',
#   'illness:',
#   'severe',
#   'depression,',
#   'anxiety,',
#   'ptsd',
#   'not',
#   'diagnosed',
#   'til',
#   'mid',
#   '’s;',
#   'debilitating',
#   'worsening',
#   'ocd',
#   'still',
#   'not',
#   'diagnosed',
#   ':',
#   '('],
#  20: ['hey',
#   'liam',
#   'see',
#   'this..i',
#   'want',
#   'know',
#   'made',
#   'year,',
#   'hard',
#   'core',
#   'diagnosed',
#   'anxiety',
#   'bit',
#   'depression',
#   'weekly',
#   'videos',
#   'shows',
#   'got',
#   'smile',
#   'face',
#   'nobody',
#   'could.',
#   'im',
#   'much',
#   'better',
#   'mentally',
#   'thanks',
#   'u'],
#  21: ['two',
#   'years',
#   'ago,',
#   'diagnosed',
#   'ptsd.',
#   'getting',
#   'better',
#   'every',
#   'day,',
#   'process',
#   '&amp;',
#   'sessions',
#   'hell',
#   'times.',
#   'two',
#   'months',
#   'ago,',
#   'diagnosed',
#   'depression.',
#   "can't",
#   'believe',
#   'made',
#   'far,',
#   'especially',
#   'year.',
#   "i'm",
#   'glad',
#   "i'm",
#   'surviving.'],
#  22: ['recently',
#   'diagnosed',
#   'major',
#   'depression',
#   'generalized',
#   'anxiety',
#   'disorder,',
#   'starting',
#   'twitter',
#   'way',
#   'track',
#   'progress',
#   'medications',
#   'therapy.',
#   'also',
#   'way',
#   'promote',
#   't-shirts',
#   'trying',
#   'sell.'],
#  23: ['earth',
#   'recently',
#   'diagnosed',
#   'form',
#   'depression...',
#   'bipolar',
#   'disorder'],
#  24: ['feel',
#   'extra',
#   'emotional',
#   'new',
#   'year.',
#   "can't",
#   'believe',
#   'made',
#   'it.',
#   'tough',
#   'year.',
#   'lost',
#   'loved',
#   'ones',
#   'diagnosed',
#   'depression',
#   '&amp;',
#   'anxiety.',
#   'honestly',
#   'thought',
#   "i'm",
#   'not',
#   'gonna',
#   'make',
#   'it.',
#   'depressed',
#   'hiding',
#   'makes',
#   'harder.',
#   "i'm",
#   'glad',
#   'survived.'],
#  25: ['don’t',
#   'anything',
#   'anxiety',
#   '&amp;',
#   'depression',
#   'diagnosed',
#   'feel',
#   'like',
#   '%',
#   'time!',
#   '😩'],
#  26: ['rollercoaster.',
#   'amoret',
#   'turned',
#   ',',
#   'got',
#   'new',
#   'car,',
#   'leo',
#   'reunited,',
#   'miscarriage,i',
#   'got',
#   'best',
#   'promotion',
#   'life,',
#   'went',
#   'worst',
#   'depression',
#   'life,',
#   'diagnosed',
#   'add.',
#   'worked',
#   'year,',
#   'family',
#   'healthy.',
#   'i’m',
#   'ready'],
#  27: ['shitty.',
#   'realized',
#   'sad,',
#   'lonely',
#   '&amp;',
#   'unmotivated',
#   'feel',
#   'really',
#   'unhealthy.',
#   'started',
#   'therapy,',
#   'got',
#   'diagnosed',
#   'ptsd,',
#   'depression',
#   'anxiety.',
#   'i’m',
#   'heaviest',
#   'i’ve',
#   'long',
#   'time.',
#   'not',
#   'saying',
#   'better',
#   'i’ve',
#   'hit',
#   'rock',
#   'bottom',
#   'can’t',
#   'get',
#   'worse.',
#   'right?'],
#  28: ['it’s',
#   'matter',
#   'definition.',
#   'unipolar',
#   'mania,',
#   'i.e.',
#   'mania',
#   'without',
#   'depression,',
#   'exist.',
#   'it’s',
#   'still',
#   'often',
#   'diagnosed',
#   'bipolar',
#   'there’s',
#   'debate',
#   'within',
#   'psychology',
#   'psychiatry',
#   'changing',
#   'that.',
#   'it’s',
#   'reported',
#   'stress',
#   'response',
#   'well.',
#   'think',
#   'so,',
#   'yeah.'],
#  29: ['diagnosed',
#   'depression?',
#   'not',
#   'please',
#   'stop',
#   'throwing',
#   'word',
#   'around',
#   'it’s',
#   'medical',
#   'term',
#   'not',
#   'adjective.'],
#  30: ['although',
#   'diagnosed',
#   'depression',
#   'anxiety',
#   'year',
#   'im',
#   'really',
#   'glad',
#   'achievements',
#   '.',
#   'got',
#   'travel',
#   'poland',
#   'see',
#   'world,',
#   'started',
#   'college,',
#   'found',
#   'new',
#   'hobbies,',
#   'got',
#   'promoted,',
#   'found',
#   'self',
#   'love,',
#   'bought',
#   'dream',
#   'car',
#   '💓'],
#  31: ['diagnosed', 'w', 'depression', 'social', 'separation', 'anxieties'],
#  32: ['//',
#   'august',
#   ',',
#   ',',
#   'done',
#   'singing',
#   'her.',
#   'hung',
#   'watched',
#   'tv.',
#   'got',
#   'called',
#   "sister's",
#   'room.',
#   'saw',
#   'grandmas',
#   'lifeless',
#   'body.',
#   'everything',
#   'went',
#   'hill',
#   'that.',
#   'diagnosed',
#   'anxiety',
#   'depression.',
#   'started',
#   'self',
#   'harming.'],
#  33: ['year',
#   'diagnosed',
#   'bipolar',
#   'depression,',
#   'even',
#   'lows',
#   'not',
#   'let',
#   'beat',
#   'me.'],
#  34: ['weird,',
#   'but:',
#   '-',
#   'made',
#   'short',
#   'films',
#   '-',
#   'got',
#   'better',
#   'editing',
#   '-',
#   'got',
#   'diagnosed',
#   'mixed',
#   'depression/anxiety',
#   'disorder',
#   '-',
#   'put',
#   'meds,',
#   'feel',
#   'much',
#   'better',
#   '-',
#   'year',
#   'not',
#   'drinking',
#   '-',
#   'went',
#   'back',
#   'uni',
#   '-',
#   'worked',
#   'musician',
#   "i've",
#   'listened',
#   'since',
#   '.',
#   'lets',
#   'go'],
#  35: ['omg',
#   '😭',
#   "i've",
#   'always',
#   'depression/anxiety',
#   'since',
#   'tween',
#   'years',
#   '-',
#   'finally',
#   'learned',
#   'autistic',
#   'mid',
#   'literally',
#   'two',
#   'years',
#   'ago',
#   'diagnosed',
#   'bipolar.',
#   'absolutely',
#   'wish',
#   'every',
#   'single',
#   'day',
#   'could',
#   'relive',
#   'life',
#   'knowledge.'],
#  36: ["don't",
#   'know,',
#   'never',
#   'diagnosed',
#   'either',
#   'never',
#   'suffered',
#   'depression.',
#   'experience',
#   'anxiety',
#   'spectrum.'],
#  37: ['got', 'diagnosed', 'trilingual', 'depression', '🤙'],
#  38: ["can't",
#   'believe',
#   'long',
#   'years',
#   'life,',
#   'recently',
#   'diagnosed',
#   'adhd,',
#   'autism,',
#   'bipolar',
#   'disorder',
#   'top',
#   'depression',
#   'anxiety',
#   'already',
#   'knew'],
#  39: ['year',
#   'worst',
#   'year',
#   'myself.',
#   'diagnosed',
#   'w',
#   'depression,',
#   'wanting',
#   'nothing',
#   'done',
#   'w',
#   'everything.',
#   'i’m',
#   'happy',
#   'say',
#   'i’m',
#   'still',
#   'still',
#   'pushing',
#   ':)'],
#  40: ['-anemia',
#   '-got',
#   'back',
#   'together',
#   '(bc',
#   'we’re',
#   'toxic',
#   'like',
#   'that)',
#   '-smart',
#   'lockdown',
#   'started',
#   'still',
#   'wasn’t',
#   'allowed',
#   'meet',
#   'friends',
#   '-every',
#   'college',
#   'except',
#   'mine',
#   'opened.',
#   'didn’t',
#   'even',
#   'get',
#   'one',
#   'week',
#   'happiness',
#   '-got',
#   'diagnosed',
#   'acute',
#   'depression.',
#   'hope',
#   'gone'],
#  41: ['read',
#   'books',
#   'written',
#   'female',
#   'autistics,',
#   'familiarize',
#   'w/',
#   'dsm',
#   'criteria,',
#   'note',
#   'symptoms',
#   'w/',
#   'since',
#   'childhood',
#   '&amp;',
#   'prepared',
#   'discuss.',
#   'women',
#   'r',
#   'typically',
#   'diagnosed',
#   'w/',
#   'ocpd,',
#   'add,',
#   'anxiety,',
#   'depression,',
#   'etc.',
#   'considering',
#   'autism',
#   'may',
#   'root'],
#  42: ['well,',
#   'way',
#   'no',
#   'actual',
#   'test',
#   'depression',
#   'migraines',
#   'trigeminal',
#   'neuralgia.',
#   'meaning',
#   'diagnosed',
#   'questionnaire.'],
#  43: ['bit',
#   'odd',
#   'mother',
#   'doesn’t',
#   'believe',
#   'i’m',
#   'depressed',
#   'won’t',
#   'anything',
#   'literally',
#   'diagnosed',
#   'clinical',
#   'depression'],
#  44: ['i’ve',
#   'social',
#   'anxiety',
#   'basically',
#   'whole',
#   'life.',
#   'didn’t',
#   'get',
#   'diagnosed',
#   'depression',
#   'anxiety',
#   'couple',
#   'years',
#   'ago.',
#   'often',
#   'wonder',
#   'would’ve',
#   'like',
#   'growing',
#   'properly',
#   'diagnosed',
#   'sooner.',
#   'probably',
#   'lot',
#   'less',
#   'awkward.'],
#  45: ['%',
#   'suicides',
#   'male',
#   'suicides,',
#   'even',
#   'though',
#   'number',
#   'men',
#   'diagnosed',
#   'depression',
#   'mental',
#   'health',
#   'issues',
#   'women',
#   'are.'],
#  46: ['✨2020',
#   'recap',
#   'happy',
#   'new',
#   'year',
#   'beating',
#   'cancer,',
#   'diagnosed',
#   'depression',
#   '&amp;',
#   'anxiety',
#   'trying',
#   'survive',
#   'pandemic',
#   'like',
#   'everyone',
#   'else.',
#   'taught',
#   'i’m',
#   'bad',
#   'b*tch',
#   '&amp;',
#   'really',
#   'difficult',
#   'things',
#   '.',
#   '#thursdaythoughts',
#   'i’m',
#   'excited',
#   '.',
#   'let’s',
#   'go!🥂'],
#  47: ['journaling',
#   'year',
#   'man.',
#   'got',
#   'diagnosed',
#   'achalasia,',
#   'got',
#   'surgery',
#   '&amp;',
#   'allergic',
#   'reaction',
#   'it,',
#   'living',
#   'pandemic,',
#   'forcing',
#   'process',
#   'past',
#   'trauma,',
#   'got',
#   'diagnosed',
#   'depression',
#   'panic',
#   'disorder.',
#   'bright',
#   'side,',
#   'got',
#   'puppy!',
#   'lol',
#   'year.'],
#  48: ['i’m', 'get', 'diagnosed', 'depression', 'oh', 'poopy'],
#  49: ['really',
#   'worst',
#   'year',
#   'life',
#   'moments',
#   'depression',
#   '&amp;',
#   'uncertainty,',
#   'getting',
#   'covid',
#   'mom',
#   'diagnosed',
#   'cancer',
#   'senior',
#   'year.',
#   'yeah',
#   'no.',
#   'i’m',
#   'ready',
#   'shit',
#   'end.'],
#  50: ['clinically', 'diagnosed', 'depression?', 'xd'],
#  51: ['-depression',
#   'sets',
#   'able',
#   'shake',
#   'since',
#   '-more',
#   'people',
#   'care',
#   'get',
#   'covid,',
#   'lucky',
#   'pull',
#   '-got',
#   'kitty',
#   '-mother',
#   'gets',
#   'diagnosed',
#   'cancer',
#   '-christmas',
#   '-new',
#   'years',
#   'everything',
#   'else',
#   'blur.',
#   '&gt;.&lt;'],
#  52: ['october:',
#   'finally',
#   'diagnosed',
#   'depression',
#   'put',
#   'antidepressants.',
#   'loooooot',
#   'studying',
#   'cat',
#   'pics.'],
#  53: ["i've",
#   'clinical',
#   'depression',
#   'life',
#   '-',
#   'childhood.',
#   'diagnosed',
#   'late',
#   'take',
#   'meds.',
#   'help',
#   'ton.',
#   'but,',
#   'going',
#   'vegan',
#   'best',
#   'thing',
#   'me.',
#   'cook',
#   'scratch',
#   'eat',
#   'variety',
#   'foods',
#   'now.',
#   'still',
#   'take',
#   'meds',
#   'depression',
#   'pretty',
#   'much',
#   'gone.'],
#  54: ['difficult',
#   'year',
#   'lot',
#   'reasons,',
#   'add',
#   'recently',
#   'diagnosed',
#   'depression.',
#   'taking',
#   'medication',
#   'now,',
#   'trying',
#   'hopeful',
#   'possible',
#   'good',
#   'year',
#   'get',
#   'back',
#   'track',
#   'recovery.',
#   'please',
#   "don't",
#   'take',
#   'mental..',
#   '/2'],
#  55: ['exactly.',
#   'like',
#   "i'm",
#   'college',
#   'picked',
#   'th',
#   'class',
#   'two',
#   'hours',
#   'long',
#   'assign',
#   'hours',
#   'homework',
#   'night',
#   'diagnosed',
#   'severe',
#   'depression',
#   'got',
#   'go',
#   'therapy',
#   'unedited',
#   'sorry',
#   'mistakes.',
#   '📈'],
#  56: ['learning',
#   'curve',
#   'me,',
#   'diagnosed',
#   'depression',
#   'february,',
#   'compulsive',
#   'thought',
#   'disorder',
#   'march,',
#   'losing',
#   'dad',
#   'july',
#   'whole',
#   'covid',
#   'situation.',
#   'still',
#   'grateful',
#   'another',
#   'year,',
#   'looking',
#   'forward',
#   ',',
#   'new',
#   'house,',
#   'baby,',
#   'life'],
#  57: ['wild.',
#   'lost',
#   'one',
#   'important',
#   'people',
#   'life,',
#   'got',
#   'diagnosed',
#   'depression',
#   'anxiety,',
#   'met',
#   'someone',
#   'amazing,',
#   'start',
#   'streaming,',
#   'growing',
#   'greatest',
#   'community.',
#   'thank',
#   'everyone💕',
#   '#goodbye2020',
#   '#happynewyear2021',
#   '#twitchstreamers'],
#  58: ['tis',
#   'wild',
#   'year.',
#   'lockdown',
#   'ever',
#   'present',
#   'worry',
#   'covid.',
#   'got',
#   'diagnosed',
#   'depression,',
#   'coming',
#   'terms',
#   'toxic',
#   'relationships/friendships.',
#   'however,',
#   'sold',
#   'loads',
#   'paintings,',
#   'got',
#   'published',
#   'book,',
#   'spent',
#   'loads',
#   'time',
#   'fave',
#   'human.'],
#  59: ['think',
#   'shit',
#   'life',
#   'syndrome',
#   'cause',
#   'quite',
#   'bit',
#   'depression',
#   'diagnosed',
#   'non',
#   'mental',
#   'health',
#   'experts',
#   '(gps)..',
#   'sometimes',
#   'not,',
#   'mental',
#   'health',
#   'issue',
#   'symptom',
#   "can't",
#   'treated',
#   'fully',
#   'without',
#   'resolving',
#   'cause'],
#  60: ['december',
#   '-',
#   'december',
#   '.',
#   'toughest',
#   'year',
#   ',',
#   'year',
#   'bad',
#   'health',
#   'condition',
#   ',',
#   'diagnosed',
#   'major',
#   'depression',
#   ',',
#   'tried',
#   'end',
#   'life',
#   'failed',
#   ',',
#   'felt',
#   'worthless',
#   'cried',
#   'everyday',
#   'family',
#   'don’t',
#   'wish',
#   'live',
#   'anymore.',
#   '[thread]'],
#  61: ['recently',
#   'diagnosed',
#   'depression',
#   'fortunately',
#   'not',
#   'severe',
#   '#saa',
#   'employee',
#   '😢😢😢😭😭😭😭😭😭'],
#  62: ['keeping',
#   'top',
#   'secrets',
#   'lies',
#   'nearly',
#   'impossible',
#   'since',
#   "he's",
#   'diagnosed',
#   'manic',
#   'depression.',
#   '#tadema22',
#   'get',
#   '#rt',
#   '#iartg',
#   '#asmsg',
#   '#bookboost'],
#  63: ['clinically', 'diagnosed', 'depression', 'patient?'],
#  64: ["i've",
#   'people',
#   'say',
#   "i'm",
#   '"faking',
#   'depression',
#   'sympathy"',
#   'argument',
#   'point.',
#   'fucking',
#   'dare',
#   'you.',
#   'diagnosed',
#   'severe',
#   'clinical',
#   'depression',
#   '&amp;',
#   'anxiety.',
#   'argument',
#   'someone',
#   "don't",
#   'like',
#   "don't",
#   'piece',
#   'shit',
#   '&amp;',
#   'gas',
#   'light',
#   'illness.🤡'],
#  65: ['believe',
#   'this.',
#   'wife',
#   'diagnosed',
#   'depression',
#   'yo.',
#   'given',
#   'meds',
#   'several',
#   'suicide',
#   'attempts',
#   'till',
#   'now.',
#   'years',
#   'ago',
#   'rediagnosed',
#   'anxiety,',
#   'changed',
#   'meds',
#   'changed',
#   'things',
#   'life.',
#   'new',
#   'person'],
#  66: ['diagnosed',
#   'depression',
#   'social',
#   'anxiety',
#   'still',
#   'called',
#   '“super',
#   'bubbly”',
#   '“such',
#   'ray',
#   'light”',
#   'people',
#   'met',
#   'me.',
#   'flex',
#   'toxic',
#   'trait?'],
#  67: ['apart',
#   'pandemic,',
#   'local',
#   'calamities.',
#   'experienced',
#   'breakup',
#   'middle',
#   'everything.',
#   'top',
#   'it,',
#   'diagnosed',
#   'chronic',
#   'depression.',
#   'doubtful',
#   'would',
#   'like',
#   'seek',
#   'second',
#   'opinion.'],
#  68: ['also',
#   'year',
#   'took',
#   'mental',
#   'health',
#   'serious,',
#   'got',
#   'diagnosed',
#   'depression,',
#   'started',
#   'antidepressants',
#   'stopped',
#   'using',
#   'didn’t',
#   'work',
#   'towards',
#   'end',
#   'year,',
#   'help',
#   'someone',
#   'dear',
#   'me,',
#   'pushed',
#   'go',
#   'therapy.',
#   'nice.'],
#  69: ['get', 'diagnosed', 'depression', 'isnt'],
#  70: ['honour',
#   'receive',
#   'certificate',
#   'merit',
#   'john',
#   'fry',
#   'prize',
#   'year',
#   'work',
#   'audit',
#   'management',
#   'newly',
#   'diagnosed',
#   'depression',
#   'primary',
#   'care.',
#   'previously',
#   'published',
#   'findings',
#   'february.',
#   '#talkinghelps',
#   '#teamgp',
#   '(6/12)'],
#  71: ['honestly,',
#   'pretty',
#   'shit',
#   'year.',
#   'good',
#   'moments.',
#   'got',
#   'toxic',
#   'relationship',
#   'broke',
#   'core.',
#   'diagnosed',
#   'severe',
#   'anxiety',
#   'chronic',
#   'depression.',
#   'lost',
#   'cousin',
#   'like',
#   'brother',
#   'me...'],
#  72: ['tahun',
#   'ini',
#   'indeed',
#   'tahun',
#   'terberat',
#   'tapi',
#   'juga',
#   'ter-blessing',
#   'yang',
#   'pernah',
#   'gue',
#   'alami.',
#   '-diterima',
#   'beasiswa',
#   'gks',
#   'dan',
#   'lanjut',
#   'kuliah',
#   'di',
#   'postech',
#   '-keluar',
#   'dari',
#   'kantor',
#   'pertama',
#   'gue',
#   'setelah',
#   'bekerja',
#   'hampir',
#   'tahun.',
#   '-been',
#   'diagnosed',
#   'depression',
#   'bipolar.',
#   '(pertama',
#   'kalinya',
#   'gue',
#   'ngetwit',
#   'ini)'],
#  73: ['makes',
#   'sense!',
#   'thank',
#   'you.',
#   'diagnosed',
#   'non-uk',
#   'psychiatrist',
#   'referred',
#   'bc',
#   'gp',
#   'thought',
#   'depression.',
#   'psychiatrist',
#   'linked',
#   'possible',
#   'viral',
#   'trigger.',
#   'called',
#   'cfs.',
#   'call',
#   'me.',
#   'either',
#   'way,',
#   'sucks!!'],
#  74: ["i'm",
#   'not',
#   'nd',
#   '(at',
#   'least',
#   'not',
#   'yet',
#   'diagnosed)',
#   'diagnosed',
#   'depression',
#   'would',
#   'get',
#   'obsessed',
#   'certain',
#   'sources',
#   '(bsd,',
#   'fe3h,',
#   'persona',
#   'genshin',
#   'late)',
#   'would',
#   'focus',
#   'little',
#   'nothing',
#   'ages,',
#   'lose',
#   'sleep',
#   'much',
#   'enjoy',
#   'etc.',
#   'just-'],
#  75: ['hi', 'yall!!!', 'im', 'self-diagnosed', 'depression', 'era', '✌️😘🤳'],
#  76: ['imagine',
#   'someone',
#   'told',
#   'diagnosed',
#   'anxiety',
#   'depression',
#   'went',
#   '....',
#   'omg....',
#   'ew...',
#   'gave',
#   'chills..',
#   'horrible!',
#   'lol',
#   'fuck',
#   'shane',
#   'dawson',
#   'mannnnn'],
#  77: ['diagnosed',
#   'depression',
#   'decade',
#   'ago',
#   'found',
#   'techniques',
#   'mitigate',
#   'worst',
#   'it,',
#   'therapist',
#   '(and',
#   'gp)',
#   'patiently',
#   'spent',
#   'months',
#   'making',
#   'understand',
#   'going',
#   'through...'],
#  78: ['reference',
#   "i'm",
#   'professionally',
#   'diagnosed',
#   'adhd,',
#   'depression',
#   'anxiety',
#   'havent',
#   'self',
#   'diagnosed',
#   'anything',
#   "i'm",
#   'wondering',
#   'might',
#   'autism',
#   'and/or',
#   'bpd',
#   '(i',
#   'personally',
#   'choose',
#   'avoid',
#   'self',
#   'diagnosing',
#   'though',
#   'uncertainty)'],
#  79: ['diagnosed',
#   'depression',
#   'years',
#   'suffering',
#   'weeks',
#   'work',
#   'almost',
#   'full',
#   'pay',
#   'lockdown',
#   'end',
#   'that.',
#   'mental',
#   'health',
#   'never',
#   'better'],
#  80: ['remember',
#   'time',
#   'talking',
#   'doctor',
#   'depression',
#   'explained',
#   'symptoms',
#   'told',
#   'take',
#   'recover,',
#   'maybe',
#   'even',
#   'couple',
#   'months.',
#   'started',
#   'crying',
#   'told',
#   'diagnosed',
#   'years',
#   'ago',
#   '(i',
#   'time)'],
#  81: ['yr',
#   'old',
#   'sister',
#   'diagnosed',
#   'depression',
#   'bc',
#   'said',
#   'sleep',
#   'lot'],
#  82: ['tw',
#   'suicide',
#   'followed',
#   ',',
#   'probably',
#   'know',
#   'happened,',
#   'basically',
#   'entered',
#   'law',
#   'school,',
#   'hated',
#   'it,',
#   'almost',
#   'killed',
#   'myself,',
#   'dropped',
#   'out,',
#   'got',
#   'diagnosed',
#   'depression,',
#   'felt',
#   'like',
#   'failure',
#   "didn't",
#   'know',
#   'aim',
#   'anymore'],
#  83: ['went',
#   'deep',
#   'emotional',
#   'mental',
#   'spiral',
#   'pandemic,',
#   'state',
#   'got',
#   'worse',
#   'breakup',
#   'ex.',
#   'got',
#   'diagnosed',
#   'anxiety',
#   'mild',
#   'depression',
#   'after,',
#   'everything',
#   'went',
#   'downhill',
#   'year.',
#   'lost',
#   'motivation',
#   'move',
#   'forward.'],
#  84: ['well',
#   'useless',
#   'thought',
#   'gonna',
#   'year',
#   'first',
#   'month',
#   'diagnosed',
#   'depression',
#   'anxiety',
#   'lol'],
#  85: ['know',
#   'depression',
#   'diagnosed',
#   'incorrectly',
#   'anxiety,',
#   'around',
#   'percent',
#   'time?',
#   "don't",
#   'ignore',
#   'signs..'],
#  86: ['it’s',
#   'year',
#   'half',
#   'since',
#   'diagnosed',
#   '&amp;',
#   'battling',
#   'severe',
#   'depression',
#   'disorder.',
#   'year',
#   'transformation',
#   'i’ve',
#   'grown.',
#   'here’s',
#   'growth',
#   'achievement.',
#   '✨✨'],
#  87: ['introduced',
#   'saying',
#   '“hi',
#   'im',
#   'sad”',
#   'joke',
#   'diagnosed',
#   'depression',
#   'later',
#   'year',
#   ':)'],
#  88: ['tw',
#   '//',
#   'mention',
#   'suicide',
#   'suicidal',
#   'thoughts',
#   'there’s',
#   'one',
#   'day',
#   'left',
#   'it’s',
#   'rough.',
#   'left',
#   'toxic',
#   'friend',
#   'group',
#   'main',
#   'support,',
#   'lost',
#   'touch',
#   'nearly',
#   'irl',
#   'friends,',
#   'lost',
#   'job',
#   'got',
#   'diagnosed',
#   'depression'],
#  89: ['di',
#   'ko',
#   'alam',
#   'kung',
#   'maggoodbye',
#   'speech',
#   'sa',
#   'kasi',
#   'got',
#   'fired',
#   'job',
#   'got',
#   'diagnosed',
#   'w',
#   'depression',
#   'anxiety',
#   "i'm",
#   'still',
#   'here,',
#   'pagod',
#   'pero',
#   'lumalaban.',
#   'sa',
#   'paparating',
#   'na',
#   '...',
#   'lumalaban',
#   'pa',
#   'din',
#   'pero',
#   'perferrably',
#   'less',
#   'pagod',
#   'w',
#   'money.',
#   'ayun',
#   'lamang.',
#   'sana',
#   'masaya',
#   'kayo',
#   'lagi.'],
#  90: ['would',
#   'find',
#   'hard',
#   'get',
#   'mornings.',
#   'restless',
#   '&amp;',
#   'no',
#   'motivation',
#   '&amp;',
#   'couldn’t',
#   'bring',
#   'go',
#   'gym.',
#   'would',
#   'extremely',
#   'tearful',
#   'would',
#   'avoid',
#   'long',
#   'could',
#   'not',
#   'go',
#   'shops.',
#   'went',
#   'doctors',
#   'got',
#   'diagnosed',
#   'depression',
#   '&amp;',
#   'anxiety.'],
#  91: ['gave',
#   'two',
#   'things',
#   ':',
#   'weight',
#   'gain',
#   'diagnosed',
#   'anxiety',
#   ',',
#   'depression'],
#  92: ['bye',
#   'diagnosed',
#   'mild',
#   'depression',
#   'earlier',
#   'year',
#   'frequents',
#   'anxiety',
#   'attacks',
#   '(introvert',
#   'prob',
#   '+',
#   'grad',
#   'thesis)',
#   'offgun',
#   'cured',
#   '(literally).',
#   'bfore',
#   'year',
#   'end,',
#   'would',
#   'like',
#   'thanks',
#   'two',
#   'people',
#   'made',
#   'year',
#   'breather.',
#   'luv',
#   'two',
#   'much!'],
#  93: ['mean…',
#   'speaking',
#   'someone',
#   'twenty',
#   'years',
#   'experience',
#   'diagnosed',
#   'depression',
#   'patient',
#   'youngest',
#   'five',
#   'children…',
#   '¿porqués',
#   'no',
#   'los',
#   'dos?'],
#  94: ['february',
#   'colleagues',
#   'published',
#   'findings',
#   'audit',
#   'management',
#   'newly',
#   'diagnosed',
#   'depression',
#   'large',
#   'multi-site',
#   'practice.',
#   'found',
#   'psychological',
#   'therapies',
#   'featuring',
#   'less',
#   'management',
#   'discussions',
#   'older',
#   'adults.',
#   '(2/12)'],
#  95: ['hi,',
#   'diagnosed',
#   'depression',
#   'bipolar',
#   'disorder',
#   'here-',
#   'don’t',
#   'use',
#   'mental',
#   'illnesses',
#   'excuse',
#   'pedal',
#   'shitty',
#   'agenda.',
#   'thanks.'],
#  96: ['cheer',
#   'keep',
#   'going',
#   'like',
#   'three',
#   'diagnosed',
#   'mental',
#   'disorders',
#   'depression',
#   'go',
#   'sometimes',
#   'long',
#   'time',
#   'not',
#   'good',
#   'always',
#   'pull',
#   'know',
#   'to.',
#   '💖'],
#  97: ['know',
#   'depression',
#   'diagnosed',
#   'incorrectly',
#   'anxiety,',
#   'around',
#   'percent',
#   'time?',
#   "don't",
#   'ignore',
#   'signs..'],
#  98: ['i’ve', 'diagnosed', 'depression.'],
#  99: ['average',
#   'american',
#   'right',
#   'winger',
#   'set',
#   'beliefs',
#   'delusional,',
#   'lacking',
#   'evidence,',
#   'divorced',
#   'reality',
#   'anything',
#   'average',
#   'person',
#   'diagnosed',
#   'depression',
#   'bipolar',
#   'ever',
#   'believed,',
#   'thought,',
#   'acted',
#   'upon,',
#   'latter',
#   'considered',
#   'unwell'],
#  100: ['oki',
#   'tysm',
#   'time',
#   'educating',
#   'me!',
#   'also',
#   'sorry',
#   'trouble',
#   'caused',
#   'd:',
#   ',',
#   'also',
#   'struggled',
#   'weight',
#   'eating',
#   'maybe',
#   'bit',
#   'self',
#   'diagnosed',
#   'depression',
#   'ion',
#   'think',
#   'eating',
#   'disorder',
#   'actual',
#   'depression?',
#   'ion',
#   'think',
#   'bothering',
#   'you-'],
#  101: ['depression', 'self', 'diagnosed', 'forgot', 'mention'],
#  102: ['song',
#   'came',
#   'next',
#   '(i',
#   'often',
#   'let',
#   'songs',
#   "'choose",
#   "themselves').",
#   'recognised',
#   'it.',
#   'looked',
#   'release',
#   'year.',
#   'year',
#   'got',
#   'married.',
#   'year',
#   'first',
#   'diagnosed',
#   'depression.',
#   'felt',
#   'bit',
#   'emotional',
#   'read',
#   'lyrics',
#   'listening',
#   'it.'],
#  103: ['speak',
#   'osime',
#   'osime',
#   'brown',
#   'yrs',
#   'old,',
#   'profoundly',
#   'autistic',
#   'developmentally',
#   'younger',
#   'peers.',
#   'osime',
#   'also',
#   'learning',
#   'disabled,',
#   'dyslexic',
#   'due',
#   'time',
#   'care',
#   'since',
#   'diagnosed',
#   'ptsd,',
#   'suffers',
#   'depression.'],
#  104: ['hi',
#   'eric,',
#   'diagnosed',
#   'autistic',
#   'early',
#   '&amp;',
#   'waiting',
#   'list',
#   'adhd',
#   'assessment',
#   'since',
#   'late',
#   '.',
#   'autism',
#   'diagnosis',
#   'came',
#   'psychotherapy',
#   'depression',
#   'failed',
#   '&amp;',
#   'adhd',
#   'referral',
#   'nhs',
#   'agreed',
#   'biochemically',
#   'resistant',
#   'anti-depressants.',
#   '/2'],
#  105: ['roughest',
#   'year',
#   'me.',
#   'giving',
#   'birth',
#   'pandemic.',
#   'no',
#   'help',
#   'confinement.',
#   'wfh',
#   'hbl',
#   'two',
#   'children.',
#   'diagnosed',
#   'postnatal',
#   'depression.',
#   'lost',
#   'favourite',
#   'family',
#   'members..'],
#  106: ['then,',
#   'tuloy',
#   'ang',
#   'pag',
#   'hinto',
#   'ng',
#   'ikot',
#   'ng',
#   'buhay',
#   'ko,',
#   'ive',
#   'diagnosed',
#   'depression',
#   'no',
#   'one',
#   'knows.',
#   'continue',
#   'church',
#   'leader,',
#   'blessing,',
#   'mentor',
#   'everyone',
#   'slowly',
#   'killing',
#   'me.',
#   'kailangan',
#   'ko',
#   'ang',
#   'sarili',
#   'ko',
#   'pero',
#   'walang',
#   'nakakaalam.'],
#  107: ['year:',
#   'get',
#   'diagnosed',
#   'depression,',
#   'anxiety,',
#   '**minor**',
#   'ocd.',
#   'parents',
#   'still',
#   'refuse',
#   'believe',
#   'actually',
#   'those.',
#   'don’t',
#   'many',
#   'people',
#   'irl',
#   'life',
#   'talk',
#   'to.',
#   'no',
#   'one',
#   'wants',
#   'listen.'],
#  108: ["i'm",
#   'similarly',
#   'nd.',
#   'severe',
#   'mdd',
#   'since',
#   'child,',
#   'adhd',
#   'inattentive',
#   'type,',
#   'seldom',
#   'diagnosed',
#   'kid,',
#   "didn't",
#   'know',
#   '.',
#   'seasonal',
#   'affective',
#   'd/o',
#   'top',
#   'depression.',
#   'panic',
#   'd/o,',
#   'generalized',
#   'anxiety.',
#   'fucking',
#   'lot.'],
#  109: ['see,',
#   'always',
#   'liked',
#   'pain,',
#   'weird',
#   'thing',
#   'young',
#   'got',
#   'diagnosed',
#   'depression',
#   'rd',
#   'grade',
#   'teacher',
#   'literally',
#   'physically',
#   'abused',
#   'infront',
#   'class',
#   'th',
#   'grade',
#   'one',
#   'teachers',
#   'told',
#   'im',
#   'old',
#   'crying'],
#  110: ['bitch....at', 'least', 'depression', 'diagnosed💀'],
#  111: ['started',
#   'stanning',
#   'bieber',
#   'barely',
#   'listened',
#   'english',
#   'songs..',
#   "i'd",
#   'sneak',
#   "brother's",
#   'computer',
#   'listen',
#   'songs.',
#   'say',
#   'jb',
#   'saved',
#   'life',
#   'worst.',
#   'diagnosed',
#   'clinical',
#   'depression',
#   'songs',
#   'thing',
#   'make',
#   'smile'],
#  112: ['thinking',
#   'getting',
#   'one',
#   'weighted',
#   'blankets',
#   'self',
#   'diagnosed',
#   'problems',
#   '(depression,',
#   'adhd,',
#   'etc)',
#   'it’s',
#   'also',
#   'wintertime',
#   'threw',
#   'extra',
#   'quilts',
#   'bed',
#   'pretty',
#   'much',
#   'thing',
#   'doesn’t',
#   'cost',
#   '$200',
#   '🤷🏻\u200d♂️'],
#  113: ['-',
#   'put',
#   'shampoo/conditioner',
#   'cup.',
#   'obviously',
#   'not',
#   'look',
#   'long',
#   'hair',
#   'is.',
#   '-',
#   'considered',
#   'picking',
#   'scabs',
#   'self',
#   'harm.',
#   '-',
#   'doctor',
#   'expected',
#   'surprised',
#   'shocked',
#   'diagnosed',
#   'anxiety/depression.',
#   'not.'],
#  114: ['no',
#   'best',
#   'friend',
#   'orbit',
#   '💫',
#   'no',
#   'partner',
#   'orbit',
#   '💫',
#   'suicidal,',
#   'chronic',
#   'depression,',
#   'diagnosed',
#   'ptsd,',
#   'toxic',
#   'job,',
#   'abusive',
#   'family',
#   '🪐',
#   'pretty',
#   'sure',
#   "i'm",
#   'going',
#   'combust',
#   'wreck',
#   'end',
#   '🌌'],
#  115: ['.',
#   'dark',
#   'secret,',
#   'followers',
#   'might',
#   'know,',
#   'might',
#   'battling',
#   'depression,',
#   'bpd',
#   'severe',
#   'anxiety',
#   'idk.',
#   'far',
#   'im',
#   'self',
#   'diagnosed',
#   'feel',
#   'time.',
#   'that’s',
#   'reason',
#   'read',
#   'many',
#   'self',
#   'help',
#   'book.',
#   'manage',
#   'beat',
#   'early',
#   'year'],
#  116: ['mom',
#   'took',
#   'away',
#   'ps4',
#   'punched',
#   'hole',
#   'bedroom',
#   'wall',
#   "i'm",
#   'not',
#   'aggressive',
#   'ooze',
#   'masculine',
#   'passion',
#   'know',
#   "i've",
#   'also',
#   'got',
#   'depression?',
#   "i'm",
#   'self-diagnosed,',
#   'thought',
#   'mention',
#   'thought',
#   'could',
#   'one',
#   'fix'],
#  117: ["...don't",
#   'feel',
#   'comfortable',
#   'making',
#   'system',
#   'polyamorous',
#   'anything.',
#   '•',
#   'current',
#   'hyperfixation',
#   'genshin',
#   'impact!',
#   '•',
#   "we've",
#   'diagnosed',
#   'bpd,',
#   'osdd-1a,',
#   'major',
#   'depressive',
#   'disorder,',
#   'general',
#   'anxiety,',
#   'social',
#   'anxiety,',
#   'general',
#   'depression,',
#   'ocd,',
#   'adhd,',
#   '&amp;',
#   'autism.'],
#  118: ['#2020_theboyz',
#   'hardest',
#   'year',
#   'life.',
#   'diagnosed',
#   'depression',
#   'anxiety,',
#   'living',
#   'fear',
#   'sadness.',
#   'found',
#   'guys,',
#   'precious',
#   'memory',
#   'life.',
#   'again,',
#   'found',
#   'little',
#   'happiness',
#   'life.'],
#  119: ['post',
#   'binge',
#   'depression',
#   'real',
#   'feel',
#   'u',
#   'lmao',
#   "didn't",
#   'know',
#   'u',
#   'adhd',
#   'tho!',
#   'diagnosed',
#   'early?'],
#  120: ['"depression',
#   'anxiety',
#   'severe',
#   'adhd"',
#   'stuff',
#   'like',
#   'bio',
#   "i'm",
#   'immediately',
#   'assuming',
#   'faking',
#   'it,',
#   "don't",
#   'go',
#   'openly',
#   'saying',
#   'depression',
#   'anxiety,',
#   'say',
#   'severe',
#   'adhd',
#   'probably',
#   'self',
#   'diagnosed.'],
#  121: ['well',
#   'year',
#   'old',
#   'diagnosed',
#   'depression',
#   'lock',
#   'down,',
#   'first',
#   'session',
#   'therapist',
#   'today,',
#   "he's",
#   '!!',
#   "that's",
#   'worst,',
#   'glad',
#   "he's",
#   'breathing',
#   'need',
#   'watch',
#   'keep',
#   'breathing'],
#  122: ['way',
#   'get',
#   'diagnosed',
#   'depression',
#   'so......literally',
#   'filling',
#   'questionnaire',
#   '😭'],
#  123: ['it’s',
#   'exaggerating',
#   'dub',
#   'someone',
#   'suffers',
#   'depression/anxiety',
#   'never',
#   'diagnosed,',
#   'difficulty',
#   'focusing',
#   'late.',
#   'hell',
#   'even',
#   'stutter',
#   'lose',
#   'thoughts',
#   'talking,',
#   'fuck',
#   'im',
#   'mess',
#   '😭'],
#  124: ['daughter',
#   'got',
#   'diagnosed',
#   'anorexia,',
#   'top',
#   'depression',
#   'anxiety.',
#   'self-harmed',
#   'suicidal',
#   'hospitalized.',
#   '#fuck2020'],
#  125: ['someone',
#   'depression',
#   'mental',
#   'issues',
#   '(as',
#   'diagnosed',
#   'doctor,',
#   'not',
#   'myself)',
#   'none',
#   'excuse',
#   'endanger',
#   'someone',
#   'else.',
#   'people',
#   'feel',
#   'way',
#   'harming',
#   'around',
#   'them,',
#   'inexcusable',
#   'worthy',
#   'ridicule.',
#   'frankly',
#   'beating.'],
#  126: ['oh',
#   'yeah,',
#   'cleared',
#   'exams.',
#   'didn’t',
#   'go',
#   'ssb',
#   'got',
#   'diagnosed',
#   'depression.'],
#  127: ['really',
#   'sorry',
#   'loss',
#   'mom.',
#   'know',
#   'like',
#   'diagnosed',
#   'depression,',
#   'getting',
#   'old,',
#   'keep',
#   'head',
#   'remain',
#   'motivated.'],
#  128: ['fun',
#   'story',
#   'diagnosed',
#   'depression',
#   'anxiety',
#   'neurologist',
#   'prescribed',
#   'adderall',
#   'didn’t',
#   'need',
#   'brain',
#   'like',
#   '❌😤😫🤬😱🥶🤮',
#   'major',
#   'mood',
#   'swings'],
#  129: ['yeee',
#   'got',
#   'diagnosed',
#   'major',
#   'depression,',
#   'anxiety',
#   'sophomore',
#   'year,',
#   'year',
#   'added',
#   'ptsd',
#   'seasonal',
#   'depression',
#   'list',
#   'ya',
#   'girl',
#   'gets',
#   'double',
#   'dunked',
#   'depressed',
#   'winter.'],
#  130: ['besides',
#   'bag',
#   'year',
#   'pretty',
#   'much,',
#   'lady',
#   'tiktok',
#   'diagnosed',
#   'depression',
#   '💀💀💀'],
#  131: ['y’all', 'diagnosed', 'depression?'],
#  132: ['.',
#   "i'm",
#   'diagnosed',
#   'amd',
#   'living',
#   'severe',
#   'depression',
#   'years',
#   'along',
#   'mental',
#   'illness',
#   'yeah.'],
#  133: ['think',
#   "that's",
#   'same.',
#   'personally,',
#   "don't",
#   'know',
#   'fibro,',
#   'depression,',
#   'probable',
#   'never',
#   'diagnosed',
#   'adhd',
#   'even',
#   'possibly',
#   'autism.',
#   'many',
#   'symptoms',
#   'overlap,',
#   "can't",
#   'say',
#   'sure.',
#   'yep,',
#   'sounds',
#   'like',
#   'brain',
#   'fog',
#   'me.',
#   'sorry,',
#   'friend.'],
#  134: ['everyone',
#   'one',
#   'diagnosed',
#   'depression',
#   'celebrity',
#   'crush',
#   'super',
#   'irl',
#   'could',
#   'take',
#   'leave'],
#  135: ['depression',
#   'hard',
#   '.',
#   'diagnosed',
#   'depression',
#   'anxiety',
#   'hard',
#   '.',
#   'things',
#   'people',
#   'find',
#   'easy',
#   ',',
#   'think',
#   'million',
#   'times',
#   'give',
#   'overthought',
#   '.',
#   'not',
#   'enjoy',
#   'taking',
#   'meds',
#   'stay',
#   '“happy”',
#   '.'],
#  136: ['read',
#   'nearly',
#   'half',
#   'people',
#   'depression',
#   'go',
#   'get',
#   'diagnosed',
#   'bipolar',
#   'coming',
#   'years',
#   "i'm",
#   'not',
#   'willing',
#   'come',
#   'terms',
#   'possibility',
#   "i'm",
#   'going',
#   'lie',
#   'hormonal',
#   'mood',
#   'swings',
#   'even',
#   'tho',
#   "i'm",
#   'past',
#   'age',
#   'lol'],
#  137: ['.',
#   'half',
#   'team',
#   'left',
#   'unprofessionally',
#   '.',
#   'acquired',
#   'digital',
#   'skills',
#   '.',
#   'family',
#   'crisis',
#   '.',
#   'diagnosed',
#   'w',
#   'severe',
#   'anxiety,',
#   'mild',
#   'depression,',
#   'put',
#   'suicidal',
#   'watch',
#   '.',
#   'started',
#   'ldr',
#   '.',
#   'started',
#   'masters',
#   'sustainability',
#   'science',
#   '.',
#   'lost',
#   'nenek',
#   '.',
#   'tied',
#   'contract',
#   'w',
#   'asean',
#   'foundation'],
#  138: ['suffering',
#   'bullying',
#   'school,',
#   'anxiety',
#   'depression.',
#   'years',
#   'later',
#   'told',
#   'counsellor',
#   'always',
#   'brought',
#   'everything',
#   'back',
#   'relationship',
#   'me,',
#   'perhaps',
#   'stifling',
#   'maturity.',
#   'years',
#   'later',
#   'diagnosed',
#   'pcos.',
#   '/3'],
#  139: ['%', 'extra', 'diagnosed', 'depression', '😉'],
#  140: ['unless',
#   'diagnosed',
#   'permanent',
#   'damage',
#   'brain',
#   'causes',
#   'depression',
#   'say',
#   'need',
#   'actually',
#   'take',
#   'look',
#   'life',
#   'shaming',
#   'people',
#   'tell',
#   'what’s',
#   'wrong'],
#  141: ['adhd',
#   'not',
#   'hyper.',
#   'actually,',
#   'hyper',
#   'people',
#   'diagnosed',
#   'type',
#   'adhd.',
#   'difficulty',
#   'dressing',
#   'feeding',
#   'would',
#   'combination',
#   'type',
#   'adhd',
#   'depression',
#   'likely.'],
#  142: ['autism,',
#   'depression,',
#   'ptsd',
#   'official',
#   'diagnoses,',
#   'anxiety',
#   'ocd',
#   'self-diagnosed',
#   'feel',
#   'like',
#   'plurality',
#   'self-evident'],
#  143: ['mom',
#   'slapped',
#   'told',
#   'depressed',
#   'aakd',
#   'kicked',
#   'out.',
#   '(thisnwas',
#   'go',
#   'diagnosed',
#   'severe',
#   'clinical',
#   'depression',
#   'ptsd',
#   'anxiety',
#   'disorder'],
#  144: ['fall',
#   'th',
#   'grade?',
#   'smart,',
#   'can’t',
#   'read?',
#   'either',
#   'absolutely',
#   'nothing',
#   'impulsively',
#   'everything',
#   'no',
#   'between?',
#   'diagnosed',
#   'w',
#   'depression/anxiety',
#   'ssris',
#   'don’t',
#   'help?',
#   'news',
#   '👇🏻👇🏻👇🏻👇🏻'],
#  145: ['so,',
#   'three',
#   'therapy',
#   'sessions',
#   'i’ve',
#   'diagnosed',
#   'neurodivergent,',
#   'clinical',
#   'depression...',
#   'like,',
#   'i’m',
#   'not',
#   'surprised,',
#   'it’s',
#   'not',
#   'exactly',
#   'good',
#   'news.',
#   'upside,',
#   'approved',
#   'medical',
#   'marijuana,',
#   'so,',
#   'i’m',
#   'looking',
#   'forward',
#   'that.'],
#  146: ['diagnosed', 'anxiety', '&amp;depression', 'cool'],
#  147: ['also',
#   'heard',
#   'people',
#   'diagnosed',
#   'depression',
#   'new',
#   'mental',
#   'health',
#   'illnesses',
#   'thanks',
#   'pandemic',
#   '🥺'],
#  148: ['also',
#   'diagnosed',
#   'pcos',
#   'hyperprolactinemia.',
#   'went',
#   'severe',
#   'depression',
#   'corticosteroids',
#   'using',
#   'greatly',
#   'contributed',
#   'to.(i',
#   'stopped',
#   'anyways).',
#   'still',
#   "don't",
#   'definitive',
#   'diagnosis',
#   'constant',
#   'pain.'],
#  149: ['guess',
#   'got',
#   'diagnosed',
#   'w',
#   'major',
#   'depression,',
#   'anxiety,',
#   'ocd',
#   '🥵🥵🥵'],
#  150: ['day',
#   'adderall....(diagnosed',
#   'adhd+anxiety,',
#   'depression,',
#   'ocd',
#   'tendencies',
#   'caused',
#   'adhd)',
#   'took',
#   'am,',
#   'no',
#   'anxiety,',
#   'productive',
#   ',',
#   'energy',
#   'level',
#   'good',
#   'day,',
#   'got',
#   'tired',
#   'around',
#   'nap',
#   'hour.'],
#  151: ["i've",
#   'recovered,',
#   'failed,',
#   'recovered...',
#   'attempted',
#   'suicide',
#   'first',
#   'time',
#   '.',
#   "i'm",
#   'suicide',
#   'survivor',
#   'will.',
#   "that's",
#   'started',
#   'going',
#   'therapy',
#   'diagnosed',
#   'bpd',
#   'severe',
#   'depression.'],
#  152: ["let's",
#   'talk',
#   'me,',
#   'not.',
#   "i'm",
#   'years',
#   'old.',
#   "i've",
#   'account',
#   'years',
#   '(aka',
#   'started',
#   ').',
#   'eds',
#   'on-and-off',
#   'struggle',
#   'years.',
#   'also',
#   'diagnosed',
#   'borderline',
#   '(bpd)',
#   '+',
#   'severe',
#   'depression',
#   '.'],
#  153: ['y’all',
#   'self-diagnosed',
#   'point',
#   'people',
#   'really',
#   'stopped',
#   'taking',
#   'mental',
#   'illness',
#   'serious,',
#   '“every',
#   'female',
#   'says',
#   'depression”',
#   '“every',
#   '___',
#   'says',
#   'anxiety',
#   'problems.”',
#   'please',
#   'learn',
#   'difference',
#   'nervous,',
#   'sad',
#   'actually',
#   'depressed/anxiety'],
#  154: ['th',
#   'birthday',
#   'year,',
#   'graduated',
#   'high',
#   'school',
#   'year,',
#   'diagnosed',
#   'depression',
#   'anxiety',
#   'year',
#   'guess',
#   'what?',
#   'wore',
#   'mask'],
#  155: ['thanks,',
#   'man.',
#   'sister',
#   'diagnosed',
#   'depression',
#   'today',
#   'i’ve',
#   'ongoing',
#   'battle',
#   'get',
#   'diagnosed',
#   'years',
#   'now,',
#   'point',
#   'feel',
#   'like',
#   'i’m',
#   'burden',
#   'psyche',
#   'alive',
#   'even',
#   'commit',
#   'not-breathing',
#   'feel',
#   'utterly',
#   'defeated.'],
#  156: ['know',
#   'ive',
#   'got',
#   'depression?',
#   'self-diagnosed,thought',
#   'mention'],
#  157: ['dont',
#   'success',
#   'story',
#   "i'm",
#   'boat.',
#   "i'm",
#   'autistic',
#   'diagnosed',
#   'bipolar',
#   'depression,',
#   'know',
#   'hard',
#   'things',
#   'know',
#   'definitely',
#   'not',
#   'alone.',
#   'dentist',
#   'since',
#   'elementary',
#   'school',
#   'embarrassing,',
#   'people+'],
#  158: ['dont',
#   'really',
#   'like',
#   'revealing',
#   'depression',
#   'guess',
#   'already',
#   'threw',
#   '🤡',
#   'again,',
#   'not',
#   'self-diagnose!',
#   'best',
#   'way',
#   'diagnosed',
#   'get',
#   'appropriate',
#   'diagnosis',
#   'meds',
#   'ever.'],
#  159: ['dont',
#   'worry',
#   'im',
#   'diagnosed',
#   'depression',
#   'anxiety,',
#   'psychiatrist',
#   'enough',
#   '👌'],
#  160: ['tw',
#   '/',
#   'suicide',
#   'depression',
#   'know,',
#   'never',
#   'said',
#   'incredibly',
#   'proud',
#   'making',
#   'year..',
#   'suicidal',
#   'one',
#   'point,',
#   'got',
#   'diagnosed',
#   'depression',
#   'year,',
#   'got',
#   'covid,',
#   'became',
#   'distant',
#   'family,',
#   'i’m',
#   'still',
#   'here..',
#   '/pos'],
#  161: ['!!!',
#   'i’ve',
#   'researching',
#   'adhd',
#   'everything',
#   'sticks',
#   'me.',
#   'i’ve',
#   'diagnosed',
#   'w',
#   'depression',
#   'anxiety',
#   'since',
#   'think',
#   'doctors',
#   'wrong'],
#  162: ["i'm",
#   'huge',
#   'proponent',
#   'affirmations',
#   "'shifting",
#   "mindset,'",
#   "don't",
#   'underestimate',
#   'power',
#   'getting',
#   'professional',
#   'help',
#   '(therapy,',
#   'medication),',
#   'especially',
#   'diagnosed',
#   'depression,',
#   'anxiety,',
#   'etc.'],
#  163: ['i’m',
#   'extremely',
#   'grateful',
#   'haven’t',
#   'experienced',
#   'feeling',
#   'type',
#   'ppd.',
#   'especially',
#   'diagnosed',
#   'depression',
#   'anxiety',
#   'years.',
#   'feel',
#   'like',
#   'baby',
#   'helped',
#   'soooo',
#   'much',
#   'i’m',
#   'thankful',
#   'her,',
#   'she’s',
#   'angel!',
#   '🤍'],
#  164: ['u',
#   'tellin',
#   'crackhead',
#   'energy',
#   'looked',
#   'like',
#   'u',
#   'got',
#   'diagnosed',
#   'depression,',
#   'fine',
#   'carrot',
#   'days',
#   'not',
#   'any?',
#   'selfish',
#   'kids'],
#  165: ['right?',
#   'thing',
#   'women',
#   'diagnosed',
#   'anxiety',
#   'depression',
#   'actually',
#   'something',
#   'else',
#   'wrong',
#   'entire',
#   'time.',
#   'blame',
#   'mental',
#   'state',
#   "don't",
#   'actual',
#   'work',
#   'even',
#   'pretend',
#   'care.'],
#  166: ['good',
#   'things',
#   'happen',
#   'me,',
#   'give',
#   'credit',
#   'others.',
#   'one',
#   'right',
#   '-',
#   'time',
#   'walked',
#   'therapy',
#   '&amp;',
#   'got',
#   'diagnosed',
#   'depression,',
#   'anxiety',
#   '&amp;',
#   'ptsd',
#   'psychiatrist',
#   '-',
#   'odds.',
#   'best',
#   'thing',
#   "i've",
#   'ever',
#   'done.'],
#  167: ['struck',
#   'forced',
#   'back',
#   'isolation',
#   'due',
#   'self',
#   'diagnosed',
#   'depression,',
#   'could',
#   'not',
#   'afford',
#   'go',
#   'hospital',
#   '"mental',
#   'issues"',
#   'not',
#   'accepted',
#   'real',
#   'issue',
#   'late',
#   'family',
#   'lack',
#   'funds.',
#   '(3/?)'],
#  168: ['last',
#   '.',
#   'fm',
#   'foot',
#   'ox',
#   'diagnosed',
#   'bipolar',
#   'depression',
#   'think',
#   'thats',
#   'hilarious'],
#  169: ['don’t',
#   'know',
#   'much',
#   'honest',
#   'you.',
#   'research',
#   'focuses',
#   'depression,',
#   'autism,',
#   'adhd',
#   'dyslexia.',
#   'well',
#   'known',
#   'diagnosed',
#   'vastly',
#   'different',
#   'rates',
#   'males',
#   'females',
#   ':)'],
#  170: ["i'm",
#   'self',
#   'diagnosed',
#   'depression,and',
#   'possibly',
#   'stuff',
#   "i'm",
#   'really',
#   'comfortable',
#   'saying',
#   'depression',
#   'done',
#   'much',
#   'research',
#   'stuff'],
#  171: ['seen',
#   'black',
#   'women',
#   'power',
#   'workplace........',
#   'generally',
#   'not',
#   'pretty',
#   'sight,',
#   'send',
#   'hospital',
#   'diagnosed',
#   'depression.'],
#  172: ['thank',
#   'much',
#   'talking',
#   'this!',
#   'cancer',
#   'went',
#   'lots',
#   'failing',
#   'meds',
#   'seizures,',
#   'not',
#   'eating',
#   'weeks,',
#   'etc.',
#   'diagnosed',
#   'ptsd',
#   'expresses',
#   'anxiety',
#   'depression.',
#   'that’s',
#   'different',
#   'someone',
#   'rough',
#   'weeks😓'],
#  173: ['today',
#   'doctor',
#   'humiliated',
#   'me,',
#   'psychologist',
#   'diagnosed',
#   'depression',
#   '...👇'],
#  174: ['y’all',
#   'real',
#   'talk..you',
#   'truly',
#   'never',
#   'know',
#   'happening',
#   'persons',
#   'life.',
#   'suffering',
#   'years',
#   'emotional,',
#   'physical,',
#   'verbal,',
#   'psychological',
#   'abuse.',
#   'diagnosed',
#   'possible',
#   'depression,',
#   'bpd,',
#   'bipolar',
#   'disorder',
#   'one,',
#   'adhd.'],
#  175: ['many',
#   'years',
#   'ive',
#   'suffering',
#   'depression',
#   'ptsd',
#   'recently',
#   'diagnosed',
#   'begun',
#   'treatment',
#   'changes',
#   'need',
#   'come',
#   'keep',
#   'methods',
#   'healing.',
#   'real',
#   'challenge',
#   'surrounded',
#   'negative',
#   'things',
#   'especially',
#   '.'],
#  176: ['diagnosed',
#   'anxiety',
#   'suspected',
#   'depression',
#   'i’m',
#   'really',
#   'impulsive',
#   'fear',
#   'abandonment',
#   'lot',
#   'always',
#   'questioned',
#   'bipolar',
#   'borderline.',
#   'anything',
#   'look',
#   'myself?'],
#  177: ['tw',
#   'meds',
#   '&amp;',
#   'diagnosed',
#   '//',
#   'doctor',
#   'appointment',
#   'today.',
#   'got',
#   'new',
#   'meds',
#   '&amp;',
#   'told',
#   'bipolar',
#   'depression',
#   'officially'],
#  178: ['struggled',
#   'years.',
#   'diagnosed',
#   "crohn's",
#   'getting',
#   'proper',
#   'treatment',
#   'fell',
#   'place.',
#   'definitely',
#   'coralation',
#   'gut',
#   'depression.'],
#  179: ['useful',
#   'life',
#   'shit,',
#   'whether',
#   'diagnosed',
#   'adhd,',
#   'depression,',
#   'no',
#   'mental',
#   'illness',
#   'all.',
#   'neuro-typical',
#   'lives',
#   'could',
#   'benefit',
#   'too,',
#   'considering',
#   'even',
#   '(we?',
#   'maybe?)',
#   'dealing',
#   'w/forced',
#   'isolation',
#   '&amp;',
#   'specter',
#   'constant',
#   'death',
#   'around',
#   'entire',
#   'country'],
#  180: ['(procrastinating',
#   'twitter',
#   '...',
#   'reading',
#   'book',
#   '...',
#   'finally',
#   'managing',
#   'cook',
#   'meal),',
#   'dread',
#   'real',
#   'life',
#   'side',
#   'fun',
#   'thing',
#   'would',
#   'ruin',
#   'it.',
#   'yes,',
#   'diagnosed',
#   'depression',
#   'anxiety,',
#   'too.',
#   "i'm",
#   'also,',
#   'like',
#   'many',
#   'people',
#   '*intensely',
#   'burnt',
#   'out*.'],
#  181: ['answer',
#   'stupid',
#   'questions.yes',
#   'people',
#   'know,',
#   'diagnosed',
#   'months',
#   'ago,',
#   'severe',
#   'fatigue',
#   'still,',
#   'depression,',
#   'one',
#   'getting',
#   'physio',
#   'no',
#   'feeling',
#   'hand,',
#   'another',
#   'no',
#   'smell',
#   'taste',
#   'still.',
#   'like',
#   'dont',
#   'know',
#   'covid',
#   'people',
#   'ask',
#   'questions.',
#   '.'],
#  182: ['exactly.',
#   'us',
#   'population',
#   'whole',
#   'pace',
#   'less',
#   'total',
#   'deaths',
#   '.',
#   'yet',
#   'future',
#   'deaths',
#   'poverty,',
#   'suicide,',
#   'domestic',
#   'abuse,',
#   'opioids,',
#   'depression/mental',
#   'health',
#   'major',
#   'medical',
#   'issues',
#   'like',
#   'cancer',
#   'diagnosed',
#   'late',
#   'exploding.'],
#  183: ['got',
#   'new',
#   'therapist',
#   '(not',
#   'physical)',
#   'like',
#   'two',
#   'months',
#   'ago,',
#   'completely',
#   'changed',
#   'life.',
#   'instead',
#   'listening',
#   'vent,',
#   'gives',
#   'tools',
#   'use',
#   'situations',
#   'calm',
#   'anxiety,',
#   'depression,',
#   'diagnosed',
#   'ptsd.',
#   'put.',
#   'in.',
#   'the.',
#   'work.',
#   'worth',
#   'it.',
#   '❤'],
#  184: ['kid',
#   '-',
#   'pre-existing',
#   'depression,',
#   'learning',
#   'disability,',
#   'recently',
#   'diagnosed',
#   'asd',
#   '-',
#   'had,',
#   'far',
#   'tell,',
#   'absolutely',
#   'no',
#   'help',
#   'support...',
#   'covid',
#   'time.',
#   'absolutely',
#   'disgraceful.',
#   'unis',
#   'thoroughly',
#   'ashamed.'],
#  185: ['diagnosed',
#   'anxiety',
#   'depression',
#   'graduating',
#   'college',
#   'treated',
#   'five',
#   'years',
#   'without',
#   'ever',
#   'really',
#   'getting',
#   'anywhere.',
#   'finally',
#   'research',
#   '&amp;',
#   'made',
#   'list',
#   'things',
#   'experience',
#   'could',
#   'either',
#   'anxiety',
#   '&amp;depression',
#   'adhd.'],
#  186: ['diagnosed',
#   'adhd',
#   '(inattentive)',
#   '.',
#   'shamed',
#   'getting',
#   'meds',
#   'pcp',
#   'time,',
#   'finally',
#   'got',
#   'medication',
#   '.',
#   'life',
#   'changing.',
#   'also',
#   'diagnosed',
#   'depression,',
#   'cptsd,',
#   'anxiety.'],
#  187: ['diagnosed',
#   'suffering',
#   'menopausal',
#   'symptoms',
#   'suffered',
#   'anxiety',
#   'depression',
#   'young',
#   'age.',
#   'high',
#   'iq',
#   'never',
#   'failed',
#   'exam',
#   "can't",
#   'time',
#   'appointment'],
#  188: ['well',
#   'running',
#   'going',
#   'walks',
#   'helps',
#   '(clinically',
#   'diagnosed)',
#   'depression.',
#   'someone',
#   'dependent',
#   'exercise',
#   'mental',
#   'health',
#   'they’ll',
#   'get',
#   'however',
#   'right',
#   'now.',
#   'also',
#   'exercise',
#   'home',
#   'outdoors',
#   'cold.'],
#  189: ['clinically',
#   'diagnosed',
#   'depression',
# ...
#  939: ['.',
#   'diagnosed',
#   'depression,',
#   'anxiety,',
#   'adhd,',
#   'ptsd,',
#   'borderline',
#   'personality',
#   'disorder'],
#  940: ['jump',
#   'dick,',
#   'struggle',
#   'depression',
#   'done',
#   'decade.',
#   'also',
#   'recently',
#   'diagnosed',
#   'autism.',
#   'anyone',
#   'trying',
#   'dismiss',
#   'neurotypical',
#   'fuck',
#   'right',
#   'off.'],
#  941: ['cw/tw:',
#   'suicidality',
#   '&amp;',
#   'suicidal',
#   'thoughts',
#   'never',
#   '~diagnosed~',
#   'depression,',
#   'long',
#   'history',
#   'flat',
#   'affect,',
#   'feeling',
#   'hopeless',
#   'catatonia.',
#   'remember',
#   'first',
#   'time',
#   'rationalized',
#   'death',
#   'years',
#   'old.'],
#  942: ['.',
#   'i’m',
#   'situation',
#   'i’m',
#   'pretty',
#   'extensive',
#   'mental',
#   'health',
#   'treatment',
#   'bipolar',
#   'ocd',
#   'mostly',
#   'stable',
#   'long',
#   'while.',
#   'husband',
#   'struggles',
#   'anxiety',
#   '(diagnosed)',
#   'depression',
#   '(undiagnosed)',
#   'receives',
#   'no',
#   'treatment',
#   '(he',
#   'treated',
#   'adhd).'],
#  943: ['$cliftongrooms',
#   'i’ve',
#   'diagnosed',
#   'depression',
#   'anxiety',
#   'i’ve',
#   'missed',
#   'much',
#   'work',
#   'year',
#   'lost',
#   'much',
#   'money.',
#   'anything',
#   'would',
#   'help',
#   'real.',
#   'thank',
#   'much.'],
#  944: ['⠀',
#   '⠀',
#   '⠀⠀⠀⠀-`',
#   '♡',
#   '´-',
#   '⠀⠀⠀⠀⠀⠀⠀basics',
#   '⠀⠀⠀⠀⠀⠀↬',
#   'eighteen',
#   '⠀⠀⠀⠀⠀⠀↬',
#   'canadian',
#   '⠀⠀⠀⠀⠀⠀↬',
#   'pro-recovery',
#   '⠀⠀⠀⠀⠀⠀⠀diagnosed:',
#   '⠀⠀⠀⠀⠀⠀↬',
#   'anorexia',
#   'nervosa',
#   '⠀⠀⠀⠀⠀⠀↬',
#   'depression'],
#  945: ['nobody',
#   'said',
#   'that....here....learn',
#   'something',
#   'depression....also',
#   'bipolar',
#   'disorder',
#   'too,',
#   'clinically',
#   'diagnosed',
#   'took',
#   'pills',
#   'family',
#   'knew',
#   'pills.'],
#  946: ['live',
#   'shitty',
#   'period',
#   'people',
#   'real',
#   'serious',
#   'mental',
#   'health',
#   'problems,',
#   'i’ve',
#   'seen',
#   'countless',
#   'people',
#   'completely',
#   'misuse',
#   'terms',
#   'related',
#   'mental',
#   'health',
#   'describing',
#   'put',
#   'people',
#   'actually',
#   'serious',
#   'problems.',
#   'self',
#   'diagnosed',
#   'depression,',
#   'bpd,',
#   'adhd'],
#  947: ['lmaooo',
#   'depression',
#   'rubbish',
#   '😂😂😂',
#   'diagnosed',
#   'you?',
#   'alright'],
#  948: ['like',
#   'feel',
#   'like',
#   'dying',
#   'came',
#   'completely',
#   'understand',
#   'kids',
#   'emo',
#   'phase',
#   'goin',
#   'thru...',
#   'self',
#   'diagnosed',
#   'depression',
#   'song',
#   'alone'],
#  949: ['pretty',
#   'sad',
#   'mom',
#   'got',
#   'email',
#   'mental',
#   'thingz',
#   'got',
#   'diagnosed',
#   'says',
#   '“nah',
#   'depression',
#   'lazy',
#   'anxiety?',
#   'person',
#   'easily',
#   'afraid',
#   'thingz”',
#   'tf',
#   'thank',
#   'guess'],
#  950: ['adhd',
#   'debilitating',
#   'impact',
#   'life',
#   'growing',
#   'up.',
#   'spread',
#   'depression',
#   'anxiety',
#   'disorder',
#   'recently',
#   'got',
#   'diagnosed',
#   'ptsd.',
#   'believe',
#   'rsd',
#   'experience',
#   'adhd',
#   'truly',
#   'mess',
#   'us',
#   'up.'],
#  951: ['hate',
#   'therapists',
#   'ignore',
#   'tell',
#   'i’ve',
#   'diagnosed',
#   'bipolar',
#   'depression.',
#   'like',
#   'met',
#   'me,',
#   'don’t',
#   'get',
#   'make',
#   'assumptions',
#   'me.'],
#  952: ['years',
#   'ago',
#   'insanely',
#   'depressed',
#   'constantly',
#   'hiding',
#   'parts',
#   'felt',
#   'embarassing',
#   'shameful.',
#   'now,',
#   "i've",
#   'gotten',
#   'help',
#   'depression,',
#   'finally',
#   'got',
#   'diagnosed',
#   'adhd,',
#   'embraced',
#   'every',
#   'side',
#   'myself,',
#   'including',
#   '"shameful"',
#   'things.',
#   'feels',
#   'good.'],
#  953: ['didn’t',
#   'believe',
#   'suffering',
#   'depression',
#   'would',
#   'smile',
#   'like',
#   '“i’m',
#   'good”',
#   'got',
#   'diagnosed',
#   'still',
#   'didn’t',
#   'believe',
#   'like',
#   'don’t',
#   'feel',
#   'depressed',
#   'feel',
#   'depressed',
#   'depressed.'],
#  954: ['else',
#   'lead',
#   'peoples',
#   'wrong',
#   'direction..',
#   'no',
#   'wonder',
#   'nowadays',
#   'someone',
#   'enduring',
#   'hard',
#   'life',
#   'thought',
#   'depression..',
#   'depression',
#   'can’t',
#   'diagnosed',
#   'stress,',
#   'it’s',
#   'worst',
#   'that..',
#   'gain',
#   'knowledge,',
#   'you’ll',
#   'know',
#   'it..'],
#  955: ['since',
#   'diagnosed',
#   'major',
#   'depression,',
#   'anxiety',
#   'panic',
#   'disorder',
#   'painting',
#   'major',
#   'stress',
#   'relief.',
#   'recently',
#   'diagnosed',
#   'sad',
#   'painting',
#   'become',
#   'even',
#   'bigger',
#   'outlet',
#   'me.'],
#  956: ['patient',
#   'diagnosed',
#   'bright',
#   'student',
#   'faculty',
#   'veterinary',
#   'medicine',
#   'mu',
#   'showed',
#   'symptoms',
#   'chronic',
#   'depression,',
#   'sever',
#   'anxiety',
#   'sad',
#   'heart',
#   'rate.'],
#  957: ['don’t',
#   'mean',
#   'clinically',
#   'diagnosed',
#   'major',
#   'depression',
#   'episode.',
#   'not',
#   'trying',
#   'pathologize.',
#   'wondering',
#   'there’s',
#   'term',
#   'feelings',
#   'sadness',
#   'happen',
#   'big',
#   'life',
#   'event,',
#   'whether',
#   'phenomenon',
#   'studied.'],
#  958: ['play',
#   'pjsekai',
#   'forget',
#   'fact',
#   'clinically',
#   'diagnosed',
#   'social',
#   'anxiety',
#   'depression',
#   'hug',
#   'miku',
#   'plush',
#   'think',
#   'fact',
#   'clinically',
#   'diagnosed',
#   'social',
#   'anxiety',
#   'depression'],
#  959: ['diagnosed',
#   'depression',
#   'anxiety',
#   '.',
#   'ruined',
#   'life.',
#   'wouldn’t',
#   'wish',
#   'anyone',
#   'like',
#   'bringing',
#   'except',
#   'overcome'],
#  960: ['keeping',
#   'top',
#   'secrets',
#   'lies',
#   'nearly',
#   'impossible',
#   'since',
#   "he's",
#   'diagnosed',
#   'manic',
#   'depression.',
#   '#tadema22',
#   'get',
#   '#rt',
#   '#iartg',
#   '#asmsg',
#   '#bookboost'],
#  961: ['slip',
#   'depression',
#   'found',
#   'pre',
#   'diabetic',
#   'months',
#   'blood',
#   'test',
#   'results',
#   '!',
#   "i'm",
#   'never',
#   'normally',
#   'ill',
#   'body',
#   'likes',
#   'deal',
#   'illness',
#   'once.',
#   'could',
#   'fill',
#   'sheet',
#   'paper',
#   "they've",
#   'found',
#   'diagnosed',
#   'mnths!'],
#  962: ['almost',
#   'over.',
#   'year:',
#   '-',
#   'dad',
#   'died',
#   '(gi',
#   'bleed)',
#   '-',
#   'uncle',
#   'died',
#   'days',
#   'later',
#   '(covid)',
#   '-',
#   '&gt;',
#   'k',
#   'died',
#   'covid',
#   '-',
#   '٪',
#   'voters',
#   'somehow',
#   'okay',
#   'w/',
#   "trump's",
#   'brand',
#   'evil+incompetence',
#   '-',
#   'diagnosed',
#   'w/',
#   'anxiety+depression',
#   'fuck',
#   'year.',
#   'want',
#   'better.',
#   'please.'],
#  963: ['therapy.',
#   'went',
#   'years',
#   'without',
#   'medication',
#   'afford',
#   'although',
#   'doctor',
#   'suggested',
#   '"meditation"',
#   'per',
#   "that's",
#   'reach,',
#   'went',
#   'back',
#   'another',
#   'series',
#   'tests',
#   'diagnosed',
#   'depression',
#   'anxiety',
#   'time',
#   'buy',
#   'another',
#   'card'],
#  964: ['anyone',
#   'chooses',
#   'move',
#   'on,',
#   'get',
#   'it.',
#   'fun',
#   'lasted',
#   'no',
#   'hard',
#   'feelings.',
#   'full',
#   'transparency:',
#   'seen',
#   'therapist',
#   'since',
#   'september,',
#   'diagnosed',
#   'depression,',
#   "i've",
#   'yet',
#   'seek',
#   'treatment',
#   'for.'],
#  965: ['i’m',
#   'agoraphobic,',
#   'anxious',
#   'depression',
#   'riddled',
#   'ex-serviceman',
#   'diagnosed',
#   'ptsd',
#   'made',
#   'chortle,',
#   'layman’s',
#   'terms,',
#   'makes',
#   'absolutely',
#   'funny',
#   'fuck',
#   'best',
#   'british',
#   'humour',
#   '-',
#   'pinch',
#   'salt.',
#   'hope',
#   'different',
#   'shoes',
#   'wrong',
#   'feet,',
#   'yrs',
#   'ago'],
#  966: ['common',
#   'type',
#   'thinking',
#   'anxiety',
#   '(i',
#   'do)',
#   'possibly',
#   'depression.',
#   ')',
#   'diagnosed',
#   '(i',
#   'believe)',
#   'relatively',
#   'early',
#   'female',
#   'bc',
#   'symptoms',
#   'usually',
#   'radar'],
#  967: ['i’m',
#   'listening',
#   'sad',
#   'depression',
#   'bout.',
#   'mom',
#   'suffered',
#   'something',
#   'never',
#   'diagnosed',
#   'seemed',
#   'like',
#   'depression.',
#   'growing',
#   'tough',
#   'recognize',
#   'mood',
#   'in.',
#   'best',
#   'luck.'],
#  968: ['talking',
#   'you,',
#   'clear',
#   'no',
#   'single',
#   'set',
#   'preferred',
#   'terms',
#   'talking',
#   'sud/other',
#   'disorders',
#   'people',
#   'experience',
#   'problems.',
#   'i,',
#   'instance,',
#   'severe',
#   'depression',
#   'long',
#   'remember,',
#   'prefer',
#   '"diagnosed',
#   'with."'],
#  969: ['never',
#   'look',
#   'come',
#   '*anything*',
#   'fucking',
#   'honest,',
#   "i'm",
#   'ready',
#   'upheaval',
#   'peaceful',
#   'change,',
#   "y'all.",
#   'not',
#   'story',
#   'tell,',
#   'long',
#   'day',
#   'yesterday,',
#   'oldest',
#   'diagnosed',
#   'depression.',
#   'follows',
#   'adhd',
#   '+',
#   'odd',
#   'diagnoses.',
#   '/x'],
#  970: ['ohh',
#   'yaaaaaay',
#   'last',
#   'month',
#   'diagnosed',
#   'crippling',
#   'depression',
#   ',',
#   'know',
#   'not',
#   'smtg',
#   'joke',
#   'problem',
#   "don't",
#   'urge',
#   'suicide',
#   'mood',
#   'swings',
#   'feelings',
#   'despair',
#   'restlessness',
#   ',',
#   'idk',
#   'anti',
#   'depressants',
#   'taste',
#   'gets',
#   'atrocious',
#   'time',
#   'time'],
#  971: ['like',
#   'even',
#   'depression',
#   'still',
#   'incredibly',
#   'stigmatized',
#   'korea',
#   'sunmi',
#   'talk',
#   'diagnosed',
#   'bpd',
#   'national',
#   'tv.....',
#   'genuinely',
#   'strongest',
#   'person',
#   'world',
#   'oh',
#   'gosh'],
#  972: ['never',
#   'thought',
#   'diagnosis',
#   'would',
#   'lead',
#   'depression,',
#   'even',
#   'though',
#   'numbers',
#   'suggest',
#   'adults',
#   'diagnosed',
#   'autistic,',
#   'adhd',
#   'usually',
#   'become',
#   'depressed',
#   'first.',
#   '(autistic',
#   'people',
#   'general',
#   'four',
#   'times',
#   'likely',
#   'cope',
#   'depression',
#   'lives.)'],
#  973: ['qondile',
#   'surely',
#   'never',
#   'diagnosed',
#   'depression',
#   'otherwise',
#   'would',
#   'get',
#   'it.',
#   'hope',
#   'eventual',
#   'receive',
#   'help',
#   'need.',
#   'love',
#   'light',
#   'sis.'],
#  974: ['diagnosed',
#   'depression',
#   ',',
#   'told',
#   'live',
#   'emotional',
#   'dysregulation',
#   'game',
#   'changer',
#   'me.',
#   'told',
#   'emotional',
#   'responses',
#   'different',
#   'others',
#   'helped',
#   'understand',
#   'much',
#   'life',
#   'experiences'],
#  975: ['mfs',
#   'think',
#   'seen',
#   'nobody.',
#   'diagnosed',
#   'severe',
#   'depression',
#   'insomnia..',
#   'years',
#   'ago..'],
#  976: ['four',
#   'years',
#   'ago:',
#   'worked',
#   'toxic',
#   'work',
#   'environment.🤬',
#   'diagnosed',
#   'depression.😞',
#   'bright',
#   'side:',
#   'created',
#   'calibri',
#   'funtimes',
#   'kicked',
#   'incredible',
#   'journey.💜',
#   'today:',
#   "i've",
#   'moved',
#   'cft',
#   'dedicated',
#   'voice',
#   "acting.🎭i've",
#   'made',
#   'incredible',
#   'friends',
#   'along',
#   'way🦄'],
#  977: ['u',
#   'ever',
#   'catch',
#   'urself',
#   'thinking',
#   'smthing',
#   "that's",
#   'like',
#   ',,',
#   'first',
#   'year',
#   'depression',
#   '?',
#   'like',
#   'sometimes',
#   "i'll",
#   'b',
#   'thinkin',
#   'like',
#   '"there\'s',
#   'something',
#   'wrong',
#   ':(("',
#   'yeah',
#   'bitch',
#   'diagnosed',
#   'mental',
#   'illnesses',
#   '???'],
#  978: ['hard',
#   'tho.',
#   'today',
#   'feeling',
#   'better',
#   'already',
#   'doubt™',
#   'facts',
#   'know.',
#   'kinda',
#   'alluded',
#   'struggles',
#   'dad',
#   "let's",
#   'see',
#   'actually',
#   'remembers',
#   'time',
#   '(not',
#   "i'm",
#   'mad',
#   "doesn't,",
#   "he's",
#   'actually',
#   'diagnosed',
#   'depression)'],
#  979: ['like',
#   'man',
#   'lived',
#   'years',
#   'self',
#   'diagnosed',
#   'anxiety',
#   'depression',
#   'adhd',
#   'moment',
#   'got',
#   'opportunity',
#   'get',
#   'diagnosed',
#   'guess',
#   'what????',
#   'uh',
#   'oh',
#   'guys',
#   'looks',
#   'like',
#   'self',
#   'diagnoser',
#   'right?',
#   "might've",
#   'coincidence',
#   'idk',
#   '🥴'],
#  980: ['not',
#   'mention',
#   'stigma',
#   'yg',
#   'akan',
#   'datang.',
#   'tak',
#   'sakit',
#   'tapi',
#   'mengaku',
#   'sakit.',
#   'lepastu',
#   'sembuh',
#   'mcmtu',
#   'je.',
#   'macam',
#   'sakit',
#   'mengada.',
#   'orang',
#   'yang',
#   'tak',
#   'tau',
#   'memang',
#   'akan',
#   'label',
#   'orang',
#   'depression',
#   'semua',
#   'ni',
#   'mengada',
#   'je',
#   'la',
#   'even',
#   'yg',
#   'betul2',
#   'diagnosed',
#   'doctor',
#   '🙄'],
#  981: ['ni',
#   'kalau',
#   'baru',
#   'gaduh',
#   'dengan',
#   'pakwe,',
#   'terus',
#   'isi',
#   'tu',
#   'tengok',
#   'score',
#   'semua',
#   'tinggi,',
#   'jangan',
#   'terus',
#   'gelabah',
#   'tetek',
#   'mengaku',
#   'ada',
#   'depression',
#   'stress',
#   'anxiety',
#   'pejadah',
#   'semua.',
#   'benda',
#   'tu',
#   'diagnosed',
#   'doctor,',
#   'bukan',
#   'dengan',
#   'soalan',
#   'yg',
#   'kau',
#   'boleh',
#   'dapat',
#   'anywhere',
#   'internet.'],
#  982: ['know',
#   "i've",
#   'also',
#   'got',
#   'depression?',
#   "i'm",
#   'self-diagnosed,',
#   'thought',
#   'mention.',
#   'thought',
#   'could',
#   'one',
#   'fix',
#   'me.'],
#  983: ['diagnosed', 'depression', 'anxiety.', 'already', 'knew', 'was.'],
#  984: ['mother',
#   'asking',
#   'perhaps',
#   'depression',
#   'bc',
#   'seem',
#   'little',
#   'tired',
#   'like',
#   "yes...i've",
#   'diagnosed',
#   'years',
#   'ago',
#   'mean'],
#  985: ['today',
#   'diagnosed',
#   'ptsd',
#   'depression.',
#   'gonna',
#   'long',
#   'road',
#   'recovery',
#   'gonna',
#   'okay.',
#   'better',
#   'man.',
#   'swear',
#   'it.'],
#  986: ['diagnosed',
#   'depression',
#   'severe',
#   'anxiety',
#   'disorder,',
#   'extent',
#   'yes,',
#   'people',
#   'jump',
#   'illnesses',
#   'like',
#   'trends',
#   'trivialises',
#   'condition',
#   'many',
#   'others',
#   'suffering'],
#  987: ['diagnosed', 'w/depression', '&amp;', 'anxiety', '.'],
#  988: ['.',
#   'finally',
#   'saw',
#   'psychiatrist',
#   'depression',
#   '&amp;',
#   'anxiety',
#   '.',
#   'finally',
#   'got',
#   'ear',
#   'checked',
#   'ent',
#   'specialist,',
#   'surgery,',
#   'know',
#   "i'm",
#   'hearing',
#   'loss',
#   '.',
#   'finally',
#   'got',
#   'long-suspected',
#   'adhd',
#   'diagnosed,',
#   'explains',
#   '"finally\'s"',
#   'list'],
#  989: ['actually',
#   "don't",
#   'think',
#   'care',
#   'friends',
#   'anymore',
#   'enit',
#   'lol',
#   'got',
#   'diagnosed',
#   'acute',
#   'depression',
#   'anxiety',
#   'july',
#   'im',
#   'not',
#   'sure',
#   "anyone's",
#   'properly',
#   'asked',
#   'im',
#   'alright',
#   'since',
#   'days',
#   'nobody',
#   'cares',
#   'front',
#   'ppl',
#   'giving',
#   'something',
#   'man'],
#  990: ['bollywood',
#   'actress',
#   'deepika',
#   'padukone',
#   'came',
#   'forward',
#   '&amp;',
#   'shared',
#   'diagnosed',
#   'anxiety',
#   '&amp;',
#   'clinical',
#   'depression.',
#   'actress',
#   'also',
#   'encouraged',
#   'people',
#   'seek',
#   'help',
#   'problems.'],
#  991: ['exactly',
#   'happened',
#   'me.',
#   'diagnosed',
#   'depression,',
#   'tried',
#   'different',
#   'medications,',
#   'nothing',
#   'helped.',
#   'sneaking',
#   'suspicion',
#   'adhd',
#   "didn't",
#   'say',
#   'anything.',
#   'talking',
#   'something',
#   'thought',
#   'mundane,',
#   'therapist',
#   'told',
#   'might',
#   'adhd.'],
#  992: ['mostly',
#   'bipolar',
#   'diagnosed',
#   'th.',
#   'interested,',
#   'ask',
#   'real',
#   'people,',
#   'suffer',
#   'disorder.',
#   'helps',
#   'lot',
#   'understand',
#   'it.',
#   'suffer',
#   'depression,',
#   'don’t',
#   'constant',
#   'suicidal',
#   'thoughts,',
#   'bipolar',
#   'person',
#   'has.'],
#  993: ['wanna',
#   'say',
#   'stop',
#   'streaming',
#   'days',
#   'time',
#   'apologize,',
#   'can’t',
#   'officially',
#   'get',
#   'diagnosed',
#   'atm',
#   'cause',
#   'genetics',
#   'shit',
#   'i’m',
#   'likely',
#   'suffer',
#   'clinical',
#   'depression',
#   '(mom,',
#   'grandma,',
#   'great',
#   'grandma',
#   'etc',
#   'suffered',
#   'it)',
#   'tend',
#   'lack',
#   'motivation',
#   'lot,',
#   'won’t'],
#  994: ['me,',
#   'experiencing',
#   'symptoms',
#   'depression',
#   "i've",
#   'diagnosed',
#   'years:',
#   'man',
#   "don't",
#   'know',
#   'whats',
#   'wrong',
#   ':/',
#   'mystery'],
#  995: ['diagnosed',
#   'depression/anxiety',
#   'nothing',
#   'seems',
#   'help',
#   'also',
#   'find',
#   'adhd',
#   'memes',
#   'relatable',
#   'i,',
#   'li',
#   '"not',
#   'doctor"',
#   'zard,',
#   'recommend',
#   'mention',
#   'adhd',
#   'next',
#   'time',
#   'talk',
#   'doctor,',
#   'probably'],
#  996: ['way',
#   'i’ve',
#   'diagnosed',
#   'depression',
#   'dumb',
#   'ass',
#   'still',
#   'thinks',
#   'i’m',
#   'faking'],
#  997: ['technically',
#   "i'm",
#   'diagnosed',
#   'asd,',
#   'gad,',
#   'depression,',
#   'past',
#   'ptsd,',
#   'self',
#   'diagnosed',
#   'derealization,',
#   'suspect',
#   'adhd',
#   'similar,',
#   'hsp',
#   'traits.'],
#  998: ['first',
#   'started',
#   'seeing',
#   'psychiatrist',
#   'age',
#   'diagnosed',
#   'chronic',
#   'depression.',
#   'wasn’t',
#   'seeing',
#   'psychiatrist',
#   'specialised',
#   'bipolar',
#   'disorder',
#   'finally',
#   'diagnosed',
#   'bipolar.'],
#  999: ['usa:',
#   'explorations',
#   'link',
#   'diagnosed',
#   '‘major',
#   'depression’',
#   'states',
#   'humans',
#   'microorganism',
#   'populations',
#   'living',
#   'around',
#   'bodies',
#   '|',
#   'wsj',
#   '|',
#   'dec'],
#  ...}

# %%
from nltk.tokenize.treebank import TreebankWordDetokenizer

# %%
TreebankWordDetokenizer().detokenize(tweets_clean_dict[1])
# Out:
# "sister even diagnosed depression. am. lashes sympathy, cry alone. boyfriend someone lean on, talk to, go with. don't. i'm tired feeling alone. truthfully, i'll never comfortable public person am."

# %%
# Here we detokenize all the tweets
detokenized_dict = {}
for key, items in tweets_clean_dict.items():
    detokenized_dict[key] = TreebankWordDetokenizer().detokenize(tweets_clean_dict[key])
# detokenized_dict

# %%
detokenized_dict[0]
# Out:
# "someone who's suffering (diagnosed 🙄) depression years now, new years resolutions don't mean anything. i'm trying (and failing lol) better every single day... great feeling! lets it!!"

# %%
detokenized_df = pd.DataFrame.from_dict(detokenized_dict, orient='index')

# %%
detokenized_df.head(10)
detokenized_df.rename(columns={0:'pre_processed'}, inplace=True)

# %%
from transformers import AutoModelForSequenceClassification
from transformers import TFAutoModelForSequenceClassification
from transformers import AutoTokenizer
import numpy as np
from scipy.special import softmax
import csv
import urllib.request

# %%
# Here we're using the roberta-base models 
task1='sentiment'
MODEL1 = f"cardiffnlp/twitter-roberta-base-{task1}"
tokenizer1 = AutoTokenizer.from_pretrained(MODEL1)

task2='emotion'
MODEL2 = f"cardiffnlp/twitter-roberta-base-{task2}"
tokenizer2 = AutoTokenizer.from_pretrained(MODEL2)

task3='irony'
MODEL3 = f"cardiffnlp/twitter-roberta-base-{task3}"
tokenizer3 = AutoTokenizer.from_pretrained(MODEL3)

# %%
# download label mapping sentiment
mapping_link = f"https://raw.githubusercontent.com/cardiffnlp/tweeteval/main/datasets/{task1}/mapping.txt"
with urllib.request.urlopen(mapping_link) as f:
    html = f.read().decode('utf-8').split("\n")
    csvreader = csv.reader(html, delimiter='\t')
labels1 = [row[1] for row in csvreader if len(row) > 1]
labels1
# Out:
# ['negative', 'neutral', 'positive']

# %%
# download label mapping emotion
mapping_link = f"https://raw.githubusercontent.com/cardiffnlp/tweeteval/main/datasets/{task2}/mapping.txt"
with urllib.request.urlopen(mapping_link) as f:
    html = f.read().decode('utf-8').split("\n")
    csvreader = csv.reader(html, delimiter='\t')
labels2 = [row[1] for row in csvreader if len(row) > 1]
labels2
# Out:
# ['anger', 'joy', 'optimism', 'sadness']

# %%
# download label mapping irony
mapping_link = f"https://raw.githubusercontent.com/cardiffnlp/tweeteval/main/datasets/{task3}/mapping.txt"
with urllib.request.urlopen(mapping_link) as f:
    html = f.read().decode('utf-8').split("\n")
    csvreader = csv.reader(html, delimiter='\t')
labels3 = [row[1] for row in csvreader if len(row) > 1]
labels3
# Out:
# ['non_irony', 'irony']

# %%
model1 = TFAutoModelForSequenceClassification.from_pretrained(MODEL1)
model2 = TFAutoModelForSequenceClassification.from_pretrained(MODEL2)
model3 = TFAutoModelForSequenceClassification.from_pretrained(MODEL3)
# Out:
# All model checkpoint layers were used when initializing TFRobertaForSequenceClassification.
#
# All the layers of TFRobertaForSequenceClassification were initialized from the model checkpoint at cardiffnlp/twitter-roberta-base-sentiment.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFRobertaForSequenceClassification for predictions without further training.
# All model checkpoint layers were used when initializing TFRobertaForSequenceClassification.
#
# All the layers of TFRobertaForSequenceClassification were initialized from the model checkpoint at cardiffnlp/twitter-roberta-base-emotion.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFRobertaForSequenceClassification for predictions without further training.
# All model checkpoint layers were used when initializing TFRobertaForSequenceClassification.
#
# All the layers of TFRobertaForSequenceClassification were initialized from the model checkpoint at cardiffnlp/twitter-roberta-base-irony.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFRobertaForSequenceClassification for predictions without further training.

# %%
# this function return labels for sentiment
def return_labels1(text):
    encoded_input = tokenizer1(text, return_tensors='tf')
    output = model1(encoded_input)
    scores = output[0][0].numpy()
    scores = softmax(scores)
    ranking = np.argsort(scores)
    ranking = ranking[::-1]
    label1 = labels1[ranking[0]]
    return label1

# %%
# this function return labels for emotions
def return_labels2(text):
    encoded_input = tokenizer2(text, return_tensors='tf')
    output = model2(encoded_input)
    scores = output[0][0].numpy()
    scores = softmax(scores)
    ranking = np.argsort(scores)
    ranking = ranking[::-1]
    label2 = labels2[ranking[0]]
    return label2

# %%
# this function return labels for irony
def return_labels3(text):
    encoded_input = tokenizer3(text, return_tensors='tf')
    output = model3(encoded_input)
    scores = output[0][0].numpy()
    scores = softmax(scores)
    ranking = np.argsort(scores)
    ranking = ranking[::-1]
    label3 = labels3[ranking[0]]
    return label3

# %%
# this function return probabilities to analize how "sure" the model is
def return_prob1(text):
    encoded_input = tokenizer1(text, return_tensors='tf')
    output = model1(encoded_input)
    scores = output[0][0].numpy()
    scores = softmax(scores)
    ranking = np.argsort(scores)
    ranking = ranking[::-1]
    return np.sort(scores)[-1]

# %%
# this function return probabilities to analize how "sure" the model is
def return_prob2(text):
    encoded_input = tokenizer2(text, return_tensors='tf')
    output = model2(encoded_input)
    scores = output[0][0].numpy()
    scores = softmax(scores)
    ranking = np.argsort(scores)
    ranking = ranking[::-1]
    return np.sort(scores)[-1]

# %%
# this function return probabilities to analize how "sure" the model is
def return_prob3(text):
    encoded_input = tokenizer3(text, return_tensors='tf')
    output = model3(encoded_input)
    scores = output[0][0].numpy()
    scores = softmax(scores)
    ranking = np.argsort(scores)
    ranking = ranking[::-1]
    return np.sort(scores)[-1]

# %%
detokenized_df['label_sentiment'] = detokenized_df['pre_processed'].apply(lambda x: return_labels1(x))
detokenized_df['probability_sentiment'] = detokenized_df['pre_processed'].apply(lambda x: return_prob1(x))

detokenized_df['label_emotion'] = detokenized_df['pre_processed'].apply(lambda x: return_labels2(x))
detokenized_df['probability_emotion'] = detokenized_df['pre_processed'].apply(lambda x: return_prob2(x))

detokenized_df['label_irony'] = detokenized_df['pre_processed'].apply(lambda x: return_labels3(x))
detokenized_df['probability_irony'] = detokenized_df['pre_processed'].apply(lambda x: return_prob3(x))

detokenized_df
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-33-6b068f423e31> in <module>
#       1 detokenized_df['label_sentiment'] = detokenized_df['pre_processed'].apply(lambda x: return_labels1(x))
# ----> 2 detokenized_df['probability_sentiment'] = detokenized_df['pre_processed'].apply(lambda x: return_prob1(x))
#       3
#       4 detokenized_df['label_emotion'] = detokenized_df['pre_processed'].apply(lambda x: return_labels2(x))
#       5 detokenized_df['probability_emotion'] = detokenized_df['pre_processed'].apply(lambda x: return_prob2(x))
#
# ~\anaconda3\envs\Thesis\lib\site-packages\pandas\core\series.py in apply(self, func, convert_dtype, args, **kwds)
#    4136             else:
#    4137                 values = self.astype(object)._values
# -> 4138                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    4139
#    4140         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas\_libs\lib.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-33-6b068f423e31> in <lambda>(x)
#       1 detokenized_df['label_sentiment'] = detokenized_df['pre_processed'].apply(lambda x: return_labels1(x))
# ----> 2 detokenized_df['probability_sentiment'] = detokenized_df['pre_processed'].apply(lambda x: return_prob1(x))
#       3
#       4 detokenized_df['label_emotion'] = detokenized_df['pre_processed'].apply(lambda x: return_labels2(x))
#       5 detokenized_df['probability_emotion'] = detokenized_df['pre_processed'].apply(lambda x: return_prob2(x))
#
# <ipython-input-30-70b18b4bfa3f> in return_prob1(text)
#       2 def return_prob1(text):
#       3     encoded_input = tokenizer1(text, return_tensors='tf')
# ----> 4     output = model1(encoded_input)
#       5     scores = output[0][0].numpy()
#       6     scores = softmax(scores)
#
# ~\anaconda3\envs\Thesis\lib\site-packages\tensorflow\python\keras\engine\base_layer.py in __call__(self, *args, **kwargs)
#    1028         with autocast_variable.enable_auto_cast_variables(
#    1029             self._compute_dtype_object):
# -> 1030           outputs = call_fn(inputs, *args, **kwargs)
#    1031
#    1032         if self._activity_regularizer:
#
# ~\anaconda3\envs\Thesis\lib\site-packages\transformers\models\roberta\modeling_tf_roberta.py in call(self, input_ids, attention_mask, token_type_ids, position_ids, head_mask, inputs_embeds, output_attentions, output_hidden_states, return_dict, labels, training, **kwargs)
#    1010             kwargs_call=kwargs,
#    1011         )
# -> 1012         outputs = self.roberta(
#    1013             inputs["input_ids"],
#    1014             attention_mask=inputs["attention_mask"],
#
# ~\anaconda3\envs\Thesis\lib\site-packages\tensorflow\python\keras\engine\base_layer.py in __call__(self, *args, **kwargs)
#    1028         with autocast_variable.enable_auto_cast_variables(
#    1029             self._compute_dtype_object):
# -> 1030           outputs = call_fn(inputs, *args, **kwargs)
#    1031
#    1032         if self._activity_regularizer:
#
# ~\anaconda3\envs\Thesis\lib\site-packages\transformers\models\roberta\modeling_tf_roberta.py in call(self, input_ids, attention_mask, token_type_ids, position_ids, head_mask, inputs_embeds, output_attentions, output_hidden_states, return_dict, training, **kwargs)
#     556             inputs["head_mask"] = [None] * self.config.num_hidden_layers
#     557
# --> 558         encoder_outputs = self.encoder(
#     559             hidden_states=embedding_output,
#     560             attention_mask=extended_attention_mask,
#
# ~\anaconda3\envs\Thesis\lib\site-packages\tensorflow\python\keras\engine\base_layer.py in __call__(self, *args, **kwargs)
#    1028         with autocast_variable.enable_auto_cast_variables(
#    1029             self._compute_dtype_object):
# -> 1030           outputs = call_fn(inputs, *args, **kwargs)
#    1031
#    1032         if self._activity_regularizer:
#
# ~\anaconda3\envs\Thesis\lib\site-packages\transformers\models\roberta\modeling_tf_roberta.py in call(self, hidden_states, attention_mask, head_mask, output_attentions, output_hidden_states, return_dict, training)
#     416                 all_hidden_states = all_hidden_states + (hidden_states,)
#     417
# --> 418             layer_outputs = layer_module(
#     419                 hidden_states=hidden_states,
#     420                 attention_mask=attention_mask,
#
# ~\anaconda3\envs\Thesis\lib\site-packages\tensorflow\python\keras\engine\base_layer.py in __call__(self, *args, **kwargs)
#    1028         with autocast_variable.enable_auto_cast_variables(
#    1029             self._compute_dtype_object):
# -> 1030           outputs = call_fn(inputs, *args, **kwargs)
#    1031
#    1032         if self._activity_regularizer:
#
# ~\anaconda3\envs\Thesis\lib\site-packages\transformers\models\roberta\modeling_tf_roberta.py in call(self, hidden_states, attention_mask, head_mask, output_attentions, training)
#     384         attention_output = attention_outputs[0]
#     385         intermediate_output = self.intermediate(hidden_states=attention_output)
# --> 386         layer_output = self.bert_output(
#     387             hidden_states=intermediate_output, input_tensor=attention_output, training=training
#     388         )
#
# ~\anaconda3\envs\Thesis\lib\site-packages\tensorflow\python\keras\engine\base_layer.py in __call__(self, *args, **kwargs)
#    1028         with autocast_variable.enable_auto_cast_variables(
#    1029             self._compute_dtype_object):
# -> 1030           outputs = call_fn(inputs, *args, **kwargs)
#    1031
#    1032         if self._activity_regularizer:
#
# ~\anaconda3\envs\Thesis\lib\site-packages\transformers\models\roberta\modeling_tf_roberta.py in call(self, hidden_states, input_tensor, training)
#     353         hidden_states = self.dense(inputs=hidden_states)
#     354         hidden_states = self.dropout(inputs=hidden_states, training=training)
# --> 355         hidden_states = self.LayerNorm(inputs=hidden_states + input_tensor)
#     356
#     357         return hidden_states
#
# ~\anaconda3\envs\Thesis\lib\site-packages\tensorflow\python\keras\engine\base_layer.py in __call__(self, *args, **kwargs)
#    1028         with autocast_variable.enable_auto_cast_variables(
#    1029             self._compute_dtype_object):
# -> 1030           outputs = call_fn(inputs, *args, **kwargs)
#    1031
#    1032         if self._activity_regularizer:
#
# ~\anaconda3\envs\Thesis\lib\site-packages\tensorflow\python\keras\layers\normalization.py in call(self, inputs)
#    1242
#    1243       # Compute layer normalization using the batch_normalization function.
# -> 1244       outputs = nn.batch_normalization(
#    1245           inputs,
#    1246           mean,
#
# ~\anaconda3\envs\Thesis\lib\site-packages\tensorflow\python\util\dispatch.py in wrapper(*args, **kwargs)
#     204     """Call target, and fall back on dispatchers if there is a TypeError."""
#     205     try:
# --> 206       return target(*args, **kwargs)
#     207     except (TypeError, ValueError):
#     208       # Note: convert_to_eager_tensor currently raises a ValueError, not a
#
# ~\anaconda3\envs\Thesis\lib\site-packages\tensorflow\python\ops\nn_impl.py in batch_normalization(x, mean, variance, offset, scale, variance_epsilon, name)
#    1566     inv = math_ops.rsqrt(variance + variance_epsilon)
#    1567     if scale is not None:
# -> 1568       inv *= scale
#    1569     # Note: tensorflow/contrib/quantize/python/fold_batch_norms.py depends on
#    1570     # the precise order of ops that are generated by the expression below.
#
# ~\anaconda3\envs\Thesis\lib\site-packages\tensorflow\python\ops\math_ops.py in binary_op_wrapper(x, y)
#    1232         #   r_binary_op_wrapper use different force_same_dtype values.
#    1233         x, y = maybe_promote_tensors(x, y, force_same_dtype=False)
# -> 1234         return func(x, y, name=name)
#    1235       except (TypeError, ValueError) as e:
#    1236         # Even if dispatching the op failed, the RHS may be a tensor aware
#
# ~\anaconda3\envs\Thesis\lib\site-packages\tensorflow\python\ops\math_ops.py in _mul_dispatch(x, y, name)
#    1573     return sparse_tensor.SparseTensor(y.indices, new_vals, y.dense_shape)
#    1574   else:
# -> 1575     return multiply(x, y, name=name)
#    1576
#    1577
#
# ~\anaconda3\envs\Thesis\lib\site-packages\tensorflow\python\util\dispatch.py in wrapper(*args, **kwargs)
#     204     """Call target, and fall back on dispatchers if there is a TypeError."""
#     205     try:
# --> 206       return target(*args, **kwargs)
#     207     except (TypeError, ValueError):
#     208       # Note: convert_to_eager_tensor currently raises a ValueError, not a
#
# ~\anaconda3\envs\Thesis\lib\site-packages\tensorflow\python\ops\math_ops.py in multiply(x, y, name)
#     528   """
#     529
# --> 530   return gen_math_ops.mul(x, y, name)
#     531
#     532
#
# ~\anaconda3\envs\Thesis\lib\site-packages\tensorflow\python\ops\gen_math_ops.py in mul(x, y, name)
#    6233   if tld.is_eager:
#    6234     try:
# -> 6235       _result = pywrap_tfe.TFE_Py_FastPathExecute(
#    6236         _ctx, "Mul", name, x, y)
#    6237       return _result
#
# KeyboardInterrupt:

# %%
official_df = pd.concat([depression_df[['renderedContent']], detokenized_df], axis = 1)
official_df

# %%
official_df.to_csv('./preprocessed_data/2020/depression_2020.csv', sep=',', index=False, encoding='utf-8-sig')

# %%
#official_df
