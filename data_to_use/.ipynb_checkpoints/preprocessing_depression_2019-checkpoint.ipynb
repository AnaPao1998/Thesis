# %%
import pandas as pd 
pd.set_option("display.max_colwidth", 400)
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns
import string
import nltk # for text manipulation
from nltk.corpus import stopwords
import preprocessor as p
import warnings 
warnings.filterwarnings("ignore", category=DeprecationWarning)

# %matplotlib inline

# %%
# Here we read the csv file that that contains depressive tweets from 2019
depression_df = pd.read_csv("./data_to_use/merged_data/2019/depression_2019.csv")

# %%
#depression_df.info()

# %%
#Here we delete all the unnecesary colums
depression_df.drop(["content","id","user","outlinks","tcooutlinks","replyCount","retweetCount","likeCount","quoteCount",\
                    "conversationId","lang","source","sourceUrl","sourceLabel","media","retweetedTweet","quotedTweet",\
                    "mentionedUsers"] ,axis=1, inplace=True)

# %%
depression_df.head(10)
# Out:
#                                                               url  \
# 0  https://twitter.com/TranscendedBass/status/1212159304532398081
# 1       https://twitter.com/bimboluvr3/status/1212153068336418818
# 2   https://twitter.com/un_apolo_getic/status/1212150784483319808
# 3         https://twitter.com/lordmooh/status/1212149960860454924
# 4     https://twitter.com/dannyspiders/status/1212137997707173890
# 5      https://twitter.com/atdapyramid/status/1212135080929443840
# 6        https://twitter.com/SisiSmurf/status/1212134354543095814
# 7     https://twitter.com/totzofficial/status/1212127724342398976
# 8   https://twitter.com/lalalandlounge/status/1212127437926076420
# 9  https://twitter.com/Ayee_Twatch_Dis/status/1212116235221184513
#
#                         date  \
# 0  2019-12-31 23:51:13+00:00
# 1  2019-12-31 23:26:26+00:00
# 2  2019-12-31 23:17:22+00:00
# 3  2019-12-31 23:14:05+00:00
# 4  2019-12-31 22:26:33+00:00
# 5  2019-12-31 22:14:58+00:00
# 6  2019-12-31 22:12:05+00:00
# 7  2019-12-31 21:45:44+00:00
# 8  2019-12-31 21:44:36+00:00
# 9  2019-12-31 21:00:05+00:00
#
#                                                                                                                                                                                                                                                                                                renderedContent
# 0                   Too many shootings, too many lives lost from evil people with power, too much hate, too much depression, and not nearly enough change to stop that. \n\nI'm gonna be in my apartment hoping every bang I hear tonight is a firework, hoping we as a people can celebrate life without fear
# 1                                                                                                                                                                                                        i hate having to walk back into my depression den after i’ve completely  altered myself in the shower
# 2                                                                                                                                                               Seriously. 2019 decided to kick my ass one more time. Now I'm listening to my depression playlist. I hate it here. twitter.com/TarotByBronx/s…
# 3                                                                                                                                                                                                                                                           First 2020 depression... yay... 👌🏻 I hate my life.
# 4                            I hate that being upfront with your emotional state as an adult is seen as "attention seeking" like no I just want you to know I'm not sulking in a corner because I'm mad at you, my brain hasnt had any feel good pharmacy chemicals in a year and its seasonal depression time
# 5                                                                                                                                                        my mom says she’s scared that im not eating because of my depression but literally won’t book me anymore therapy sessions i fucking hate my life dawg
# 6  I’d have to say 2019 was one of the worst years I’ve ever had.  I lost my brother to a heart attack and my niece (who Was like my sister) to depression...  Happened 2 months apart within me moving to a different state (which I hate being here).  Can I move back home in 2020? https://t.co/U3S377FiGV
# 7                              Every trial, tribulation, and obstacle that came my way this past year tried to corrupt me again... i made it through depression, anxiety, addiction, manipulation, PTSD and just hate in general. Not even the worst of me could get the best of me. Lets do better in 2020. 🥀
# 8     @realDonaldTrump Don’t like Rush but wish my grandma was alive, she loved the guy and would have liked to see him not be humiliated but uplifted. So much hate for a President who is a narcissist but hey, I have depression. News refuses to report on his accomplishments, so he compliments himself.
# 9                     So besides losin my dad I had a good year, Went on a baecae to Miami, Got some clarity on things that have bugged me, let go of a few demons n released some of the hate in my heart, started talkin to my mom more, got closer with family, sorta getting this depression under control

# %%
p.set_options(p.OPT.URL, p.OPT.EMOJI)
p.clean('Preprocessor is #awesome 👍 https://github.com/s/preprocessor')
# Out:
# 'Preprocessor is #awesome'

# %%
# Here we use a preprocessing library for tweet data called "Preprocessor" and we use it to delete the url's, mentions 
#and numbers
p.set_options(p.OPT.URL, p.OPT.MENTION, p.OPT.NUMBER)
depression_df['pre_proccessed'] = depression_df['renderedContent'].apply(lambda x: p.clean(x)).str.lower()
#depression_df.head(10)

# %%
# Here we use the nltk library and we download the stopwords
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Usuario\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
stopwords_english = stopwords.words('english') 
print('Stop words\n')
print(stopwords_english)
# Out:
# Stop words
#
# ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', "you're", "you've", "you'll", "you'd", 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', "she's", 'her', 'hers', 'herself', 'it', "it's", 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', "that'll", 'these', 'those', 'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such', 'no', 'nor', 'not', 'only', 'own', 'same', 'so', 'than', 'too', 'very', 's', 't', 'can', 'will', 'just', 'don', "don't", 'should', "should've", 'now', 'd', 'll', 'm', 'o', 're', 've', 'y', 'ain', 'aren', "aren't", 'couldn', "couldn't", 'didn', "didn't", 'doesn', "doesn't", 'hadn', "hadn't", 'hasn', "hasn't", 'haven', "haven't", 'isn', "isn't", 'ma', 'mightn', "mightn't", 'mustn', "mustn't", 'needn', "needn't", 'shan', "shan't", 'shouldn', "shouldn't", 'wasn', "wasn't", 'weren', "weren't", 'won', "won't", 'wouldn', "wouldn't"]

# %%
'no' in stopwords_english
# Out:
# True

# %%
# After doing some testing, I noticed that negations are important, so I removed them from the stopwords list
to_remove = ['no', 'not',"don't",'didn', "didn't", 'doesn', "doesn't", 'hadn', "hadn't", 'hasn', "hasn't"]
to_remove
            
[stopwords_english.remove(item) for item in to_remove if item in stopwords_english]
stopwords_english
# Out:
# ['i',
#  'me',
#  'my',
#  'myself',
#  'we',
#  'our',
#  'ours',
#  'ourselves',
#  'you',
#  "you're",
#  "you've",
#  "you'll",
#  "you'd",
#  'your',
#  'yours',
#  'yourself',
#  'yourselves',
#  'he',
#  'him',
#  'his',
#  'himself',
#  'she',
#  "she's",
#  'her',
#  'hers',
#  'herself',
#  'it',
#  "it's",
#  'its',
#  'itself',
#  'they',
#  'them',
#  'their',
#  'theirs',
#  'themselves',
#  'what',
#  'which',
#  'who',
#  'whom',
#  'this',
#  'that',
#  "that'll",
#  'these',
#  'those',
#  'am',
#  'is',
#  'are',
#  'was',
#  'were',
#  'be',
#  'been',
#  'being',
#  'have',
#  'has',
#  'had',
#  'having',
#  'do',
#  'does',
#  'did',
#  'doing',
#  'a',
#  'an',
#  'the',
#  'and',
#  'but',
#  'if',
#  'or',
#  'because',
#  'as',
#  'until',
#  'while',
#  'of',
#  'at',
#  'by',
#  'for',
#  'with',
#  'about',
#  'against',
#  'between',
#  'into',
#  'through',
#  'during',
#  'before',
#  'after',
#  'above',
#  'below',
#  'to',
#  'from',
#  'up',
#  'down',
#  'in',
#  'out',
#  'on',
#  'off',
#  'over',
#  'under',
#  'again',
#  'further',
#  'then',
#  'once',
#  'here',
#  'there',
#  'when',
#  'where',
#  'why',
#  'how',
#  'all',
#  'any',
#  'both',
#  'each',
#  'few',
#  'more',
#  'most',
#  'other',
#  'some',
#  'such',
#  'nor',
#  'only',
#  'own',
#  'same',
#  'so',
#  'than',
#  'too',
#  'very',
#  's',
#  't',
#  'can',
#  'will',
#  'just',
#  'don',
#  'should',
#  "should've",
#  'now',
#  'd',
#  'll',
#  'm',
#  'o',
#  're',
#  've',
#  'y',
#  'ain',
#  'aren',
#  "aren't",
#  'couldn',
#  "couldn't",
#  'haven',
#  "haven't",
#  'isn',
#  "isn't",
#  'ma',
#  'mightn',
#  "mightn't",
#  'mustn',
#  "mustn't",
#  'needn',
#  "needn't",
#  'shan',
#  "shan't",
#  'shouldn',
#  "shouldn't",
#  'wasn',
#  "wasn't",
#  'weren',
#  "weren't",
#  'won',
#  "won't",
#  'wouldn',
#  "wouldn't"]

# %%
'no' in stopwords_english
# Out:
# False

# %%
tokenized_tweet = depression_df['pre_proccessed'].apply(lambda x: x.split()) # tokenizing
#tokenized_tweet[:10]

# %%
# print(tokenized_tweet[:10])
tweets_clean_dict = {}
for num, sentence in enumerate(tokenized_tweet): #Go through every tweet in the list of tweets 
    tweets_clean = [] #create an empty list to save the cleaned tweet for each tweet 
    for word in sentence: #go through every word inside the "dirty" tweet and keep only the ones you want
        if (word not in stopwords_english): 
            tweets_clean.append(word)
    tweets_clean_dict[num] = tweets_clean #save the list of "cleaned" words (cleaned tweet) into a dict in the position num (0,1,2,... ,len(tweets))
tweets_clean_dict
# Out:
# {0: ['many',
#   'shootings,',
#   'many',
#   'lives',
#   'lost',
#   'evil',
#   'people',
#   'power,',
#   'much',
#   'hate,',
#   'much',
#   'depression,',
#   'not',
#   'nearly',
#   'enough',
#   'change',
#   'stop',
#   'that.',
#   "i'm",
#   'gonna',
#   'apartment',
#   'hoping',
#   'every',
#   'bang',
#   'hear',
#   'tonight',
#   'firework,',
#   'hoping',
#   'people',
#   'celebrate',
#   'life',
#   'without',
#   'fear'],
#  1: ['hate',
#   'walk',
#   'back',
#   'depression',
#   'den',
#   'i’ve',
#   'completely',
#   'altered',
#   'shower'],
#  2: ['seriously.',
#   'decided',
#   'kick',
#   'ass',
#   'one',
#   'time.',
#   "i'm",
#   'listening',
#   'depression',
#   'playlist.',
#   'hate',
#   'here.'],
#  3: ['first', 'depression...', 'yay...', '👌🏻', 'hate', 'life.'],
#  4: ['hate',
#   'upfront',
#   'emotional',
#   'state',
#   'adult',
#   'seen',
#   '"attention',
#   'seeking"',
#   'like',
#   'no',
#   'want',
#   'know',
#   "i'm",
#   'not',
#   'sulking',
#   'corner',
#   "i'm",
#   'mad',
#   'you,',
#   'brain',
#   'hasnt',
#   'feel',
#   'good',
#   'pharmacy',
#   'chemicals',
#   'year',
#   'seasonal',
#   'depression',
#   'time'],
#  5: ['mom',
#   'says',
#   'she’s',
#   'scared',
#   'im',
#   'not',
#   'eating',
#   'depression',
#   'literally',
#   'won’t',
#   'book',
#   'anymore',
#   'therapy',
#   'sessions',
#   'fucking',
#   'hate',
#   'life',
#   'dawg'],
#  6: ['i’d',
#   'say',
#   'one',
#   'worst',
#   'years',
#   'i’ve',
#   'ever',
#   'had.',
#   'lost',
#   'brother',
#   'heart',
#   'attack',
#   'niece',
#   '(who',
#   'like',
#   'sister)',
#   'depression...',
#   'happened',
#   'months',
#   'apart',
#   'within',
#   'moving',
#   'different',
#   'state',
#   '(which',
#   'hate',
#   'here).',
#   'move',
#   'back',
#   'home',
#   '?'],
#  7: ['every',
#   'trial,',
#   'tribulation,',
#   'obstacle',
#   'came',
#   'way',
#   'past',
#   'year',
#   'tried',
#   'corrupt',
#   'again...',
#   'made',
#   'depression,',
#   'anxiety,',
#   'addiction,',
#   'manipulation,',
#   'ptsd',
#   'hate',
#   'general.',
#   'not',
#   'even',
#   'worst',
#   'could',
#   'get',
#   'best',
#   'me.',
#   'lets',
#   'better',
#   '.',
#   '🥀'],
#  8: ['don’t',
#   'like',
#   'rush',
#   'wish',
#   'grandma',
#   'alive,',
#   'loved',
#   'guy',
#   'would',
#   'liked',
#   'see',
#   'not',
#   'humiliated',
#   'uplifted.',
#   'much',
#   'hate',
#   'president',
#   'narcissist',
#   'hey,',
#   'depression.',
#   'news',
#   'refuses',
#   'report',
#   'accomplishments,',
#   'compliments',
#   'himself.'],
#  9: ['besides',
#   'losin',
#   'dad',
#   'good',
#   'year,',
#   'went',
#   'baecae',
#   'miami,',
#   'got',
#   'clarity',
#   'things',
#   'bugged',
#   'me,',
#   'let',
#   'go',
#   'demons',
#   'n',
#   'released',
#   'hate',
#   'heart,',
#   'started',
#   'talkin',
#   'mom',
#   'more,',
#   'got',
#   'closer',
#   'family,',
#   'sorta',
#   'getting',
#   'depression',
#   'control'],
#  10: ['something',
#   'hate',
#   'living',
#   'parents',
#   "can't",
#   'take',
#   'really',
#   'long',
#   'showers',
#   'without',
#   'someone',
#   'saying',
#   '"hey',
#   'u',
#   'while"',
#   'shut',
#   'dad',
#   'depression',
#   'needed',
#   'shave'],
#  11: ['broke',
#   'allowing',
#   'depression',
#   'win',
#   'going',
#   'ny.',
#   'hate',
#   'much',
#   'rn'],
#  12: ['main',
#   'goal',
#   'better',
#   'myself.',
#   'took',
#   'lot',
#   'work',
#   ',',
#   'drew',
#   'lot',
#   'depression.',
#   'want',
#   'able',
#   'offer',
#   'commissions,',
#   'also',
#   'not',
#   'hate',
#   'it.',
#   'things',
#   'love',
#   'not',
#   'feel',
#   'stifled.',
#   '^_^',
#   'feels',
#   'good',
#   'plan',
#   'for.'],
#  13: ['hate',
#   'seeing',
#   'like',
#   'this,',
#   'especially',
#   'since',
#   'helped',
#   'depression.',
#   'bruh'],
#  14: ["didn't",
#   'go',
#   'christmas',
#   'leaving',
#   'bed',
#   'past',
#   'week.',
#   'thanks',
#   'depression.',
#   'go',
#   'tonight.',
#   'excited!',
#   'happy',
#   'end',
#   'decade!',
#   'hate',
#   'depressed!'],
#  15: ['wish',
#   'survive',
#   'year',
#   'like',
#   'always',
#   'please',
#   'depression',
#   'go',
#   'away',
#   'hate'],
#  16: ['hate',
#   'people',
#   'ask',
#   'like',
#   'fun',
#   'start',
#   'wondering:',
#   'really',
#   'enjoy',
#   'spending',
#   'time',
#   'watching',
#   'tv',
#   'bed',
#   'really',
#   'bad',
#   'depression',
#   '&lt;3'],
#  17: ['like',
#   'honeslty',
#   'not',
#   'dramatic',
#   'really',
#   'stupidest',
#   'wasteful',
#   'year',
#   'life.',
#   'nothing',
#   'anxiety,',
#   'depression',
#   'getting',
#   'heart',
#   'broken',
#   'everyone.',
#   'thank',
#   'god',
#   'it’s',
#   'gonna',
#   'over.',
#   'hate',
#   'here.'],
#  18: ['hate',
#   'depression',
#   'makes',
#   'like',
#   'forget',
#   'legit',
#   'everything',
#   'bc',
#   'i’m',
#   'trying',
#   'fill',
#   'fucking',
#   'college',
#   'applications',
#   'can’t',
#   'remember',
#   'one',
#   'thing',
#   'i’ve',
#   'done',
#   'high',
#   'school',
#   '🤪'],
#  19: ['real',
#   'life',
#   'accuracy',
#   'damned',
#   'fucking',
#   'hate',
#   'pokémon',
#   'sword',
#   'shield',
#   'cloudy',
#   'damn',
#   'time.',
#   'already',
#   'bad',
#   'depression',
#   'escapist',
#   'video',
#   'game',
#   'come',
#   'seasonal',
#   'depression'],
#  20: ['major',
#   'depressive',
#   'disorder',
#   'marked',
#   'severe',
#   'medical',
#   'record.',
#   'cant',
#   '"manage',
#   'depression"',
#   'without',
#   'meds',
#   'therapy.',
#   'hate',
#   'retail',
#   'planet.',
#   "there's",
#   'no',
#   'help',
#   'people',
#   'like',
#   'me.',
#   'im',
#   'barred',
#   'medical',
#   'relief',
#   'money.'],
#  21: ['/2',
#   'world',
#   'inhabit.',
#   'much',
#   'despair.',
#   'hypocrisy',
#   'abounds.',
#   'anyway,',
#   "there's",
#   'much',
#   'solve.',
#   'depression,',
#   'homelessness,',
#   'hate,',
#   'name',
#   'few.',
#   "i'll",
#   'try',
#   'bit,',
#   'whether',
#   'buying',
#   'meals',
#   "mcd's",
#   'someone',
#   'street,',
#   'playing',
#   '"let',
#   'go"',
#   'often.',
#   '🕺🤦\u200d♀️'],
#  22: ['.',
#   'get',
#   'active',
#   'overweight',
#   'no',
#   'energy',
#   'anymore.',
#   'hate',
#   'way',
#   'look',
#   'photos',
#   'know',
#   'contributing',
#   'anxiety',
#   'depression.',
#   'need',
#   'get',
#   'moving.',
#   'combination',
#   'keeping',
#   'food',
#   'diary',
#   'working',
#   'lose',
#   'weight...'],
#  23: ['#tuesdaythoughts',
#   'no',
#   'wednesday',
#   'thanks',
#   'correcting',
#   'twitter.',
#   '#newyearseve',
#   'hate',
#   'a,',
#   'party',
#   'pooper',
#   'feel',
#   'like',
#   'sitting',
#   'alone.',
#   'fear',
#   '#depression',
#   'coming',
#   'back',
#   'somewhat.',
#   'hate',
#   'fake',
#   'fun',
#   'noone',
#   'knows',
#   'hard',
#   'day',
#   'day'],
#  24: ['like',
#   'people',
#   'hate',
#   'tiny',
#   'little',
#   'adorable',
#   'creatures',
#   'literally',
#   'cured',
#   'depression',
#   'around',
#   'them.',
#   'it’s',
#   'literally',
#   'impossible',
#   'hate',
#   'them!'],
#  25: ['no',
#   'pain',
#   'no',
#   'sadness',
#   'no',
#   'heartbreak',
#   'no',
#   'anxiety',
#   'no',
#   'depression',
#   'no',
#   'fake',
#   'people',
#   'no',
#   'hate',
#   'full',
#   'blessings',
#   'clearskin',
#   'self',
#   'love',
#   'high',
#   'grades',
#   'happiness',
#   'good',
#   'health',
#   'full',
#   'love',
#   'hope',
#   "'my'",
#   'year!'],
#  26: ["i'm",
#   'currently',
#   'state',
#   'motivation',
#   'anything',
#   'gone,',
#   'may',
#   'post',
#   'concert',
#   'depression,',
#   'may',
#   'cold',
#   'something',
#   'else',
#   "don't",
#   'know.',
#   'thing',
#   'know',
#   'hate',
#   'feeling',
#   '😕'],
#  27: ['israel’s',
#   'smile',
#   'literally',
#   'cured',
#   'depression',
#   'i’ve',
#   'never',
#   'seen',
#   'someone',
#   'cuter',
#   'smile',
#   'hate',
#   'man'],
#  28: ['no',
#   'pimples',
#   'no',
#   'sadness',
#   'no',
#   'fake',
#   'love',
#   'no',
#   'hate',
#   'no',
#   'depression',
#   'no',
#   'anxiety',
#   'no',
#   'heartbreaks',
#   'full',
#   'love',
#   'high',
#   'grades',
#   'blessed2020',
#   'self',
#   'love2020',
#   'healthy',
#   'lifestyle2020',
#   'safe',
#   'god’s',
#   'love',
#   'forever',
#   'hope',
#   'gonna',
#   '“my”',
#   'year.',
#   '#happynewyear2020'],
#  29: ['extremely',
#   'selfish',
#   'small.',
#   'hated',
#   'back',
#   'then.',
#   'nowadays,',
#   'depression',
#   'making',
#   'numb',
#   'emotions,',
#   'i’ve',
#   'prone',
#   'angry,',
#   'i’m',
#   'constantly',
#   'feeling',
#   'aching',
#   'pain.',
#   'hate',
#   'now.',
#   'im',
#   'glad',
#   'decided',
#   'share',
#   'this.',
#   'inspires',
#   'little'],
#  30: ['no',
#   'pimples',
#   'no',
#   'sadness',
#   'no',
#   'fake',
#   'love',
#   'no',
#   'hate',
#   'no',
#   'depression',
#   'no',
#   'anxiety',
#   'no',
#   'heartbreaks',
#   'full',
#   'love',
#   'high',
#   'grades',
#   'blessed2020',
#   'self',
#   'love2020',
#   'healthy',
#   'lifestyle2020',
#   'safe',
#   'god’s',
#   'love',
#   'forever',
#   'hope',
#   'gonna',
#   '“my”',
#   'year.'],
#  31: ['(t/w',
#   'negativity)',
#   'lmaooo',
#   'finally',
#   'looked',
#   'forward',
#   'spending',
#   'new',
#   'year’s',
#   'w',
#   'hometown',
#   'friends',
#   'apparently',
#   'we’re',
#   'not',
#   'meeting',
#   ':30',
#   'i’ll',
#   'spend',
#   'evening',
#   'nothing',
#   'w',
#   'fam',
#   'all.',
#   'hate',
#   'holidays',
#   'sm,',
#   'esp',
#   'new',
#   'year’s',
#   'eve.',
#   'depression',
#   'am.'],
#  32: ['no',
#   'pimples',
#   'no',
#   'sadness',
#   'no',
#   'fake',
#   'love',
#   'no',
#   'hate',
#   'no',
#   'depression',
#   'no',
#   'anxiety',
#   'no',
#   'heartbreaks',
#   'full',
#   'love',
#   'high',
#   'grades',
#   'blessed2020',
#   'self',
#   'love2020',
#   'healthy',
#   'lifestyle2020',
#   'safe',
#   'god’s',
#   'love',
#   'forever',
#   'hope',
#   'gonna',
#   '“my”',
#   'year.',
#   '#happynewyear2020'],
#  33: ['no',
#   'sadness',
#   'no',
#   'fake',
#   'friends2020',
#   'no',
#   'hate',
#   'no',
#   'depression',
#   'family',
#   'safety',
#   'no',
#   'pimples2020',
#   'full',
#   'love',
#   'high',
#   'grades',
#   'blessed2020',
#   'self',
#   'love2020',
#   'healthy',
#   'lifestyle2020',
#   'safe',
#   'god’s',
#   'love',
#   'forever',
#   'hope',
#   'best',
#   'year.',
#   '#happynewyear2020'],
#  34: ['no',
#   'pimples',
#   'no',
#   'sadness',
#   'no',
#   'fake',
#   'love',
#   'no',
#   'hate',
#   'no',
#   'depression',
#   'no',
#   'anxiety',
#   'no',
#   'heartbreaks',
#   'full',
#   'love',
#   'high',
#   'grades',
#   'blessed2020',
#   'self',
#   'love2020',
#   'healthy',
#   'lifestyle2020',
#   'safe',
#   'god’s',
#   'love',
#   'forever',
#   'hope',
#   'gonna',
#   '“my”',
#   'year.',
#   '#happynewyear2020'],
#  35: ['no',
#   'pimples',
#   'no',
#   'sadness',
#   'no',
#   'fake',
#   'love',
#   'no',
#   'hate',
#   'no',
#   'depression',
#   'no',
#   'anxiety',
#   'no',
#   'heartbreaks',
#   'full',
#   'love',
#   'high',
#   'grades',
#   'blessed2020',
#   'self',
#   'love2020',
#   'healthy',
#   'lifestyle2020',
#   'safe',
#   'god’s',
#   'love',
#   'forever',
#   'hope',
#   'gonna',
#   '“my”',
#   'year.',
#   '#happynewyear2020'],
#  36: ['no',
#   'pimples',
#   'no',
#   'sadness',
#   'no',
#   'fake',
#   'love',
#   'no',
#   'hate',
#   'no',
#   'depression',
#   'no',
#   'anxiety',
#   'no',
#   'heartbreaks',
#   'hydrated',
#   'full',
#   'love',
#   'high',
#   'grades',
#   'blessed',
#   'self',
#   'love',
#   'healthy',
#   'lifestyle',
#   'safe',
#   'god’s',
#   'love',
#   'forever',
#   'hope',
#   'gonna',
#   '“my”',
#   'year.'],
#  37: ['oof',
#   'depression',
#   'shot',
#   'up.',
#   'nico',
#   'bad',
#   'omen',
#   '%.',
#   'three',
#   'pulls',
#   'far',
#   'got',
#   'chika',
#   'sr.',
#   'fml',
#   'man...fuck',
#   'stars...why',
#   'hate',
#   'much..'],
#  38: ['#happynewyear2020',
#   'no',
#   'sadness',
#   'no',
#   'fake',
#   'love',
#   'no',
#   'hate',
#   'no',
#   'depression',
#   'no',
#   'anxiety',
#   'no',
#   'heartbreaks',
#   'full',
#   'love',
#   'blessed2020',
#   'self',
#   'love2020',
#   'healthy',
#   'lifestyle2020',
#   'safe',
#   'god’s',
#   'love',
#   'forever',
#   'hope',
#   'gonna',
#   '“my”',
#   'year.',
#   '#happynewyear2020'],
#  39: ['sometimes',
#   'depression',
#   'gets',
#   'bad',
#   'can’t',
#   'even',
#   'get',
#   'bed',
#   'shower',
#   'brush',
#   'teeth,',
#   'days.',
#   'hate',
#   '&amp;',
#   'causes',
#   'spiral',
#   'bc',
#   'self',
#   'loathing',
#   'really',
#   'takes',
#   'over.',
#   'it’s',
#   'probably',
#   'worst',
#   'symptom',
#   'clinical',
#   'depression.',
#   'like',
#   'can’t',
#   'even',
#   'basic',
#   'hygiene!?🤢'],
#  40: ['no',
#   'sadness',
#   'no',
#   'fake',
#   'love',
#   'no',
#   'hate',
#   'no',
#   'depression',
#   'no',
#   'anxiety',
#   'no',
#   'heartbreaks',
#   'full',
#   'love',
#   'high',
#   'grades',
#   'blessed2020',
#   'self',
#   'love2020',
#   'healthy',
#   'lifestyle2020',
#   'safe',
#   'god’s',
#   'love',
#   'forever',
#   'hope',
#   'gonna',
#   '“my”',
#   'year.',
#   '#happynewyear2020'],
#  41: ['lol',
#   'block',
#   'imagine',
#   'dragons',
#   'hate',
#   'tl?',
#   'dan',
#   'reynolds',
#   'changed',
#   'life',
#   'outlook',
#   'since',
#   'literally',
#   'people',
#   'pressed',
#   'he’s',
#   'successful?',
#   'he’s',
#   'always',
#   'preached',
#   'love,',
#   'depression',
#   'treatment,',
#   'lgbt',
#   'rights!',
#   'keep',
#   'hate',
#   'it’s',
#   'ugly'],
#  42: ['finished',
#   'registering',
#   'classes',
#   'spring.',
#   'sad',
#   'retake',
#   'class',
#   'maybe',
#   'new',
#   'campus',
#   'might',
#   'help',
#   'me.',
#   'hate',
#   'depression',
#   'anxiety',
#   'getting',
#   'way',
#   'future.',
#   'least',
#   "don't",
#   'want',
#   'die',
#   'like',
#   'used',
#   'to..'],
#  43: ['don’t',
#   'understand',
#   'everything',
#   'expensive,',
#   'mean',
#   'electronics',
#   'understand',
#   'hate',
#   'clothes',
#   'too.',
#   'you’re',
#   'independent',
#   'creator/stylist',
#   '(not',
#   'sure',
#   'call',
#   'them)',
#   'like',
#   'etsy',
#   'get',
#   'price',
#   'still',
#   'doesn’t',
#   'help',
#   'depression'],
#  44: ['sister',
#   ':',
#   'say',
#   '?',
#   'im',
#   'really',
#   'freaking',
#   'sorry',
#   'made',
#   'felt',
#   'way,',
#   'im',
#   'sorry',
#   'reason',
#   'severe',
#   'depression,',
#   'tried',
#   'best',
#   'remove',
#   'side',
#   'actually',
#   'cant',
#   'bcs',
#   'cared',
#   'abt',
#   'you.',
#   'im',
#   'sorry',
#   'hate',
#   'freaking',
#   'much.'],
#  45: ['no',
#   'pimples',
#   'no',
#   'sadness',
#   'no',
#   'fake',
#   'love',
#   'no',
#   'hate',
#   'no',
#   'depression',
#   'no',
#   'anxiety',
#   'no',
#   'heartbreaks',
#   'hydrated',
#   'full',
#   'love',
#   'high',
#   'grades',
#   'blessed',
#   'self',
#   'love',
#   'healthy',
#   'lifestyle',
#   'safe',
#   'god’s',
#   'love',
#   'forever',
#   'hope',
#   'gonna',
#   '“my”',
#   'year.'],
#  46: ['hate', 'depression', 'hits', 'times', 'really', 'forget', 'worth.'],
#  47: ['reason',
#   'family',
#   'hard',
#   'time',
#   'understanding',
#   'insomnia.',
#   'like',
#   'bro',
#   'it’s',
#   'not',
#   'hard',
#   'understand',
#   'means',
#   'depression',
#   'anxiety',
#   'hate',
#   'take',
#   'sleep'],
#  48: ['hate',
#   'friends',
#   'bc',
#   'theatre',
#   'watching',
#   'frozen',
#   'anna',
#   'singing',
#   'cave',
#   'mad',
#   'quiet',
#   'bitch',
#   'goes',
#   '“okay',
#   'bitch',
#   'called',
#   'depression”'],
#  49: ['&amp;',
#   'soft',
#   'hell',
#   'gon',
#   'hate',
#   'somebody',
#   'trying',
#   'help',
#   'people',
#   'battling',
#   'depression.',
#   'get',
#   'face',
#   'stupid',
#   'ass',
#   'shit.',
#   'wanna',
#   'make',
#   'change',
#   '&amp;',
#   'save',
#   'life’s',
#   'don’t',
#   'mean',
#   'gotta',
#   'hate',
#   'period.',
#   'keep',
#   'nigga'],
#  50: ['movies',
#   '/commercials',
#   '/talking',
#   'people',
#   '/tv',
#   '/thinking',
#   'much',
#   'love',
#   'friends/family',
#   '/the',
#   'cruelty/unfairness',
#   '/',
#   'hate',
#   'people',
#   'towards',
#   'others/animals',
#   'haven’t',
#   'i?',
#   'hormones/depression/anxiety/happiness.',
#   'goodness,',
#   'everything',
#   'makes',
#   'cry',
#   '(lol).',
#   'let',
#   'help',
#   'heal'],
#  51: ['hate', 'i’m', 'good', 'time', 'depression', 'kicks'],
#  52: ['really',
#   'really',
#   'hate',
#   'mentality',
#   'vid.',
#   'perhaps',
#   'less',
#   'serious',
#   'thing,',
#   'took',
#   'forever',
#   'find',
#   'doctor',
#   'would',
#   'take',
#   'depression',
#   'seriously',
#   'wanted',
#   'blame',
#   'lack',
#   'energy',
#   'weight.'],
#  53: ['hate',
#   'loner.',
#   'depression',
#   'makes',
#   'want',
#   'isolate',
#   'everyone.',
#   'it’s',
#   'endless',
#   'cycle',
#   'pain.',
#   'cause',
#   'i’m',
#   'social',
#   'butterfly',
#   'feel',
#   'odd',
#   'around',
#   'people',
#   'don’t',
#   'wanna',
#   'house',
#   '/7',
#   'idk',
#   'do.'],
#  54: ['i’m',
#   'nervous',
#   'he’s',
#   'going',
#   'say.',
#   'thought',
#   'handle',
#   'depression',
#   'ptsd',
#   'would',
#   'hate',
#   'back',
#   'worse',
#   'before.'],
#  55: ['i’m',
#   'tired',
#   'depression',
#   'poverty',
#   'shit',
#   'much',
#   'officially',
#   'hate',
#   'i’m',
#   'selling',
#   'soul',
#   'y’all'],
#  56: ['depression', 'easily', 'seen', 'eyes', 'hate'],
#  57: ['someone',
#   'suffers',
#   'severe',
#   'depression,',
#   'best',
#   'believe',
#   "i'm",
#   'taking',
#   'alive',
#   'fuckin',
#   'win.',
#   'hate',
#   'people',
#   'try',
#   'swerve',
#   'lane.',
#   'either',
#   'keep',
#   'stay',
#   'dumbasses',
#   '"keep',
#   'fuckery',
#   'myself"',
#   'lane'],
#  58: ['wish',
#   'trans.',
#   'hate',
#   'dealing',
#   'dysphoria.',
#   'best',
#   'friends',
#   'anxiety',
#   'depression.'],
#  59: ['woke',
#   'like',
#   '“wow',
#   'hate',
#   'myself!?!?”',
#   'laugh',
#   'like',
#   'oh',
#   'seasonal',
#   'depression',
#   'wait',
#   'til',
#   'solstice???',
#   'witchy',
#   'ass',
#   'moody',
#   'ass',
#   'cancer',
#   'ass',
#   'winter'],
#  60: ['come',
#   'hate',
#   'month',
#   'december',
#   '-',
#   'holidays',
#   'birthday',
#   'right',
#   'christmas',
#   'new',
#   'years.',
#   'miss',
#   'sun.',
#   'cannot',
#   'fight',
#   'demons.',
#   "i'm",
#   'expected',
#   'happy',
#   'festive.',
#   "life's",
#   'good',
#   'too,',
#   'seasonal',
#   'depression',
#   'monster.'],
#  61: ['decade',
#   'i:',
#   'hiked',
#   'milford',
#   'learned',
#   'spin',
#   'started',
#   'craft',
#   'business',
#   'learned',
#   'l',
#   'hate',
#   'retail,',
#   'love',
#   'code',
#   'gave',
#   'birth',
#   'quit',
#   'day',
#   'job',
#   'sahm',
#   'graduated',
#   'dev',
#   'bootcamp',
#   'baked',
#   'way',
#   'depression',
#   '-',
#   'bread,',
#   'pastry,',
#   'caramels,',
#   'macarons.',
#   'traveled',
#   'bunch',
#   'started',
#   'new',
#   'career'],
#  62: ['legit',
#   'exact',
#   'thing',
#   'happening',
#   'me.',
#   'like',
#   'depression',
#   'honestly',
#   'makes',
#   'feel',
#   'like',
#   'friends',
#   'hate',
#   "don't",
#   'care',
#   'know',
#   'real',
#   'people',
#   'actually',
#   'care',
#   '😊.'],
#  63: ["i've",
#   'spent',
#   'great',
#   'deal',
#   'career',
#   'trying',
#   'help',
#   'people,',
#   'depression,',
#   'anxiety',
#   'disorders,',
#   'bipolar',
#   'disorder',
#   'etc.',
#   'reason',
#   'social',
#   'workers',
#   'councelers',
#   'burnout',
#   'is,',
#   'hate',
#   'say',
#   'this,',
#   'people',
#   'beyond',
#   'help.',
#   'least',
#   'help.',
#   'good',
#   'talk.'],
#  64: ['really',
#   'hate',
#   'anxiety',
#   'depression',
#   'hits',
#   'nowhere,',
#   'i’m',
#   'happy',
#   'grateful',
#   'people',
#   'life',
#   'sucks',
#   'hurts',
#   'much',
#   'looking',
#   'back',
#   'missing',
#   'people',
#   'life',
#   'disappeared'],
#  65: ['god',
#   'fucking',
#   'hate',
#   'upset',
#   'still',
#   'tros',
#   'like',
#   'know',
#   'movie,',
#   'rlly',
#   'looking',
#   'forward',
#   'yrs',
#   'fuck',
#   'badly',
#   'top',
#   'already',
#   'severe',
#   'depression,',
#   'thanks',
#   'jj!'],
#  66: ['hate',
#   'random',
#   'spurts',
#   'depression',
#   'wanna',
#   'lay',
#   'bed',
#   'cry',
#   'hours'],
#  67: ['home',
#   'break',
#   'i’ve',
#   'fallen',
#   'high',
#   'school-style',
#   'depression.',
#   'hate',
#   'want',
#   'go',
#   'back',
#   'college.'],
#  68: ['depression',
#   'makes',
#   'feel',
#   'worthless',
#   'lazy.',
#   'time',
#   'contribute',
#   'nothing',
#   'house',
#   'besides',
#   'money',
#   'work',
#   'work',
#   'bc',
#   'to.',
#   'force',
#   'clean',
#   'smallest',
#   'bit',
#   'laundry.',
#   'hate'],
#  69: ['know',
#   'feel',
#   'cause',
#   'depression',
#   'anxiety',
#   'kick',
#   'ass',
#   'lot',
#   'absolutely',
#   'hate',
#   'it.'],
#  70: ['bro', 'room', 'gross,', 'hate', 'depression'],
#  71: ['me:',
#   'hate',
#   'talking',
#   'emotions',
#   'also',
#   'me:',
#   '*tweets',
#   'depression',
#   'every',
#   'mishap',
#   'happens',
#   'family',
#   'they’re',
#   'immensely',
#   'flawed',
#   'except',
#   'dad',
#   'love',
#   'dad*'],
#  72: ['i’m',
#   'not',
#   'sure',
#   'hate',
#   'binghamton',
#   'hate',
#   'i’m',
#   'not',
#   'los',
#   'angeles.',
#   'wait.',
#   'hate',
#   'binghamton.',
#   'growing',
#   'up,',
#   'could',
#   'not',
#   'wait',
#   'get',
#   'it’s',
#   'far',
#   'depressing',
#   'then.',
#   'productivity',
#   'level',
#   'drops',
#   'i’m',
#   'bc',
#   'flight',
#   'depression',
#   'day!'],
#  73: ['hate',
#   'downer',
#   'main',
#   'fr',
#   'worst',
#   'year',
#   'ive',
#   'ever',
#   'had.',
#   'lost',
#   'best',
#   'friends,',
#   'depression',
#   'worsened,',
#   'began',
#   'feeling',
#   's*icidal...im',
#   'v',
#   'grateful',
#   'amazing',
#   'experiences',
#   '&amp;',
#   'ppl',
#   'helped',
#   'im',
#   'v',
#   'ready',
#   'leave',
#   'past',
#   ':('],
#  74: [':',
#   'depression',
#   '+',
#   'got',
#   'heart',
#   'broken',
#   '+',
#   'depression',
#   ':',
#   'crippling',
#   'anxiety',
#   '+',
#   'crippled',
#   'myself/destroyed',
#   'knee',
#   '+',
#   'depression',
#   ':',
#   'keep',
#   'shit',
#   'im',
#   'fucking',
#   'deserted',
#   'island',
#   'forever',
#   'hate'],
#  75: ['ashamed',
#   'depression,',
#   'ashamed',
#   'anxiety,',
#   'it’s',
#   'crippling',
#   'me,',
#   'can’t',
#   'go',
#   'mind',
#   'fucking',
#   'paranoia',
#   'sees',
#   'hate',
#   'everyone’s',
#   'eyes!',
#   '&amp;',
#   'like',
#   'song',
#   'says',
#   'drugs',
#   'don’t',
#   'work!’',
#   'thank',
#   'god',
#   'therapy',
#   'would',
#   'psych',
#   'ward!'],
#  76: ['negative',
#   'stuff:',
#   '-',
#   'brother',
#   'suffers',
#   'depression,',
#   'psychatrie',
#   'weeks',
#   'everyone',
#   'home',
#   'down,',
#   'tough',
#   'guy',
#   'time.',
#   'brother',
#   'tried',
#   'kill',
#   'himself.',
#   '-',
#   'lost',
#   'friends',
#   'year',
#   'hate',
#   'people',
#   'come',
#   'go',
#   'unfortunately.'],
#  77: ['hate',
#   'global',
#   'warming',
#   'much',
#   'educated',
#   'human',
#   'degree',
#   'weather',
#   'wonders',
#   'seasonal',
#   'depression'],
#  78: ['that’s',
#   'hate',
#   'depression.',
#   'says',
#   'joy',
#   'anything.',
#   'audial',
#   'escapes',
#   'hope',
#   'don’t',
#   'work.',
#   'luckily',
#   'able',
#   'build',
#   'lego',
#   'set',
#   'days.',
#   'sessions.',
#   'wife',
#   'got',
#   'play',
#   'game',
#   'last',
#   'night.',
#   'enjoyed',
#   'time',
#   'play.',
#   'appreciate'],
#  79: ['lose',
#   'weight',
#   'gained',
#   'recently',
#   'depression',
#   '&amp;',
#   'pray',
#   'something',
#   'awful',
#   'happens',
#   'lump',
#   'lard',
#   'say',
#   'karma',
#   'bitch',
#   'well',
#   'please',
#   'worse',
#   'hate',
#   'man',
#   '&amp;',
#   'country.'],
#  80: ['jesus.',
#   'despise',
#   'instagram.',
#   'never',
#   'hated',
#   'app',
#   'hate',
#   'app.',
#   'no,',
#   'doesn’t',
#   'anything',
#   'seasonal',
#   'depression.',
#   'fuck',
#   'off.'],
#  81: ['tw:',
#   ':',
#   'still',
#   'school.',
#   'still',
#   'hate',
#   'it.',
#   'develop',
#   'severe',
#   'depression',
#   'make',
#   'attempts',
#   'life.'],
#  82: ['think',
#   'lucky',
#   "don't",
#   'possess',
#   'suicidal',
#   'thoughts',
#   'anymore,',
#   'enough',
#   'self-esteem',
#   'not',
#   'actively',
#   'hate',
#   'myself,',
#   "don't",
#   'tend',
#   'lash',
#   'anger.',
#   'screening',
#   'anxiety',
#   'depression,',
#   'symptoms',
#   'always',
#   'mild',
#   '"okay"',
#   'think...'],
#  83: ['well',
#   'done',
#   'it,',
#   'could',
#   'not',
#   'take',
#   'anymore',
#   'christmas',
#   'tree',
#   '🎄',
#   'taken',
#   'down.',
#   'christmas',
#   'difficult',
#   'alone',
#   'parents',
#   'dead,',
#   'tree',
#   '🎄',
#   'go.',
#   'hate',
#   'christmas',
#   'time',
#   'always',
#   'plays',
#   'depression'],
#  84: ['mental',
#   'health',
#   'sometimes',
#   'taboo',
#   'subject.',
#   'suffer',
#   'ptsd',
#   'anxiety,',
#   'hate',
#   'say',
#   'depression',
#   'sadly',
#   'suffer',
#   'it.',
#   'real',
#   'life',
#   'hide',
#   'well,',
#   'laugh',
#   'smile',
#   'lot',
#   'wear',
#   'bright',
#   'clothes',
#   'armour',
#   'protect',
#   'me.'],
#  85: ['coincidences.',
#   'kept',
#   'comming.',
#   'so,',
#   'one',
#   'month',
#   'ago,',
#   'told',
#   'sister',
#   'suspicions',
#   'may',
#   'adhd',
#   'told',
#   'hers.',
#   'now,',
#   "i'm",
#   'serious',
#   'mental',
#   'problems,',
#   'someone',
#   "who's",
#   'depression',
#   'anxiety',
#   'hate',
#   'hear',
#   'people',
#   'use',
#   'like',
#   "they're"],
#  86: ['hate',
#   'leaving',
#   'hometown',
#   'family.',
#   'moving',
#   'away',
#   'home',
#   'college.',
#   'friends',
#   'have.',
#   'that’s',
#   'type',
#   'post',
#   'graduate',
#   'depression',
#   'no',
#   'one',
#   'talks',
#   'about.'],
#  87: ['#datamustfall',
#   'terrible',
#   'pains',
#   'heart,',
#   'could',
#   'sign',
#   'stroke🤔been',
#   'stressing',
#   'lot',
#   'lately,',
#   'depression',
#   'dealing',
#   'accordingly,',
#   'unemployed',
#   'killed',
#   'homeless',
#   'tomorrow😭',
#   'oh',
#   'god',
#   'life',
#   'mess',
#   'hate',
#   'it💔💔😭'],
#  88: ['hate', 'depression', 'kicks', 'ass', 'bad', 'can’t', 'get', 'bed'],
#  89: ["don't",
#   'take',
#   'many',
#   'pictures',
#   'cus',
#   'overall',
#   'hate',
#   'year',
#   'ago',
#   'gotten',
#   'hair',
#   'cut.',
#   'feeling',
#   'good',
#   'doesnt',
#   'happen',
#   'often',
#   'anxiety',
#   'depression',
#   'not',
#   'best',
#   'picture',
#   'hope',
#   'work',
#   'loving',
#   'even',
#   'lil'],
#  90: ['depression/anxiety',
#   'medication',
#   'damn',
#   'numb',
#   'shit',
#   'it’s',
#   'ridiculous',
#   '😭',
#   'smoke',
#   'weed',
#   'instead',
#   'taking',
#   'shit.',
#   'hate',
#   'feeling',
#   'like'],
#  91: ['rape',
#   'victim',
#   'promise',
#   'years',
#   'depression,',
#   'anxiety,',
#   'self',
#   'hate,',
#   'etc.',
#   'weren’t',
#   'favorable',
#   'me.',
#   'say',
#   'something',
#   'like',
#   'disgusting',
#   'completely',
#   'untrue.',
#   'time',
#   'not,',
#   'women',
#   'aren’t',
#   'believed',
#   'nothing',
#   'done',
#   'attackers,',
#   'stay',
#   'quiet.'],
#  92: ['hate',
#   'away',
#   'cat',
#   'hours',
#   'days',
#   'would',
#   'send',
#   'depression',
#   'roof.',
#   "he's",
#   'kitty',
#   'therapy.',
#   'helps',
#   'keep',
#   'depression',
#   'control'],
#  93: ['broke',
#   'up,',
#   "can't",
#   'even',
#   'recognise',
#   'myself.',
#   'suffered',
#   'severe',
#   'depression',
#   'anxiety.',
#   'current',
#   'dose',
#   'mg',
#   'venlafaxine.',
#   "can't",
#   'sleep',
#   'without',
#   'sleeping',
#   'pills.',
#   'till',
#   'now,',
#   'hate',
#   'myself.',
#   "can't",
#   'find',
#   'reason',
#   'love',
#   'myself..',
#   'stupid',
#   "isn't?"],
#  94: ['hate',
#   'dad',
#   'disgusting',
#   'pig',
#   'really',
#   'really',
#   'is,',
#   'abusive',
#   'fucking',
#   'cunt',
#   'i’m',
#   'fucking',
#   'glad',
#   'left',
#   'kid',
#   'put',
#   'much',
#   'depression,',
#   'well',
#   'least',
#   'haven’t',
#   'killed',
#   'yet',
#   'thankful',
#   'for.'],
#  95: ['broke',
#   'years',
#   'relationship.',
#   'caused',
#   'suffer',
#   'severe',
#   'depression',
#   'anxiety.',
#   'current',
#   'dose',
#   'mg',
#   'venlafaxine.',
#   "can't",
#   'even',
#   'sleep',
#   'without',
#   'sleeping',
#   'pills.',
#   'still',
#   'x',
#   'bole',
#   'cope',
#   'dgan',
#   'diri',
#   'sndiri.',
#   'hate',
#   'too..',
#   'hmm'],
#  96: ['going',
#   'ok',
#   'though',
#   'would',
#   'hate',
#   'see',
#   'depression',
#   'bring',
#   'like',
#   'that,',
#   'hopefully',
#   'make',
#   'believe',
#   'honest',
#   'heart',
#   '♥'],
#  97: ['damn', 'hate', 'shit', 'jus', 'thinking', 'way', 'depression', '😪'],
#  98: ['depression',
#   'really',
#   'fucks',
#   'no',
#   'reason',
#   'honestly',
#   'hate',
#   'especially',
#   'cant',
#   'explain',
#   "what's",
#   'going',
#   'tell',
#   'someone',
#   "i'm",
#   'actually',
#   'fine',
#   "i'm",
#   'sad',
#   'no',
#   'reason',
#   'brain',
#   'hates',
#   'like',
#   'hey',
#   'depressed',
#   "i'm",
#   'like',
#   'now?...'],
#  99: ['seasonal',
#   'depression',
#   'period',
#   'gets',
#   'severely',
#   'feels.',
#   'got',
#   'crying',
#   'smallest',
#   'things',
#   'damn',
#   'hate',
#   'hella',
#   'emotional'],
#  100: ['see,',
#   'hate',
#   'seeing',
#   'wastage',
#   'like',
#   'this.',
#   'gives',
#   'flash',
#   'depression.',
#   'heart',
#   'experienced',
#   'mild',
#   'surge',
#   'now.'],
#  101: ['please',
#   'forgive',
#   'her,i',
#   'use',
#   'hate',
#   'mother',
#   'not',
#   'knowing',
#   'depression',
#   'worse',
#   'raised',
#   'woman',
#   'suffered',
#   'depression',
#   '(',
#   'grandmother)',
#   'please',
#   'ask',
#   'childhood'],
#  102: ['feel', 'depression', 'creeping', 'back', 'hate'],
#  103: ['(5/7)',
#   '-',
#   'put',
#   'last',
#   'energy',
#   'last',
#   'batch',
#   'commission.',
#   'i’m',
#   'tired.',
#   'i’m',
#   'bad.',
#   '-',
#   '***',
#   'i’m',
#   'dead',
#   'full',
#   'month.',
#   'going',
#   'full',
#   'life.',
#   'stress',
#   'depression',
#   'hit.',
#   'hate',
#   'life.',
#   'here?',
#   'even',
#   'exist?'],
#  104: ['brother',
#   'engineer.',
#   'used',
#   'hate',
#   'smoking.he',
#   'always',
#   'advised',
#   'dad',
#   'stop',
#   'smoking.',
#   'started',
#   'face',
#   'pressure',
#   ',',
#   'depression',
#   'alot',
#   'responsibilities.',
#   'ended',
#   'smoker',
#   'really',
#   'hurt',
#   '.',
#   'sometimes',
#   'smoking',
#   'doesnt',
#   'mean',
#   'r',
#   'bad',
#   'one',
#   '!'],
#  105: ['thank',
#   'posting',
#   'this.',
#   'hate',
#   'anxiety',
#   'depression.',
#   'needed',
#   'see',
#   'feel',
#   'better'],
#  106: ['depression', 'seriously', 'make', 'pessimistic', 'hate'],
#  107: ['hate',
#   'months',
#   'jan-march',
#   'tbh',
#   'makes',
#   'depression',
#   'intense',
#   'anyone',
#   'else',
#   'feel',
#   'way??'],
#  108: ['battle',
#   'depression',
#   'every',
#   'single',
#   'day',
#   'days',
#   'hate',
#   'everything',
#   'myself.',
#   'super',
#   'self',
#   'conscience.',
#   'told',
#   'ugly',
#   'whole',
#   'life.',
#   'still',
#   'go',
#   'everyday',
#   'try',
#   'best.'],
#  109: ['reminds',
#   'fortune',
#   'cookie',
#   'haha,',
#   'one',
#   'hope',
#   'depression',
#   'inevitably',
#   'die',
#   'sooner',
#   'later,',
#   'hate',
#   'days',
#   'like'],
#  110: ['obviously',
#   "i've",
#   'sad',
#   'shit.',
#   'wake',
#   'pm',
#   'barely',
#   'post',
#   'bc',
#   "i'm",
#   'busy',
#   'watching',
#   'netflix',
#   'shows',
#   'hate',
#   'using',
#   'energy',
#   'write',
#   'music',
#   "that's",
#   'boring.',
#   'fine',
#   'happens',
#   'every',
#   'year',
#   "i'll",
#   'cool',
#   'soon',
#   'fix',
#   'depression',
#   'light'],
#  111: ['anxiety', 'depression', 'sucks.', 'hard.', 'hate', 'brain', 'right'],
#  112: ['tomorrow',
#   'new',
#   'year.',
#   'oh',
#   'god.',
#   'end',
#   'test',
#   'me.',
#   'even',
#   'sometimes',
#   'seemed',
#   'shit',
#   'not',
#   'happening',
#   'me.',
#   'understood',
#   'depression',
#   'betrayal',
#   'are.',
#   'hate',
#   'reading',
#   'anyone',
#   "else's",
#   'posts',
#   'like',
#   'this.',
#   'talking',
#   'about...'],
#  113: ['not',
#   'magical!',
#   'apathy',
#   'magicals,',
#   'detriment',
#   'person.',
#   'hate',
#   'v.',
#   'interesting',
#   'bed',
#   'bugs',
#   'eating,',
#   'least',
#   'them,',
#   'seems',
#   'me.',
#   'eating',
#   'good.',
#   'appetite',
#   'back.',
#   'depression',
#   'gone',
#   ':)'],
#  114: ['irritating',
#   'medical',
#   'marijuana',
#   'difficult',
#   'expensive',
#   'thing',
#   'live.',
#   'depression',
#   'meds',
#   'work',
#   'depression',
#   'make',
#   'anxiety',
#   'skyrocket,',
#   'weed/cbd',
#   'helps',
#   'depression',
#   'anxiety.',
#   'hate',
#   'living',
#   'here.',
#   'hate',
#   'south',
#   'east.'],
#  115: ['hate',
#   'cliche',
#   'weight',
#   'loss.',
#   'dont',
#   'feel',
#   'myself.',
#   'im',
#   'tired',
#   'time.',
#   'depression',
#   'time',
#   'high',
#   'year....',
#   'trimming',
#   'weight,',
#   'getting',
#   'head',
#   'better',
#   'space,',
#   'maybe',
#   'going',
#   'back',
#   'therapy.',
#   '#imatter',
#   '#selfcare',
#   '#gettingmeback'],
#  116: ['trying',
#   'combat',
#   'depression',
#   '/',
#   'self',
#   'hate',
#   'look',
#   'bright',
#   'side'],
#  117: ['every',
#   'time',
#   'run',
#   'depression,',
#   'catches',
#   'me.',
#   'hate',
#   'state',
#   'mind.'],
#  118: ['need',
#   'clean',
#   'closet',
#   'out;',
#   'i’m',
#   'starting',
#   'hate',
#   'everything',
#   'i’m',
#   'wearing',
#   'ugh.',
#   'maybe',
#   'it’s',
#   'depression',
#   'talking',
#   'i’m',
#   'like',
#   'ugh',
#   'lol'],
#  119: ['literally',
#   'nothing',
#   'hate',
#   'manic',
#   'depression',
#   'n',
#   'badly',
#   'affects',
#   'rships',
#   'friends/family'],
#  120: ['hate',
#   'twits',
#   'much',
#   'like',
#   'sitting',
#   'little',
#   'apartment',
#   'parents',
#   'took',
#   'loan',
#   'trying',
#   'escape',
#   'depression',
#   'much',
#   'can,',
#   'buying',
#   'reusable',
#   'shopping',
#   'bags',
#   'sorting',
#   'plastic',
#   'bottles',
#   'feel',
#   'bad.',
#   'want',
#   'twit'],
#  121: ['hate',
#   'anxiety',
#   'depression...i',
#   'use',
#   'two',
#   'days',
#   'sleep',
#   'day',
#   'need',
#   'recharge',
#   'work',
#   'week....but',
#   'weekend',
#   'gone',
#   'no',
#   'time',
#   'things',
#   'actually',
#   'like'],
#  122: ['autumn',
#   'winter',
#   'bring',
#   'many',
#   'favourite',
#   'things',
#   'like',
#   'rust',
#   'coloured',
#   'long',
#   'coats',
#   'cozy',
#   'jumpers.',
#   'also',
#   'brings',
#   'high',
#   'anxiety',
#   'deepest',
#   'depression',
#   'phases',
#   "i've",
#   'ever',
#   'in.',
#   'love',
#   'hate',
#   'time',
#   'year.',
#   'thank',
#   'baring',
#   'time'],
#  123: ['hate',
#   'everything',
#   'going',
#   'rn',
#   ',',
#   'depression',
#   'disappointments',
#   'really',
#   'want',
#   'smth',
#   'change',
#   'mood'],
#  124: ['hate',
#   'christmas',
#   'new',
#   'year.',
#   'hate',
#   "valentine's",
#   'day',
#   'too.',
#   'partly',
#   'due',
#   'ridiculous',
#   'pressure',
#   'work',
#   'hours',
#   'festive',
#   'sales',
#   'period',
#   'rest',
#   'personal',
#   'reasons.',
#   'always',
#   'puts',
#   'depression',
#   'anxiety',
#   'roof.',
#   'gets',
#   'paranoia',
#   'insecurity',
#   'worst'],
#  125: ['think',
#   '“ah',
#   'maybe',
#   'depression',
#   'would',
#   'eased',
#   'friends”',
#   'someone',
#   'internet',
#   'posts',
#   'opinion',
#   'remember',
#   'everything',
#   'awful',
#   'hate',
#   'people.'],
#  126: ['since',
#   'injury',
#   'suffered',
#   'worst',
#   'headaches',
#   'depression',
#   'sound',
#   'worse',
#   'really',
#   'hope',
#   'works',
#   'out...',
#   'take',
#   'many',
#   'pills',
#   'hate'],
#  127: ['hate', 'mom', 'doesn’t', 'understand', 'means', 'depression'],
#  128: ['new',
#   'years',
#   'holiday',
#   'hate',
#   'flares',
#   'anxiety/depression',
#   'much',
#   'want',
#   'get'],
#  129: ['thank',
#   'you.',
#   'really',
#   'appreciate',
#   'that.',
#   'i’m',
#   'trying',
#   'best.',
#   'talk',
#   'wife',
#   'last',
#   'night',
#   'breaking',
#   'again.',
#   'i’m',
#   'really',
#   'hoping',
#   'get',
#   'good',
#   'place',
#   'soon.',
#   'hate',
#   'depression',
#   'undying',
#   'passion.'],
#  130: ['hate',
#   'everyone',
#   'behind',
#   'making',
#   'tragedy',
#   'movie.',
#   'think',
#   'kill',
#   'last',
#   'skywalker',
#   'think',
#   'that’s',
#   '“hopeful',
#   'happy',
#   'ending”',
#   'ben',
#   'skywalker',
#   'line?',
#   'horrible',
#   'put',
#   'back',
#   'depression.',
#   'thanks,',
#   'assholes.'],
#  131: ['kinda',
#   'fucking',
#   'hate',
#   'winter',
#   'whole',
#   'seasonal',
#   'depression',
#   'shit,',
#   'like',
#   'bro',
#   'already',
#   'depression',
#   'bitch',
#   'names',
#   'winter',
#   'think',
#   'fuck',
#   'upset',
#   'feel',
#   'even',
#   'more.'],
#  132: ['/2',
#   'hour',
#   'visit',
#   'long',
#   'time',
#   'friend',
#   'today',
#   'battles',
#   'anxiety',
#   '&amp;',
#   'depression.',
#   'one',
#   'candid',
#   '&amp;',
#   'heartfelt',
#   'talks',
#   'ever',
#   'shared.',
#   'grateful',
#   'friend',
#   'sharing',
#   'story.',
#   'hour',
#   'left,',
#   'curled',
#   'panic',
#   'attack.',
#   'hate',
#   'this.'],
#  133: ['anxiety',
#   'seasonal',
#   'depression',
#   'kicking',
#   'ass',
#   '✌',
#   'want',
#   'hang',
#   'friends',
#   'also',
#   'make',
#   'believe',
#   'hate',
#   '🙃'],
#  134: ['u',
#   'ever',
#   'feel',
#   'like',
#   'you’re',
#   'big',
#   'huge',
#   'ginormous',
#   'mess?',
#   'feel',
#   'like',
#   'absolutely',
#   'hate',
#   'myself,',
#   'whenever',
#   'i’m',
#   'around',
#   'family',
#   'feel',
#   'like',
#   'i’m',
#   'letting',
#   'no',
#   'reason,',
#   'even',
#   'promise',
#   'i’m',
#   'not',
#   ':(',
#   'depression',
#   'rly',
#   'big',
#   'fat',
#   'black',
#   'cloud',
#   'sigh'],
#  135: ['ls,',
#   "i've",
#   'come',
#   'conclusion',
#   'quitting',
#   'twitter',
#   '#1',
#   'way',
#   'block',
#   'toxicity.',
#   "i've",
#   'enjoyed',
#   'reading',
#   'tweets',
#   '-they',
#   'often',
#   'lightened',
#   'day-',
#   "can't",
#   'overcome',
#   'depression',
#   "i'm",
#   'venom,',
#   'hate',
#   'lies',
#   'spewed',
#   'platform.',
#   '#byebyetwitter'],
#  136: ['hate', 'winter.', 'triggers', 'depression.'],
#  137: ['hilfe',
#   'bei',
#   'depression',
#   'rt',
#   ':',
#   'cannot',
#   'enjoy',
#   'birthday?',
#   'train',
#   'vicky',
#   'want',
#   'cry.',
#   'hate',
#   'feeling',
#   'like',
#   'this.',
#   't…'],
#  138: ['it’s',
#   'list',
#   'ever',
#   'since',
#   'came',
#   'out,',
#   'really',
#   'liked',
#   'concept',
#   'wanted',
#   'give',
#   'shot',
#   'started',
#   'getting',
#   'loop',
#   'reason',
#   'didn’t',
#   'drop',
#   'lincoln,',
#   'he’s',
#   'dead',
#   'it’s',
#   'giving',
#   'depression',
#   ':)',
#   'fucking',
#   'hate',
#   'show'],
#  139: ['cannot',
#   'enjoy',
#   'birthday?',
#   'train',
#   'vicky',
#   'want',
#   'cry.',
#   'hate',
#   'feeling',
#   'like',
#   'this.',
#   'f**king',
#   '#depression',
#   'killing',
#   'slowly',
#   'every',
#   'day.',
#   '#mentalhealth'],
#  140: ['depression',
#   'hit',
#   'hard',
#   'lastnight!',
#   'often',
#   'get',
#   'mixed',
#   'emotions',
#   'like',
#   'time',
#   'year!',
#   'joys',
#   'complex',
#   'mental',
#   'health',
#   'issues',
#   '😢',
#   'struggling!',
#   'believe',
#   'better',
#   '&amp;',
#   'hate',
#   'i’m',
#   'not.',
#   'issues!',
#   'it’s',
#   'doesn’t',
#   'mean',
#   'im',
#   'ungrateful',
#   '💗'],
#  141: ['feel',
#   'depression',
#   'creeping',
#   'back',
#   'way',
#   'used',
#   'hate',
#   'man',
#   'no',
#   'one',
#   'understands',
#   'bad',
#   'hate',
#   'feeling',
#   'depressed',
#   'not'],
#  142: ['depression',
#   'lately',
#   'screaming',
#   'no',
#   'one',
#   'appreciates',
#   'anything',
#   'do,',
#   'whole',
#   'prep',
#   'time',
#   'convinced',
#   'everyone',
#   'going',
#   'either',
#   'hate',
#   'everything',
#   'not',
#   'care.',
#   'know',
#   'what?',
#   'everyone',
#   'loved',
#   'it.',
#   'ton',
#   'fun',
#   'meeting',
#   'abnormal',
#   'day'],
#  143: ['anxiety',
#   '&amp;',
#   'depression',
#   '&amp;',
#   'chronic',
#   'headaches',
#   'literally',
#   'affect',
#   'every',
#   'aspect',
#   'life..',
#   'hate',
#   'it..',
#   'tv',
#   'movies',
#   'make',
#   'little',
#   'bit',
#   'better,',
#   'thank',
#   'everyone',
#   'letting',
#   'talk',
#   'goddamn',
#   'much'],
#  144: ['state',
#   'depression,',
#   'started',
#   'notice',
#   'often',
#   'movies',
#   'feel',
#   'need',
#   'romance',
#   'it,',
#   'even',
#   'not',
#   'warranted',
#   'genre.',
#   'hate',
#   'much',
#   'right',
#   'now!',
#   'like,',
#   'i’m',
#   'trying',
#   'get',
#   'distracted',
#   'miseries,',
#   'don’t',
#   'wanna',
#   'see',
#   'nobody',
#   'kiss',
#   'fuck',
#   'ffs'],
#  145: ['there’s',
#   'new',
#   'year',
#   'coming.',
#   'honestly',
#   'plan',
#   'better',
#   'comes',
#   'mental',
#   'health.',
#   'kick',
#   'depression',
#   'slay',
#   'demon',
#   'self',
#   'hate',
#   'low',
#   'esteem.',
#   'think',
#   'owe',
#   'try',
#   'happier.',
#   'lets',
#   'raise',
#   'energy',
#   '#newyearsresolution'],
#  146: ['first',
#   'impression',
#   'hate',
#   'depression',
#   'entire',
#   'personality,',
#   'gonna',
#   'tough',
#   'build',
#   'conversation.',
#   'okay',
#   'vent',
#   'never',
#   'anything',
#   'constructive',
#   'future-thinking',
#   'say,',
#   'going',
#   'real',
#   'hard.'],
#  147: ["i'm",
#   'glad',
#   'employer',
#   'understands',
#   'mental',
#   'health',
#   'work/life',
#   'balance',
#   'addition',
#   'understanding',
#   'depression',
#   'might',
#   'not',
#   'able',
#   'many',
#   'things',
#   'thought',
#   'could.',
#   'hate',
#   'lot',
#   'workplaces',
#   'think',
#   'people',
#   'work',
#   '"better".'],
#  148: ['made',
#   'entire',
#   'life.',
#   'like',
#   'wish',
#   'level',
#   'please',
#   "don't",
#   'die',
#   'get',
#   'meet',
#   'carry',
#   'legacy...',
#   'get',
#   'it.',
#   'depression',
#   'sucks',
#   'people',
#   'suck',
#   'even',
#   'harder.',
#   'keep',
#   'pushing',
#   'queen.',
#   'hate',
#   'cause',
#   "ain't",
#   'you.'],
#  149: ['hate',
#   'disabilities',
#   'holidays',
#   'deep',
#   'depression',
#   'hits.',
#   'former',
#   'cutter',
#   'hurting',
#   'myself.',
#   'either',
#   'outside',
#   'family',
#   "doesn't",
#   'get',
#   'siblings',
#   "don't",
#   'get',
#   'me.',
#   'say',
#   'something',
#   'tries',
#   'confuse',
#   'make'],
#  150: ["i'm",
#   'behind',
#   'man',
#   'mo',
#   'temple',
#   'wan',
#   'chai,',
#   'catching',
#   'leaves',
#   'calm',
#   'mind.',
#   "i'm",
#   'definitely',
#   'not',
#   'sitting',
#   'stewing',
#   'anger',
#   'depression,',
#   'ruminating',
#   'much',
#   'hate',
#   'fucking',
#   'life.',
#   'everything',
#   'fine.',
#   'music',
#   'beautiful.',
#   'mind',
#   'polished',
#   'mirror.',
#   'yes.'],
#  151: ['i’m',
#   'sad',
#   'tonight',
#   'idk',
#   'why.',
#   'ugh.',
#   'can’t',
#   'sleep,',
#   'minds',
#   'racing.',
#   'hate',
#   'depression.'],
#  152: ['think',
#   'might',
#   'idea',
#   'im',
#   'always',
#   'tired.',
#   '.',
#   'depression',
#   'no',
#   'help',
#   'it.',
#   '.',
#   'im',
#   'tired',
#   'non',
#   'escapable',
#   'situation.',
#   'poorer',
#   'dirt,',
#   'got',
#   'no',
#   'food,',
#   'im',
#   'tired',
#   'awake',
#   'see',
#   'fucked',
#   'are.',
#   'hate',
#   'life,',
#   'sleep',
#   'escape',
#   'it.'],
#  153: ['god,',
#   'hate',
#   'stage',
#   '#depression',
#   'don’t',
#   'even',
#   'motivation',
#   'thing',
#   'usually',
#   'distact',
#   'depression.',
#   'know',
#   'i’ll',
#   'fine,',
#   'end,',
#   'hope',
#   'anyone',
#   'reading',
#   'needs',
#   'hear',
#   'knows',
#   'same.'],
#  154: ['aaaaaand',
#   'depression',
#   'back.',
#   'it’s',
#   'fun',
#   'days,',
#   'hate',
#   'everyone',
#   'crawling',
#   'back',
#   'bed',
#   'forever.',
#   '#breatheinbreatheout',
#   '#onedayatatime'],
#  155: ['hate',
#   'depression,',
#   'hate',
#   'overthinking,',
#   'hate',
#   'overprotective,',
#   'hate',
#   'ocd,',
#   'hate',
#   'anxiety,',
#   'hate',
#   'schizophrenia,',
#   'hate',
#   'ways.',
#   'nothing',
#   'ever',
#   'seems',
#   'help',
#   'try',
#   'fix',
#   'problems.',
#   'im',
#   'done'],
#  156: ['hi',
#   '👋',
#   'i’m',
#   'danish',
#   'artist.',
#   'current',
#   'addition',
#   'depression',
#   'statistics.',
#   'trying',
#   'overcome',
#   'disease',
#   'art',
#   'therapy.',
#   'fully',
#   'resisting',
#   'hate',
#   'right',
#   'wing',
#   'movement',
#   'russian',
#   'agent',
#   'white',
#   'house.',
#   'hope',
#   'well.'],
#  157: ['hate',
#   'get',
#   'sick',
#   'like',
#   'this,',
#   'depression',
#   'episodes',
#   'start',
#   'start',
#   'thinking',
#   'lonely',
#   'really',
#   'feel...'],
#  158: ['hate',
#   'moments',
#   'im',
#   'like',
#   '"hm',
#   'maybe',
#   "don't",
#   'hate',
#   'body"',
#   'crippling',
#   'feeling',
#   '"maybe',
#   'im',
#   'not',
#   'trans',
#   'man',
#   'im',
#   'actually',
#   'experience',
#   'extreme',
#   'mental',
#   'breakdown',
#   'hating',
#   'body',
#   'like',
#   'women',
#   'im',
#   'exaggerating',
#   'depression"'],
#  159: ['hate',
#   'work,',
#   'hate',
#   'school,',
#   'i’m',
#   'absolute',
#   'degenerate',
#   'wasting',
#   'away',
#   'late',
#   'capitalism',
#   'high',
#   'functioning',
#   'depression.',
#   'layed',
#   'bed',
#   'past',
#   'days',
#   'slept',
#   'not',
#   'saying',
#   'word',
#   'job',
#   'can’t',
#   'count',
#   'many',
#   'times',
#   'i’ve',
#   'done',
#   'past.',
#   'don’t',
#   'care.'],
#  160: ['/feeling',
#   'mix',
#   'emotions',
#   'right',
#   'now...sad...part',
#   'wants',
#   'curl',
#   'ball',
#   'cry,',
#   'part',
#   'wishes',
#   'someone',
#   'hang',
#   'with/talk',
#   'rn...k',
#   'family,',
#   'sissies',
#   'sick',
#   'not',
#   'around...i',
#   'hate',
#   'way',
#   'feel...like',
#   'depression'],
#  161: ['dont',
#   'know',
#   'anymore',
#   'really,',
#   'world',
#   'dark,',
#   'shit,',
#   'getting',
#   'worse',
#   'destroys',
#   'faith',
#   'hope',
#   'daily.',
#   'hate',
#   'myself,',
#   'dont',
#   'want',
#   'awake',
#   'days.',
#   'depression',
#   'like',
#   'fucking',
#   'roller',
#   'coaster',
#   'days.'],
#  162: ['hate',
#   'get',
#   'feeling',
#   'i’m',
#   'fine',
#   'sudden',
#   'depression',
#   'hits',
#   'no',
#   'again,',
#   'especially',
#   'i’m',
#   'good',
#   'place',
#   'life',
#   ':('],
#  163: ['hate',
#   'depression',
#   'people',
#   'ask',
#   'details',
#   'past',
#   'like',
#   'bitch',
#   'i’m',
#   'starting',
#   'play',
#   'shit',
#   'give',
#   'minute'],
#  164: ['telling',
#   'boy',
#   'psychiatrist',
#   'getting',
#   'checked',
#   'cfs',
#   'instead',
#   'depression',
#   'hate',
#   'men',
#   'much'],
#  165: ['can’t',
#   'bare',
#   'even',
#   'look',
#   'face',
#   'can’t',
#   'create',
#   'art',
#   'sheer',
#   'amount',
#   'self',
#   'hate',
#   'point.',
#   'genuinely',
#   'say',
#   'depression',
#   'never',
#   'bad',
#   'i’m',
#   'working',
#   'finding',
#   'again.'],
#  166: ['i’m',
#   'trying',
#   'not',
#   'let',
#   'depression',
#   'win',
#   'not',
#   'one',
#   'soul',
#   'check',
#   'christmas.',
#   'son’s',
#   'grandmother',
#   'took',
#   'house',
#   'could',
#   'use',
#   'wifi',
#   'take',
#   'family’s',
#   'house.',
#   'couldn’t',
#   'say',
#   'no.',
#   'won’t',
#   'stop',
#   'fun',
#   'hate',
#   'stewart’s.'],
#  167: ['hate',
#   'internally.',
#   'whenever',
#   'someone',
#   'talks',
#   'something',
#   'wants',
#   'something',
#   'wanna',
#   'know',
#   'also',
#   'do.',
#   'feel',
#   'like',
#   'soloed',
#   'depression',
#   'consumes',
#   'more.'],
#  168: ["i'm",
#   'sorry',
#   'came',
#   'across',
#   'trying',
#   'gain',
#   'sympathy..',
#   'far',
#   'it.',
#   'main',
#   'point',
#   'understand',
#   'care!',
#   'hate',
#   'see',
#   'others',
#   'suffering',
#   'depression',
#   'know',
#   'feels',
#   'like..',
#   'truly',
#   'hope',
#   'find',
#   'way',
#   'out!'],
#  169: ['hello',
#   'iys',
#   'depression',
#   'hours',
#   'bc',
#   'i’m',
#   'drunk',
#   'i’m',
#   'convinced',
#   'friend',
#   'hate',
#   'x'],
#  170: ['depression',
#   'feeling',
#   'lonely',
#   'even',
#   'group',
#   'friends.',
#   'anxiety',
#   'always',
#   'making',
#   'think',
#   'friends',
#   'hate',
#   'tells',
#   'do.'],
#  171: ['nothing',
#   'pisses',
#   'people',
#   'say',
#   'think',
#   'fix',
#   'depression',
#   'eating',
#   'certain',
#   'foods',
#   'exercising',
#   'whatever',
#   'bullshit.',
#   'don’t',
#   'think',
#   'could',
#   'fix',
#   'fucking',
#   'would?',
#   'don’t',
#   'enjoy',
#   'this.',
#   'fucking',
#   'hate',
#   'this,',
#   'actually.',
#   'thanks',
#   'much.',
#   '👌🏻🙄😒'],
#  172: ['hate',
#   'say',
#   'it,',
#   'do.',
#   'it’s',
#   'always',
#   'around',
#   'birthday',
#   'kinda',
#   'depressing.',
#   'rather',
#   'not',
#   'much',
#   'around',
#   'time.',
#   'friends',
#   'don’t',
#   'like',
#   'let',
#   'sit',
#   'ur',
#   'depression',
#   'kinda',
#   'nice.',
#   'sometimes',
#   '😂'],
#  173: ['hate',
#   'depression',
#   'bc',
#   'wait',
#   'long',
#   'pick',
#   'antidepressants',
#   'pharmacy',
#   'dont',
#   'energy',
#   'motivation',
#   'walk',
#   'minutes',
#   'get',
#   'id',
#   'rather',
#   'lie',
#   'bed',
#   'rot'],
#  174: ['hate',
#   'talk',
#   'bout',
#   'depression',
#   'first',
#   'thing',
#   'say',
#   'pretty',
#   'sad',
#   '?',
#   'tf',
#   'mental',
#   'emotional',
#   'health'],
#  175: ['depression', 'back', 'hate'],
#  176: ['hope',
#   'make',
#   'friends',
#   'grad',
#   'school',
#   'want',
#   'stuff',
#   'me.',
#   'i’m',
#   'i’ve',
#   'basically',
#   'done',
#   'seen',
#   'nothing',
#   '🤦🏽\u200d♀️',
#   '&amp;',
#   'everybody',
#   'wonder',
#   'depression',
#   'bad.',
#   'cause',
#   'spend',
#   'time',
#   'alone..',
#   'really',
#   'hate'],
#  177: ['yeah,',
#   'sucks.',
#   'depression',
#   'like',
#   'heavily.',
#   'legit',
#   'hate',
#   "doesn't",
#   'freaking',
#   'go',
#   'away',
#   'days',
#   'months.',
#   '._.'],
#  178: ['wish',
#   'someone',
#   'talk',
#   'depression',
#   ',',
#   'hate',
#   'getting',
#   'deep',
#   'thoughts',
#   'feelings',
#   '.',
#   'hate',
#   'feeling',
#   'sad',
#   'miserable,',
#   'ian',
#   'trippin',
#   'thuggin',
#   'years',
#   'na',
#   '..'],
#  179: ['guy',
#   'responsible',
#   'current',
#   'state',
#   'anguish',
#   'depression',
#   'getting',
#   'high',
#   'five',
#   'queen.',
#   'world',
#   'fuckity',
#   'bye',
#   'bye',
#   'atm.',
#   'hate',
#   'it.'],
#  180: ['thanks',
#   'comments.',
#   'think',
#   'depression',
#   'caused',
#   'health',
#   'issues',
#   'not',
#   'helping',
#   'matters.',
#   'i’m',
#   'struggling',
#   'find',
#   'positives',
#   'anything',
#   'honest.',
#   'hate',
#   'feeling',
#   'like',
#   'this,',
#   'pain',
#   'over,',
#   'feel',
#   'weak',
#   'no',
#   'energy,',
#   'it’s',
#   'hard',
#   'upbeat.'],
#  181: ['things',
#   'get',
#   'worse,',
#   'fell',
#   'back',
#   'depression,',
#   'started',
#   'mounting',
#   'hate',
#   'again.',
#   'bottled',
#   'anger,',
#   'bursted',
#   'wrong',
#   'person,',
#   'wrong',
#   'time.'],
#  182: ['honestly',
#   'kind',
#   'hate',
#   'end',
#   'year',
#   '-',
#   'sunk',
#   'hard',
#   'depression',
#   'time',
#   'consistently',
#   '&amp;',
#   'start',
#   'question',
#   'much',
#   'around',
#   'music,',
#   'artist,',
#   '&amp;',
#   'want',
#   'life.',
#   'trying',
#   'positive,',
#   'gets',
#   'hard',
#   'time',
#   'year.'],
#  183: ['it’s',
#   'not',
#   'even',
#   'yet',
#   'already',
#   'feel',
#   'like',
#   'crying',
#   'no',
#   'reason.',
#   'hate',
#   'depression.',
#   'least',
#   'i’m',
#   'going',
#   'today',
#   'that’s',
#   'nice',
#   'distraction,',
#   'hate',
#   'fact',
#   'need',
#   'distraction',
#   'get',
#   'day',
#   'without',
#   'crying.',
#   'that’s',
#   'not',
#   'normal',
#   ':/'],
#  184: ['evening',
#   'rough,',
#   'may',
#   'hate',
#   'life',
#   'moment',
#   'know',
#   'wont',
#   'hate',
#   'life',
#   'wake',
#   'up,',
#   'not',
#   'life',
#   'bad,',
#   'depression'],
#  185: ['drastically',
#   'changed',
#   'appearance',
#   'bc',
#   "don't",
#   'know',
#   'deal',
#   'depression',
#   'negative',
#   'feelings',
#   'hate',
#   'look,,,',
#   'kidding,,,,',
#   'unless?'],
#  186: ['depression',
#   'here...',
#   'kicking',
#   'butt...',
#   'making',
#   'hate',
#   'everything',
#   'i’ve',
#   'worked',
#   'ass',
#   'for.',
#   'shit',
#   'exhausting.'],
#  187: ['depression',
#   'can’t',
#   'get',
#   'it.',
#   'i’m',
#   'stuck',
#   'it.',
#   'dealing',
#   'since',
#   'elementary',
#   'school',
#   'tbh.',
#   'even',
#   'since',
#   'kids.',
#   'hate',
#   'stuff',
#   'makes',
#   'person',
#   'feel',
#   'self',
#   'times',
#   'smh',
#   'hate'],
#  188: ['hate',
#   'someone',
#   "i've",
#   'known',
#   'year',
#   'half',
#   'trashtalking',
#   'friends',
#   'behind',
#   'scenes',
#   'pulling',
#   'depression',
#   'card'],
#  189: ['environmental',
#   'not,',
#   'depression',
#   'depression.',
#   'medication',
#   'treats',
#   'depression,',
#   'not',
#   'specifically',
#   'non-environmental',
#   'depression.',
#   'trust',
#   'me,',
#   'live',
#   'place',
#   'absolutely',
#   'hate,',
#   'meds',
#   'help',
#   'cope',
# ...
#   'bed',
#   ':('],
#  928: ['hi',
#   'im',
#   'sarawakian',
#   '%',
#   'agree',
#   'w',
#   'u!!',
#   '🙌',
#   'ngl',
#   'almost',
#   'sarawakian',
#   'open',
#   'minded',
#   'kpop.',
#   'never',
#   'gain',
#   'hate',
#   'locals',
#   'interest',
#   'kpop',
#   'moved',
#   'kl',
#   'meleis',
#   'judgemental',
#   'way',
#   'minor',
#   'depression',
#   "i'm",
#   'stressing',
#   'lmao',
#   '💀'],
#  929: ['hate', 'depression', 'fucking', 'much'],
#  930: ['depression',
#   'bad',
#   'today.',
#   'everyone',
#   'keeps',
#   'asking',
#   'what’s',
#   'wrong.',
#   'keep',
#   'saying',
#   'i’m',
#   'tired.',
#   'want',
#   'reach',
#   'friends',
#   'don’t',
#   'want',
#   'burden',
#   'bc',
#   'technically',
#   'nothing',
#   'wrong.',
#   'hate',
#   'this.'],
#  931: ['going',
#   'great!!',
#   '😩',
#   'don’t',
#   'think',
#   'guys',
#   'understand',
#   'prosperous',
#   'year',
#   'going',
#   'be.',
#   'no',
#   'drama.',
#   'no',
#   'negativity.',
#   'no',
#   'hate.',
#   'nooooo',
#   'depression.',
#   'i’m',
#   'fighting',
#   'positivity',
#   'love.',
#   'whatever',
#   'set',
#   'heart',
#   'on❤️',
#   'mine🥳🙏🏾'],
#  932: ['sometimes',
#   'hate',
#   'i’m',
#   'easily',
#   'affected',
#   'weather!',
#   'lack',
#   'sun',
#   'not',
#   'help',
#   '#depression',
#   'brought',
#   '#bipolardisorder',
#   '.',
#   'today',
#   'sun',
#   'shining',
#   'i’m',
#   'going',
#   'ride',
#   'cheer',
#   'brings.'],
#  933: ['hate',
#   'people',
#   'touch',
#   'hair,',
#   'honestly',
#   'probably',
#   'feels',
#   'like',
#   'depression',
#   'dry',
#   'shampoo.'],
#  934: ['thank',
#   'you!!',
#   ';v',
#   ';',
#   'hate',
#   'head',
#   'works',
#   'depression',
#   'anxiety,',
#   "i'm",
#   'always',
#   'bit',
#   'surprised',
#   'taken',
#   'aback',
#   'friends',
#   'let',
#   'know',
#   "i'm",
#   'good',
#   'talk',
#   "i'm",
#   'sdhjfbasgj',
#   'appreciate',
#   'sentiment',
#   'immensely',
#   '❤️❤️'],
#  935: ['see',
#   'millions',
#   'posts',
#   'end',
#   'every',
#   'single',
#   'year',
#   'like',
#   '“please',
#   'destroy',
#   'year”',
#   '“me',
#   'start',
#   'year',
#   'vs',
#   'end”',
#   '“worst',
#   'year',
#   'life”',
#   'etc.',
#   'ever',
#   'considered',
#   'maybe',
#   'hate',
#   'life',
#   'general?',
#   'perhaps',
#   'suffer',
#   'depression!'],
#  936: ['i’m',
#   'gymnastics',
#   'competition',
#   'lowkey',
#   'miss',
#   'passion',
#   'something',
#   'commit',
#   'to💔',
#   'depression',
#   'rlly',
#   'taking',
#   'whole',
#   'life',
#   'hate'],
#  937: ['hate',
#   'hair',
#   'not',
#   'done,',
#   'feel',
#   'like',
#   'i’m',
#   'going',
#   'depression',
#   '🤦🏾\u200d♀️'],
#  938: ['really',
#   'hate',
#   'sleeping',
#   'doesnt',
#   'make',
#   'depression',
#   'go',
#   'away'],
#  939: ['hate',
#   'depression',
#   'makes',
#   'comeback',
#   'anytime',
#   'go',
#   'home',
#   'visit',
#   'family',
#   ':)'],
#  940: ['hate',
#   'winters.',
#   'yes',
#   'it’s',
#   'birthday',
#   'season',
#   'really',
#   'hate',
#   'it..',
#   'cold,',
#   'lack',
#   'fun,',
#   'seasonal',
#   'depression..',
#   'yep'],
#  941: ['love',
#   'rustic',
#   'coffee',
#   'houses',
#   'exposed',
#   'brick.',
#   'hate',
#   'leaving',
#   'house.',
#   'either',
#   'move',
#   'coffee',
#   'shop',
#   'go',
#   'full',
#   'reno',
#   'place.',
#   'bad',
#   'depression',
#   'ensures',
#   'no',
#   'energy',
#   'anything',
#   'consider',
#   'i’d',
#   'sims.'],
#  942: ['lovely',
#   '#xmas',
#   'dinner',
#   'family',
#   'they’ve',
#   'gone,',
#   'true',
#   'true',
#   'passion',
#   'depression',
#   'hate',
#   'tweeting'],
#  943: ['heartbroken,depression,hate,stress,sadness',
#   'going',
#   'mind',
#   'don’t',
#   'ask',
#   'what’s',
#   'wrong'],
#  944: ['kind..',
#   'gave',
#   'articles',
#   'suspicion..',
#   '“white”',
#   'it.',
#   'it’s',
#   'suicide',
#   'depression.',
#   'they’re',
#   '“black”',
#   'hung.',
#   'i’m',
#   'not',
#   'saying',
#   'racism',
#   'isn’t',
#   'fucking',
#   'around.',
#   'guys',
#   'act',
#   'like',
#   'hanging',
#   'people',
#   'streets.',
#   'you’re',
#   'literally',
#   'keeping',
#   'hate👌',
#   'good',
#   'job'],
#  945: ['anyone',
#   'else',
#   'get',
#   'post-semester',
#   'depression?',
#   'fucking',
#   'hate',
#   'school',
#   'took',
#   'last',
#   'final',
#   'today',
#   'it’s',
#   'like',
#   'idk',
#   'something'],
#  946: ['lol,',
#   'find',
#   'fault',
#   'least',
#   'half',
#   'list!!!',
#   'hate',
#   'working',
#   'out,',
#   'struggle',
#   'depression',
#   'overweight,',
#   'two',
#   'step-kids,',
#   'curse',
#   '(sometimes',
#   'like',
#   'sailor)',
#   '&amp;after',
#   'that,',
#   '&amp;maybe',
#   'more,',
#   'managed',
#   'find',
#   '-in-a-lifetime',
#   '&amp;father',
#   'daughter'],
#  947: ['depression', 'sucks', 'hate', 'it.'],
#  948: ['problem',
#   'knowing',
#   'anxiety/',
#   'depression',
#   'constant',
#   'circle',
#   'going',
#   '“all',
#   'people',
#   'hate',
#   'talking',
#   'me”',
#   '“that’s',
#   'probably',
#   'anxiety',
#   'talking”',
#   '“actually',
#   'no',
#   'don’t',
#   'know',
#   'probably',
#   'hate',
#   'me.”',
#   'repeat.'],
#  949: ['hate',
#   'depression',
#   'literally',
#   'wanted',
#   'hang',
#   'friend',
#   'planned',
#   'cancelled',
#   'wasn’t',
#   'mentally',
#   'regret',
#   'i’d',
#   'like',
#   'company',
#   ':/'],
#  950: ['fucking',
#   'depression',
#   'tho',
#   'rn...',
#   'kicked',
#   'hella',
#   'hard.',
#   'hate',
#   'shit.'],
#  951: ['depression',
#   'sucks,being',
#   'alone',
#   'sucks,being',
#   'complicated',
#   'everything,depression',
#   'like',
#   'war,u',
#   'either',
#   'win',
#   'die',
#   'trying,i',
#   'hate',
#   'life!,my',
#   'life',
#   'like',
#   'burden',
#   'everyone.but,just',
#   'pretend',
#   'im',
#   'ok',
#   'im',
#   'happier',
#   'infont',
#   'peoples,just',
#   'little',
#   'bit',
#   'time,love',
#   'everyone',
#   'make',
#   'u',
#   'sucks'],
#  952: ['tw//',
#   'self',
#   'harm,',
#   'alcoholic,',
#   'depression',
#   'dad',
#   'drank',
#   'told',
#   'wouldn’t',
#   'mouthwash',
#   'gum',
#   'clear',
#   'smell',
#   'could',
#   'still',
#   'tell',
#   'mom',
#   'could',
#   'too,',
#   'told',
#   'go',
#   'back',
#   'room',
#   'side',
#   'hate',
#   'this-'],
#  953: ['someone',
#   "who's",
#   'struggled',
#   'depression',
#   'life,',
#   'always',
#   'worries',
#   'see',
#   'people',
#   'say',
#   'things',
#   'like',
#   'this.',
#   'know',
#   'gets',
#   'lot',
#   'hate,',
#   "don't",
#   'want',
#   'see',
#   'anyone',
#   'die.',
#   "there's",
#   'much',
#   'that.',
#   '#gethelp',
#   '#suicideprevention'],
#  954: ['mood',
#   'hate',
#   'life',
#   'im',
#   'gonna',
#   'rewatch',
#   'skins',
#   'trigger',
#   'depression',
#   'feelin',
#   'tew',
#   'good',
#   'lately'],
#  955: ["there's",
#   'honestly',
#   'no',
#   'way',
#   'anyone',
#   'could',
#   'hate',
#   'you.',
#   'someone',
#   "who's",
#   'also',
#   'struggled',
#   'depression',
#   'past,',
#   'even',
#   'though',
#   'managed',
#   'get',
#   'own,',
#   'done',
#   'myself.',
#   'beyond',
#   'glad',
#   'decided',
#   'seek',
#   'help',
#   'got',
#   'troubles.'],
#  956: ['i’m',
#   'plus',
#   'sized',
#   'black',
#   'woman',
#   'first',
#   'heard',
#   'coconut',
#   'oil',
#   'cried',
#   'cried',
#   'played',
#   'repeat',
#   'it’s',
#   'much',
#   'something',
#   'pulled',
#   'depression',
#   'self',
#   'hate.'],
#  957: ['hate',
#   'days',
#   'idk',
#   'it’s',
#   'depression',
#   'sed,',
#   'dam',
#   'ears',
#   'three',
#   'i’m',
#   'tired',
#   'want',
#   'crawl',
#   'bed',
#   'never',
#   'get',
#   'out.',
#   'fight',
#   'it’s',
#   'today’s',
#   'tough',
#   'day',
#   'fight.',
#   'hopefully',
#   'horror',
#   'distract',
#   'me.'],
#  958: ['depression',
#   'anxiety',
#   'bad',
#   'enough',
#   'own,',
#   'add',
#   'loneliness',
#   'mix,',
#   'becomes',
#   'recipe',
#   'mental',
#   'health',
#   'disaster....',
#   'fuck',
#   'hate',
#   'life....'],
#  959: ['hate',
#   'holiday',
#   'depression.',
#   'broke',
#   'work.',
#   'brain',
#   'telling',
#   'me,',
#   'congrats',
#   'fail',
#   'qa',
#   'tester',
#   'streamer',
#   'since',
#   'no',
#   'sign',
#   'improvement',
#   'since',
#   'last',
#   'year.',
#   "i'm",
#   'going',
#   'lay',
#   'try',
#   'get',
#   'happy',
#   'zone',
#   'more.'],
#  960: ['hate', 'friday', 'night', 'depression'],
#  961: ['official....i',
#   'hate',
#   'depression',
#   'like',
#   'fucking',
#   'much!',
#   'wish',
#   'would',
#   'disappear',
#   'life!',
#   'please',
#   'leave',
#   'not',
#   'welcome',
#   'here!',
#   '#depression',
#   '#furrydepression',
#   '#goaway'],
#  962: ['couple',
#   'shit',
#   'feeds',
#   'released',
#   'depression',
#   'i’ve',
#   'masking.',
#   'want',
#   'give',
#   'everything.',
#   'hate',
#   'holidays.',
#   'hate',
#   'everything.',
#   'goodnight'],
#  963: ['one',
#   'thing',
#   'hate',
#   'anxiety/depression',
#   'december',
#   'keeps',
#   'enjoying',
#   'things',
#   'love',
#   'like',
#   'music.',
#   'played',
#   'music',
#   'radio',
#   'car',
#   'month.'],
#  964: ['generally',
#   'try',
#   'vague',
#   'less',
#   'ranty',
#   'fuck',
#   'hate',
#   'period.',
#   'hurts,',
#   'it’s',
#   'gross,',
#   'fucks',
#   'anxiety',
#   'depression',
#   'makes',
#   'nightmare.',
#   'it’s',
#   'absolute',
#   'bullshit',
#   'loathe',
#   'it.',
#   'fuck',
#   'periods.',
#   'feel',
#   'better',
#   'lol'],
#  965: ['hate', 'depression', 'kick'],
#  966: ['disagree,',
#   'lot',
#   'people',
#   'depression',
#   'could',
#   'feel',
#   'better',
#   'knew',
#   'caused',
#   'diet.',
#   'mom',
#   'pmdd,',
#   'moved',
#   'ate',
#   'healthier',
#   'depression',
#   'went',
#   'away.',
#   'i’ve',
#   'house',
#   'two',
#   'weeks',
#   'hate',
#   'everything',
#   'everyone.'],
#  967: ['(2/2)',
#   'depression',
#   'fucking',
#   'real',
#   'awful.',
#   'hate',
#   'food',
#   'service',
#   'industry,',
#   'hate',
#   'money',
#   'hate',
#   'corrupt',
#   'entire',
#   'world',
#   'is.',
#   'nothing',
#   'change',
#   'though.',
#   'votes',
#   'never',
#   'mean',
#   'shit',
#   'long',
#   'run.',
#   'wife,',
#   'friends',
#   'pokemon',
#   'keep',
#   'going'],
#  968: ['really',
#   'hate',
#   'winter.',
#   'skin',
#   'always',
#   'fucking',
#   'dry.',
#   'it’s',
#   'cold',
#   'look',
#   'cute.',
#   'sun',
#   'gone.',
#   'it’s',
#   'one',
#   'big',
#   'depression.'],
#  969: ['no',
#   'one',
#   'live.',
#   'hate',
#   'much.',
#   'depression',
#   'time',
#   'high.',
#   'sucks',
#   ':('],
#  970: ['hate', 'get', 'depression', 'fucking', 'nowhere'],
#  971: ['seasonal',
#   'depression',
#   'thing?',
#   '😭',
#   'whole',
#   'mood',
#   'changes',
#   'winter',
#   'time',
#   'lol',
#   'hate',
#   'it’s',
#   'always',
#   'damn',
#   'gloomy',
#   'dark'],
#  972: ['hate',
#   'depression.',
#   'feels',
#   'like',
#   "i'm",
#   'constantly',
#   'fighting',
#   'myself.',
#   'hate',
#   'feeling',
#   'disgusting',
#   "can't",
#   'even',
#   'get',
#   'bed',
#   'brush',
#   'teeth',
#   'eat.',
#   'sucks'],
#  973: ['hate',
#   'people',
#   'try',
#   'relate',
#   'depression',
#   'like',
#   'it’s',
#   'not',
#   'bonding',
#   'exercise'],
#  974: ['doctors',
#   'wanted',
#   'prescribe',
#   'medication',
#   'depression',
#   'not',
#   'taking',
#   'no',
#   'medicine,',
#   'literally',
#   'hate',
#   'taking',
#   'pills',
#   'shit.',
#   'don’t',
#   'even',
#   'take',
#   'medicine',
#   'get',
#   'monthly',
#   'deal',
#   'wit',
#   'pain.'],
#  975: ['depression', 'real.', 'hate', 'life'],
#  976: ['im',
#   'tired',
#   'feeling',
#   'bad',
#   'depressed',
#   'weight',
#   'look',
#   ':(',
#   'effecting',
#   'life',
#   'much...',
#   'dont',
#   'know',
#   "anymore:'(",
#   'hate',
#   '#ihatemyself',
#   '#help',
#   '#depression',
#   '#depressed',
#   '#upset',
#   '#selfhate'],
#  977: ['like',
#   'post',
#   'lot',
#   'depression',
#   'stuff',
#   'like',
#   'that.people',
#   "don't",
#   'follow',
#   'others',
#   'look',
#   'people',
#   'depressed.and',
#   'not',
#   'good',
#   'cause',
#   'make',
#   'people',
#   'depressed.this',
#   'opinion',
#   "don't",
#   'get',
#   'like',
#   'hate',
#   'something',
#   'really',
#   'like',
#   'posts.✌🏼'],
#  978: ['depression',
#   'may',
#   'caught',
#   'ass.',
#   'absolutely',
#   'hate',
#   'see',
#   'it.'],
#  979: ['hate',
#   'depression..',
#   'lot',
#   'right',
#   'no',
#   'way',
#   'give',
#   'kids',
#   'christmas',
#   'year...'],
#  980: ['hate',
#   'depression..',
#   'lot',
#   'right',
#   'no',
#   'way',
#   'give',
#   'kids',
#   'christmas',
#   'year...'],
#  981: ['ex',
#   'came',
#   'get',
#   'last',
#   'night',
#   'shit',
#   'hit',
#   'fan.',
#   'held',
#   'night',
#   'cried',
#   'hate',
#   'people',
#   'trigger',
#   'anxiety',
#   'depression.'],
#  982: ['know',
#   'pain',
#   'suffer',
#   'from.',
#   'part',
#   'every',
#   'day',
#   'struggles',
#   'fighting',
#   'depression',
#   'comes',
#   'feeling',
#   'like',
#   "can't",
#   "don't",
#   'contribute',
#   'enough.',
#   'hate',
#   'feel',
#   'like',
#   'burden',
#   'live',
#   'government.',
#   'daily',
#   'fight.'],
#  983: ["i'm",
#   'usually',
#   'not',
#   'festive',
#   'around',
#   'time',
#   'year,',
#   'get',
#   'pretty',
#   'wicked',
#   'seasonal',
#   'depression.',
#   'hate',
#   'cold,',
#   'grey,',
#   'icy',
#   'weather.',
#   'usually',
#   'hide',
#   'house',
#   'lol',
#   '😂😭🙌'],
#  984: ['hate',
#   'no',
#   'smoke..',
#   '🙄🤦🏽\u200d♀️',
#   'mind',
#   'gets',
#   'racing',
#   'thoughts',
#   'take',
#   'over..',
#   '#depression'],
#  985: ['ikr!',
#   'i’ve',
#   'struggling',
#   'depression',
#   'young',
#   'age,',
#   'lupus.',
#   'self',
#   'harmed',
#   'too,',
#   'hate',
#   'seeing',
#   'idiots',
#   'making',
#   'jokes',
#   'things',
#   'like',
#   'that.'],
#  986: ['bone',
#   'deep',
#   'sticking',
#   'ribs',
#   'better',
#   'part',
#   'years',
#   'depression/burn',
#   'year',
#   'really',
#   'making',
#   'feel',
#   'worse.',
#   "i'm",
#   'much',
#   'medication',
#   'hate',
#   'internet',
#   "doesn't",
#   'care',
#   'creators.'],
#  987: ['idk',
#   'what‘s',
#   'wrong',
#   'today',
#   'can‘t',
#   'stop',
#   'crying',
#   'hate',
#   'fucking',
#   'depression',
#   'much'],
#  988: ['grandparents',
#   'lived',
#   'great',
#   'depression',
#   'ww2',
#   'living',
#   'germany.',
#   'remember',
#   'grandmother',
#   'talking',
#   'many',
#   'backed',
#   'hitler',
#   'first',
#   'gave',
#   'food',
#   'jobs',
#   'also',
#   'kept',
#   'distracted',
#   'hate',
#   'many',
#   'never',
#   'realized',
#   'late'],
#  989: ['rut',
#   'art',
#   'wise.',
#   "don't",
#   'even',
#   'know',
#   'do.',
#   'start',
#   'something,',
#   'either',
#   'hate',
#   'it,',
#   'quit',
#   "can't",
#   'seem',
#   'draw',
#   'pose/character',
#   'properly.',
#   "i'm",
#   'sure',
#   'related',
#   'anxiety',
#   '+',
#   'depression,',
#   'ignore',
#   'ranting.',
#   'screaming',
#   'void'],
#  990: ['no.',
#   'not',
#   'stand',
#   'me.',
#   'gay,',
#   'non',
#   'binary,',
#   'depression',
#   'anxiety',
#   'riddled,',
#   'working',
#   'class',
#   'citizen.',
#   'hate',
#   'existence',
#   'being.',
#   'not',
#   'support',
#   'people',
#   'like',
#   'me.'],
#  991: ['hate',
#   'school',
#   'teachers.',
#   'literally',
#   'good',
#   'thing',
#   'classmates',
#   '(1st',
#   'time',
#   'ever',
#   'happens)',
#   'idk',
#   "i'm",
#   'gonna',
#   'get',
#   'years',
#   'deep',
#   'depression',
#   'says',
#   'hi'],
#  992: ['not',
#   'poland:d',
#   'have:',
#   'great:',
#   '"worst',
#   'day',
#   'life!"',
#   'pretty',
#   'good:',
#   '"i',
#   'hate',
#   'life!"',
#   'so-so:',
#   '"i',
#   'depression"',
#   'not',
#   'good:',
#   '"never',
#   'felt',
#   'worse"',
#   'better:',
#   '"..."',
#   'terrible:',
#   '"f',
#   'off"'],
#  993: ['i’ve',
#   'kinda',
#   'hard',
#   'time',
#   'last',
#   'months,',
#   'i’ve',
#   'underlying',
#   'depression',
#   'that’s',
#   'tearing',
#   'since',
#   'summer.',
#   'hate',
#   'complaining',
#   'it,',
#   'live',
#   'decent',
#   'life',
#   'enjoy',
#   'job',
#   'bf',
#   'travel',
#   'lot',
#   'ugh',
#   'fuuuck'],
#  994: ['i’m',
#   'disappointed',
#   'nastiness',
#   'going',
#   'round.',
#   'friends',
#   'son',
#   'involved',
#   'awful',
#   'tragedy',
#   'last',
#   'week',
#   'resulted',
#   'year',
#   'old',
#   'boy',
#   'losing',
#   'life.',
#   'people',
#   'need',
#   'realise',
#   'nastiness',
#   'voting',
#   'breeds',
#   'depression',
#   'hate.',
#   'bullet',
#   'mind!',
#   'happy!',
#   'life',
#   'short.'],
#  995: ['really',
#   'don’t',
#   'think',
#   'anyone',
#   'suffering',
#   'depression',
#   'would',
#   'behave',
#   'like',
#   'does.',
#   'last',
#   'thing',
#   'want',
#   'negativity',
#   'opinion',
#   'would',
#   'insite',
#   'much',
#   'hate',
#   'upset',
#   '?'],
#  996: ["ronoh's",
#   'videofor',
#   'reading',
#   'hate',
#   'comments',
#   'someone:',
#   'people',
#   'say',
#   'suffer',
#   'depression',
#   'ronoh:',
#   'yes',
#   'big',
#   'depression',
#   'back',
#   'ass',
#   '😭🤣🤣🤣🤣🤣🤣🤣🤣🤣🤣🤣🤣🤣🤣🤣🤣🤣🤣🤣🤣🤣🤣🤣🤣',
#   'yes',
#   'sis'],
#  997: ['hate',
#   'cant',
#   'handle',
#   'depression..',
#   'kena',
#   'ka',
#   'juga',
#   'fikir',
#   'bila',
#   'kau',
#   'tak',
#   'mau',
#   'fikir..😭😭😭'],
#  998: ['know',
#   'aggressively',
#   'treat',
#   'physical',
#   'pain,',
#   'depression',
#   'vanishes.',
#   'requires',
#   'pain',
#   'meds',
#   'society',
#   'thinks',
#   'acceptable,',
#   'instead',
#   'hate',
#   'time.'],
#  999: ['offered',
#   'one',
#   'last',
#   'month.',
#   'said',
#   'would',
#   'help',
#   'depression',
#   'well.',
#   'told',
#   '"i\'ve',
#   'success',
#   'this."',
#   "that's",
#   'line',
#   'fucking',
#   'hate;',
#   'means',
#   'nothing.',
#   'drug',
#   'side',
#   'effect',
#   'doc',
#   'warned',
#   'nymphomania.']}

# %%
from nltk.tokenize.treebank import TreebankWordDetokenizer

# %%
TreebankWordDetokenizer().detokenize(tweets_clean_dict[1])
# Out:
# 'hate walk back depression den i’ve completely altered shower'

# %%
# Here we detokenize all the tweets
detokenized_dict = {}
for key, items in tweets_clean_dict.items():
    detokenized_dict[key] = TreebankWordDetokenizer().detokenize(tweets_clean_dict[key])
# detokenized_dict

# %%
detokenized_dict[0]
# Out:
# "many shootings, many lives lost evil people power, much hate, much depression, not nearly enough change stop that. i'm gonna apartment hoping every bang hear tonight firework, hoping people celebrate life without fear"

# %%
detokenized_df = pd.DataFrame.from_dict(detokenized_dict, orient='index')

# %%
detokenized_df.head(10)
detokenized_df.rename(columns={0:'pre_processed'}, inplace=True)

# %%
from transformers import AutoModelForSequenceClassification
from transformers import TFAutoModelForSequenceClassification
from transformers import AutoTokenizer
import numpy as np
from scipy.special import softmax
import csv
import urllib.request

# %%
# Here we're using the roberta-base models 
task1='sentiment'
MODEL1 = f"cardiffnlp/twitter-roberta-base-{task1}"
tokenizer1 = AutoTokenizer.from_pretrained(MODEL1)

task2='emotion'
MODEL2 = f"cardiffnlp/twitter-roberta-base-{task2}"
tokenizer2 = AutoTokenizer.from_pretrained(MODEL2)

task3='irony'
MODEL3 = f"cardiffnlp/twitter-roberta-base-{task3}"
tokenizer3 = AutoTokenizer.from_pretrained(MODEL3)

# %%
# download label mapping sentiment
mapping_link = f"https://raw.githubusercontent.com/cardiffnlp/tweeteval/main/datasets/{task1}/mapping.txt"
with urllib.request.urlopen(mapping_link) as f:
    html = f.read().decode('utf-8').split("\n")
    csvreader = csv.reader(html, delimiter='\t')
labels1 = [row[1] for row in csvreader if len(row) > 1]
labels1
# Out:
# ['negative', 'neutral', 'positive']

# %%
# download label mapping emotion
mapping_link = f"https://raw.githubusercontent.com/cardiffnlp/tweeteval/main/datasets/{task2}/mapping.txt"
with urllib.request.urlopen(mapping_link) as f:
    html = f.read().decode('utf-8').split("\n")
    csvreader = csv.reader(html, delimiter='\t')
labels2 = [row[1] for row in csvreader if len(row) > 1]
labels2
# Out:
# ['anger', 'joy', 'optimism', 'sadness']

# %%
# download label mapping irony
mapping_link = f"https://raw.githubusercontent.com/cardiffnlp/tweeteval/main/datasets/{task3}/mapping.txt"
with urllib.request.urlopen(mapping_link) as f:
    html = f.read().decode('utf-8').split("\n")
    csvreader = csv.reader(html, delimiter='\t')
labels3 = [row[1] for row in csvreader if len(row) > 1]
labels3
# Out:
# ['non_irony', 'irony']

# %%
model1 = TFAutoModelForSequenceClassification.from_pretrained(MODEL1)
model2 = TFAutoModelForSequenceClassification.from_pretrained(MODEL2)
model3 = TFAutoModelForSequenceClassification.from_pretrained(MODEL3)
# Out:
# All model checkpoint layers were used when initializing TFRobertaForSequenceClassification.
#
# All the layers of TFRobertaForSequenceClassification were initialized from the model checkpoint at cardiffnlp/twitter-roberta-base-sentiment.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFRobertaForSequenceClassification for predictions without further training.
# All model checkpoint layers were used when initializing TFRobertaForSequenceClassification.
#
# All the layers of TFRobertaForSequenceClassification were initialized from the model checkpoint at cardiffnlp/twitter-roberta-base-emotion.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFRobertaForSequenceClassification for predictions without further training.
# All model checkpoint layers were used when initializing TFRobertaForSequenceClassification.
#
# All the layers of TFRobertaForSequenceClassification were initialized from the model checkpoint at cardiffnlp/twitter-roberta-base-irony.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFRobertaForSequenceClassification for predictions without further training.

# %%
# this function return labels for sentiment
def return_labels1(text):
    encoded_input = tokenizer1(text, return_tensors='tf')
    output = model1(encoded_input)
    scores = output[0][0].numpy()
    scores = softmax(scores)
    ranking = np.argsort(scores)
    ranking = ranking[::-1]
    label1 = labels1[ranking[0]]
    return label1

# %%
# this function return labels for emotions
def return_labels2(text):
    encoded_input = tokenizer2(text, return_tensors='tf')
    output = model2(encoded_input)
    scores = output[0][0].numpy()
    scores = softmax(scores)
    ranking = np.argsort(scores)
    ranking = ranking[::-1]
    label2 = labels2[ranking[0]]
    return label2

# %%
# this function return labels for irony
def return_labels3(text):
    encoded_input = tokenizer3(text, return_tensors='tf')
    output = model3(encoded_input)
    scores = output[0][0].numpy()
    scores = softmax(scores)
    ranking = np.argsort(scores)
    ranking = ranking[::-1]
    label3 = labels3[ranking[0]]
    return label3

# %%
# this function return probabilities to analize how "sure" the model is
def return_prob1(text):
    encoded_input = tokenizer1(text, return_tensors='tf')
    output = model1(encoded_input)
    scores = output[0][0].numpy()
    scores = softmax(scores)
    ranking = np.argsort(scores)
    ranking = ranking[::-1]
    return np.sort(scores)[-1]

# %%
# this function return probabilities to analize how "sure" the model is
def return_prob2(text):
    encoded_input = tokenizer2(text, return_tensors='tf')
    output = model2(encoded_input)
    scores = output[0][0].numpy()
    scores = softmax(scores)
    ranking = np.argsort(scores)
    ranking = ranking[::-1]
    return np.sort(scores)[-1]

# %%
# this function return probabilities to analize how "sure" the model is
def return_prob3(text):
    encoded_input = tokenizer3(text, return_tensors='tf')
    output = model3(encoded_input)
    scores = output[0][0].numpy()
    scores = softmax(scores)
    ranking = np.argsort(scores)
    ranking = ranking[::-1]
    return np.sort(scores)[-1]

# %%
detokenized_df['label_sentiment'] = detokenized_df['pre_processed'].apply(lambda x: return_labels1(x))
detokenized_df['probability_sentiment'] = detokenized_df['pre_processed'].apply(lambda x: return_prob1(x))

detokenized_df['label_emotion'] = detokenized_df['pre_processed'].apply(lambda x: return_labels2(x))
detokenized_df['probability_emotion'] = detokenized_df['pre_processed'].apply(lambda x: return_prob2(x))

detokenized_df['label_irony'] = detokenized_df['pre_processed'].apply(lambda x: return_labels3(x))
detokenized_df['probability_irony'] = detokenized_df['pre_processed'].apply(lambda x: return_prob3(x))

detokenized_df
# Out:
#                                                                                                                                                                                                                  pre_processed  \
# 0    many shootings, many lives lost evil people power, much hate, much depression, not nearly enough change stop that. i'm gonna apartment hoping every bang hear tonight firework, hoping people celebrate life without fear
# 1                                                                                                                                                                 hate walk back depression den i’ve completely altered shower
# 2                                                                                                                                          seriously. decided kick ass one time. i'm listening depression playlist. hate here.
# 3                                                                                                                                                                                     first depression... yay... 👌🏻 hate life.
# 4                                     hate upfront emotional state adult seen "attention seeking" like no want know i'm not sulking corner i'm mad you, brain hasnt feel good pharmacy chemicals year seasonal depression time
# ..                                                                                                                                                                                                                         ...
# 995                                                                                    really don’t think anyone suffering depression would behave like does. last thing want negativity opinion would insite much hate upset?
# 996                                                                          ronoh's videofor reading hate comments someone: people say suffer depression ronoh: yes big depression back ass 😭🤣🤣🤣🤣🤣🤣🤣🤣🤣🤣🤣🤣🤣🤣🤣🤣🤣🤣🤣🤣🤣🤣🤣🤣 yes sis
# 997                                                                                                                                               hate cant handle depression.. kena ka juga fikir bila kau tak mau fikir..😭😭😭
# 998                                                                                               know aggressively treat physical pain, depression vanishes. requires pain meds society thinks acceptable, instead hate time.
# 999                                                       offered one last month. said would help depression well. told "i've success this." that's line fucking hate; means nothing. drug side effect doc warned nymphomania.
#
#     label_sentiment  probability_sentiment label_emotion  probability_emotion  \
# 0          negative               0.722731       sadness             0.641728
# 1          negative               0.651571       sadness             0.966754
# 2          negative               0.700923         anger             0.931618
# 3          negative               0.743294       sadness             0.834031
# 4          negative               0.919534       sadness             0.794845
# ..              ...                    ...           ...                  ...
# 995        negative               0.859181         anger             0.519134
# 996        negative               0.735361           joy             0.624706
# 997        negative               0.940350       sadness             0.984390
# 998        negative               0.647686       sadness             0.904937
# 999        negative               0.833453       sadness             0.584299
#
#     label_irony  probability_irony
# 0     non_irony           0.648788
# 1     non_irony           0.822530
# 2     non_irony           0.892144
# 3         irony           0.984495
# 4     non_irony           0.844464
# ..          ...                ...
# 995   non_irony           0.936035
# 996   non_irony           0.566493
# 997   non_irony           0.902412
# 998       irony           0.717084
# 999   non_irony           0.730816
#
# [1000 rows x 7 columns]

# %%
official_df = pd.concat([depression_df[['renderedContent']], detokenized_df], axis = 1)
official_df
# Out:
#                                                                                                                                                                                                                                                                                                             renderedContent  \
# 0                                Too many shootings, too many lives lost from evil people with power, too much hate, too much depression, and not nearly enough change to stop that. \n\nI'm gonna be in my apartment hoping every bang I hear tonight is a firework, hoping we as a people can celebrate life without fear
# 1                                                                                                                                                                                                                     i hate having to walk back into my depression den after i’ve completely  altered myself in the shower
# 2                                                                                                                                                                            Seriously. 2019 decided to kick my ass one more time. Now I'm listening to my depression playlist. I hate it here. twitter.com/TarotByBronx/s…
# 3                                                                                                                                                                                                                                                                        First 2020 depression... yay... 👌🏻 I hate my life.
# 4                                         I hate that being upfront with your emotional state as an adult is seen as "attention seeking" like no I just want you to know I'm not sulking in a corner because I'm mad at you, my brain hasnt had any feel good pharmacy chemicals in a year and its seasonal depression time
# ..                                                                                                                                                                                                                                                                                                                      ...
# 995                                                                                         @Charbrevolution @DoctorChristian I really don’t think that anyone suffering with depression would behave like he does. The last thing you want is negativity in my opinion and so why would he insite so much hate and upset ?
# 996                                                                                                                        That ronoh's videofor reading hate comments \nSomeone: people say you suffer from depression \nRonoh: yes there is a big depression between my back and my ass 😭🤣🤣🤣🤣🤣🤣🤣🤣🤣🤣🤣🤣🤣🤣🤣🤣🤣🤣🤣🤣🤣🤣🤣🤣 yes sis
# 997                                                                                                                                                                                                                               I hate that i cant handle my depression..\nKena ka juga fikir bila kau tak mau fikir..😭😭😭
# 998                                                                                                             @queuelessness I do know that if I aggressively treat my physical pain, the depression vanishes. But that requires more pain meds than society thinks is acceptable, so instead I hate myself all the time.
# 999  @PlanetJanice @KellyMartin02 @AkathisiaRx @akathisiaalli @wendyburn I was offered one last month. Said it would help with depression as well. Told me "I've had success with this." That's the line I fucking hate; it means nothing. This is the drug where the only side effect my doc warned me of was nymphomania.
#
#                                                                                                                                                                                                                  pre_processed  \
# 0    many shootings, many lives lost evil people power, much hate, much depression, not nearly enough change stop that. i'm gonna apartment hoping every bang hear tonight firework, hoping people celebrate life without fear
# 1                                                                                                                                                                 hate walk back depression den i’ve completely altered shower
# 2                                                                                                                                          seriously. decided kick ass one time. i'm listening depression playlist. hate here.
# 3                                                                                                                                                                                     first depression... yay... 👌🏻 hate life.
# 4                                     hate upfront emotional state adult seen "attention seeking" like no want know i'm not sulking corner i'm mad you, brain hasnt feel good pharmacy chemicals year seasonal depression time
# ..                                                                                                                                                                                                                         ...
# 995                                                                                    really don’t think anyone suffering depression would behave like does. last thing want negativity opinion would insite much hate upset?
# 996                                                                          ronoh's videofor reading hate comments someone: people say suffer depression ronoh: yes big depression back ass 😭🤣🤣🤣🤣🤣🤣🤣🤣🤣🤣🤣🤣🤣🤣🤣🤣🤣🤣🤣🤣🤣🤣🤣🤣 yes sis
# 997                                                                                                                                               hate cant handle depression.. kena ka juga fikir bila kau tak mau fikir..😭😭😭
# 998                                                                                               know aggressively treat physical pain, depression vanishes. requires pain meds society thinks acceptable, instead hate time.
# 999                                                       offered one last month. said would help depression well. told "i've success this." that's line fucking hate; means nothing. drug side effect doc warned nymphomania.
#
#     label_sentiment  probability_sentiment label_emotion  probability_emotion  \
# 0          negative               0.722731       sadness             0.641728
# 1          negative               0.651571       sadness             0.966754
# 2          negative               0.700923         anger             0.931618
# 3          negative               0.743294       sadness             0.834031
# 4          negative               0.919534       sadness             0.794845
# ..              ...                    ...           ...                  ...
# 995        negative               0.859181         anger             0.519134
# 996        negative               0.735361           joy             0.624706
# 997        negative               0.940350       sadness             0.984390
# 998        negative               0.647686       sadness             0.904937
# 999        negative               0.833453       sadness             0.584299
#
#     label_irony  probability_irony
# 0     non_irony           0.648788
# 1     non_irony           0.822530
# 2     non_irony           0.892144
# 3         irony           0.984495
# 4     non_irony           0.844464
# ..          ...                ...
# 995   non_irony           0.936035
# 996   non_irony           0.566493
# 997   non_irony           0.902412
# 998       irony           0.717084
# 999   non_irony           0.730816
#
# [1000 rows x 8 columns]

# %%
official_df.to_csv('./preprocessed_data/2019/depression_2019.csv', sep=',', index=False, encoding='utf-8-sig')

# %%
#official_df
