# %%
import pandas as pd 
pd.set_option("display.max_colwidth", 400)
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns
import string
import nltk # for text manipulation
from nltk.corpus import stopwords
import preprocessor as p
import warnings 
warnings.filterwarnings("ignore", category=DeprecationWarning)

# %matplotlib inline

# %%
# Here we read the csv file that that contains depressive tweets from 2019
depression_df = pd.read_csv("./merged_data/2020/depression_2020.csv")

# %%
#depression_df.info()

# %%
#Here we delete all the unnecesary colums
depression_df.drop(["content","id","user","outlinks","tcooutlinks","replyCount","retweetCount","likeCount","quoteCount",\
                    "conversationId","lang","source","sourceUrl","sourceLabel","media","retweetedTweet","quotedTweet",\
                    "mentionedUsers"] ,axis=1, inplace=True)

# %%
depression_df.head(10)
# Out:
#                                                               url  \
# 0       https://twitter.com/tarottubbo/status/1212161379257462785
# 1     https://twitter.com/leah_valerie/status/1212160098593857536
# 2         https://twitter.com/itsTerru/status/1212159833530609664
# 3        https://twitter.com/DrLichita/status/1212158568088125440
# 4       https://twitter.com/jodiesbaby/status/1212158419639185411
# 5         https://twitter.com/kpxulson/status/1212156939410513920
# 6        https://twitter.com/fatems_19/status/1212154209862336512
# 7         https://twitter.com/ShobaPaw/status/1212153272653565952
# 8  https://twitter.com/jamesdcharrison/status/1212152053281234944
# 9          https://twitter.com/tinolqa/status/1212151406330810370
#
#                         date  \
# 0  2019-12-31 23:59:28+00:00
# 1  2019-12-31 23:54:23+00:00
# 2  2019-12-31 23:53:19+00:00
# 3  2019-12-31 23:48:18+00:00
# 4  2019-12-31 23:47:42+00:00
# 5  2019-12-31 23:41:49+00:00
# 6  2019-12-31 23:30:59+00:00
# 7  2019-12-31 23:27:15+00:00
# 8  2019-12-31 23:22:24+00:00
# 9  2019-12-31 23:19:50+00:00
#
#                                                                                                                                                                                                                                                                                              renderedContent
# 0                         i think self discovery has been the coolest part out of all of this. i was such an outgoing kid, then i completely retreated into my shell about 4 years ago when i was diagnosed with depression and anxiety. working my way back out even with the best support system was very-
# 1                                 In this decade, I started and graduated high school, I lost my grandma and my Dad and nearly lost myself, met my childhood hero @TheEllenShow twice, started college, was diagnosed with depression and GAD, met another hero @Matt_Morrison who gave me so much hope, 1/3
# 2                                                              10 years ago I was diagnosed with ADHD and put on a heavy dose of ritalin which backfired. Ended up with extreme anxiety and depression. Started university and I quit the drugs and I had no idea who I was. Struggling a lot with identity.
# 3                              &amp; ALSO THIS DECADE:\n•2 miscarriages\n•Painful, if not excruciating, pregnancies\n•Parents divorced\n•Diagnosed w/anxiety, depression,&amp; fibromyalgia\n•In therapy &amp; on meds entire decade \n•Moved 5 times b4 buying house \n•Abuelita &amp; tía passed away QEPD
# 4                                                                    guys o can’t wait for 2020. 2019 has genuinely been shit apart from a couple events. being diagnosed woth adhd ontop of depression and anxiety has been a difficult road for me. my mental and physical health have been the worst ngl.
# 5                  Things that happened in 2019:\n~ diagnosed w/ depression yay \n~ made new friends\n~ lost my b/friend of 12 years\n~ came out as bi \n~ finished 7th grade \n~ started 8th \n~ started talking with my family again \n~ made new online friends\n\n~ I made it after thinking I wouldn't.
# 6                                                                                                                                                  2010s lows:\n-diagnosed with depression\n-tough first year of uni\n-almost got suspended in grade-8\n-didn't have my mom for 7 months \n-first heartbreak
# 7  Last decade I:\n-married\n-dead broke twice\n-bought 3 houses\n-had 3 jobs \n-bought 2 cars\n-got divorced\n-traveled U.S.\n-became furry\n-came out as bisexual\n-got diagnosed with depression,anxiety &amp;functioning schizophrenic\n-went on 3 cruises\n-made family friends\n\nWhat a rollercoaster
# 8                                                                                                                                   @amandaasette My mother’s non-Hodgkin’s Lymphoma was variously diagnosed as fibromyalgia, Lyme Disease and depression. Fourteen months from eventual diagnosis to death.
# 9                      it was a very transsexual decade. Graduated high school, immediately started living full-time as a man, went to college, got diagnosed with depression, dropped out of college, was stuck in an increasingly abusive relationship with a terf for almost three years, escaped that...

# %%
p.set_options(p.OPT.URL, p.OPT.EMOJI)
p.clean('Preprocessor is #awesome 👍 https://github.com/s/preprocessor')
# Out:
# 'Preprocessor is #awesome'

# %%
# Here we use a preprocessing library for tweet data called "Preprocessor" and we use it to delete the url's, mentions 
#and numbers
p.set_options(p.OPT.URL, p.OPT.MENTION, p.OPT.NUMBER)
depression_df['pre_proccessed'] = depression_df['renderedContent'].apply(lambda x: p.clean(x)).str.lower()
#depression_df.head(10)

# %%
# Here we use the nltk library and we download the stopwords
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Usuario\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
stopwords_english = stopwords.words('english') 
print('Stop words\n')
print(stopwords_english)
# Out:
# Stop words
#
# ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', "you're", "you've", "you'll", "you'd", 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', "she's", 'her', 'hers', 'herself', 'it', "it's", 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', "that'll", 'these', 'those', 'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such', 'no', 'nor', 'not', 'only', 'own', 'same', 'so', 'than', 'too', 'very', 's', 't', 'can', 'will', 'just', 'don', "don't", 'should', "should've", 'now', 'd', 'll', 'm', 'o', 're', 've', 'y', 'ain', 'aren', "aren't", 'couldn', "couldn't", 'didn', "didn't", 'doesn', "doesn't", 'hadn', "hadn't", 'hasn', "hasn't", 'haven', "haven't", 'isn', "isn't", 'ma', 'mightn', "mightn't", 'mustn', "mustn't", 'needn', "needn't", 'shan', "shan't", 'shouldn', "shouldn't", 'wasn', "wasn't", 'weren', "weren't", 'won', "won't", 'wouldn', "wouldn't"]

# %%
'no' in stopwords_english
# Out:
# True

# %%
# After doing some testing, I noticed that negations are important, so I removed them from the stopwords list
to_remove = ['no', 'not',"don't",'didn', "didn't", 'doesn', "doesn't", 'hadn', "hadn't", 'hasn', "hasn't"]
to_remove
            
[stopwords_english.remove(item) for item in to_remove if item in stopwords_english]
stopwords_english
# Out:
# ['i',
#  'me',
#  'my',
#  'myself',
#  'we',
#  'our',
#  'ours',
#  'ourselves',
#  'you',
#  "you're",
#  "you've",
#  "you'll",
#  "you'd",
#  'your',
#  'yours',
#  'yourself',
#  'yourselves',
#  'he',
#  'him',
#  'his',
#  'himself',
#  'she',
#  "she's",
#  'her',
#  'hers',
#  'herself',
#  'it',
#  "it's",
#  'its',
#  'itself',
#  'they',
#  'them',
#  'their',
#  'theirs',
#  'themselves',
#  'what',
#  'which',
#  'who',
#  'whom',
#  'this',
#  'that',
#  "that'll",
#  'these',
#  'those',
#  'am',
#  'is',
#  'are',
#  'was',
#  'were',
#  'be',
#  'been',
#  'being',
#  'have',
#  'has',
#  'had',
#  'having',
#  'do',
#  'does',
#  'did',
#  'doing',
#  'a',
#  'an',
#  'the',
#  'and',
#  'but',
#  'if',
#  'or',
#  'because',
#  'as',
#  'until',
#  'while',
#  'of',
#  'at',
#  'by',
#  'for',
#  'with',
#  'about',
#  'against',
#  'between',
#  'into',
#  'through',
#  'during',
#  'before',
#  'after',
#  'above',
#  'below',
#  'to',
#  'from',
#  'up',
#  'down',
#  'in',
#  'out',
#  'on',
#  'off',
#  'over',
#  'under',
#  'again',
#  'further',
#  'then',
#  'once',
#  'here',
#  'there',
#  'when',
#  'where',
#  'why',
#  'how',
#  'all',
#  'any',
#  'both',
#  'each',
#  'few',
#  'more',
#  'most',
#  'other',
#  'some',
#  'such',
#  'nor',
#  'only',
#  'own',
#  'same',
#  'so',
#  'than',
#  'too',
#  'very',
#  's',
#  't',
#  'can',
#  'will',
#  'just',
#  'don',
#  'should',
#  "should've",
#  'now',
#  'd',
#  'll',
#  'm',
#  'o',
#  're',
#  've',
#  'y',
#  'ain',
#  'aren',
#  "aren't",
#  'couldn',
#  "couldn't",
#  'haven',
#  "haven't",
#  'isn',
#  "isn't",
#  'ma',
#  'mightn',
#  "mightn't",
#  'mustn',
#  "mustn't",
#  'needn',
#  "needn't",
#  'shan',
#  "shan't",
#  'shouldn',
#  "shouldn't",
#  'wasn',
#  "wasn't",
#  'weren',
#  "weren't",
#  'won',
#  "won't",
#  'wouldn',
#  "wouldn't"]

# %%
'no' in stopwords_english
# Out:
# False

# %%
tokenized_tweet = depression_df['pre_proccessed'].apply(lambda x: x.split()) # tokenizing
#tokenized_tweet[:10]

# %%
# print(tokenized_tweet[:10])
tweets_clean_dict = {}
for num, sentence in enumerate(tokenized_tweet): #Go through every tweet in the list of tweets 
    tweets_clean = [] #create an empty list to save the cleaned tweet for each tweet 
    for word in sentence: #go through every word inside the "dirty" tweet and keep only the ones you want
        if (word not in stopwords_english): 
            tweets_clean.append(word)
    tweets_clean_dict[num] = tweets_clean #save the list of "cleaned" words (cleaned tweet) into a dict in the position num (0,1,2,... ,len(tweets))
tweets_clean_dict
# Out:
# {0: ['think',
#   'self',
#   'discovery',
#   'coolest',
#   'part',
#   'this.',
#   'outgoing',
#   'kid,',
#   'completely',
#   'retreated',
#   'shell',
#   'years',
#   'ago',
#   'diagnosed',
#   'depression',
#   'anxiety.',
#   'working',
#   'way',
#   'back',
#   'even',
#   'best',
#   'support',
#   'system',
#   'very-'],
#  1: ['decade,',
#   'started',
#   'graduated',
#   'high',
#   'school,',
#   'lost',
#   'grandma',
#   'dad',
#   'nearly',
#   'lost',
#   'myself,',
#   'met',
#   'childhood',
#   'hero',
#   'twice,',
#   'started',
#   'college,',
#   'diagnosed',
#   'depression',
#   'gad,',
#   'met',
#   'another',
#   'hero',
#   'gave',
#   'much',
#   'hope,',
#   '/3'],
#  2: ['years',
#   'ago',
#   'diagnosed',
#   'adhd',
#   'put',
#   'heavy',
#   'dose',
#   'ritalin',
#   'backfired.',
#   'ended',
#   'extreme',
#   'anxiety',
#   'depression.',
#   'started',
#   'university',
#   'quit',
#   'drugs',
#   'no',
#   'idea',
#   'was.',
#   'struggling',
#   'lot',
#   'identity.'],
#  3: ['&amp;',
#   'also',
#   'decade:',
#   '•2',
#   'miscarriages',
#   '•painful,',
#   'not',
#   'excruciating,',
#   'pregnancies',
#   '•parents',
#   'divorced',
#   '•diagnosed',
#   'w/anxiety,',
#   'depression,&amp;',
#   'fibromyalgia',
#   '•in',
#   'therapy',
#   '&amp;',
#   'meds',
#   'entire',
#   'decade',
#   '•moved',
#   'times',
#   'b4',
#   'buying',
#   'house',
#   '•abuelita',
#   '&amp;',
#   'tía',
#   'passed',
#   'away',
#   'qepd'],
#  4: ['guys',
#   'can’t',
#   'wait',
#   '.',
#   'genuinely',
#   'shit',
#   'apart',
#   'couple',
#   'events.',
#   'diagnosed',
#   'woth',
#   'adhd',
#   'ontop',
#   'depression',
#   'anxiety',
#   'difficult',
#   'road',
#   'me.',
#   'mental',
#   'physical',
#   'health',
#   'worst',
#   'ngl.'],
#  5: ['things',
#   'happened',
#   ':',
#   '~',
#   'diagnosed',
#   'w/',
#   'depression',
#   'yay',
#   '~',
#   'made',
#   'new',
#   'friends',
#   '~',
#   'lost',
#   'b/friend',
#   'years',
#   '~',
#   'came',
#   'bi',
#   '~',
#   'finished',
#   'th',
#   'grade',
#   '~',
#   'started',
#   'th',
#   '~',
#   'started',
#   'talking',
#   'family',
#   '~',
#   'made',
#   'new',
#   'online',
#   'friends',
#   '~',
#   'made',
#   'thinking',
#   "wouldn't."],
#  6: ['lows:',
#   '-diagnosed',
#   'depression',
#   '-tough',
#   'first',
#   'year',
#   'uni',
#   '-almost',
#   'got',
#   'suspended',
#   'grade-8',
#   "-didn't",
#   'mom',
#   'months',
#   '-first',
#   'heartbreak'],
#  7: ['last',
#   'decade',
#   'i:',
#   '-married',
#   '-dead',
#   'broke',
#   'twice',
#   '-bought',
#   'houses',
#   '-had',
#   'jobs',
#   '-bought',
#   'cars',
#   '-got',
#   'divorced',
#   '-traveled',
#   'u.s.',
#   '-became',
#   'furry',
#   '-came',
#   'bisexual',
#   '-got',
#   'diagnosed',
#   'depression,anxiety',
#   '&amp;functioning',
#   'schizophrenic',
#   '-went',
#   'cruises',
#   '-made',
#   'family',
#   'friends',
#   'rollercoaster'],
#  8: ['mother’s',
#   'non-hodgkin’s',
#   'lymphoma',
#   'variously',
#   'diagnosed',
#   'fibromyalgia,',
#   'lyme',
#   'disease',
#   'depression.',
#   'fourteen',
#   'months',
#   'eventual',
#   'diagnosis',
#   'death.'],
#  9: ['transsexual',
#   'decade.',
#   'graduated',
#   'high',
#   'school,',
#   'immediately',
#   'started',
#   'living',
#   'full-time',
#   'man,',
#   'went',
#   'college,',
#   'got',
#   'diagnosed',
#   'depression,',
#   'dropped',
#   'college,',
#   'stuck',
#   'increasingly',
#   'abusive',
#   'relationship',
#   'terf',
#   'almost',
#   'three',
#   'years,',
#   'escaped',
#   'that...'],
#  10: ['diagnosed',
#   'depression',
#   '.',
#   'renamed.',
#   'wanting',
#   'escape',
#   'prison.',
#   'sort',
#   'know',
#   'ghosts',
#   'feel.',
#   'trapped.'],
#  11: ['decade',
#   'i:',
#   '-worked',
#   'pa',
#   'several',
#   'tv',
#   'shows',
#   'movie',
#   '-got',
#   'diagnosed',
#   'clinical',
#   'depression',
#   '-got',
#   'treatment',
#   'clinical',
#   'depression',
#   '-started',
#   'freelance',
#   'animation',
#   'career',
#   '-moved',
#   '-got',
#   'married',
#   '-got',
#   'lots',
#   'pets',
#   'insane.'],
#  12: ['i’ve',
#   'heard',
#   'many',
#   'people',
#   'say',
#   '“our',
#   'generation',
#   'never',
#   'depression/pcos/allergies/&lt;insert',
#   '‘modern’',
#   'ailment',
#   'here&gt;.',
#   'young',
#   'people',
#   'soft.”',
#   'yes',
#   'fucking',
#   'did!',
#   'wasn’t',
#   'properly',
#   'diagnosed.',
#   'suffered',
#   'silence.',
#   'thought',
#   'weren’t',
#   '“tough',
#   'enough”'],
#  13: ['..be',
#   'diagnosed',
#   'leukaemia,',
#   'needing',
#   'bone',
#   'marrow',
#   'transplant.',
#   'fought',
#   'like',
#   'trooper,',
#   'also',
#   'losing',
#   'dad,',
#   'left',
#   'depression,',
#   'anxiety',
#   'drink',
#   'problem.',
#   'years',
#   'drink',
#   'free',
#   'getting',
#   'issues.',
#   'happy',
#   'new',
#   'year.'],
#  14: [':',
#   'ending',
#   'right',
#   ':',
#   'starting',
#   'right',
#   'battled',
#   'depression,',
#   'insomnia',
#   'ptsd.',
#   'not',
#   'mention',
#   'recently',
#   'diagnosed',
#   'heart',
#   'problems...',
#   'weeks',
#   'ago',
#   'jumpstart',
#   'changes',
#   '#newyear',
#   '#happynewyear2020',
#   '#'],
#  15: ['•',
#   'cons',
#   '•',
#   '-',
#   'i’ve',
#   'lost',
#   'nearly',
#   'people',
#   'raised',
#   'child',
#   'mom',
#   'passed.',
#   '-',
#   'diagnosed',
#   'w/',
#   'anxiety',
#   '&amp;',
#   'depression.',
#   '-',
#   'went',
#   'college',
#   'end',
#   'not',
#   'pursuing',
#   'career',
#   'path.',
#   '-',
#   'engaged',
#   '&amp;',
#   'relationship',
#   'ending',
#   'not',
#   'working',
#   'out.'],
#  16: ['interest',
#   'keeping',
#   'track:',
#   'felt',
#   'first',
#   'stirrings',
#   'depression',
#   '&amp;',
#   'anxiety',
#   ',',
#   'finally',
#   'got',
#   'diagnosed',
#   'came',
#   'gay,',
#   'settled',
#   'queer,',
#   'moved',
#   'first',
#   'time,',
#   'got',
#   'dream',
#   'jobs',
#   'made',
#   'feel',
#   'sad',
#   'lol,',
#   'got',
#   'masters,',
#   'put',
#   'shows,',
#   'alive',
#   '🎆'],
#  17: ['taught',
#   'put',
#   'lot',
#   '.',
#   'diagnosed',
#   'severe',
#   'depression',
#   'deal',
#   'truly',
#   'not',
#   'wanting',
#   'live',
#   'anymore.',
#   'lost',
#   'purpose',
#   'life',
#   'still',
#   'struggle',
#   'see',
#   'it.',
#   'yet,',
#   'moved',
#   'best',
#   'friend.',
#   'went',
#   'craziest',
#   'hour',
#   'trip',
#   '/2'],
#  18: ['decade,',
#   'i:',
#   '💻',
#   'started',
#   'career',
#   'digital',
#   '👩\u200d❤️\u200d👨',
#   'eloped',
#   '🤟🏽',
#   'moved',
#   'atx',
#   '👯\u200d♀️',
#   'met',
#   'best',
#   'friends',
#   '👨\u200d👩\u200d👧',
#   'baby',
#   '💪🏼',
#   'laid',
#   '(which',
#   'actually',
#   'best',
#   'thing',
#   'career)',
#   '🐱',
#   'adopted',
#   'cats',
#   '❤️',
#   'diagnosed',
#   'depression',
#   'anxiety',
#   'became',
#   'okay'],
#  19: ['diagnosed',
#   'general',
#   'anxiety',
#   'disorder,',
#   'depression,',
#   '&amp;',
#   'ptsd.',
#   'spent',
#   'year',
#   '&amp;',
#   'hospitals',
#   'i’m',
#   'thankful',
#   'it.',
#   'made',
#   'realize',
#   'one',
#   'thing,',
#   'nothing',
#   'really',
#   'matters',
#   'except',
#   'people',
#   'love',
#   '&amp;',
#   'love',
#   'return.'],
#  20: ['last',
#   'decade',
#   'rollercoaster',
#   'me!',
#   'bought',
#   'house,',
#   'got',
#   'married,',
#   'baby,',
#   'separated',
#   '(now',
#   'ex)',
#   'husband,',
#   'got',
#   'diagnosed',
#   'witn',
#   'depression,',
#   'met',
#   '&amp;',
#   'started',
#   'dating',
#   'best',
#   'man',
#   'ever',
#   'met,',
#   'moved',
#   'back',
#   'home,',
#   'moved',
#   'place,',
#   'stopped',
#   'taking',
#   'antidepressants'],
#  21: ['-2019',
#   '-finished',
#   'first',
#   'two',
#   'novels',
#   'i’ll',
#   'never',
#   'publish',
#   '-got',
#   'second',
#   'fourth',
#   'girlfriends',
#   '-graduated',
#   'high',
#   'school',
#   '-had',
#   'sex',
#   '-got',
#   'depression',
#   '-did',
#   'five',
#   'years',
#   'university',
#   '-met',
#   'current',
#   'gf',
#   '-began',
#   'writing',
#   'poetry',
#   '-diagnosed',
#   'asperger’s'],
#  22: ['entire',
#   'decade',
#   'utter',
#   'shit',
#   'personally.',
#   'diagnosed',
#   'incurable',
#   'skin',
#   'condition,',
#   'tried',
#   'commit',
#   'suicide',
#   'times',
#   'longest',
#   'battle',
#   'depression',
#   'hating',
#   'still',
#   'going',
#   'date,',
#   'but...',
#   '/?'],
#  23: ['existential',
#   'crisis',
#   'diagnosed',
#   'depression',
#   "i've",
#   'spent',
#   'whole',
#   'decade',
#   'depressed',
#   'gotten',
#   'better',
#   'rip'],
#  24: ['year',
#   'diagnosed',
#   '‘treatment-resistant',
#   'depression’.',
#   'year',
#   'major',
#   'episode',
#   'hit',
#   'even',
#   'though',
#   'everything',
#   'right',
#   'taking',
#   'good',
#   'medication.',
#   'year',
#   'realised',
#   'doesn’t',
#   'matter',
#   'do,',
#   'can’t',
#   'make',
#   'not',
#   'ill…'],
#  25: ['stole',
#   'friend....',
#   'decade',
#   '-',
#   'skipped',
#   'grade',
#   '&amp;',
#   'graduated',
#   'high',
#   'school',
#   '-',
#   'parents',
#   'divorced',
#   '-',
#   'diagnosed',
#   'w/',
#   'depression',
#   '-',
#   'moved',
#   'canyon',
#   '&amp;',
#   'started',
#   'wt',
#   'met',
#   'amazing',
#   'best',
#   'friends',
#   '-',
#   'kicked',
#   'nursing',
#   'program',
#   '-',
#   'considered',
#   'giving'],
#  26: ['year',
#   'lived',
#   'car',
#   'bit,',
#   'moved',
#   'moms,',
#   'dad',
#   'diagnosed',
#   'cancer,',
#   'literally',
#   '$0',
#   'account,',
#   'lost',
#   'pounds',
#   'due',
#   'depression,',
#   'cried',
#   'work,',
#   'dad',
#   'passed,',
#   'lost',
#   'long',
#   'time',
#   'friend,',
#   'still',
#   'deep',
#   'depression',
#   'bitch',
#   'made'],
#  27: ['...found',
#   'depression',
#   'anxiety,',
#   'therapy,',
#   'started',
#   'streaming,',
#   'diagnosed',
#   'personality',
#   'disorder,',
#   'quit',
#   'job,',
#   'ended',
#   'disability,',
#   'lost',
#   'contact',
#   'friends,',
#   'removed',
#   'gallbladder,',
#   'remarried,',
#   "i'm",
#   'fatter',
#   'ever,',
#   'streamed',
#   'ages,',
#   'barely',
#   'afford',
#   'food',
#   '🎉'],
#  28: ['real',
#   'nose',
#   'face',
#   '-',
#   'amount',
#   'people',
#   "i've",
#   'met',
#   'claim',
#   'bpd,',
#   'depression,',
#   'anxiety',
#   'etc',
#   'reality',
#   "they've",
#   'tumblr',
#   'long',
#   'ridiculous.',
#   'experience',
#   'mostly',
#   'women',
#   'blaming',
#   'self',
#   'diagnosed',
#   'bpd',
#   'shitty',
#   'behaviour'],
#  29: ['✅',
#   'graduated',
#   'hs',
#   '✅graduated',
#   'college',
#   '✅received',
#   'master’s',
#   '✅had',
#   'nervous',
#   'breakdown,',
#   'briefly',
#   'hospitalized',
#   '✅diagnosed',
#   'depression',
#   ',',
#   'bpd',
#   '✅adpoted',
#   'dog',
#   '✅lived',
#   'different',
#   'states',
#   'country'],
#  30: ['got', 'diagnosed', 'depression', 'fucking', 'years', 'ago', 'bizzare'],
#  31: ['diagnosed',
#   'breast',
#   'cancer',
#   ',',
#   'clear',
#   'years,',
#   'no',
#   'one',
#   'told',
#   'saving',
#   'life',
#   'would',
#   'ultimately',
#   'mean',
#   'losing',
#   'great',
#   'deal',
#   'quality',
#   'life.',
#   'struggle',
#   'physical',
#   'pain',
#   'led',
#   'depression',
#   'anxiety.',
#   '"at',
#   'least',
#   'not',
#   '\'under."',
#   '/2'],
#  32: ['ok',
#   'lovely',
#   'speech',
#   'time:',
#   'year',
#   'intense',
#   'me.',
#   'diagnosed',
#   'depression',
#   'anorexia,',
#   'almost',
#   'losing',
#   'life',
#   'suicide',
#   'attempt...',
#   'overall',
#   'say',
#   'i’m',
#   'much',
#   'better',
#   'place',
#   'mental',
#   'illnesses',
#   'don’t',
#   'define'],
#  33: ['-became',
#   'great/grand',
#   'aunt.',
#   'twice.',
#   '-lost',
#   'bunch',
#   'weight!',
#   '-gained',
#   'back.',
#   '-and',
#   'officially',
#   'diagnosed',
#   'depression',
#   '&amp;',
#   'generalized',
#   'anxiety',
#   'disorder.',
#   '-got',
#   'back',
#   'health',
#   'wagon.',
#   'weight',
#   'training',
#   'year.',
#   '-had',
#   'migraine',
#   'lasted',
#   'year.',
#   'second',
#   'time.',
#   '..'],
#  34: [':',
#   '-',
#   'younger',
#   'sister',
#   'diagnosed',
#   'w/ms',
#   '-',
#   'unexpectedly',
#   'dumped',
#   '-',
#   'severe',
#   'work',
#   'burnout',
#   '-',
#   'return',
#   'crippling',
#   'depression',
#   "can't",
#   'even',
#   'bear',
#   'thought',
#   'interact',
#   'people,',
#   'esp.',
#   'xmas',
#   'appreciate',
#   'stuck',
#   'me♥️',
#   "let's",
#   'ctrl-alt-del',
#   'decade',
#   '🎉'],
#  35: ['year',
#   'rollercoaster',
#   'say',
#   'least.',
#   'lost',
#   'people',
#   'used',
#   'love.',
#   'diagnosed',
#   'depression.',
#   'dealt',
#   'immense',
#   'amount',
#   'stupid.',
#   'but...',
#   'i’ve',
#   'come',
#   'top,',
#   'i’ve',
#   'gained',
#   'many',
#   'people',
#   'life',
#   'love',
#   'much,',
#   'i’ve',
#   'pushed',
#   'limits...'],
#  36: ['lrt:',
#   'something',
#   'striking',
#   'me,',
#   'someone',
#   'diagnosed',
#   'depression',
#   'years',
#   'ago',
#   'got',
#   'physical',
#   'illnesses',
#   'diagnosed',
#   'last',
#   'so,',
#   'different',
#   'suicidal',
#   'treated',
#   'suddenly',
#   'wrong',
#   'depression/anxiety'],
#  37: ['fell',
#   'rabbit',
#   'hole',
#   'mental',
#   'illness.',
#   'hospitalized',
#   'month.',
#   'diagnosed',
#   'major',
#   'depression',
#   'anxiety',
#   'bipolar',
#   '.',
#   'went',
#   'many',
#   'medications.',
#   'felt',
#   'like',
#   'nothing',
#   'self',
#   'hate',
#   'terrible.',
#   '(yes',
#   'me)'],
#  38: ['year',
#   'shit',
#   'show,',
#   'biggest',
#   'thing',
#   'changed',
#   'diagnosed',
#   'depression,',
#   'eventually',
#   'it’s',
#   'gonna',
#   'get',
#   'worse.',
#   'wanna',
#   'thank',
#   'friends',
#   'helped',
#   'thank',
#   'everything.',
#   'thank',
#   'much'],
#  39: ['diagnosed',
#   'hashimoto’s',
#   'disease.',
#   'everything',
#   'clicked-',
#   'chronic',
#   'fatigue,',
#   'depression',
#   'anxiety,',
#   'hair',
#   'falling',
#   'handfuls,',
#   'weight',
#   'steadily',
#   'climbing.',
#   'care',
#   'plan',
#   'constantly',
#   'evolving,',
#   'places',
#   'makes',
#   'world',
#   'difference.'],
#  40: ['diagnosed',
#   'depression',
#   'anxiety',
#   'young',
#   'age,',
#   'steven',
#   'always',
#   'felt',
#   'overlooked.',
#   'steven',
#   'needed',
#   'way',
#   'build',
#   'confidence,',
#   'afraid',
#   'timidness',
#   'would',
#   'hold',
#   'back.',
#   'found',
#   'juma.'],
#  41: ['i:',
#   '-learned',
#   'korean',
#   'fluently',
#   '-graduated',
#   'elementary',
#   'school',
#   '-became',
#   'otaku',
#   '-begun',
#   'learn',
#   'japanese',
#   '-graduated',
#   'middle',
#   'school',
#   '-got',
#   's/o',
#   '-graduated',
#   'high',
#   'school',
#   '-got',
#   'college',
#   '-became',
#   'suicidal',
#   '-flopped',
#   'gpa',
#   '-got',
#   'dumped',
#   's/o',
#   '-got',
#   'diagnosed',
#   'depression',
#   'yay'],
#  42: ['okwam',
#   'kukubulela',
#   'ku',
#   'thixo,',
#   'family,',
#   'friends,',
#   'colleagues',
#   'acquaintances',
#   'nge',
#   'support',
#   'kulo',
#   'nyaka',
#   'diagnosed',
#   'depression.',
#   'konke',
#   'kuyedlula',
#   'zihlobo.',
#   '❤❤❤'],
#  43: ['well,',
#   'hello!',
#   'welcome',
#   'wrapping',
#   '!',
#   'so,',
#   'last',
#   'year',
#   'diagnosed',
#   'anxiety',
#   'depression,',
#   'something',
#   'pretty',
#   'hard',
#   'even',
#   'admit',
#   'myself.',
#   'remember',
#   'saying',
#   'last',
#   'year',
#   'going',
#   'take',
#   'better',
#   'myself,',
#   'moment',
#   'didn’t',
#   'mean',
#   'that.'],
#  44: ['explaining',
#   'sam',
#   'diagnosed',
#   'certain',
#   'kind',
#   'major',
#   'depression',
#   'different',
#   'bipolar',
#   'disorder',
#   'like,',
#   'nah,',
#   'bipolar',
#   'really',
#   'seems',
#   'like',
#   'you.',
#   'offended',
#   'enlightened??',
#   'lmao.'],
#  45: ['last',
#   'decade',
#   'diagnosed',
#   'depression/anxiety.',
#   'parents',
#   'got',
#   'divorced.',
#   'lost',
#   'grandfathers,',
#   'lost',
#   'car,',
#   'got',
#   'evicted,',
#   'lost',
#   'friends.',
#   'got',
#   'go',
#   'back',
#   'two',
#   'places',
#   'call',
#   'home',
#   'miami',
#   'colombia.',
#   'found',
#   'appreciation',
#   'loved'],
#  46: ['actually',
#   'go',
#   'address',
#   'one',
#   'thing:',
#   'im',
#   'not',
#   'diagnosed',
#   'depression.',
#   'havent',
#   'done',
#   'tests',
#   'determine',
#   'it.',
#   'people',
#   'past',
#   'saying',
#   'depression',
#   'despite'],
#  47: ["'s",
#   'great',
#   'depression,',
#   'think',
#   "'s",
#   'greatest',
#   'hits',
#   'depression.',
#   'millenials',
#   'gen',
#   'z',
#   'learning',
#   'great',
#   'time',
#   'collectively',
#   'diagnosed',
#   'depression.',
#   '#2020',
#   '#thebigsad',
#   '#depressioncanbeajokeifyoudistractyourselfenough'],
#  48: ['beginning',
#   'decade',
#   'pure',
#   'suffering.',
#   'absolute',
#   'desaster.',
#   '...',
#   'middle',
#   'diagnosed',
#   '#depression.',
#   'started',
#   'recovery.',
#   'slowly',
#   'improving.',
#   'hope',
#   'new',
#   'decade',
#   'side.'],
#  49: ["(don't",
#   'worry,',
#   'joke',
#   'tweet!',
#   'actually',
#   'diagnosed',
#   'depression',
#   ')'],
#  50: ['diagnosed',
#   'w/',
#   'lupus',
#   'survived,',
#   'graduated',
#   'college,',
#   'got',
#   'help',
#   'w/',
#   'depression,',
#   'lost',
#   'two',
#   'cousins,',
#   'long',
#   'time',
#   'relationship',
#   'came',
#   'end,',
#   'became',
#   'closer',
#   'certain',
#   'people,',
#   'art',
#   'really',
#   'improved.',
#   "there's",
#   'much',
#   'ones',
#   'stand',
#   'most.'],
#  51: ['new',
#   'decade',
#   'begun.',
#   'remembered',
#   'last',
#   'diagnosed',
#   'heart',
#   'failure',
#   'time',
#   'silently',
#   'painfully',
#   'suffered',
#   'depression.',
#   'really',
#   'wish',
#   'new',
#   'decade',
#   'bring',
#   'best',
#   'me,',
#   'no',
#   'heartaches',
#   'pain,',
#   'success',
#   'happiness.'],
#  52: ['unless',
#   'something',
#   'extreme',
#   'happens',
#   'next',
#   'half',
#   'hours,',
#   'survived',
#   'first',
#   'year',
#   'diagnosed',
#   'depression',
#   'taking',
#   'medication',
#   'it.',
#   'guess',
#   "that's",
#   'accomplishment.'],
#  53: ['bad',
#   'experience.',
#   'got',
#   'many',
#   'cool',
#   'things',
#   'forever',
#   'greatful.',
#   'though',
#   'year',
#   'amazing',
#   'did,',
#   'probably',
#   'worst',
#   'year',
#   'mentally.',
#   'know',
#   'diagnosed',
#   'depression',
#   'anxiety',
#   'year',
#   'incredibly',
#   'tough...'],
#  54: ['diagnosed',
#   'things',
#   "i'd",
#   'never',
#   'thought',
#   'sending',
#   'deep',
#   'depression,',
#   'breaking',
#   'first',
#   'bone',
#   'going',
#   'first',
#   'major',
#   'surgery,',
#   'kicked',
#   'ass',
#   'ready',
#   '(hopefully)',
#   'better',
#   'year',
#   '💛',
#   'happy',
#   'new',
#   'year,',
#   'everyone.'],
#  55: ['dad',
#   'lost',
#   'battle',
#   'cancer',
#   ',',
#   'lost',
#   'people,',
#   'diagnosed',
#   'anxiety',
#   'depression',
#   'days',
#   'debilitating.',
#   '...'],
#  56: ['diagnosed',
#   'anxiety',
#   '&amp;',
#   'depression,',
#   'counselling,',
#   'medication,',
#   'healing,',
#   'turned',
#   ',',
#   'married',
#   'years.',
#   'downs?',
#   'better',
#   'believe',
#   'it.',
#   "i'm",
#   'stronger',
#   'ever',
#   'been.',
#   'not',
#   'always',
#   'easy,',
#   'life',
#   'precious.',
#   "here's",
#   'next',
#   'decade',
#   '🍾'],
#  57: ['ten',
#   'years',
#   'ago:',
#   'diagnosed',
#   'depression',
#   'hating',
#   'today:',
#   'pretty',
#   'much',
#   'tattoos'],
#  58: ['tw??',
#   'mum',
#   'says',
#   'don’t',
#   'depression',
#   'nothing',
#   'depressed',
#   'about.',
#   'even',
#   'though',
#   'you’ve',
#   'literally',
#   'diagnosed',
#   'anxiety',
#   'depressive',
#   'disorder.',
#   'fucking',
#   'mint'],
#  59: ['sept.',
#   '!',
#   'rushed',
#   'er',
#   'cuz',
#   'nagwawala',
#   'ako',
#   'hurting',
#   'kasi',
#   'wanted',
#   'commit',
#   'suicide.',
#   'diagnosed',
#   'depression.',
#   'ff',
#   'year,',
#   "i'm",
#   'happy',
#   'alive.',
#   "i'm",
#   'meds',
#   'free',
#   "don't",
#   'need',
#   'go',
#   'therapy',
#   'anymore.',
#   'well',
#   '✊🏼✊🏼'],
#  60: ['blame',
#   'lot',
#   'now,',
#   "i'm",
#   'scared',
#   'talk',
#   'anyone',
#   'fear',
#   'taking',
#   'everything',
#   'wrong',
#   'way',
#   'insulting',
#   'me,',
#   'works.',
#   'officially',
#   'diagnosed',
#   'anything,',
#   'likely',
#   'anxiety',
#   'maybe',
#   'even',
#   'depression',
#   'now.'],
#  61: ['-2011',
#   'hardest',
#   'years',
#   'life.',
#   'cosmetology',
#   'school',
#   'severely',
#   'depressed',
#   'couldn’t',
#   'breathe',
#   'half',
#   'time.',
#   'got',
#   'diagnosed',
#   'anxiety,',
#   'depression',
#   'severe',
#   'panic',
#   'disorder.',
#   'finished',
#   'cosmetology',
#   'school',
#   'began',
#   'working',
#   'salon.'],
#  62: ['damn.',
#   'well',
#   'someone',
#   'like',
#   'recently',
#   'diagnosed',
#   'w',
#   'depression,',
#   'started',
#   ',',
#   'i’m',
#   '.',
#   'mind',
#   'plays',
#   'tricks',
#   'you.',
#   'lot',
#   'times',
#   'don’t',
#   'think',
#   'clearly.'],
#  63: ['things',
#   'happened',
#   'decade:',
#   '-',
#   'graduated',
#   'hs',
#   'college',
#   '-',
#   'diagnosed',
#   'w',
#   'lymphedema',
#   '-',
#   'published',
#   'six',
#   'books',
#   '-',
#   'wrote',
#   'books',
#   '-',
#   'got',
#   'agent',
#   '-',
#   'found',
#   'tøp',
#   '-',
#   'assaulted',
#   'twice',
#   '-',
#   'travelled',
#   '-',
#   'fell',
#   'love',
#   '-',
#   'came',
#   '-',
#   'fought',
#   'depression',
#   '-',
#   'heart',
#   'broken',
#   '-',
#   'moved',
#   'nyc'],
#  64: ['cbd',
#   'health',
#   'benefits',
#   'treating',
#   'cancer?',
#   'united',
#   'states,',
#   'million',
#   'people',
#   'diagnosed',
#   'cancer',
#   'year.',
#   'patients',
#   'suffer',
#   'lot',
#   'depression,',
#   'anxiety,',
#   'fear.'],
#  65: ['depression,',
#   'ptsd,',
#   'adhd',
#   'possibly',
#   'mild',
#   'form',
#   'bipolar',
#   'hasn’t',
#   'officially',
#   'diagnosed.',
#   'feel',
#   'trying',
#   'feel',
#   'dominant.',
#   'days',
#   'wake',
#   'question',
#   'feel',
#   'like',
#   'nothing',
#   'offer',
#   'feel',
#   'like',
#   'dommes/subs',
#   'would',
#   '...',
#   'cont'],
#  66: [':',
#   'accidentally',
#   'started',
#   'boobquake.',
#   'graduated',
#   'purdue.',
#   'started',
#   'phd',
#   'uw',
#   ':',
#   'started',
#   'dating',
#   'now-fiance.',
#   'adopted',
#   'pixel',
#   ':',
#   'passed',
#   'quals.',
#   'went',
#   'paris',
#   ':',
#   'mom',
#   'diagnosed',
#   'cancer',
#   'nearly',
#   'dies',
#   'blot',
#   'clot',
#   ':',
#   'mom',
#   'passes',
#   ':',
#   'depression'],
#  67: ['decade',
#   'highlights:',
#   '•',
#   'went',
#   'cruise',
#   '•',
#   'got',
#   'tattoos',
#   '•',
#   'moved',
#   'fayetteville',
#   '•',
#   'started',
#   'playing',
#   'd&amp;d',
#   '•',
#   'started',
#   'podcast',
#   '•',
#   'ren',
#   'fest',
#   'weekends',
#   '•',
#   'board',
#   'game',
#   'nights',
#   '•',
#   'diagnosed',
#   'w/',
#   'anxiety',
#   '&amp;',
#   'depression',
#   'i’m',
#   'sure',
#   'there’s',
#   'loads',
#   'more,',
#   'can’t',
#   'think',
#   '‘em',
#   'moment.'],
#  68: ['#thedecadethatwas',
#   '*',
#   'gave',
#   'work',
#   '-',
#   'emerita',
#   'professor',
#   '*',
#   'diagnosed',
#   'autosomal',
#   'dominant',
#   'polycystic',
#   'kidney',
#   'disease',
#   '*',
#   'memoir',
#   'depression',
#   'psychiatry',
#   'published',
#   '*sepsis',
#   '*',
#   '#rcpsych',
#   'presidential',
#   'medal',
#   '*moving',
#   'live',
#   '🏴\U000e0067\U000e0062\U000e0073\U000e0063\U000e0074\U000e007f',
#   'again!'],
#  69: ['won’t',
#   'go',
#   'specifics',
#   'happened',
#   'i’ll',
#   'share',
#   'ive',
#   'diagnosed',
#   'i’ve',
#   'thought',
#   'told',
#   'they’re',
#   'unable',
#   'fully',
#   'diagnose',
#   'rn.',
#   'ptsd,',
#   'severe',
#   'anxiety/depression,',
#   'bipolar',
#   ',',
#   'possible',
#   'did/schizophrenia',
#   'cont.'],
#  70: ['fucking',
#   'crazy',
#   'diagnosed',
#   'depression',
#   'anxiety',
#   'got',
#   'girlfriend',
#   'feel',
#   'like',
#   'finally',
#   'found',
#   'real',
#   'identity',
#   'personality',
#   'im',
#   'much',
#   'comfortable',
#   'everyone',
#   'feel',
#   'like',
#   'ups',
#   'downs',
#   'hope',
#   'treats',
#   'yall',
#   'well',
#   '🤍'],
#  71: ['confirm.',
#   'ever',
#   'since',
#   'diagnosed',
#   '&amp;',
#   'started',
#   'sleeping',
#   'cpap,',
#   'life',
#   'changed.',
#   "i'm",
#   'rested',
#   'hours',
#   'sleep.',
#   'no',
#   'dozing',
#   'day,',
#   'headaches,',
#   'needing',
#   'cups',
#   'coffee.',
#   'depression',
#   '&amp;',
#   'motivation',
#   'improved.',
#   'blood',
#   'pressure',
#   'down.',
#   'congrats',
#   'diagnosis!'],
#  72: ['last',
#   'decade,',
#   'i:',
#   '-',
#   'gave',
#   'birth',
#   'another',
#   'marvelous',
#   'son',
#   '-',
#   'burnt',
#   'work',
#   '-',
#   'got',
#   'diagnosed',
#   'severe',
#   'depression',
#   '+',
#   'ptsd',
#   'raped',
#   '-',
#   'got',
#   'abandoned',
#   'husband',
#   '-',
#   'divorced',
#   '-',
#   'transitioned',
#   'full',
#   'veganism',
#   '/2'],
#  73: ['past',
#   'decade',
#   'gotten',
#   'divorced',
#   'parents',
#   'diagnosed',
#   'bipolar',
#   'manic',
#   'depression',
#   'hospitalized',
#   'times',
#   'due',
#   'attemted',
#   'suicide',
#   'met',
#   'amazing',
#   'people',
#   'gave',
#   'light',
#   'squared',
#   'away',
#   'scholarship',
#   'far',
#   'years',
#   'fun',
#   'happy',
#   'start',
#   'new',
#   'one',
#   '😁'],
#  74: ['cn:',
#   'mental',
#   'health',
#   'start',
#   'decade,',
#   'not',
#   'anxiety',
#   'depression.',
#   'middle',
#   'decade,',
#   'diagnosed',
#   'ocd.',
#   'end',
#   'decade,',
#   'medication',
#   'handle',
#   'it.',
#   'working,',
#   'mostly.',
#   'got',
#   'good',
#   'writing',
#   'it.',
#   '#2009vs2019'],
#  75: ['“mental',
#   'illness”',
#   'downward',
#   'spiral',
#   'led',
#   'there.',
#   'not',
#   'imaginary',
#   'mental',
#   'illness.',
#   'diagnosed',
#   'doctor',
#   'prescribed',
#   'pills.',
#   '“bi-polar”',
#   'vibrating',
#   'back',
#   'forth',
#   'poles',
#   'mania',
#   'depression.',
#   'prescribed',
#   'meds,',
#   'not',
#   'take',
#   'them.',
#   'glad',
#   'bout',
#   'that.'],
#  76: ['dont',
#   'like',
#   'saying',
#   'without',
#   'evaluated/diagnosed',
#   'think',
#   'important',
#   'tell',
#   "i'm",
#   'probably',
#   'dealing',
#   'depression',
#   'not',
#   'way',
#   'teen.',
#   "i'm",
#   'gonna',
#   'work',
#   'towards',
#   'finding',
#   'something',
#   'combat',
#   'i-'],
#  77: [',',
#   'diagnosed',
#   'severe',
#   'anxiety,',
#   'depression,',
#   'ocd',
#   'traumatic',
#   'childhood.',
#   '(age',
#   ').',
#   'started',
#   'non',
#   'profit',
#   'travelled',
#   'dc',
#   'twice,',
#   'go',
#   'school,',
#   'apartment',
#   'car,',
#   'manic',
#   'depression',
#   '(bipolar',
#   'disorder).',
#   'i’m',
#   ',',
#   'days.'],
#  78: ['😺✏',
#   '—',
#   'sent',
#   'days',
#   'ago.',
#   'news',
#   'flash',
#   'diagnosed',
#   'depression',
#   'not',
#   'like',
#   'chose',
#   'feel',
#   'way.…'],
#  79: ['going',
#   'super',
#   'long',
#   'thread',
#   'decade',
#   'honestly',
#   "don't",
#   'want',
#   'ill',
#   'blog.',
#   'quick',
#   'recap.',
#   'graduated',
#   'high',
#   'school,',
#   'diagnosed',
#   'anxiety',
#   'clinical',
#   'depression,',
#   'dating',
#   'one',
#   'best',
#   'friends,',
#   'got',
#   'engaged',
#   '&amp;',
#   'eventually'],
#  80: ['guilt',
#   'anxiety',
#   'punishments.',
#   'time',
#   'cried',
#   'trouble.',
#   'told',
#   'lazy',
#   'unmotivated.',
#   'fault.',
#   'even',
#   'though',
#   'i’d',
#   'diagnosed',
#   'adhd',
#   'depression'],
#  81: ['actually,',
#   'year',
#   'along',
#   'rough',
#   'enough.',
#   'diagnosed',
#   'depression,',
#   'faced',
#   'redundancy',
#   'third',
#   'time,',
#   'involved',
#   'two',
#   'crashes,',
#   'assaulted.',
#   'still,',
#   'i’ve',
#   'survived',
#   'it,',
#   'lot',
#   'offer',
#   'already!'],
#  82: ['take',
#   'feel',
#   'special',
#   'heart',
#   'cuz',
#   'released',
#   'little',
#   'time',
#   'got',
#   'serious',
#   'case',
#   'anxiety',
#   '&amp;',
#   'depression.',
#   'around',
#   'time',
#   'mina',
#   'also',
#   'diagnosed',
#   '&amp;',
#   'seeing',
#   'recovery',
#   'helped',
#   'mine.',
#   'feel',
#   'special',
#   'made',
#   'realize',
#   "i'm",
#   'not',
#   'alone',
#   '💕💕'],
#  83: [':',
#   'met',
#   'current',
#   'bf,',
#   'literally',
#   'love',
#   'first',
#   'sight',
#   '(yes),',
#   'new',
#   'job',
#   'working',
#   'nights',
#   'destroyed',
#   'me,',
#   'diagnosed',
#   'anxiety',
#   '&amp;',
#   'depression,',
#   'gained',
#   'shit',
#   'tonne',
#   'weight,',
#   'lost',
#   'friends',
#   'diagnosis',
#   'full',
#   'support',
#   'bf',
#   'entire',
#   'time,',
#   'ended',
#   'year',
#   'low'],
#  84: ['depression',
#   'free',
#   'ngayong',
#   '.',
#   'opo,',
#   'clinically',
#   'diagnosed',
#   'po.'],
#  85: ['gets',
#   'even',
#   'weirder',
#   'bipolar.',
#   'depression',
#   'kills',
#   'sex',
#   'drive.',
#   'mania',
#   'makes',
#   'insatiable',
#   'gay/bi.',
#   'got',
#   'diagnosed,',
#   'confused',
#   'long',
#   'time.',
#   'no',
#   'one',
#   'believes',
#   'person’s',
#   'sexuality',
#   'change',
#   'not',
#   'uncommon',
#   'bipolar.'],
#  86: ['close',
#   'friends',
#   'betraying',
#   'me,',
#   'first',
#   'heartbreak,',
#   'loosing',
#   'uncle',
#   'middle',
#   'st',
#   'semester',
#   'college,',
#   'finding',
#   'grandma',
#   'stage',
#   'lung',
#   'cancer',
#   'even',
#   'diagnosed',
#   'depression',
#   'getting',
#   'help',
#   'throughout',
#   'trials,',
#   'learned'],
#  87: ['she’s',
#   'diagnosed',
#   'depression.',
#   'pernah',
#   'surrender',
#   'dekat',
#   'hospital',
#   'sebab',
#   'almost',
#   'suicide.',
#   'listen',
#   'listen',
#   'listen.',
#   'don’t',
#   'judge.',
#   'just,',
#   'listen',
#   'utter',
#   'good',
#   'words'],
#  88: ['january',
#   'st',
#   "i'm",
#   'atheist',
#   'left',
#   'ministry',
#   'years',
#   'ago.',
#   'went',
#   'college',
#   'got',
#   'job',
#   'accounting.',
#   "i'm",
#   'non',
#   'binary,',
#   'diagnosed',
#   'autism,',
#   'married',
#   'woman',
#   'dreams,',
#   'youtuber.',
#   'still',
#   'struggle',
#   'depression',
#   'nowhere',
#   'near',
#   'bad.',
#   "i'm",
#   'happy.'],
#  89: ['last',
#   'decade',
#   'ups',
#   'downs.',
#   'diagnosed',
#   'autism,',
#   'still',
#   'battling',
#   'depression.',
#   'came',
#   'family',
#   'became',
#   'uncle',
#   'gorgeous',
#   'nieces',
#   'nephew',
#   '❤️'],
#  90: ['-', 'year', 'everyone', 'diagnosed', 'depression.'],
#  91: ['year',
#   'god',
#   'damn',
#   'roller',
#   'coaster.',
#   'switched',
#   'jobs',
#   'several',
#   'times',
#   'got',
#   'diagnosed',
#   'depression.',
#   'good',
#   'news',
#   'kicked',
#   'it’s',
#   'ass',
#   'i’m',
#   'better',
#   'i’ve',
#   'ever',
#   'been.',
#   'oh',
#   'yeah',
#   'became',
#   'dad.',
#   'bring',
#   '.',
#   '🤘🤘🤘'],
#  92: ['last',
#   'decade',
#   'hard',
#   'one.',
#   'wouldnt',
#   'change',
#   'it.',
#   'decade',
#   'put',
#   'many',
#   'challenges,',
#   'diagnosed',
#   'depression',
#   'general',
#   'anxiety',
#   'disorder,',
#   'attempted',
#   'suicide',
#   'twice.',
#   'also',
#   'made',
#   'new',
#   'friends',
#   'life,',
#   'discovered'],
#  93: ['within',
#   'last',
#   'decade',
#   'hairs',
#   'got',
#   'shorter.',
#   'i’ve',
#   'got',
#   'fatter.',
#   'i’ve',
#   'diagnosed',
#   'depression',
#   'anxiety.',
#   'ive',
#   'contemplated',
#   'suicide.',
#   'i’ve',
#   'completed',
#   'degree.',
#   'got',
#   'dog.',
#   'i’ve',
#   'had…'],
#  94: ['grandma',
#   'diagnosed',
#   'th',
#   'stage',
#   'cancer',
#   'till',
#   'eventually',
#   'succumbed',
#   'illness',
#   'completely',
#   'numbed',
#   'helpless.',
#   'another',
#   'dose',
#   'depression',
#   'hit',
#   'hardest.',
#   'year',
#   'later,',
#   'house',
#   'gets',
#   'sprayed',
#   'god',
#   'literally',
#   'reason',
#   'still',
#   'here.'],
#  95: ['crazy',
#   'year,',
#   'co',
#   'hosted',
#   'performed',
#   'stand',
#   'comedy',
#   'show',
#   ',',
#   'lots',
#   'travelling',
#   'including',
#   'chicago',
#   '&amp;',
#   'marrakech.',
#   'summer',
#   'highs,',
#   'late',
#   'autumn',
#   'worst',
#   '#depression',
#   'life,',
#   'november',
#   'diagnosed',
#   '#bipolar.'],
#  96: ['.',
#   'got',
#   'hired',
#   '.',
#   'diagnosed',
#   'anxiety',
#   'disorder',
#   '.',
#   'thesis',
#   'approved',
#   'tested',
#   '.',
#   'failing',
#   'thesis',
#   '.',
#   'fell',
#   'depression',
#   '.',
#   'got',
#   'fired',
#   '.',
#   'fell',
#   'depression',
#   '(again)',
#   '.',
#   'accepting',
#   'fate',
#   '.',
#   'struggling',
#   'life',
#   '.',
#   'ready',
#   'face',
#   'new',
#   'reality'],
#  97: ['clinically',
#   'diagnosed',
#   'depression',
#   'anxiety',
#   'disorder.',
#   'pero',
#   'naniniwala',
#   'akong',
#   'hindi',
#   'ito',
#   'ang',
#   'makakapagbagsak',
#   'sa',
#   'akin.',
#   'hello',
#   'b*tch.',
#   'keep',
#   'up!',
#   'charot'],
#  98: ['percent',
#   'drug',
#   'reactions,',
#   'akathisia,',
#   'wrongly',
#   'diagnosed',
#   '“agitated',
#   'depression”',
#   'eact',
#   '“treatment”??',
#   '%??'],
#  99: ['sadly,i’ve',
#   'not',
#   'much',
#   'happy',
#   'last',
#   'years.continued',
#   'problems',
#   'hydrocephalus,diagnosed',
#   'depression',
#   'anxiety',
#   'worse',
#   'losing',
#   'mum.but',
#   'glad',
#   'joined',
#   'twitter',
#   '.got',
#   'know',
#   'many',
#   'lovely',
#   'people.1/2'],
#  100: ['entered',
#   'aged',
#   ',',
#   'not',
#   'diagnosed',
#   'another',
#   '&amp;',
#   '/2',
#   'years.',
#   "i've",
#   'countries',
#   'graduated',
#   'twice.',
#   "i've",
#   'learned',
#   'speak',
#   'spanish,',
#   'manage',
#   'adhd,',
#   'depression,',
#   'anxiety,',
#   'ocd,',
#   'multiple',
#   'years',
#   'recovery',
#   'self',
#   'harm.',
#   'bring',
#   ',',
#   "i'm",
#   'ready.'],
#  101: ['diagnosed', 'depression...'],
#  102: ['crazy',
#   'old',
#   'year',
#   'wasn’t',
#   'it?',
#   'not',
#   'best',
#   'one',
#   'personal',
#   'level',
#   '-',
#   'got',
#   'diagnosed',
#   'depression,',
#   'long',
#   'term',
#   'relationship',
#   'ended,',
#   'last',
#   'couple',
#   'months',
#   'struggle.',
#   'makes',
#   'determined',
#   'improve'],
#  103: ['also',
#   'spirit',
#   'memorializing',
#   'decade,in',
#   '’s',
#   'i:',
#   'got',
#   'ba,',
#   'moved',
#   'new',
#   'city,got',
#   'ma,got',
#   'diagnosed',
#   'stage',
#   'cancer',
#   'nye',
#   ',',
#   'battle',
#   'stage',
#   'cancer(mostly',
#   'luck',
#   'still',
#   'cool),and',
#   'pulled',
#   'long',
#   'hazy',
#   'depression',
#   'followed',
#   'it!!'],
#  104: ['not',
#   'good',
#   'year',
#   'me,',
#   'diagnosed',
#   'clinical',
#   'depression',
#   'earlier',
#   'year',
#   'taking',
#   'medicines',
#   'past',
#   'months',
#   'help',
#   'get',
#   'everyday.',
#   'cannot',
#   'cope',
#   'properly',
#   'academics',
#   'responsibilities',
#   'handling.'],
#  105: ['officially',
#   'diagnosed',
#   'depression',
#   'year,',
#   'struggling',
#   'decade',
#   'it.',
#   'began',
#   'medication',
#   'despite',
#   'unfounded',
#   'fear',
#   'messing',
#   'body.',
#   'it’s',
#   'not',
#   'perfect',
#   'science',
#   'cannot',
#   'say',
#   'entirely',
#   'happy',
#   'like',
#   'women',
#   'commercials.'],
#  106: ['#dailydecision',
#   '#injuredworkers',
#   '#whatdoyouthink',
#   '#reallife',
#   'severed',
#   'nerve',
#   'cleaning',
#   'stove.',
#   'pain',
#   'hand,',
#   'arm,',
#   'neck,',
#   'shoulder,',
#   'neck,',
#   'headaches.',
#   'diagnosed',
#   'depression',
#   'accident.',
#   'still',
#   'cant',
#   'move',
#   'without',
#   'pain',
#   'write.',
#   'think?'],
#  107: ['/❄️',
#   'goodbye',
#   'fucking',
#   'sucked.',
#   'well..',
#   'maybe',
#   'not',
#   'completely,',
#   'plenty',
#   'bad',
#   'things',
#   'like',
#   'multiple',
#   'panic',
#   'attacks,',
#   'bouts',
#   'depression,',
#   'diagnosed',
#   'cancer.',
#   'not',
#   'fun.',
#   'thank',
#   'twitter',
#   'rp',
#   'community',
#   'making',
#   'bearable.'],
#  108: ['diagnosed',
#   'major',
#   'depression',
#   'disorder',
#   'anxiety',
#   'last',
#   '.',
#   'not',
#   'much',
#   'known',
#   'people',
#   'not',
#   'educated',
#   'mh',
#   'back',
#   'then.',
#   'scared',
#   'judged',
#   "don't",
#   'want',
#   'special',
#   'treatment',
#   'case',
#   'people',
#   'know.',
#   'want',
#   'live',
#   'normal',
#   'person'],
#  109: ['s:',
#   '-attended',
#   'graduated',
#   'dream',
#   'school',
#   '-found',
#   'learned',
#   'happy',
#   'shoes',
#   '-got',
#   'diagnosed',
#   'treated',
#   'depression',
#   '-left',
#   'country',
#   'first',
#   '(and',
#   'second)',
#   'time',
#   '-repeatedly',
#   'loved',
#   'lost',
#   '-saw',
#   'super',
#   'bowl',
#   'win',
#   '(go',
#   'packers)'],
#  110: ['decade',
#   'thoughts:',
#   'dad',
#   'left',
#   'month',
#   'went',
#   'away',
#   'college,',
#   'divorce',
#   'years',
#   'long',
#   'upsetting.',
#   'college',
#   'hell',
#   'bad',
#   'breakup',
#   'hospital',
#   'finally',
#   'decided',
#   'get',
#   'medicated',
#   'diagnosed',
#   'depression'],
#  111: ["i've",
#   'never',
#   'serious',
#   'new',
#   "year's",
#   'resolutions',
#   'past',
#   'goal',
#   'recover',
#   'think',
#   'getting',
#   'diagnosed',
#   'would',
#   'hurt',
#   'would',
#   'help',
#   'right',
#   "i'm",
#   'pretty',
#   'certain',
#   'year',
#   'put',
#   'back',
#   'depression'],
#  112: ['mid', 'october,', 'got', 'diagnosed', 'depression.', 'pits!!!'],
#  113: ['-',
#   'downs',
#   '|',
#   'behavioral',
#   'health',
#   'center.',
#   'diagnosed',
#   'major',
#   'depression',
#   'anxiety',
#   ',&amp;',
#   'symptoms',
#   'schizophrenia.',
#   'dealing',
#   'lawsuit',
#   'deferred',
#   'graduation',
#   'spring',
#   '‘19.',
#   'suicide',
#   'attempts',
#   ',',
#   'physical',
#   'fights',
#   'mom,',
#   'lost',
#   'belongings'],
#  114: ['think',
#   "i'd",
#   'chronical',
#   "'s",
#   'tweets.',
#   ':',
#   'boring',
#   'high',
#   'school',
#   'life',
#   ':',
#   'went',
#   'first',
#   'concerts/diagnosed',
#   'depression',
#   ':',
#   'graduated',
#   'high',
#   'school',
#   ':',
#   'started',
#   'college',
#   ':',
#   'began',
#   'relationship',
#   ':',
#   'finished',
#   'college'],
#  115: [':',
#   '-',
#   'lost',
#   'grandfather',
#   '💔',
#   '-',
#   'resigned',
#   'toxic',
#   'work',
#   'environment',
#   '-',
#   'got',
#   'healthy',
#   'work',
#   'environment',
#   '-',
#   'got',
#   'diagnosed',
#   'depression',
#   'anxiety',
#   '-',
#   'got',
#   'help',
#   'got',
#   'admitted',
#   '(still',
#   'work',
#   'progress)',
#   '-',
#   'got',
#   'cousy',
#   'apartment',
#   'yessssses'],
#  116: ['not',
#   'best',
#   'year.',
#   'decided',
#   'go',
#   'back',
#   'school',
#   'year...',
#   'son',
#   'diagnosed',
#   'adhd',
#   'borderline',
#   'autism',
#   'traits',
#   'anxiety',
#   'i’ve',
#   'dealt',
#   'major',
#   'depression',
#   'anxiety...',
#   'meanwhile',
#   'daughter',
#   'shinning-bright'],
#  117: ['it’s',
#   'hell',
#   'decade.',
#   'last',
#   'years',
#   'i:',
#   '-',
#   'met',
#   'pretty',
#   'much',
#   'best',
#   'friends,',
#   'including',
#   'one',
#   'person',
#   'i’d',
#   'like',
#   'spend',
#   'rest',
#   'life',
#   'with.',
#   '-',
#   'came',
#   'out,',
#   'family.',
#   '-',
#   'anxiety',
#   'depression',
#   'diagnosed,',
#   'went',
#   'therapy',
#   'started',
#   'meds.'],
#  118: ['much',
#   'happened',
#   'year',
#   'got',
#   'diagnosed',
#   'post',
#   'natal',
#   'depression.',
#   'thankfully',
#   'come.',
#   'albert',
#   'first',
#   'birthday.',
#   'went',
#   'away',
#   'first',
#   'holiday',
#   'abroad.',
#   'saw',
#   'one',
#   'best',
#   'friends',
#   'the…'],
#  119: ['not',
#   'lot',
#   'know',
#   'diagnosed',
#   'pcos',
#   'depression.',
#   'it’s',
#   'hard',
#   'accept,',
#   'always',
#   'kinda',
#   'knew,',
#   'know?',
#   'live',
#   'better',
#   'life',
#   '(i',
#   'work',
#   'literally',
#   'everyday,',
#   'think',
#   'better',
#   'healthier,',
#   'etc)',
#   'want',
#   'tackle',
#   'personal',
#   'themes',
#   'photography.'],
#  120: ['last',
#   'decade',
#   'roller',
#   'coaster',
#   'iv',
#   'loved',
#   'iv',
#   'lost',
#   'iv',
#   'laughed',
#   'iv',
#   'cried',
#   'got',
#   'see',
#   'not',
#   'new',
#   '#starwars',
#   'movies.',
#   'mental',
#   'breakdown',
#   'got',
#   'diagnosed',
#   'depression',
#   'became',
#   'uncle.',
#   'parents',
#   'beat',
#   'cancers',
#   'ass',
#   'sister',
#   'got',
#   'married',
#   '-'],
#  121: ['yr',
#   'got',
#   'diagnosed',
#   'w',
#   'depression.',
#   'also',
#   'year',
#   'headed',
#   'first',
#   'projects',
#   'got',
#   'cpsni',
#   '&amp;',
#   'cmh.',
#   'also',
#   'yr',
#   'got',
#   'meds.',
#   'wild',
#   'k',
#   'n',
#   'w',
#   'wilder',
#   'i’m',
#   '🤩'],
#  122: ['trying',
#   'one',
#   '"my',
#   'art',
#   'summary',
#   'decade"',
#   'things',
#   'makes',
#   'depressed',
#   'seeing',
#   'time',
#   'diagnosed',
#   'anxiety',
#   'depression',
#   'drawings',
#   'dead',
#   'muted',
#   'colors,',
#   'like',
#   "didn't",
#   'notice',
#   'back',
#   'looking',
#   'back',
#   'it,',
#   'kinda',
#   'sad...'],
#  123: ['it’s',
#   'ok',
#   'white',
#   'still',
#   'trending',
#   'i’ve',
#   'diagnosed',
#   'depression',
#   'anxiety',
#   'since',
#   'i’ve',
#   'never',
#   'insecure',
#   'folks',
#   'keep',
#   'going',
#   'chans',
#   'news',
#   'world',
#   'views',
#   'though'],
#  124: ['autism',
#   'adhd',
#   'anxiety',
#   'depression',
#   'ptsd',
#   'ocd',
#   'not',
#   'officially',
#   'diagnosed',
#   'would',
#   'difficult',
#   'untangle',
#   'conditions'],
#  125: ['loved',
#   'one',
#   'diagnosed',
#   'depression,',
#   'easy',
#   'find',
#   'best',
#   'people',
#   'around',
#   'help',
#   'you.',
#   'join',
#   'mydepressionteam',
#   'meet',
#   'people:'],
#  126: ['.',
#   'diagnosed',
#   'anxiety',
#   'disorder',
#   'depression.',
#   '.diagnosed',
#   'sakit',
#   'tulang',
#   '.',
#   'mental',
#   'breakdown',
#   'everyday',
#   'sampai',
#   'ayah',
#   'kena',
#   'panggil',
#   'ustaz.',
#   '.',
#   'struggle',
#   'study',
#   '.',
#   'got',
#   'ukm.',
#   '.',
#   'masuk',
#   'ukm',
#   'rasa',
#   "i'm",
#   'not',
#   'belong',
#   'anxiety.'],
#  127: ['-',
#   'high',
#   'school',
#   'lactose',
#   'intolerant',
#   '-',
#   'got',
#   'gcses,',
#   'passed',
#   'driving',
#   'test,',
#   'diagnosed',
#   'depression',
#   'anxiety,',
#   'stopped',
#   'lactose',
#   'intolerant,',
#   'got',
#   'levels,',
#   'got',
#   'degree',
#   'finished',
#   'pgce.',
#   'interesting',
#   'decade',
#   'suppose',
#   '#2009vs2019'],
#  128: ['worst',
#   'year',
#   'life...',
#   'got',
#   'sexually',
#   'assaulted',
#   'diagnosed',
#   'depression',
#   'anxiety.',
#   'can’t',
#   'come',
#   'quicker',
#   'get',
#   'better'],
#  129: ['-found',
#   'love',
#   'life',
#   '-broke',
#   'butt',
#   '-got',
#   'fired',
#   'd*sney',
#   '-got',
#   'new',
#   'school',
#   '-started',
#   'working',
#   'consistently',
#   '-started',
#   'going',
#   'therapy',
#   '-found',
#   'forever',
#   'friends',
#   '-got',
#   'diagnosed',
#   'anxiety',
#   '&amp;',
#   'depression',
#   '-finally',
#   'went',
#   'new',
#   'york',
#   '-met',
#   'laura',
#   'osnes'],
#  130: ['i’ve',
#   'diagnosed',
#   'major',
#   'depression,',
#   'generalized',
#   'anxiety,',
#   'ocd,',
#   'ptsd,',
#   '&amp;',
#   'borderline',
#   'personality',
#   'disorder.',
#   'i’m',
#   'not',
#   'saying',
#   'want',
#   'pity—i',
#   'really',
#   'don’t.',
#   'i’m',
#   'saying',
#   'people',
#   'know',
#   'many',
#   'dommes',
#   'lot',
#   'going',
#   '&amp;',
#   'still',
#   'amazing',
#   'badasses.',
#   'let’s',
#   'normalize'],
#  131: ['however',
#   'near',
#   'end',
#   'year',
#   'things',
#   'start',
#   'go',
#   'downhill.',
#   'besides',
#   'situations',
#   'rather',
#   'not',
#   'mention,',
#   'found',
#   'diagnosed',
#   'depression,',
#   'doesnt',
#   'help',
#   'also',
#   'anxiety',
#   'disorder',
#   'lol.',
#   'mental',
#   'state',
#   'great',
#   'really.'],
#  132: ['selesai',
#   'kesedihan',
#   'muncul',
#   'lagi',
#   'kesedihan',
#   'yg',
#   'lain.',
#   'tiba',
#   'tiba',
#   'adik',
#   'nelpon',
#   'gue',
#   'katanya',
#   'mau',
#   'm4t1',
#   'aja.',
#   'kalap',
#   'bgt',
#   'mana',
#   'waktu',
#   'itu',
#   'gue',
#   'lagi',
#   'gak',
#   'deket',
#   'dia.',
#   'ahirnya',
#   'besoknya',
#   'w',
#   'bawa',
#   'berobat',
#   'dan',
#   'dia',
#   'clinically',
#   'diagnosed',
#   'severe',
#   'depression..'],
#  133: ['decade:',
#   '-',
#   'moved',
#   'back',
#   'japan',
#   'years',
#   'taipei',
#   '-',
#   'became',
#   'survivor',
#   '-',
#   'diagnosed',
#   'depression,',
#   'anxiety,',
#   'ptsd,',
#   'chronic',
#   'migraines',
#   '-',
#   'graduated',
#   'hs',
#   '-',
#   'moved',
#   'boston',
#   'university',
#   '-',
#   'got',
#   'teaching',
#   'license',
#   '-',
#   'got',
#   'teaching',
#   'job',
#   'vietnam',
#   '🙌🏻👩🏻\u200d🏫❤️'],
#  134: ['yeah,',
#   'man.',
#   "i'm",
#   'oldest',
#   'parents',
#   'divorced,',
#   'dad',
#   'worked',
#   'lot',
#   'pretty',
#   'absent',
#   'emotionally',
#   'mom',
#   'diagnosed',
#   'severe',
#   'depression.',
#   'take',
#   'care',
#   "didn't",
#   'really',
#   'emotional',
#   'support',
#   'form',
#   'either',
#   'parent.',
#   'expected',
#   'deal'],
#  135: [':',
#   'failed',
#   'engagement',
#   'aggravated',
#   'depression',
#   'first',
#   'diagnosed',
#   'australia',
#   '.',
#   ':',
#   'attendance',
#   'work',
#   'performance',
#   'drastically',
#   'changed.',
#   ':',
#   'suicide',
#   'attempts',
#   'real.',
#   ':',
#   'brought',
#   'er',
#   'due',
#   'attempt.'],
#  136: ['oh',
#   'boy.',
#   '’s',
#   'interesting',
#   'say',
#   'least.',
#   'diagnosed',
#   'high',
#   'functioning',
#   'autism',
#   '(and',
#   'depression)',
#   'definitely',
#   'way',
#   'start',
#   'decade',
#   'off,',
#   'opened',
#   'lot',
#   'opportunities',
#   'me...',
#   '(1/2)'],
#  137: ['years',
#   'ago',
#   'diagnosed',
#   'anorexia',
#   'admitted',
#   'hospital.',
#   'year',
#   'later',
#   'diagnosed',
#   'clinical',
#   'depression.',
#   'year',
#   'tried',
#   'take',
#   'life.',
#   'two',
#   'years',
#   'later',
#   'admitted',
#   'hospital',
#   'again.',
#   'year',
#   'felt',
#   'feeling',
#   'positive',
#   'recovery',
#   '🦋',
#   '#decadeofchange'],
#  138: ['get',
#   'medical',
#   'help',
#   'diagnosed',
#   'depression',
#   'w/',
#   'melancholia.',
#   '😊'],
#  139: ['so,',
#   'whoever',
#   'yang',
#   'simply',
#   'say',
#   '"aku',
#   'depressed"',
#   'without',
#   'consult',
#   'dengan',
#   'pakar,',
#   'screw',
#   'you!',
#   'nak',
#   'dpt',
#   'apa?',
#   'simpati?',
#   'lol.',
#   'differentiate',
#   'prolong',
#   'sadness',
#   'ataupun',
#   'mmg',
#   'depression.',
#   'jgn',
#   'simply',
#   'self',
#   'diagnosed',
#   'ok?'],
#  140: ['highlights,',
#   'still',
#   'work-in-progress:',
#   '.',
#   'got',
#   'understudy',
#   'program',
#   'toward',
#   'promotion',
#   '.',
#   'finally',
#   'saw',
#   'psychiatrist',
#   'got',
#   'diagnosed',
#   'depression'],
#  141: ['also',
#   'run',
#   '"non-federally',
#   'activated.',
#   'splits',
#   'is,',
#   'near',
#   'figure',
#   'far,',
#   'went',
#   'iraq',
#   'afghanistan,',
#   "didn't.",
#   'hell,',
#   "didn't",
#   'go.',
#   'ptsd',
#   'diagnosed.',
#   'treatment',
#   'destabilization,',
#   'depression(1986)'],
#  142: ['diagnosed',
#   '#autism',
#   'aged',
#   ':',
#   'bbc.co.uk/news/health-50…',
#   '#aspergers',
#   '#asd',
#   '#mentalhealth',
#   '#depression'],
#  143: ['solitude,',
#   'began',
#   'pick',
#   'up,',
#   'consulted',
#   'specialist',
#   'started',
#   'take',
#   'antidepressants.',
#   'yep,',
#   'diagnosed',
#   'depression',
#   '(again).',
#   'know',
#   'not',
#   'best',
#   'past',
#   'months,',
#   'poorly',
#   'school',
#   'job.',
#   'days',
#   '-4',
#   'hours'],
#  144: ['..',
#   'found',
#   'new',
#   'love',
#   '..',
#   'diagnosed',
#   'anxiety',
#   'disorder,',
#   'panic',
#   'disorder',
#   'severe',
#   'depression',
#   '..',
#   'took',
#   'medicines',
#   'everyday',
#   '..',
#   'battled',
#   'demons',
#   'greatly',
#   'changed',
#   'life',
#   'perspective',
#   'it.',
#   'total',
#   'twist',
#   'every',
#   'aspect.',
#   'proud',
#   'myself.',
#   '❤'],
#  145: ['diagnosed',
#   'moderate',
#   'anxiety',
#   'depression,',
#   'freely',
#   'admit',
#   'heavily',
#   'affected',
#   'life,',
#   'i’m',
#   'going',
#   'new',
#   'year',
#   'new',
#   'decade',
#   'finally',
#   'seeking',
#   'help',
#   'need,',
#   'thanks',
#   'close',
#   'special',
#   'me.'],
#  146: ['mine,',
#   'healed',
#   'fractured',
#   'bones.',
#   'done',
#   'leg',
#   'days',
#   '(never',
#   'before)',
#   'physiotherapy',
#   'specialist',
#   'diagnosed',
#   'osteopenia',
#   '🙌🏼',
#   'active',
#   'person,',
#   '"depression"',
#   'moments',
#   'limitation',
#   'moving',
#   'around',
#   'alhamdulillah',
#   'healed',
#   'fast!'],
#  147: ['really',
#   'say',
#   'rollercoaster',
#   ',,,',
#   'graduated',
#   'honors',
#   'science',
#   'hs,',
#   'time',
#   'not',
#   'pass',
#   'sa',
#   'dream',
#   'school',
#   'ko',
#   '((what’s',
#   'good???))',
#   'diagnosed',
#   'manic',
#   '(bipolar)',
#   'depression',
#   '[[i’m',
#   'yari',
#   'na',
#   'sa',
#   'psych',
#   'ko',
#   'kasi',
#   'di',
#   'na',
#   'ako',
#   'bumalik]]'],
#  148: ['suffer',
#   'depression',
#   'anxiety..i',
#   'would',
#   'heart',
#   'broken',
#   'son',
#   'diagnosed',
#   'it.',
#   'feel',
#   'sad',
#   'you.',
#   'thank',
#   'sharing,',
#   'ever',
#   'need',
#   'chat',
#   'someone',
#   'feel',
#   'free',
#   'message',
#   'me.',
#   'can’t',
#   'much',
#   '“listen/read”',
#   'messages',
#   'supportive'],
#  149: ['latter',
#   'months',
#   'toughest',
#   "i've",
#   'recently',
#   'diagnosed',
#   'depression',
#   'anxiety',
#   'probably',
#   'reached',
#   'rock',
#   'bottom.',
#   'thankful',
#   'people',
#   'reached',
#   'whether',
#   "we're",
#   'close',
#   'not.',
#   'would',
#   'also',
#   'like',
#   'apologize',
#   'shutting',
#   'people',
#   'isolating',
#   ':((',
#   '++'],
#  150: ['i’ve',
#   'minor',
#   'ups',
#   'downs,',
#   'started',
#   'drama,',
#   'ended',
#   'others.',
#   'didn’t',
#   'expect',
#   'year',
#   'take',
#   'mental',
#   'toll',
#   'health',
#   'sanity.',
#   'span',
#   'year',
#   'diagnosed',
#   'anxiety,',
#   'depression,',
#   'gout,',
#   'arthritis,',
#   'conditions'],
#  151: ['study',
#   'explains',
#   'happens',
#   'brain',
#   'diffuse',
#   'essential',
#   'oils',
#   'many',
#   'diagnosed',
#   'adhd,',
#   'depression,',
#   'anxiety',
#   'sleep',
#   'disorders.',
#   ',',
#   'medical',
#   'expenditure',
#   'survey',
#   'determined',
#   'americans',
#   'take',
#   'psychiatric',
#   'medication',
#   'dail…'],
#  152: ['diagnosed',
#   'depression',
#   'social',
#   'anxiety/phobia.',
#   '😔',
#   'heard',
#   'lot',
#   '“being',
#   'young',
#   'depression”...',
#   'hugs',
#   'hon!',
#   '😘'],
#  153: ['planned',
#   'events',
#   'got',
#   'canceled',
#   'met',
#   'founder',
#   'musgrave',
#   'gin',
#   '(almost',
#   'worked',
#   'failed)',
#   'wine',
#   'founder',
#   'rebeth',
#   'wines',
#   'got',
#   'diagnosed',
#   'depression',
#   'sort',
#   'anxiety',
#   'moved',
#   'place',
#   'got',
#   'debt',
#   'started',
#   'youtube',
#   'one',
#   'gnt',
#   'picnic'],
#  154: ['went',
#   'doctor',
#   'diagnosed',
#   'depression,',
#   'get',
#   'boarding',
#   'school',
#   'lot',
#   'hates',
#   'managed',
#   'live',
#   'till',
#   'day🤘🏻',
#   'anxiety',
#   'class',
#   'also',
#   'lack',
#   'sleep',
#   'almost',
#   'everyday',
#   'performed',
#   'semester',
#   'gpa',
#   '🙌🏻',
#   'thank',
#   'whoever',
#   'stays'],
#  155: ['"people',
#   'w',
#   'asd',
#   'may',
#   'risk',
#   'getting',
#   'depression,',
#   'also',
#   'may',
#   'less',
#   'likely',
#   'diagnosed',
#   'w',
#   'depression',
#   '&amp;',
#   'support',
#   'networks',
#   'place',
#   'help',
#   'w',
#   'mental',
#   'illness',
#   'means',
#   'may',
#   'likely',
#   'take',
#   'lives',
#   'rather',
#   'successfully',
#   'treated"'],
#  156: ['years',
#   'depression',
#   'years',
#   'med',
#   'diagnosed',
#   'c-ptsd,',
#   'affection',
#   'others',
#   'painful,',
#   'surounded',
#   'people',
#   'feeling',
#   'lonely',
#   'wake',
#   'everyday',
#   'wondering',
#   'not',
#   'dead',
#   'yet',
#   'ولا',
#   'شيء',
#   'يمنحني',
#   'السلام.',
#   '#كلمه_اخيره__٢٠١٩'],
#  157: ['absolute',
#   'worst',
#   'year',
#   'life,',
#   'lost',
#   'stepbrother',
#   'unexpectedly,',
#   'diagnosed',
#   'depression',
#   'anxiety,',
#   'went',
#   'hardest',
#   'break',
#   'attempted',
#   'suicide.',
#   'however',
#   'year',
#   'also',
#   'got',
#   'uni',
#   'year',
#   'early,',
#   'healthy',
#   'outlook',
#   'life',
#   'now,',
#   'bring',
#   '❤️'],
#  158: ['getting',
#   'healthy.',
#   'husband',
#   'diagnosed',
#   'diabetes',
#   'depression/anxiety,',
#   'son',
#   'autism',
#   'binge',
#   'eating,',
#   'daughter',
#   'wants',
#   'get',
#   'shape',
#   'learn',
#   'wrestle.',
#   'get',
#   'hold',
#   'together.'],
#  159: ['jumpe',
#   'doktor',
#   'utk',
#   'dptkn',
#   'bantuan',
#   'psychologist.',
#   'diagnosed',
#   'depression&amp;panic',
#   'attack.',
#   'lose',
#   'weight,',
#   'attempting',
#   'suicide',
#   'changed',
#   'mind,',
#   'self',
#   'harm',
#   'feel',
#   'bit',
#   'better',
#   'now.',
# ...
#   'does.',
#   ':)',
#   'i’m',
#   'diagnosed',
#   'mental',
#   'health',
#   'disorders,',
#   'dog',
#   'helped',
#   'much.'],
#  936: ['😢',
#   'wasn´t',
#   'diagnosed',
#   'depression',
#   'vegan,',
#   'pretty',
#   'sure',
#   'was.',
#   'became',
#   'mentally',
#   'weak',
#   'unstable',
#   'general.'],
#  937: ["i'm",
#   'grateful',
#   'last',
#   'years.',
#   "i've",
#   'never',
#   'clinically',
#   'diagnosed',
#   'depression',
#   'anxiety,',
#   'know',
#   'something',
#   'unhealthy',
#   'going',
#   'brain.',
#   "i'm",
#   'grateful',
#   'could',
#   'stand',
#   'people',
#   'hurting',
#   'able',
#   'get',
#   'away',
#   'them.'],
#  938: ['crazy',
#   'thing',
#   'adhd',
#   'people',
#   'always',
#   'sort',
#   'mental',
#   'health',
#   'issue',
#   'due',
#   'adhd.',
#   'diagnosed',
#   'major',
#   'depression,',
#   'mild',
#   'anxiety,',
#   'adhd',
#   'one',
#   'day',
#   '😂',
#   'i’m',
#   'also',
#   'hypersensitive',
#   'got',
#   'synesthesia'],
#  939: ['agree.',
#   'losing',
#   'mother',
#   'last',
#   'year',
#   'i,',
#   'first',
#   'time,',
#   'diagnosed',
#   'depression.',
#   'got',
#   'treated,',
#   'also',
#   'take',
#   'medication.',
#   'sometimes',
#   'necessary',
#   'works'],
#  940: ['ppl',
#   'talking',
#   'crap',
#   'side',
#   'effects',
#   'medications,',
#   'don’t',
#   'know',
#   '“crap”',
#   'effects',
#   'not',
#   'taking',
#   'ure',
#   'actually',
#   'diagnosed',
#   'depression',
#   '(in',
#   'case,',
#   'non',
#   'natural',
#   'remedies',
#   'would',
#   'help).'],
#  941: ['self',
#   'diagnosed',
#   'severe',
#   'depression,',
#   'anxiety,',
#   'add,',
#   'insomnia,',
#   'ocd,',
#   'antisocial',
#   'personality',
#   'disorder,',
#   'ptsd,',
#   'bipolar',
#   'disorder,',
#   '&amp;',
#   'schizophrenia'],
#  942: ['diagnosed',
#   'depression',
#   'generalized',
#   'anxiety',
#   'disorder',
#   'goes',
#   'ignored',
#   'real',
#   'world',
#   'despite',
#   'care',
#   'oncologist',
#   'happy',
#   'know',
#   'don’t',
#   'cancer.',
#   'yes',
#   'it’s',
#   'frightening',
#   'journey',
#   'past',
#   'years.'],
#  943: ['forgot', 'felt', 'like', 'not', 'diagnosed', 'depression', ':/'],
#  944: ['diagnosed',
#   'depression',
#   'panic',
#   'disorder',
#   'suffering',
#   'mental',
#   'illnesses'],
#  945: ['im', 'waiting', 'diagnosed', 'depression', 'anxiety...'],
#  946: ['still',
#   'work',
#   'progress',
#   "i'd",
#   'like',
#   'something',
#   'mum',
#   'well.',
#   'mum',
#   'ms',
#   'wheelchair',
#   'dad',
#   'diagnosed',
#   'cancer',
#   'heroes.',
#   'also',
#   'fallout',
#   'thing',
#   'turned',
#   'whenever',
#   'depression',
#   'flaired'],
#  947: ['seeing',
#   'adults',
#   'life',
#   'finally',
#   'coming',
#   'terms',
#   'serious',
#   'depression',
#   'actually',
#   'right',
#   'one',
#   'loved',
#   'ones',
#   'diagnosed'],
#  948: ['.',
#   'idk',
#   'bcs',
#   'never',
#   'really',
#   'diagnosed',
#   "i'm",
#   'scared',
#   'go',
#   'doctor',
#   'shdjdn',
#   'recently',
#   'saw',
#   'test',
#   'online',
#   'said',
#   'legit',
#   'tried',
#   'says',
#   'major',
#   'depression',
#   'bipolar',
#   'disorder',
#   'sooo',
#   'hsdjdh'],
#  949: ['family',
#   'doctor',
#   'incredible',
#   'daughter',
#   'since',
#   'dx',
#   '.',
#   'never',
#   'beg.',
#   'moves,',
#   'quickly,',
#   'services,',
#   'referrals',
#   'accessible',
#   'us.',
#   'honestly',
#   "don't",
#   'know',
#   'would',
#   'without',
#   'him,',
#   'especially',
#   'now.',
#   'kid',
#   'diagnosed',
#   'depression.'],
#  950: ['earlier',
#   'year',
#   'diagnosed',
#   'clinical',
#   'depression.',
#   'nature',
#   'big',
#   'part',
#   'getting',
#   'better.',
#   'may',
#   'next',
#   'year',
#   'i’ll',
#   'climbing',
#   'snowdon',
#   'dark',
#   'aid',
#   'mind.',
#   'you’d',
#   'like',
#   'sponsor',
#   'would',
#   'ace'],
#  951: ['also',
#   'believe',
#   'lot',
#   'gets',
#   'diagnosed',
#   '"depression"',
#   'serotonin',
#   'issue'],
#  952: ['people',
#   'act',
#   'like',
#   'clinically-diagnosed',
#   'people',
#   'depression',
#   'valid',
#   'depressed',
#   'individuals.',
#   'honestly,',
#   'fuck',
#   '🖕🏻'],
#  953: ['diagnosed',
#   'camhs',
#   'ocd',
#   'four',
#   'years',
#   'ago',
#   'received',
#   'cbt',
#   'worked',
#   'really',
#   'well.',
#   'think',
#   'current',
#   'depression',
#   'partly',
#   'triggered',
#   'ocd.',
#   'i’m',
#   'bit',
#   'cross',
#   'gp',
#   'didn’t',
#   'seem',
#   'concerned,',
#   'knowing',
#   'history'],
#  954: ['anita',
#   'totally',
#   'empathise',
#   'diagnosed',
#   'severe',
#   'emotional',
#   'depression',
#   '&amp;',
#   'severe',
#   'mental',
#   'breakdown,',
#   'see',
#   'coming,',
#   'not',
#   'know',
#   'journey',
#   'long',
#   'sun',
#   'shine',
#   'return.',
#   'anita',
#   'please',
#   'say',
#   'what/when',
#   'want🙌🏼'],
#  955: ['feel',
#   'major',
#   'spiritual',
#   'level.',
#   'diagnosed',
#   'adhd',
#   'child',
#   'growing',
#   'major',
#   'ups',
#   'downs.',
#   'though',
#   'seems',
#   'mostly',
#   'downs',
#   'hinders',
#   'job',
#   'almost',
#   'time,',
#   'caused',
#   'major',
#   'depression',
#   'issues',
#   ':/'],
#  956: ['oh',
#   'agree!!!!',
#   'despite',
#   'copy',
#   'scan',
#   'diagnosed',
#   'yrs',
#   'ago',
#   'vascular',
#   'dementia',
#   'physciatrist',
#   'telling',
#   'depression.',
#   'hr',
#   'meeting',
#   '!!!!!!!!!!'],
#  957: ['ugh',
#   'something',
#   'like',
#   'depression',
#   'half',
#   'years',
#   '(nothing',
#   'diagnosed',
#   "don't",
#   'like',
#   'call',
#   'depression)',
#   'terrorizing',
#   "i'm",
#   'constantly',
#   'scared',
#   "i'm",
#   'going',
#   'path',
#   'again.',
#   "can't",
#   'believe',
#   'people',
#   'find',
#   'aesthetic',
#   'wtf'],
#  958: ['wish',
#   'well,',
#   'personally',
#   'diagnosed',
#   'mental',
#   'illness',
#   'wife',
#   'has........',
#   'depression',
#   '/anxiety',
#   'hard',
#   'shift',
#   'anyone',
#   'connected.',
#   'battle',
#   'never',
#   'thought',
#   'would',
#   'face',
#   'ever,',
#   'continuous',
#   'battle.',
#   'stay',
#   'strong',
#   '💪'],
#  959: ['new',
#   'study',
#   'finds',
#   'one',
#   'three',
#   '#patients',
#   'newly',
#   'diagnosed',
#   'advanced-stage',
#   '#lungcancer',
#   'struggle',
#   'moderate',
#   'severe',
#   'symptoms',
#   '#depression'],
#  960: ['bad:',
#   'lost',
#   'lot',
#   'friends',
#   'close',
#   'me,',
#   'got',
#   'diagnosed',
#   'type',
#   'diabeties,',
#   'lost',
#   'grandfather',
#   'first',
#   'dog',
#   'span',
#   'week,',
#   'developed',
#   'severe',
#   'depression',
#   'anxiety.',
#   'used',
#   'happy',
#   'kid,',
#   'got',
#   'older',
#   'just....couldn’t',
#   'anymore.'],
#  961: ['+',
#   'doesn’t',
#   'need',
#   'people',
#   'pointing',
#   'like',
#   'it’s',
#   'flaw.',
#   'makes',
#   'people',
#   'insecure,',
#   'coming',
#   'someone',
#   'diagnosed',
#   'depression.',
#   'think',
#   'post',
#   'insensitive',
#   'comments',
#   'like',
#   'that.',
#   'mental',
#   'illnesses',
#   'not',
#   'adjectives.'],
#  962: ['year',
#   'hard.',
#   'first',
#   'got',
#   'sick',
#   'leave',
#   'stress',
#   'got',
#   'diagnosed',
#   'severe',
#   'depression.',
#   'it’s',
#   'almost',
#   'christmas,',
#   'got',
#   'bad',
#   'mood',
#   'drop.',
#   'new',
#   'years',
#   'eve',
#   'excactly',
#   'years',
#   'ago',
#   'lost',
#   'mom.',
#   'miss',
#   'much.',
#   'would',
#   'known',
#   '😞'],
#  963: ['thank',
#   'rajud',
#   'akong',
#   'maingun',
#   'guys',
#   'karun',
#   'nga',
#   'year',
#   'lisud',
#   'kaayu',
#   'sa',
#   'ngatanan',
#   'diagnosed',
#   'depression',
#   'pero',
#   'since',
#   'day',
#   'wa',
#   'jud',
#   'ko',
#   'ninyu',
#   'biyae',
#   'grabe',
#   'aside',
#   'sa',
#   'akong',
#   'pamilya',
#   'kamo',
#   'jud',
#   'ang',
#   'nitabang',
#   'nako',
#   'ikaduha',
#   'nga',
#   'family',
#   'hays',
#   'cebu',
#   'lifer',
#   'jud',
#   'tungud',
#   'ninyu.i',
#   'love',
#   'you!',
#   '❤️'],
#  964: ['.',
#   'moses-',
#   'reason',
#   'teach',
#   'anger',
#   'management',
#   'classes',
#   'aaron-',
#   'saw',
#   'god',
#   'eyes',
#   'destroy',
#   'pharoah',
#   'aaaaand',
#   'still',
#   'built',
#   'golden',
#   'calf.',
#   'samson-',
#   'committed',
#   'suicide',
#   'bc',
#   'woman.',
#   'solomon-',
#   'first',
#   'man',
#   'diagnosed',
#   'depression',
#   'bipolar',
#   'disorder.',
#   'im',
#   'not',
#   'done!'],
#  965: ['ya',
#   'doing?',
#   'diagnosed',
#   'anxiety,',
#   'depression',
#   'ptsd',
#   'early',
#   'year.',
#   'bucket',
#   'full,',
#   'last',
#   'drop',
#   'made',
#   'spill',
#   'over.'],
#  966: ['finally', 'clinically', 'diagnosed', 'depression!', 'wow', 'shocker!'],
#  967: ['yeah',
#   'remember',
#   'diagnosed',
#   'year',
#   'ago',
#   'depression',
#   'anxiety...',
#   'yeah',
#   'it’s',
#   'back',
#   'hitting',
#   'harder',
#   'ever',
#   ':('],
#  968: ['experienced',
#   'devastating',
#   'loss',
#   'love',
#   'due',
#   'spinal',
#   'stenosis',
#   'age',
#   'prior',
#   'diagnosis.',
#   'diagnosed',
#   'years',
#   'later.',
#   'horrible',
#   'pain.',
#   'depression',
#   'pain',
#   'lost',
#   'friends,',
#   'relationships,',
#   'life,',
#   'sorts',
#   'things',
#   'take',
#   'granted.'],
#  969: ["i've",
#   'learned',
#   'depression',
#   'since',
#   'getting',
#   'diagnosed',
#   'hate',
#   'helpless',
#   'makes',
#   'feel.',
#   'hard',
#   'enough',
#   'deal',
#   'things',
#   'going',
#   'well.',
#   'stay',
#   'strong,',
#   'broken',
#   'people',
#   'stick',
#   'together',
#   '&lt;3'],
#  970: ['take',
#   'long',
#   'time',
#   'find',
#   'right',
#   'combo',
#   'meds.',
#   "i've",
#   'dozens',
#   'medications',
#   'depression',
#   'anxiety',
#   'last',
#   'years',
#   'since',
#   'diagnosed.',
#   'sometimes',
#   "don't",
#   'work,',
#   'stop',
#   'working,',
#   'bad',
#   'side',
#   'effects.',
#   'hang',
#   'there.'],
#  971: ["i've",
#   'diagnosed',
#   'clinical',
#   'depression',
#   'know',
#   'tough.',
#   'even',
#   'though',
#   'high',
#   'standards',
#   'content,',
#   'know',
#   'depression',
#   'telling',
#   'might',
#   'putting',
#   '"sub',
#   'par"',
#   'content.',
#   'great,',
#   'keep',
#   '💪'],
#  972: ["he's",
#   'getting',
#   'lots',
#   'hate',
#   'knows,',
#   'reads',
#   'them.',
#   'breakdown',
#   'recently,',
#   'spamming',
#   'posts',
#   "that's",
#   'raised',
#   'concerns',
#   'fancafe(he',
#   'deleted',
#   'guess).',
#   "he's",
#   'also',
#   'reported',
#   'diagnosed',
#   'depression',
#   'panic',
#   'disorder',
#   'march.'],
#  973: ["he's",
#   'getting',
#   'lot',
#   'hate',
#   'breakdown',
#   'recently',
#   'fancafe,',
#   'spamming',
#   'lots',
#   'posts',
#   "that's",
#   'concerning',
#   'th',
#   'dec',
#   'midnight(i',
#   'think',
#   'deleted',
#   'already)',
#   "he's",
#   'reported',
#   'diagnosed',
#   'depression',
#   'panic',
#   'disorder',
#   'since',
#   'march.'],
#  974: ['got', 'diagnosed', 'lowkey', 'depression', 'today', '😔💔'],
#  975: ['‘oooh',
#   'x',
#   'fan',
#   'haha',
#   'bet',
#   'x',
#   'cured',
#   'depression',
#   'haha',
#   'self',
#   'diagnosed',
#   'depression,',
#   'haha',
#   'fake',
#   'depression’'],
#  976: ['find',
#   'new',
#   'joke.',
#   'i’m',
#   'sure',
#   'self',
#   'diagnosed',
#   'depression'],
#  977: ['semester',
#   'mentally',
#   'hardest',
#   'several',
#   'months',
#   'life.',
#   'diagnosed',
#   'depression',
#   'anxiety.',
#   'started',
#   'medicine',
#   'began',
#   'journey',
#   'getting',
#   'better.',
#   'so,',
#   'proud',
#   'say',
#   'finished',
#   'gpa.',
#   'may',
#   'not',
#   'seem',
#   'like',
#   'much',
#   'it’s',
#   'everything',
#   'me.'],
#  978: ['celiac',
#   'serious',
#   'condition',
#   'lead',
#   'stunted',
#   'growth,',
#   'malnutrition,',
#   'malabsorption,',
#   'epilepsy,',
#   'depression,',
#   'anxiety,',
#   'joint',
#   'pain,',
#   'cancer,',
#   'infertility,',
#   'weak',
#   'bones,',
#   'peripheral',
#   'neuropathy.',
#   'it’s',
#   'important',
#   'diagnosed',
#   'soon',
#   'possible.'],
#  979: ['started',
#   'new',
#   'game',
#   'ulla',
#   'britta',
#   'diagnosed',
#   'depression',
#   'anxiety',
#   'classmates',
#   'mean',
#   'her,',
#   'cat',
#   'died,',
#   'seems',
#   'cured',
#   'depression.'],
#  980: ['im',
#   'sorry.',
#   'ill',
#   'let',
#   'here.',
#   'hirap',
#   'na',
#   'kasi',
#   'si',
#   'mommy.',
#   'diagnosed',
#   'depression,',
#   'may',
#   'sakit',
#   'pa,',
#   'may',
#   'vertigo.',
#   'ewan',
#   'ko',
#   'ba.',
#   'want',
#   'migrate',
#   'save',
#   'everything.'],
#  981: ['he’s',
#   'getting',
#   'lot',
#   'hate',
#   'days,',
#   'especially',
#   'dating',
#   'news',
#   'came',
#   '(which',
#   'find',
#   'ridiculous',
#   'reason',
#   'hate).',
#   'apparently',
#   'also',
#   'diagnosed',
#   'depression',
#   'he’s',
#   'taking',
#   'break',
#   'activities.'],
#  982: ['diagnosed',
#   'dępręssion',
#   '&amp;',
#   'recently',
#   'attãck',
#   'ãntis',
#   'caused',
#   'fall',
#   'deeper',
#   '&amp;',
#   'cancelled',
#   'showings.',
#   '😔',
#   'it’s',
#   'sad.',
#   '😔'],
#  983: ['kd',
#   'fans',
#   'asked',
#   'politely',
#   'support',
#   'hearts',
#   'words',
#   'encouragement',
#   'social',
#   'media.',
#   'recently',
#   'took',
#   'break',
#   'hate',
#   'comments',
#   'antis',
#   'gotten',
#   'hand',
#   'fancafe.',
#   'also',
#   'recently',
#   'diagnosed',
#   'depression',
#   'hate',
#   'made',
#   'worse.'],
#  984: ['credentials:',
#   '"dr.',
#   'lucy',
#   'johnstone',
#   'worked',
#   'many',
#   'years',
#   'frontline',
#   'adult',
#   'mental',
#   'health',
#   'services',
#   '-',
#   'helping',
#   'may',
#   'diagnosed',
#   'conditions',
#   'like',
#   'schizophrenia,',
#   'bipolar',
#   'disorder',
#   'clinical',
#   'depression."',
#   'insider',
#   'system.'],
#  985: ['thomas',
#   'recently',
#   'diagnosed',
#   'depression,which',
#   'suprise',
#   'sides.',
#   'days',
#   'thomas',
#   'started',
#   'taking',
#   'depression',
#   'pills',
#   'started',
#   'act',
#   'bit',
#   'insane,dangerous',
#   'extremely',
#   'aggressive',
#   'someone',
#   'tried',
#   'take',
#   'away'],
#  986: ['many',
#   'different',
#   'mental',
#   'health',
#   'diagnoses',
#   'receive',
#   'reaching',
#   'current',
#   'diagnosis?',
#   'diagnosed',
#   'depression,',
#   'anxiety,',
#   'bipolar',
#   'disorder,',
#   'ocd,',
#   'finally',
#   'schizoaffective',
#   'disorder.',
#   '#schizochat'],
#  987: ['patients,',
#   'diagnosis',
#   'process',
#   'journey.',
#   'diagnosed',
#   'depression,',
#   'anxiety,',
#   'bipolar',
#   'ii',
#   'disorder,',
#   'ocd,',
#   'finally',
#   'schizoaffective',
#   'disorder.',
#   '#schizochat'],
#  988: ['same.',
#   'first',
#   'time',
#   'someone',
#   'diagnosed',
#   'depression.',
#   'didnt',
#   'feel',
#   'like',
#   'depression',
#   'then,',
#   'argue',
#   'dr',
#   'right'],
#  989: ['trader',
#   'diagnosed',
#   'depression',
#   'excessive',
#   'working',
#   'wins',
#   'tribunal',
#   'claim',
#   'trader',
#   'became',
#   'ill',
#   'working',
#   'excessive',
#   'hours',
#   'understaffed',
#   'department',
#   'discriminated',
#   'mental...',
#   'post',
#   'trader',
#   'diagnose...',
#   'via'],
#  990: ['found', 'yesterday', 'diagnosed', 'depression', 'wow'],
#  991: ['one',
#   'thing',
#   'people',
#   'mental',
#   'illness',
#   'share',
#   'anxiety',
#   'form.',
#   'also,',
#   'many',
#   'people',
#   'diagnosed',
#   'bipolar',
#   'depression,',
#   'little',
#   'odd',
#   'happens.'],
#  992: ['got', 'depression', 'anxiety', 'diagnosed', 'today', 'that’s', 'cute'],
#  993: ['back',
#   'problems',
#   'plantar',
#   'fasciitis',
#   '-',
#   'oh,',
#   "let's",
#   'go',
#   'ahead',
#   'throw',
#   'depression',
#   "i'm",
#   'it.',
#   'wife',
#   'bedridden',
#   'decade',
#   'finally',
#   'diagnosed',
#   'trigeminal',
#   'neuralgia,',
#   'much',
#   'pain',
#   'even',
#   'sit',
#   'up.'],
#  994: ['know',
#   'feel.',
#   'list',
#   'goes',
#   'adhd,',
#   'anxiety,',
#   'depression,',
#   'severe',
#   'stomach',
#   'issues',
#   'still',
#   'yet',
#   'diagnosed',
#   'cause',
#   'i’m',
#   'dumbass',
#   'top',
#   'previous',
#   'things,',
#   'fucked',
#   'joints,',
#   'eye',
#   'problems,',
#   'list',
#   'goes',
#   'on.',
#   'it’s',
#   'wonder',
#   'i’m',
#   'alive',
#   'tbh',
#   'lol'],
#  995: ['study',
#   'women',
#   'diagnosed',
#   'depression',
#   'showed',
#   'exercise',
#   'intensity',
#   'significantly',
#   'decreased',
#   'feelings',
#   'depression.',
#   'find',
#   'sauna',
#   'assist',
#   'begin',
#   'joyful,',
#   'natural,',
#   'healthy',
#   'living',
#   'journey!',
#   'jnhlifestyles.com'],
#  996: ['would',
#   'also',
#   'like',
#   'point',
#   'doctor',
#   'originally',
#   'diagnosed',
#   'treat',
#   'depression/anxiety',
#   'pediatric',
#   'pcp,',
#   'not',
#   'like',
#   'something',
#   'primary',
#   'care',
#   'physicians',
#   "don't"],
#  997: ['psa:',
#   'not',
#   'diagnosed',
#   'professional',
#   'mental',
#   'health',
#   'issue',
#   '(i.e.',
#   'depression,',
#   'anxiety,',
#   'panic',
#   'disorder',
#   'etc)',
#   'not',
#   'use',
#   'excuses',
#   'things',
#   'jokes!!!!',
#   'you’re',
#   'making',
#   'light',
#   'us',
#   'live',
#   'debilitating',
#   'illnesses',
#   'everyday'],
#  998: ['😺✏',
#   '—',
#   'cause',
#   'patients',
#   'i’ve',
#   'seen',
#   'diagnosed',
#   'depression,',
#   'anxiety,',
#   'ptsd',
#   'cause',
#   'discriminated',
#   'against,',
#   'bullied..',
#   'etc',
#   '.',
#   'discrimination',
#   'bee…'],
#  999: ['.',
#   'previously',
#   'diagnosed',
#   'clinical',
#   'depression',
#   'i’m',
#   'much',
#   'better',
#   '(not',
#   'treatment',
#   'anymore)',
#   'that’s',
#   'one',
#   'reasons',
#   'choosing',
#   'therapist.'],
#  ...}

# %%
from nltk.tokenize.treebank import TreebankWordDetokenizer

# %%
TreebankWordDetokenizer().detokenize(tweets_clean_dict[1])
# Out:
# 'decade, started graduated high school, lost grandma dad nearly lost myself, met childhood hero twice, started college, diagnosed depression gad, met another hero gave much hope, /3'

# %%
# Here we detokenize all the tweets
detokenized_dict = {}
for key, items in tweets_clean_dict.items():
    detokenized_dict[key] = TreebankWordDetokenizer().detokenize(tweets_clean_dict[key])
# detokenized_dict

# %%
detokenized_dict[0]
# Out:
# 'think self discovery coolest part this. outgoing kid, completely retreated shell years ago diagnosed depression anxiety. working way back even best support system very-'

# %%
detokenized_df = pd.DataFrame.from_dict(detokenized_dict, orient='index')

# %%
detokenized_df.head(10)
detokenized_df.rename(columns={0:'pre_processed'}, inplace=True)

# %%
from transformers import AutoModelForSequenceClassification
from transformers import TFAutoModelForSequenceClassification
from transformers import AutoTokenizer
import numpy as np
from scipy.special import softmax
import csv
import urllib.request

# %%
# Here we're using the roberta-base models 
task1='sentiment'
MODEL1 = f"cardiffnlp/twitter-roberta-base-{task1}"
tokenizer1 = AutoTokenizer.from_pretrained(MODEL1)

task2='emotion'
MODEL2 = f"cardiffnlp/twitter-roberta-base-{task2}"
tokenizer2 = AutoTokenizer.from_pretrained(MODEL2)

task3='irony'
MODEL3 = f"cardiffnlp/twitter-roberta-base-{task3}"
tokenizer3 = AutoTokenizer.from_pretrained(MODEL3)

# %%
# download label mapping sentiment
mapping_link = f"https://raw.githubusercontent.com/cardiffnlp/tweeteval/main/datasets/{task1}/mapping.txt"
with urllib.request.urlopen(mapping_link) as f:
    html = f.read().decode('utf-8').split("\n")
    csvreader = csv.reader(html, delimiter='\t')
labels1 = [row[1] for row in csvreader if len(row) > 1]
labels1
# Out:
# ['negative', 'neutral', 'positive']

# %%
# download label mapping emotion
mapping_link = f"https://raw.githubusercontent.com/cardiffnlp/tweeteval/main/datasets/{task2}/mapping.txt"
with urllib.request.urlopen(mapping_link) as f:
    html = f.read().decode('utf-8').split("\n")
    csvreader = csv.reader(html, delimiter='\t')
labels2 = [row[1] for row in csvreader if len(row) > 1]
labels2
# Out:
# ['anger', 'joy', 'optimism', 'sadness']

# %%
# download label mapping irony
mapping_link = f"https://raw.githubusercontent.com/cardiffnlp/tweeteval/main/datasets/{task3}/mapping.txt"
with urllib.request.urlopen(mapping_link) as f:
    html = f.read().decode('utf-8').split("\n")
    csvreader = csv.reader(html, delimiter='\t')
labels3 = [row[1] for row in csvreader if len(row) > 1]
labels3
# Out:
# ['non_irony', 'irony']

# %%
model1 = TFAutoModelForSequenceClassification.from_pretrained(MODEL1)
model2 = TFAutoModelForSequenceClassification.from_pretrained(MODEL2)
model3 = TFAutoModelForSequenceClassification.from_pretrained(MODEL3)
# Out:
# All model checkpoint layers were used when initializing TFRobertaForSequenceClassification.
#
# All the layers of TFRobertaForSequenceClassification were initialized from the model checkpoint at cardiffnlp/twitter-roberta-base-sentiment.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFRobertaForSequenceClassification for predictions without further training.
# All model checkpoint layers were used when initializing TFRobertaForSequenceClassification.
#
# All the layers of TFRobertaForSequenceClassification were initialized from the model checkpoint at cardiffnlp/twitter-roberta-base-emotion.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFRobertaForSequenceClassification for predictions without further training.
# All model checkpoint layers were used when initializing TFRobertaForSequenceClassification.
#
# All the layers of TFRobertaForSequenceClassification were initialized from the model checkpoint at cardiffnlp/twitter-roberta-base-irony.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFRobertaForSequenceClassification for predictions without further training.

# %%
# this function return labels for sentiment
def return_labels1(text):
    encoded_input = tokenizer1(text, return_tensors='tf')
    output = model1(encoded_input)
    scores = output[0][0].numpy()
    scores = softmax(scores)
    ranking = np.argsort(scores)
    ranking = ranking[::-1]
    label1 = labels1[ranking[0]]
    return label1

# %%
# this function return labels for emotions
def return_labels2(text):
    encoded_input = tokenizer2(text, return_tensors='tf')
    output = model2(encoded_input)
    scores = output[0][0].numpy()
    scores = softmax(scores)
    ranking = np.argsort(scores)
    ranking = ranking[::-1]
    label2 = labels2[ranking[0]]
    return label2

# %%
# this function return labels for irony
def return_labels3(text):
    encoded_input = tokenizer3(text, return_tensors='tf')
    output = model3(encoded_input)
    scores = output[0][0].numpy()
    scores = softmax(scores)
    ranking = np.argsort(scores)
    ranking = ranking[::-1]
    label3 = labels3[ranking[0]]
    return label3

# %%
# this function return probabilities to analize how "sure" the model is
def return_prob1(text):
    encoded_input = tokenizer1(text, return_tensors='tf')
    output = model1(encoded_input)
    scores = output[0][0].numpy()
    scores = softmax(scores)
    ranking = np.argsort(scores)
    ranking = ranking[::-1]
    return np.sort(scores)[-1]

# %%
# this function return probabilities to analize how "sure" the model is
def return_prob2(text):
    encoded_input = tokenizer2(text, return_tensors='tf')
    output = model2(encoded_input)
    scores = output[0][0].numpy()
    scores = softmax(scores)
    ranking = np.argsort(scores)
    ranking = ranking[::-1]
    return np.sort(scores)[-1]

# %%
# this function return probabilities to analize how "sure" the model is
def return_prob3(text):
    encoded_input = tokenizer3(text, return_tensors='tf')
    output = model3(encoded_input)
    scores = output[0][0].numpy()
    scores = softmax(scores)
    ranking = np.argsort(scores)
    ranking = ranking[::-1]
    return np.sort(scores)[-1]

# %%
detokenized_df['label_sentiment'] = detokenized_df['pre_processed'].apply(lambda x: return_labels1(x))
detokenized_df['probability_sentiment'] = detokenized_df['pre_processed'].apply(lambda x: return_prob1(x))

detokenized_df['label_emotion'] = detokenized_df['pre_processed'].apply(lambda x: return_labels2(x))
detokenized_df['probability_emotion'] = detokenized_df['pre_processed'].apply(lambda x: return_prob2(x))

detokenized_df['label_irony'] = detokenized_df['pre_processed'].apply(lambda x: return_labels3(x))
detokenized_df['probability_irony'] = detokenized_df['pre_processed'].apply(lambda x: return_prob3(x))

detokenized_df

# %%
official_df = pd.concat([depression_df[['renderedContent']], detokenized_df], axis = 1)
official_df

# %%
official_df.to_csv('./preprocessed_data/2020/depression_2020.csv', sep=',', index=False, encoding='utf-8-sig')

# %%
#official_df
