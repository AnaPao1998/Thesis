# %%
# Imports
import os
import pandas as pd

# %%
# Here we read the csv file that that contains anxious tweets from 2019
anxiety1_2019_df1 = pd.read_csv("./tweets_2019/anxiety/diag_socialanxiety.csv")

# %%
#anxiety1_2019_df1

# %%
# Here we read the csv file that that contains anxious tweets from 2019
anxiety2_2019_df2 = pd.read_csv("./tweets_2019/anxiety/hate_socialanxiety.csv")

# %%
#anxiety2_2019_df2

# %%
frames = [anxiety1_2019_df1, anxiety2_2019_df2]

# %%
# Here we concatenate the df's
result_anxiety_2019 = pd.concat(frames)

# %%
#result_anxiety_2019

# %%
# Here we export the tweets deleting the duplicated ones 
result_anxiety_2019.drop_duplicates().to_csv('./merged_data/2019/anxiety_2019.csv', sep=',', index=False, encoding='utf-8-sig')

# %%
# Here we read the csv file that that contains depressed tweets from 2019
depression1_2019_df1 = pd.read_csv("./tweets_2019/depression/diag_depression.csv")

# %%
#depression1_2019_df1

# %%
# Here we read the csv file that that contains depressed tweets from 2019
depression2_2019_df2 = pd.read_csv("./tweets_2019/depression/hate_depression.csv")

# %%
#depression2_2019_df2

# %%
frames2 = [depression1_2019_df1, depression2_2019_df2]

# %%
# Here we concatenate the df's
result_depression_2019 = pd.concat(frames2)

# %%
#result_depression_2019

# %%
# Here we export the tweets deleting the duplicated ones
result_depression_2019.drop_duplicates().to_csv('./merged_data/2019/depression_2019.csv', sep=',', index=False, encoding='utf-8-sig')

# %%
result_depression_2019.drop_duplicates()
# Out:
#                                                    url  \
# 0    https://twitter.com/tarottubbo/status/12121613...
# 1    https://twitter.com/leah_valerie/status/121216...
# 2    https://twitter.com/itsTerru/status/1212159833...
# 3    https://twitter.com/DrLichita/status/121215856...
# 4    https://twitter.com/jodiesbaby/status/12121584...
# ..                                                 ...
# 995  https://twitter.com/rikahimechan/status/120654...
# 996  https://twitter.com/GoddessShanell_/status/120...
# 997  https://twitter.com/KBDaMarathonMan/status/120...
# 998  https://twitter.com/itsEndz/status/12065378353...
# 999  https://twitter.com/Star_55/status/12065296197...
#
#                           date  \
# 0    2019-12-31 23:59:28+00:00
# 1    2019-12-31 23:54:23+00:00
# 2    2019-12-31 23:53:19+00:00
# 3    2019-12-31 23:48:18+00:00
# 4    2019-12-31 23:47:42+00:00
# ..                         ...
# 995  2019-12-16 12:04:07+00:00
# 996  2019-12-16 11:51:11+00:00
# 997  2019-12-16 11:44:12+00:00
# 998  2019-12-16 11:33:31+00:00
# 999  2019-12-16 11:00:52+00:00
#
#                                                content  \
# 0    i think self discovery has been the coolest pa...
# 1    In this decade, I started and graduated high s...
# 2    10 years ago I was diagnosed with ADHD and put...
# 3    &amp; ALSO THIS DECADE:\n•2 miscarriages\n•Pai...
# 4    guys o can’t wait for 2020. 2019 has genuinely...
# ..                                                 ...
# 995  My biggest flex this year is i got worse depre...
# 996  I can hear the depression when I talk to her. ...
# 997  GM all my beautiful people on the inside.  Let...
# 998  Long story short, I hate xmas with a passion. ...
# 999  depression december is real. god i hate this m...
#
#                                        renderedContent                   id  \
# 0    i think self discovery has been the coolest pa...  1212161379257462785
# 1    In this decade, I started and graduated high s...  1212160098593857536
# 2    10 years ago I was diagnosed with ADHD and put...  1212159833530609664
# 3    &amp; ALSO THIS DECADE:\n•2 miscarriages\n•Pai...  1212158568088125440
# 4    guys o can’t wait for 2020. 2019 has genuinely...  1212158419639185411
# ..                                                 ...                  ...
# 995  My biggest flex this year is i got worse depre...  1206545538474098690
# 996  I can hear the depression when I talk to her. ...  1206542283987927041
# 997  GM all my beautiful people on the inside.  Let...  1206540524657807365
# 998  Long story short, I hate xmas with a passion. ...  1206537835387539456
# 999  depression december is real. god i hate this m...  1206529619790155781
#
#                                                   user outlinks tcooutlinks  \
# 0    {'username': 'tarottubbo', 'displayname': 'ash...       []          []
# 1    {'username': 'leah_valerie', 'displayname': 'l...       []          []
# 2    {'username': 'itsTerru', 'displayname': '「 T e...       []          []
# 3    {'username': 'DrLichita', 'displayname': 'Dr. ...       []          []
# 4    {'username': 'jodiesbaby', 'displayname': 'les...       []          []
# ..                                                 ...      ...         ...
# 995  {'username': 'rikahimechan', 'displayname': 'f...       []          []
# 996  {'username': 'GoddessShanell_', 'displayname':...       []          []
# 997  {'username': 'KBDaMarathonMan', 'displayname':...       []          []
# 998  {'username': 'itsEndz', 'displayname': 'Endz',...       []          []
# 999  {'username': 'Star_55', 'displayname': 'Star 🏳...       []          []
#
#      replyCount  retweetCount  ...  quoteCount       conversationId  lang  \
# 0             1             0  ...           0  1212160817849913344    en
# 1             1             0  ...           0  1212160098593857536    en
# 2             1             0  ...           0  1212159832117194755    en
# 3             0             0  ...           0  1212158470868406274    en
# 4             1             0  ...           0  1212158419639185411    en
# ..          ...           ...  ...         ...                  ...   ...
# 995           1             0  ...           0  1206545538474098690    en
# 996           1             1  ...           0  1206541960397426689    en
# 997           0             0  ...           0  1206540524657807365    en
# 998           1             0  ...           0  1206537835387539456    en
# 999           0             0  ...           0  1206529619790155781    en
#
#                                                 source  \
# 0    <a href="http://twitter.com/download/iphone" r...
# 1    <a href="http://twitter.com/download/iphone" r...
# 2    <a href="http://twitter.com/download/android" ...
# 3    <a href="http://twitter.com/download/iphone" r...
# 4    <a href="http://twitter.com/download/iphone" r...
# ..                                                 ...
# 995  <a href="http://twitter.com/download/iphone" r...
# 996  <a href="http://twitter.com/download/iphone" r...
# 997  <a href="https://mobile.twitter.com" rel="nofo...
# 998  <a href="https://mobile.twitter.com" rel="nofo...
# 999  <a href="http://twitter.com" rel="nofollow">Tw...
#
#                                sourceUrl          sourceLabel  \
# 0     http://twitter.com/download/iphone   Twitter for iPhone
# 1     http://twitter.com/download/iphone   Twitter for iPhone
# 2    http://twitter.com/download/android  Twitter for Android
# 3     http://twitter.com/download/iphone   Twitter for iPhone
# 4     http://twitter.com/download/iphone   Twitter for iPhone
# ..                                   ...                  ...
# 995   http://twitter.com/download/iphone   Twitter for iPhone
# 996   http://twitter.com/download/iphone   Twitter for iPhone
# 997           https://mobile.twitter.com      Twitter Web App
# 998           https://mobile.twitter.com      Twitter Web App
# 999                   http://twitter.com   Twitter Web Client
#
#                                                  media retweetedTweet  \
# 0                                                  NaN            NaN
# 1                                                  NaN            NaN
# 2                                                  NaN            NaN
# 3                                                  NaN            NaN
# 4                                                  NaN            NaN
# ..                                                 ...            ...
# 995  [{'thumbnailUrl': 'https://pbs.twimg.com/tweet...            NaN
# 996                                                NaN            NaN
# 997                                                NaN            NaN
# 998                                                NaN            NaN
# 999                                                NaN            NaN
#
#      quotedTweet                                     mentionedUsers
# 0            NaN                                                NaN
# 1            NaN  [{'username': 'TheEllenShow', 'displayname': '...
# 2            NaN                                                NaN
# 3            NaN                                                NaN
# 4            NaN                                                NaN
# ..           ...                                                ...
# 995          NaN  [{'username': 'Stray_Kids', 'displayname': 'St...
# 996          NaN                                                NaN
# 997          NaN                                                NaN
# 998          NaN                                                NaN
# 999          NaN                                                NaN
#
# [4995 rows x 21 columns]
