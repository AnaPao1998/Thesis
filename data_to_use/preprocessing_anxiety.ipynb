# %%
import pandas as pd 
pd.set_option("display.max_colwidth", 400)
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns
import string
import nltk # for text manipulation
from nltk.corpus import stopwords
import preprocessor as p
import warnings 
warnings.filterwarnings("ignore", category=DeprecationWarning)

# %matplotlib inline

# %%
depression_df = pd.read_csv("./tweets_2019/anxiety/hate_socialanxiety.csv")

# %%
#depression_df.info()

# %%
depression_df.drop(["content","id","user","outlinks","tcooutlinks","replyCount","retweetCount","likeCount","quoteCount",\
                    "conversationId","lang","source","sourceUrl","sourceLabel","media","retweetedTweet","quotedTweet",\
                    "mentionedUsers"] ,axis=1, inplace=True)

# %%
depression_df.head(10)
# Out:
#                                                               url  \
# 0     https://twitter.com/bingustheory/status/1212151265637130240
# 1         https://twitter.com/isaokken/status/1212141248942944262
# 2        https://twitter.com/Naracooga/status/1212140689447882752
# 3       https://twitter.com/NikiSuffer/status/1212137436417003521
# 4       https://twitter.com/lolsportz1/status/1212135354465050624
# 5  https://twitter.com/Beardtimusprim1/status/1212130082124369922
# 6      https://twitter.com/sunsetbarbm/status/1212105449010368513
# 7  https://twitter.com/Pink_Flamingo74/status/1212101648006418438
# 8       https://twitter.com/SNAX0nHand/status/1212067189303500801
# 9       https://twitter.com/Kiwishiima/status/1212011384466235395
#
#                         date  \
# 0  2019-12-31 23:19:17+00:00
# 1  2019-12-31 22:39:28+00:00
# 2  2019-12-31 22:37:15+00:00
# 3  2019-12-31 22:24:19+00:00
# 4  2019-12-31 22:16:03+00:00
# 5  2019-12-31 21:55:06+00:00
# 6  2019-12-31 20:17:13+00:00
# 7  2019-12-31 20:02:07+00:00
# 8  2019-12-31 17:45:11+00:00
# 9  2019-12-31 14:03:26+00:00
#
#                                                                                                                                                                                                                                                                               renderedContent
# 0                                                                                                                                                                                                                                                   Sometimes I really hate my social anxiety
# 1                                                                                                                                                                                                                                                               i hate social anxiety omg 😓😓😓
# 2                                                                                                                                                                 Social anxiety says "stay home all day and do nothing"\nBut depression says "idiot why do you stay home all day I hate you"
# 3                                                                                                                                                                                In the space of an hour I've gone from drunk, to pounding migraine and social anxiety, I fucking hate myself
# 4  I love leaving the house (lol jk… fucking HATE it)\n\nTook a quick jaunt into town today and lit about $25-$30 on fire today in celebration of my #socialanxiety. Had a solid 2 opportunities after realizing it within 1 min of paying but.....\n#fuckit\n#goinghome\n#notworthanothermin
# 5                                                                                                                                                                              I used to not have social anxiety, but now I hate when people invite me places especially if they are not open
# 6                                                                                                                                                                                                                                          @depressionnote This is me I hate social anxiety 😓
# 7                                                                                                   Well I’m sitting here talking to you lot cus no one here is talking to me. I hate social gatherings. Hate crowds, hate loud music. Anxiety kicking in. Socially awkward and out of place.
# 8          On June 7, I gave my graduation speech, and it was one of the best days of my life. I hate public speaking, and I’ve got pretty bad social anxiety, but I had a story to tell, and it resonated with a lot of people, and I will always be extremely grateful for this experience.
# 9                                                        The worst part of my social anxiety is that I care too much about what other people think of me. That I feel like they constantly Judge me. And I HATE it that I now feel about gacha games this way, too. Idol Twt is so toxic, man

# %%
p.set_options(p.OPT.URL, p.OPT.EMOJI)
p.clean('Preprocessor is #awesome 👍 https://github.com/s/preprocessor')
# Out:
# 'Preprocessor is #awesome'

# %%
#def remove_punctuation(s):
 #   s = ''.join([i for i in s if i not in frozenset(string.punctuation)])
  #  return s
#depression_df['pre_proccessed'] = depression_df['pre_proccessed'].apply(remove_punctuation)
#depression_df.head(10)

# %%
p.set_options(p.OPT.URL, p.OPT.MENTION, p.OPT.NUMBER)
depression_df['pre_proccessed'] = depression_df['renderedContent'].apply(lambda x: p.clean(x)).str.lower()
#depression_df.head(10)

# %%
#removing punctuations, numbers and special characters
#regular expression = any character that's not az or AZ or #
depression_df['pre_proccessed']= depression_df['pre_proccessed'].str.replace("[^a-zA-Z#]", " ")

#removing short words
depression_df['pre_proccessed'] = depression_df['pre_proccessed'].apply(lambda x: ' '.join([w for w in x.split() if len(w) > 1]))

depression_df.head(10)
# Out:
# <ipython-input-9-07343f14a852>:3: FutureWarning: The default value of regex will change from True to False in a future version.
#   depression_df['pre_proccessed']= depression_df['pre_proccessed'].str.replace("[^a-zA-Z#]", " ")
#                                                               url  \
# 0     https://twitter.com/bingustheory/status/1212151265637130240
# 1         https://twitter.com/isaokken/status/1212141248942944262
# 2        https://twitter.com/Naracooga/status/1212140689447882752
# 3       https://twitter.com/NikiSuffer/status/1212137436417003521
# 4       https://twitter.com/lolsportz1/status/1212135354465050624
# 5  https://twitter.com/Beardtimusprim1/status/1212130082124369922
# 6      https://twitter.com/sunsetbarbm/status/1212105449010368513
# 7  https://twitter.com/Pink_Flamingo74/status/1212101648006418438
# 8       https://twitter.com/SNAX0nHand/status/1212067189303500801
# 9       https://twitter.com/Kiwishiima/status/1212011384466235395
#
#                         date  \
# 0  2019-12-31 23:19:17+00:00
# 1  2019-12-31 22:39:28+00:00
# 2  2019-12-31 22:37:15+00:00
# 3  2019-12-31 22:24:19+00:00
# 4  2019-12-31 22:16:03+00:00
# 5  2019-12-31 21:55:06+00:00
# 6  2019-12-31 20:17:13+00:00
# 7  2019-12-31 20:02:07+00:00
# 8  2019-12-31 17:45:11+00:00
# 9  2019-12-31 14:03:26+00:00
#
#                                                                                                                                                                                                                                                                               renderedContent  \
# 0                                                                                                                                                                                                                                                   Sometimes I really hate my social anxiety
# 1                                                                                                                                                                                                                                                               i hate social anxiety omg 😓😓😓
# 2                                                                                                                                                                 Social anxiety says "stay home all day and do nothing"\nBut depression says "idiot why do you stay home all day I hate you"
# 3                                                                                                                                                                                In the space of an hour I've gone from drunk, to pounding migraine and social anxiety, I fucking hate myself
# 4  I love leaving the house (lol jk… fucking HATE it)\n\nTook a quick jaunt into town today and lit about $25-$30 on fire today in celebration of my #socialanxiety. Had a solid 2 opportunities after realizing it within 1 min of paying but.....\n#fuckit\n#goinghome\n#notworthanothermin
# 5                                                                                                                                                                              I used to not have social anxiety, but now I hate when people invite me places especially if they are not open
# 6                                                                                                                                                                                                                                          @depressionnote This is me I hate social anxiety 😓
# 7                                                                                                   Well I’m sitting here talking to you lot cus no one here is talking to me. I hate social gatherings. Hate crowds, hate loud music. Anxiety kicking in. Socially awkward and out of place.
# 8          On June 7, I gave my graduation speech, and it was one of the best days of my life. I hate public speaking, and I’ve got pretty bad social anxiety, but I had a story to tell, and it resonated with a lot of people, and I will always be extremely grateful for this experience.
# 9                                                        The worst part of my social anxiety is that I care too much about what other people think of me. That I feel like they constantly Judge me. And I HATE it that I now feel about gacha games this way, too. Idol Twt is so toxic, man
#
#                                                                                                                                                                                                                                                pre_proccessed
# 0                                                                                                                                                                                                                     sometimes really hate my social anxiety
# 1                                                                                                                                                                                                                                     hate social anxiety omg
# 2                                                                                                                                        social anxiety says stay home all day and do nothing but depression says idiot why do you stay home all day hate you
# 3                                                                                                                                                      in the space of an hour ve gone from drunk to pounding migraine and social anxiety fucking hate myself
# 4   love leaving the house lol jk fucking hate it took quick jaunt into town today and lit about on fire today in celebration of my #socialanxiety had solid opportunities after realizing it within min of paying but #fuckit #goinghome #notworthanothermin
# 5                                                                                                                                                   used to not have social anxiety but now hate when people invite me places especially if they are not open
# 6                                                                                                                                                                                                                              this is me hate social anxiety
# 7                                                                               well sitting here talking to you lot cus no one here is talking to me hate social gatherings hate crowds hate loud music anxiety kicking in socially awkward and out of place
# 8  on june gave my graduation speech and it was one of the best days of my life hate public speaking and ve got pretty bad social anxiety but had story to tell and it resonated with lot of people and will always be extremely grateful for this experience
# 9                                     the worst part of my social anxiety is that care too much about what other people think of me that feel like they constantly judge me and hate it that now feel about gacha games this way too idol twt is so toxic man

# %%
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Usuario\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
stopwords_english = stopwords.words('english') 

print('Stop words\n')
print(stopwords_english)
# Out:
# Stop words
#
# ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', "you're", "you've", "you'll", "you'd", 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', "she's", 'her', 'hers', 'herself', 'it', "it's", 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', "that'll", 'these', 'those', 'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such', 'no', 'nor', 'not', 'only', 'own', 'same', 'so', 'than', 'too', 'very', 's', 't', 'can', 'will', 'just', 'don', "don't", 'should', "should've", 'now', 'd', 'll', 'm', 'o', 're', 've', 'y', 'ain', 'aren', "aren't", 'couldn', "couldn't", 'didn', "didn't", 'doesn', "doesn't", 'hadn', "hadn't", 'hasn', "hasn't", 'haven', "haven't", 'isn', "isn't", 'ma', 'mightn', "mightn't", 'mustn', "mustn't", 'needn', "needn't", 'shan', "shan't", 'shouldn', "shouldn't", 'wasn', "wasn't", 'weren', "weren't", 'won', "won't", 'wouldn', "wouldn't"]

# %%
'no' in stopwords_english
# Out:
# True

# %%
to_remove = ['no', 'not',"don't",'didn', "didn't", 'doesn', "doesn't", 'hadn', "hadn't", 'hasn', "hasn't"]
to_remove

#for item in to_remove:
 #    while item in stopwords_english:
 #       stopwords_english.remove(item)
            
[stopwords_english.remove(item) for item in to_remove if item in stopwords_english]
stopwords_english
# Out:
# ['i',
#  'me',
#  'my',
#  'myself',
#  'we',
#  'our',
#  'ours',
#  'ourselves',
#  'you',
#  "you're",
#  "you've",
#  "you'll",
#  "you'd",
#  'your',
#  'yours',
#  'yourself',
#  'yourselves',
#  'he',
#  'him',
#  'his',
#  'himself',
#  'she',
#  "she's",
#  'her',
#  'hers',
#  'herself',
#  'it',
#  "it's",
#  'its',
#  'itself',
#  'they',
#  'them',
#  'their',
#  'theirs',
#  'themselves',
#  'what',
#  'which',
#  'who',
#  'whom',
#  'this',
#  'that',
#  "that'll",
#  'these',
#  'those',
#  'am',
#  'is',
#  'are',
#  'was',
#  'were',
#  'be',
#  'been',
#  'being',
#  'have',
#  'has',
#  'had',
#  'having',
#  'do',
#  'does',
#  'did',
#  'doing',
#  'a',
#  'an',
#  'the',
#  'and',
#  'but',
#  'if',
#  'or',
#  'because',
#  'as',
#  'until',
#  'while',
#  'of',
#  'at',
#  'by',
#  'for',
#  'with',
#  'about',
#  'against',
#  'between',
#  'into',
#  'through',
#  'during',
#  'before',
#  'after',
#  'above',
#  'below',
#  'to',
#  'from',
#  'up',
#  'down',
#  'in',
#  'out',
#  'on',
#  'off',
#  'over',
#  'under',
#  'again',
#  'further',
#  'then',
#  'once',
#  'here',
#  'there',
#  'when',
#  'where',
#  'why',
#  'how',
#  'all',
#  'any',
#  'both',
#  'each',
#  'few',
#  'more',
#  'most',
#  'other',
#  'some',
#  'such',
#  'nor',
#  'only',
#  'own',
#  'same',
#  'so',
#  'than',
#  'too',
#  'very',
#  's',
#  't',
#  'can',
#  'will',
#  'just',
#  'don',
#  'should',
#  "should've",
#  'now',
#  'd',
#  'll',
#  'm',
#  'o',
#  're',
#  've',
#  'y',
#  'ain',
#  'aren',
#  "aren't",
#  'couldn',
#  "couldn't",
#  'haven',
#  "haven't",
#  'isn',
#  "isn't",
#  'ma',
#  'mightn',
#  "mightn't",
#  'mustn',
#  "mustn't",
#  'needn',
#  "needn't",
#  'shan',
#  "shan't",
#  'shouldn',
#  "shouldn't",
#  'wasn',
#  "wasn't",
#  'weren',
#  "weren't",
#  'won',
#  "won't",
#  'wouldn',
#  "wouldn't"]

# %%
'no' in stopwords_english
# Out:
# False

# %%
tokenized_tweet = depression_df['pre_proccessed'].apply(lambda x: x.split()) # tokenizing
#tokenized_tweet[:10]

# %%
# print(tokenized_tweet[:10])
tweets_clean_dict = {}
for num, sentence in enumerate(tokenized_tweet): #Go through every tweet in the list of tweets 
    tweets_clean = [] #create an empty list to save the cleaned tweet for each tweet 
    for word in sentence: #go through every word inside the "dirty" tweet and keep only the ones you want
        if (word not in stopwords_english): 
            tweets_clean.append(word)
    tweets_clean_dict[num] = tweets_clean #save the list of "cleaned" words (cleaned tweet) into a dict in the position num (0,1,2,... ,len(tweets))
tweets_clean_dict
# Out:
# {0: ['sometimes', 'really', 'hate', 'social', 'anxiety'],
#  1: ['hate', 'social', 'anxiety', 'omg'],
#  2: ['social',
#   'anxiety',
#   'says',
#   'stay',
#   'home',
#   'day',
#   'nothing',
#   'depression',
#   'says',
#   'idiot',
#   'stay',
#   'home',
#   'day',
#   'hate'],
#  3: ['space',
#   'hour',
#   'gone',
#   'drunk',
#   'pounding',
#   'migraine',
#   'social',
#   'anxiety',
#   'fucking',
#   'hate'],
#  4: ['love',
#   'leaving',
#   'house',
#   'lol',
#   'jk',
#   'fucking',
#   'hate',
#   'took',
#   'quick',
#   'jaunt',
#   'town',
#   'today',
#   'lit',
#   'fire',
#   'today',
#   'celebration',
#   '#socialanxiety',
#   'solid',
#   'opportunities',
#   'realizing',
#   'within',
#   'min',
#   'paying',
#   '#fuckit',
#   '#goinghome',
#   '#notworthanothermin'],
#  5: ['used',
#   'not',
#   'social',
#   'anxiety',
#   'hate',
#   'people',
#   'invite',
#   'places',
#   'especially',
#   'not',
#   'open'],
#  6: ['hate', 'social', 'anxiety'],
#  7: ['well',
#   'sitting',
#   'talking',
#   'lot',
#   'cus',
#   'no',
#   'one',
#   'talking',
#   'hate',
#   'social',
#   'gatherings',
#   'hate',
#   'crowds',
#   'hate',
#   'loud',
#   'music',
#   'anxiety',
#   'kicking',
#   'socially',
#   'awkward',
#   'place'],
#  8: ['june',
#   'gave',
#   'graduation',
#   'speech',
#   'one',
#   'best',
#   'days',
#   'life',
#   'hate',
#   'public',
#   'speaking',
#   'got',
#   'pretty',
#   'bad',
#   'social',
#   'anxiety',
#   'story',
#   'tell',
#   'resonated',
#   'lot',
#   'people',
#   'always',
#   'extremely',
#   'grateful',
#   'experience'],
#  9: ['worst',
#   'part',
#   'social',
#   'anxiety',
#   'care',
#   'much',
#   'people',
#   'think',
#   'feel',
#   'like',
#   'constantly',
#   'judge',
#   'hate',
#   'feel',
#   'gacha',
#   'games',
#   'way',
#   'idol',
#   'twt',
#   'toxic',
#   'man'],
#  10: ['super',
#   'excited',
#   '#winnercrosstourmanila',
#   'first',
#   'concert',
#   'ever',
#   'social',
#   'anxiety',
#   'hate',
#   'crowd',
#   'ignoring',
#   'fear',
#   'anxiety',
#   'attack',
#   'started',
#   'listening',
#   'kpop',
#   'early',
#   'became',
#   'winner',
#   'fan',
#   'months',
#   'ago',
#   'everything',
#   'new'],
#  11: ['literally',
#   'tries',
#   'humble',
#   'people',
#   'shit',
#   'buys',
#   'expensive',
#   'shit',
#   'shit',
#   'nobody',
#   'ever',
#   'pleased',
#   'sad',
#   'even',
#   'says',
#   'doesn',
#   'log',
#   'twitter',
#   'even',
#   'social',
#   'media',
#   'lot',
#   'general',
#   'bc',
#   'get',
#   'anxiety',
#   'hate'],
#  12: ['spent',
#   'great',
#   'deal',
#   'career',
#   'trying',
#   'help',
#   'people',
#   'depression',
#   'anxiety',
#   'disorders',
#   'bipolar',
#   'disorder',
#   'etc',
#   'reason',
#   'social',
#   'workers',
#   'councelers',
#   'burnout',
#   'hate',
#   'say',
#   'people',
#   'beyond',
#   'help',
#   'least',
#   'help',
#   'good',
#   'talk'],
#  13: ['get',
#   'saying',
#   'social',
#   'anxiety',
#   'really',
#   'bad',
#   'hate',
#   'attention',
#   'days',
#   'comfortable',
#   'exposed',
#   'comfortable',
#   'talking',
#   'people',
#   'comfortable',
#   'depressings',
#   'days'],
#  14: ['hate', 'social', 'situations', 'no', 'alcohol', '#socialanxiety'],
#  15: ['also', 'really', 'hate', 'social', 'anxiety', 'hate', 'much'],
#  16: ['bad',
#   'social',
#   'anxiety',
#   'panic',
#   'attack',
#   'pull',
#   'highway',
#   'hate',
#   'like'],
#  17: ['work',
#   'christmas',
#   'party',
#   'social',
#   'anxiety',
#   'hate',
#   'small',
#   'talk',
#   'decided',
#   'get',
#   'comfort',
#   'zone',
#   'go'],
#  18: ['hate',
#   'ppl',
#   'misuse',
#   'depression',
#   'anxiety',
#   'like',
#   'claim',
#   'something',
#   'know',
#   'handle',
#   'real',
#   'life',
#   'get',
#   'social',
#   'media',
#   'clout',
#   'shits',
#   'annoying'],
#  19: ['idk',
#   'social',
#   'anxiety',
#   'peeps',
#   'find',
#   'comfort',
#   'online',
#   'part',
#   'hate',
#   'texting',
#   'cant',
#   'read',
#   'tone',
#   'socialising',
#   'irl',
#   'million',
#   'times',
#   'easier',
#   'online',
#   'get',
#   'instant',
#   'feedback',
#   'say',
#   'words'],
#  20: ['never', 'goin', 'back', 'salon', 'hate', 'attn', 'social', 'anxiety'],
#  21: ['unlike',
#   'us',
#   'suffer',
#   'social',
#   'anxiety',
#   'personally',
#   'no',
#   'self',
#   'confidence',
#   'hate',
#   'however',
#   'need',
#   'someone',
#   'attack',
#   'directly',
#   'indirectly',
#   'clout',
#   'worry',
#   'fear',
#   'rejection',
#   'no',
#   'need',
#   'handle'],
#  22: ['fucking', 'hate', 'social', 'anxiety', 'describe', 'mom', 'understand'],
#  23: ['fuck',
#   'replying',
#   'tweets',
#   'unwarrented',
#   'hard',
#   'srsly',
#   'really',
#   'hate',
#   'social',
#   'anxiety',
#   'sometimes'],
#  24: ['hate',
#   'people',
#   'spoken',
#   'since',
#   'high',
#   'school',
#   'send',
#   'invites',
#   'come',
#   'event',
#   'house',
#   'sorry',
#   'social',
#   'anxiety'],
#  25: ['hate', 'social', 'anxiety'],
#  26: ['social',
#   'anxiety',
#   'knocking',
#   'door',
#   'new',
#   'years',
#   'eve',
#   'coming',
#   'hate',
#   'parties',
#   'guess',
#   'gotta',
#   'let'],
#  27: ['es',
#   'que',
#   'escrito',
#   'tal',
#   'suena',
#   'super',
#   'borde',
#   'la',
#   'cultura',
#   'del',
#   'hate',
#   'de',
#   'las',
#   'cosas',
#   'populares',
#   'parece',
#   'una',
#   'cagada',
#   'no',
#   'quer',
#   'que',
#   'lo',
#   'entendierais',
#   'en',
#   'plan',
#   'mimimimi',
#   'twitter',
#   'social',
#   'anxiety'],
#  28: ['exhales',
#   'ive',
#   'tried',
#   'baksk',
#   'social',
#   'anxiety',
#   'like',
#   'nooe',
#   'everyone',
#   'hate',
#   'ooc',
#   'ic',
#   'advert'],
#  29: ['jar',
#   'zerglings',
#   'lul',
#   'little',
#   'bit',
#   'social',
#   'anxiety',
#   'afraid',
#   'public',
#   'speaking',
#   'sometimes',
#   'hate',
#   'life'],
#  30: ['honestly',
#   'also',
#   'social',
#   'anxiety',
#   'ah',
#   'barely',
#   'talk',
#   'hate',
#   'like',
#   'want',
#   'outgoing',
#   'easy',
#   'talk'],
#  31: ['potential',
#   'life',
#   'partner',
#   'would',
#   'know',
#   'hate',
#   'public',
#   'proposals',
#   'social',
#   'anxiety',
#   'things',
#   'anyway',
#   'would',
#   'big',
#   'feelings'],
#  32: ['hate', 'social', 'anxiety', 'cause', 'feel', 'like', 'anymore'],
#  33: ['hate', 'social', 'anxiety', 'helpjz'],
#  34: ['yoooo', 'hate', 'social', 'anxiety', 'lmaoooo'],
#  35: ['know',
#   'everyone',
#   'went',
#   'highschool',
#   'never',
#   'thought',
#   'depressed',
#   'uni',
#   'girl',
#   'goes',
#   'decade',
#   'cause',
#   'hate',
#   'much',
#   'terrible',
#   'social',
#   'anxiety',
#   'really',
#   'didn',
#   'see',
#   'coming'],
#  36: ['really',
#   'hate',
#   'nasty',
#   'feeling',
#   'seeming',
#   'putting',
#   'others',
#   'know',
#   'friends',
#   'jump',
#   'say',
#   'otherwise',
#   'remain',
#   'feeling',
#   'like',
#   'bad',
#   'apple',
#   'mind',
#   'races',
#   'social',
#   'anxiety'],
#  37: ['dont',
#   'know',
#   'social',
#   'anxiety',
#   'absolutely',
#   'hate',
#   'going',
#   'peoples',
#   'houses',
#   'instead',
#   'mine',
#   'hate',
#   'asking',
#   'food',
#   'water',
#   'etc',
#   'house',
#   'wander',
#   'around',
#   'fulfill',
#   'needs',
#   'different',
#   'close',
#   'otherwise',
#   'place',
#   'necessary'],
#  38: ['perks',
#   'married',
#   'cheat',
#   'social',
#   'anxiety',
#   'hate',
#   'leaving',
#   'house',
#   'unlimited',
#   'supply',
#   'dick',
#   'jokes',
#   'easy',
#   'feed',
#   'likes',
#   'chicken',
#   'nuggets',
#   'bomb',
#   'ass',
#   'pussy',
#   'ever',
#   'beat',
#   'video',
#   'game',
#   'terrible'],
#  39: ['interests',
#   'friend',
#   'groups',
#   'place',
#   'hella',
#   'anime',
#   'also',
#   'carnival',
#   'junkie',
#   'love',
#   'traveling',
#   'hate',
#   'trying',
#   'new',
#   'foods',
#   'friendly',
#   'social',
#   'also',
#   'almost',
#   'always',
#   'depressed',
#   'crippling',
#   'anxiety',
#   'fun',
#   'diverse'],
#  40: ['hate',
#   'complaining',
#   'social',
#   'anxiety',
#   'feel',
#   'like',
#   'big',
#   'brat',
#   'baby'],
#  41: ['dammit', 'hate', 'social', 'anxiety'],
#  42: ['social', 'anxiety', 'actually', 'hate'],
#  43: ['twitter',
#   'actually',
#   'extremely',
#   'toxic',
#   'spent',
#   'lot',
#   'time',
#   'either',
#   'upset',
#   'worried',
#   'anxiety',
#   'worse',
#   'extreme',
#   'social',
#   'anxiety',
#   'already',
#   'simply',
#   'never',
#   'type',
#   'person',
#   'affected',
#   'hate',
#   'not',
#   'hate'],
#  44: ['really',
#   'stupid',
#   'thing',
#   'social',
#   'anxiety',
#   'okay',
#   'front',
#   'camera',
#   'person',
#   'small',
#   'groups',
#   'reaching',
#   'saying',
#   'hi',
#   'let',
#   'video',
#   'together',
#   'always',
#   'seemed',
#   'like',
#   'pushing',
#   'others',
#   'hate'],
#  45: ['hate', 'fact', 'social', 'anxiety'],
#  46: ['suck',
#   'starting',
#   'conversation',
#   'women',
#   'hate',
#   'social',
#   'anxiety'],
#  47: ['way',
#   'social',
#   'anxiety',
#   'set',
#   'hate',
#   'going',
#   'places',
#   'know',
#   'one',
#   'person',
#   'would',
#   'hate',
#   'underneath',
#   'like',
#   'parent',
#   'cause',
#   'scared',
#   'make',
#   'new',
#   'friends'],
#  48: ['worst',
#   'social',
#   'anxiety',
#   'people',
#   'talk',
#   'idk',
#   'say',
#   'back',
#   'lmao',
#   'hate',
#   'fix',
#   'hahah'],
#  49: ['shit',
#   'person',
#   'hate',
#   'mh',
#   'makes',
#   'less',
#   'social',
#   'always',
#   'get',
#   'called',
#   'wish',
#   'anxiety',
#   'didn',
#   'stop',
#   'fun',
#   'worse',
#   'best',
#   'friend',
#   'said',
#   'disappointed'],
#  50: ['hate',
#   'introvert',
#   'not',
#   'harry',
#   'potter',
#   'livejournal',
#   'kinda',
#   'way',
#   'feel',
#   'oppressed',
#   'anxiety',
#   'hung',
#   'anyone',
#   'days',
#   'chill',
#   'definitely',
#   'getting',
#   'loopy',
#   'like',
#   'legiterally',
#   'crazy',
#   'atrophying',
#   'social',
#   'skills'],
#  51: ['hate',
#   'ppl',
#   'try',
#   'force',
#   'go',
#   'like',
#   'chill',
#   'bro',
#   'keep',
#   'inviting',
#   'shit',
#   'social',
#   'anxiety',
#   'like'],
#  52: ['hate', 'social', 'media', 'anxiety', 'provoking'],
#  53: ['talk',
#   'summer',
#   'walker',
#   'social',
#   'anxiety',
#   'breath',
#   'hate',
#   'large',
#   'group',
#   'people',
#   'sings',
#   'happy',
#   'birthday'],
#  54: ['struggle',
#   'bit',
#   'think',
#   'might',
#   'symptom',
#   'anxiety',
#   'adhd',
#   'diagnosis',
#   'hate',
#   'leaving',
#   'apartment',
#   'social',
#   'really',
#   'hard',
#   'mostly',
#   'show',
#   'work',
#   'amp',
#   'church',
#   'go',
#   'outside'],
#  55: ['gotta',
#   'say',
#   'transphobic',
#   'hate',
#   'getting',
#   'little',
#   'thick',
#   'skin',
#   'social',
#   'anxiety',
#   'depression',
#   'issues',
#   'people',
#   'saying',
#   'biology',
#   'driving',
#   'crazy',
#   'wish',
#   'could',
#   'live',
#   'day',
#   'maybe',
#   'would',
#   'understand',
#   '#transgender',
#   '#ftm'],
#  56: ['hate', 'social', 'anxiety'],
#  57: ['hate',
#   'much',
#   'anxiety',
#   'putting',
#   'social',
#   'media',
#   'day',
#   'get',
#   'anxious',
#   'feel',
#   'like',
#   'judged',
#   'time'],
#  58: ['god',
#   'help',
#   'improve',
#   'relationship',
#   'snaps',
#   'videos',
#   'really',
#   'hate',
#   'random',
#   'snaps',
#   'generally',
#   'hide',
#   'behind',
#   'social',
#   'anxiety',
#   'truth',
#   'told',
#   'mental',
#   'image',
#   'see',
#   'images',
#   'always',
#   'war',
#   'maybe',
#   'image',
#   'consultant',
#   'would',
#   'ideal'],
#  59: ['know',
#   'not',
#   'big',
#   'deal',
#   'social',
#   'anxiety',
#   'kind',
#   'hate',
#   'share',
#   'bathroom',
#   'strangers'],
#  60: ['want',
#   'go',
#   'nice',
#   'drink',
#   'friends',
#   'tonight',
#   'no',
#   'contemplate',
#   'every',
#   'minutes',
#   'hate',
#   'social',
#   'anxiety',
#   'like'],
#  61: ['fucking',
#   'done',
#   'caring',
#   'people',
#   'think',
#   'social',
#   'anxiety',
#   'makes',
#   'feel',
#   'like',
#   'fucking',
#   'piece',
#   'shit',
#   'makes',
#   'act',
#   'like',
#   'fucking',
#   'piece',
#   'shit',
#   'towards',
#   'people',
#   'love',
#   'hate',
#   'seen',
#   'certain',
#   'way',
#   'well',
#   'guess',
#   'fuck',
#   'youvsocial',
#   'anxiety',
#   'dont',
#   'give',
#   'fuck'],
#  62: ['social', 'anxiety', 'hate', 'meeeee'],
#  63: ['really', 'hate', 'self', 'social', 'anxiety'],
#  64: ['idk',
#   'get',
#   'lot',
#   'anxiety',
#   'people',
#   'talk',
#   'much',
#   'hate',
#   'movie',
#   'social',
#   'media'],
#  65: ['literally',
#   'hate',
#   'first',
#   'one',
#   'group',
#   'arrive',
#   'not',
#   'walk',
#   'think',
#   'something',
#   'social',
#   'anxiety'],
#  66: ['hate',
#   'inability',
#   'carry',
#   'conversation',
#   'bc',
#   'social',
#   'anxiety',
#   'dying',
#   'friends',
#   'pretty',
#   'girl',
#   'trust',
#   'months',
#   'shy',
#   'come',
#   'bacccc'],
#  67: ['hate',
#   'much',
#   'people',
#   'say',
#   'depressed',
#   'ase',
#   'sad',
#   'hate',
#   'peole',
#   'say',
#   'anxiety',
#   'tummy',
#   'butterflies',
#   'hate',
#   'people',
#   'say',
#   'social',
#   'anxiety',
#   'dont',
#   'fun',
#   'hang',
#   'dont',
#   'idea',
#   'stfu'],
#  68: ['hate',
#   'hard',
#   'make',
#   'friends',
#   'online',
#   'real',
#   'life',
#   'social',
#   'anxiety',
#   'snazzy',
#   'right'],
#  69: ['also',
#   'hate',
#   'whole',
#   'owe',
#   'anyone',
#   'anything',
#   'rhetoric',
#   'well',
#   'definitely',
#   'not',
#   'entitlement',
#   'want',
#   'make',
#   'sure',
#   'alive',
#   'mentally',
#   'physically',
#   'well',
#   'social',
#   'anxiety',
#   'definitely',
#   'not',
#   'dependent',
#   'communication',
#   'whatever',
#   'said'],
#  70: ['people',
#   'kidding',
#   'think',
#   'people',
#   'attacked',
#   'staff',
#   'would',
#   'blocked',
#   'comments',
#   'hate',
#   'received',
#   'strong',
#   'member',
#   'ended',
#   'anxiety',
#   'social',
#   'networks'],
#  71: ['make',
#   'fun',
#   'summer',
#   'social',
#   'anxiety',
#   'twist',
#   'words',
#   'always',
#   'explain',
#   'people',
#   'still',
#   'hate',
#   'try',
#   'come',
#   'meg',
#   'height',
#   'try',
#   'make',
#   'seem',
#   'like',
#   'problematic',
#   'bitch',
#   'not'],
#  72: ['social',
#   'anxiety',
#   'spiked',
#   'bad',
#   'easiest',
#   'shit',
#   'like',
#   'calling',
#   'make',
#   'appointments',
#   'hard',
#   'talk',
#   'even',
#   'family',
#   'want',
#   'alone',
#   'time',
#   'hate',
#   'alone'],
#  73: ['hate', 'social', 'anxiety', 'kicks', 'mid', 'groove', 'mxm'],
#  74: ['social',
#   'anxiety',
#   'disorder',
#   'fucking',
#   'sucks',
#   'like',
#   'cool',
#   'normal',
#   'dms',
#   'anxious',
#   'nervous',
#   'wreck',
#   'meeting',
#   'hate'],
#  75: ['ya',
#   'kno',
#   'im',
#   'fed',
#   'always',
#   'social',
#   'anxiety',
#   'amp',
#   'fed',
#   'always',
#   'holding',
#   'back',
#   'amp',
#   'making',
#   'not',
#   'things',
#   'amp',
#   'imfed',
#   'alw',
#   'scared',
#   'judged',
#   'pls',
#   'pray',
#   'get',
#   'better',
#   'next',
#   'con',
#   'hate',
#   'shit',
#   'always',
#   'holds',
#   'back',
#   'amp'],
#  76: ['anti',
#   'muslim',
#   'hate',
#   'islamophobia',
#   'must',
#   'reported',
#   'know',
#   'many',
#   'use',
#   'social',
#   'media',
#   'not',
#   'report',
#   'hate',
#   'receive',
#   'assist',
#   'many',
#   'ways',
#   'amp',
#   'know',
#   'not',
#   'alone',
#   'much',
#   'anxiety',
#   'feel',
#   'feel',
#   'alone'],
#  77: ['another',
#   'thing',
#   'definitely',
#   'hate',
#   'tell',
#   'someone',
#   'social',
#   'anxiety',
#   'stopping',
#   'speaking',
#   'hear',
#   'afraid',
#   'say',
#   'want',
#   'tell',
#   'someone',
#   'something',
#   'sitting',
#   'like',
#   'wish',
#   'easy'],
#  78: ['new',
#   'movie',
#   'ruined',
#   'life',
#   'new',
#   'show',
#   'cant',
#   'sleep',
#   'much',
#   'makes',
#   'mad',
#   'new',
#   'album',
#   'giving',
#   'anxiety',
#   'im',
#   'throwing',
#   'much',
#   'hate',
#   'literally',
#   'masses',
#   'sound',
#   'social',
#   'media',
#   'news',
#   'articles'],
#  79: ['hate',
#   'parties',
#   'always',
#   'showed',
#   'late',
#   'avoidance',
#   'turns',
#   'show',
#   'early',
#   'fewer',
#   'people',
#   'get',
#   'see',
#   'host',
#   'second',
#   'leave',
#   'many',
#   'people',
#   'show',
#   'awesome',
#   'social',
#   'anxiety'],
#  80: ['think',
#   'yr',
#   'adik',
#   'social',
#   'anxiety',
#   'introversion',
#   'simply',
#   'means',
#   'one',
#   'regains',
#   'energy',
#   'alone',
#   'not',
#   'necessarily',
#   'mean',
#   'hate',
#   'ppl',
#   'introvert',
#   'dont',
#   'mind',
#   'getting',
#   'pics',
#   'taken',
#   'haha'],
#  81: ['hate',
#   'wanna',
#   'go',
#   'actually',
#   'social',
#   'anxiety',
#   'kicks',
#   'literally',
#   'fight',
#   'go',
#   'social',
#   'sometimes'],
#  82: ['hate',
#   'social',
#   'anxiety',
#   'stops',
#   'going',
#   'always',
#   'bailing',
#   'plans',
#   'swear',
#   'hate',
#   'barely',
#   'go',
#   'store'],
#  83: ['dude',
#   'mocked',
#   'stuttering',
#   'back',
#   'wearing',
#   'social',
#   'anxiety',
#   'shirt',
#   'yeezys',
#   'hate',
#   'people',
#   'lol'],
#  84: ['congratulations',
#   'years',
#   'sober',
#   'past',
#   'nd',
#   'december',
#   'using',
#   'alcohol',
#   'cope',
#   'social',
#   'anxiety',
#   'busy',
#   'places',
#   'hate',
#   'crowds'],
#  85: ['something',
#   'keeps',
#   'night',
#   'might',
#   'get',
#   'tweeting',
#   'social',
#   'media',
#   'someone',
#   'admire',
#   'carefully',
#   'thinking',
#   'every',
#   'word',
#   'still',
#   'obsess',
#   'idea',
#   'might',
#   'sound',
#   'rude',
#   'expressed',
#   'wrong',
#   'hate',
#   '#socialanxiety'],
#  86: ['hate', 'extroverted', 'person', 'much', 'social', 'anxiety'],
#  87: ['hate', 'social', 'anxiety', 'works'],
#  88: ['hate',
#   'much',
#   'twitter',
#   'adding',
#   'insanity',
#   'depression',
#   'cause',
#   'much',
#   'anxiety',
#   'negativity',
#   'life',
#   'basically',
#   'no',
#   'social',
#   'life',
#   'need',
#   'disgusting',
#   'sad'],
#  89: ['omg',
#   'hate',
#   'niggas',
#   'try',
#   'bag',
#   'front',
#   'mad',
#   'people',
#   'got',
#   'social',
#   'anxiety',
#   'nigga'],
#  90: ['hate',
#   'fact',
#   'cant',
#   'feel',
#   'like',
#   'talk',
#   'something',
#   'without',
#   'fear',
#   'constant',
#   'attacks',
#   'things',
#   'yes',
#   'want',
#   'discussions',
#   'stuff',
#   'fears',
#   'every',
#   'time',
#   'autistic',
#   'social',
#   'anxiety',
#   'worst'],
#  91: ['hi',
#   'want',
#   'people',
#   'talk',
#   'wont',
#   'hate',
#   'not',
#   'answering',
#   'bc',
#   'social',
#   'anxiety',
#   'also',
#   'wont',
#   'forget',
#   'two',
#   'weeks'],
#  92: ['back',
#   'social',
#   'anxiety',
#   'hates',
#   'hate',
#   'send',
#   'hi',
#   'personaly',
#   'say',
#   'sorry',
#   'not',
#   'saying',
#   'word',
#   'half',
#   'year',
#   'think',
#   'even',
#   'know',
#   'say',
#   'srry',
#   'happy',
#   'holydays',
#   'everyone'],
#  93: ['still',
#   'continuing',
#   'visceral',
#   'anxiety',
#   'issues',
#   'around',
#   'people',
#   'arriving',
#   'picking',
#   'social',
#   'events',
#   'directly',
#   'connected',
#   'occasion',
#   'thing',
#   'pentecostals',
#   'hate',
#   'sceptics',
#   'critics',
#   'cult',
#   'one',
#   'year',
#   'old',
#   'copped',
#   'not',
#   'accepting'],
#  94: ['mother',
#   'forcing',
#   'go',
#   'brother',
#   'new',
#   'years',
#   'hate',
#   'burning',
#   'passion',
#   'clubbing',
#   'severe',
#   'social',
#   'anxiety',
#   'qnd',
#   'stressing',
#   'tf',
#   'outta'],
#  95: ['low',
#   'key',
#   'high',
#   'key',
#   'fucking',
#   'hate',
#   'goddamn',
#   'social',
#   'awkwardness',
#   'anxiety'],
#  96: ['hate',
#   'social',
#   'anxiety',
#   'stops',
#   'lot',
#   'things',
#   'speaking',
#   'shit',
#   'like',
#   'shit',
#   'like',
#   'simply',
#   'trying',
#   'walk',
#   'store',
#   'hella',
#   'ppl',
#   'hard'],
#  97: ['social',
#   'anxiety',
#   'introvert',
#   'ie',
#   'simply',
#   'preferring',
#   'alone',
#   'social',
#   'anxiety',
#   'terrified',
#   'interacting',
#   'people',
#   'fear',
#   'humiliation',
#   'fear',
#   'wrong',
#   'thing',
#   'making',
#   'people',
#   'hate',
#   'etc',
#   'extrovert',
#   'amp',
#   'social',
#   'anxiety'],
#  98: ['hate', 'social', 'anxiety', 'waste', 'space'],
#  99: ['hate',
#   'hate',
#   'hate',
#   'getting',
#   'anti',
#   'sm',
#   'king',
#   'shock',
#   'adverts',
#   'social',
#   'media',
#   'considering',
#   'currently',
#   'therapy',
#   'deal',
#   'severe',
#   'anxieties',
#   'related',
#   'loved',
#   'ones',
#   'sm',
#   'king',
#   'censoring',
#   'surely',
#   'vain',
#   'attempt',
#   'not',
#   'feed',
#   'ad',
#   'algorithm'],
#  100: ['hate',
#   'social',
#   'anxiety',
#   'come',
#   'fgs',
#   'family',
#   'issues',
#   'helping',
#   'fuck'],
#  101: ['not',
#   'say',
#   'someone',
#   '#socialanxiety',
#   'girl',
#   'let',
#   'take',
#   'pictures',
#   'laughingly',
#   'oh',
#   'man',
#   'hate',
#   'photos',
#   'guy',
#   'part',
#   'marketing',
#   'survive',
#   'donations',
#   'really',
#   'important',
#   'take',
#   'picture',
#   'leaves',
#   '#whatwomendontwantfrommen'],
#  102: ['not',
#   'social',
#   'anxiety',
#   'know',
#   'stuff',
#   'like',
#   'always',
#   'happen',
#   'hate',
#   'social',
#   'events',
#   'lots',
#   'people'],
#  103: ['hate', 'people', 'put', 'spotlight', 'social', 'anxiety'],
#  104: ['totally',
#   'get',
#   'sort',
#   'social',
#   'agoraphobia',
#   'fuelled',
#   'anxiety',
#   'means',
#   'cut',
#   'unnecessary',
#   'interactions',
#   'people',
#   'hate',
#   'big',
#   'gatherings',
#   'unfortunately',
#   'family',
#   'christmas',
#   'not',
#   'something',
#   'avoid'],
#  105: ['hate',
#   'hard',
#   'come',
#   'social',
#   'anxiety',
#   'open',
#   'amp',
#   'happy',
#   'around',
#   'people',
#   'yet',
#   'everytime',
#   'feel',
#   'comfortable',
#   'pull',
#   'immature',
#   'age',
#   'card',
#   'definitely',
#   'not',
#   'bc',
#   'humous',
#   'fun',
#   'doesn',
#   'make',
#   'childish',
#   'hurts',
#   'tbh'],
#  106: ['afraid',
#   'growing',
#   'several',
#   'panic',
#   'attacks',
#   'thinking',
#   'future',
#   'severe',
#   'hypochondria',
#   'social',
#   'anxiety',
#   'trouble',
#   'bonding',
#   'people',
#   'creating',
#   'solid',
#   'relationships',
#   'hate',
#   'behaviour',
#   'act',
#   'childish',
#   'forget'],
#  107: ['nothing',
#   'even',
#   'happened',
#   'everyone',
#   'kind',
#   'yet',
#   'im',
#   'like',
#   'oh',
#   'god',
#   'hate',
#   'im',
#   'boring',
#   'not',
#   'bad',
#   'social',
#   'anxiety'],
#  108: ['hate',
#   'ppl',
#   'social',
#   'anxiety',
#   'stop',
#   'judging',
#   'others',
#   'things',
#   'hurt',
#   'no',
#   'one'],
#  109: ['sometimes',
#   'get',
#   'urge',
#   'record',
#   'singing',
#   'ahead',
#   'century',
#   'post',
#   'scared',
#   'someone',
#   'know',
#   'irl',
#   'hear',
#   'know',
#   'scares',
#   'much',
#   'hate',
#   'social',
#   'anxiety',
#   '#renewannewithane'],
#  110: ['omg',
#   'im',
#   'unique',
#   'love',
#   'color',
#   'black',
#   'food',
#   'bae',
#   'im',
#   'fucking',
#   'anti',
#   'social',
#   'hate',
#   'people',
#   'anxiety',
#   'everyone',
#   'social',
#   'media'],
#  111: ['really',
#   'trying',
#   'get',
#   'better',
#   'social',
#   'hate',
#   'social',
#   'anxiety',
#   'sooooo',
#   'much'],
#  112: ['hate', 'social', 'anxiety'],
#  113: ['hate', 'social', 'anxiety', 'keeps', 'things', 'really', 'wanna'],
#  114: ['lol',
#   'sounds',
#   'ok',
#   'not',
#   'dealing',
#   'great',
#   'severe',
#   'social',
#   'anxiety',
#   'hate',
#   'alone',
#   'well',
#   'essentially',
#   'trying',
#   'manage',
#   'anxiety',
#   'issues',
#   'today'],
#  115: ['noooo',
#   'social',
#   'anxiety',
#   'like',
#   'okay',
#   'tf',
#   'door',
#   'bc',
#   'hate',
#   'talking',
#   'strangers',
#   'get',
#   'uncomfortable',
#   'especially',
#   'show',
#   'apartment'],
#  116: ['social',
#   'anxiety',
#   'disorder',
#   'doesn',
#   'mean',
#   'hate',
#   'people',
#   'like',
#   'socialize',
#   'actually',
#   'strong',
#   'love',
#   'people',
#   'interact',
#   'feel',
#   'social',
#   'interactions',
#   'great',
#   'intensity',
#   'exhausting',
#   'makes',
#   'things',
#   'like',
#   'eye',
#   'contact',
#   'hard'],
#  117: ['antisocial',
#   'people',
#   'crazy',
#   'hate',
#   'get',
#   'social',
#   'anxiety',
#   'space',
#   'unfamiliar',
#   'person',
#   'long'],
#  118: ['im',
#   'thirty',
#   'year',
#   'old',
#   'man',
#   'turns',
#   'ig',
#   'notifications',
#   'anxiety',
#   'posts',
#   'hate',
#   'social',
#   'media',
#   'lmao'],
#  119: ['shy', 'mad', 'social', 'anxiety', 'really', 'hate', 'bro'],
#  120: ['shoutout',
#   'everyone',
#   'social',
#   'anxiety',
#   'christmas',
#   'no',
#   'one',
#   'else',
#   'knows',
#   'much',
#   'beat',
#   'someone',
#   'going',
#   'like',
#   'gifts',
#   'not',
#   'no',
#   'one',
#   'understand',
#   'much',
#   'hate',
#   'reacting',
#   'gifts'],
#  121: ['hate',
#   'children',
#   'lowkey',
#   'would',
#   'help',
#   'friend',
#   'significant',
#   'raise',
#   'child',
#   'ever',
#   'came',
#   'not',
#   'good',
#   'idea',
#   'not',
#   'trembling',
#   'social',
#   'anxiety',
#   'spook'],
#  122: ['hate',
#   'seeing',
#   'introvert',
#   'memes',
#   'really',
#   'shy',
#   'actual',
#   'social',
#   'anxiety',
#   'problems',
#   'not',
#   'thing'],
#  123: ['got',
#   'social',
#   'anxiety',
#   'like',
#   'crazy',
#   'hate',
#   'around',
#   'crowd',
#   'people'],
#  124: ['social',
#   'anxiety',
#   'generalized',
#   'anxiety',
#   'disorder',
#   'no',
#   'hate',
#   'socializing',
#   'fact',
#   'stripped',
#   'anxiety',
#   'pretty',
#   'social',
#   'thing',
#   'monster',
#   'shoulder',
#   'making',
#   'almost',
#   'anything',
#   'living',
#   'nightmare'],
#  125: ['hate',
#   'generation',
#   'bro',
#   'getting',
#   'girl',
#   'also',
#   'requires',
#   'text',
#   'rather',
#   'talk',
#   'kick',
#   'person',
#   'phones',
#   'dumbing',
#   'us',
#   'causing',
#   'lots',
#   'girls',
#   'social',
#   'anxiety',
#   'neta',
#   'foo',
#   'also',
#   'goes',
#   'guys',
#   'scared',
#   'talk',
#   'girls'],
#  126: ['hate',
#   'normal',
#   'checkout',
#   'lines',
#   'order',
#   'pizza',
#   'phone',
#   'anymore',
#   'want',
#   'talk',
#   'people',
#   'buying',
#   'groceries',
#   'social',
#   'anxiety',
#   'job',
#   'killer'],
#  127: ['low',
#   'self',
#   'confidence',
#   'high',
#   'self',
#   'hate',
#   'social',
#   'anxiety',
#   'almost',
#   'no',
#   'real',
#   'friends',
#   'body',
#   'negativity',
#   'ending',
#   'want',
#   'change',
#   'time',
#   'next',
#   'year',
#   'not',
#   'not',
#   'sure'],
#  128: ['hate', 'social', 'anxiety'],
#  129: ['guy',
#   'sets',
#   'low',
#   'expectations',
#   'hate',
#   'disappointed',
#   'want',
#   'marginally',
#   'increase',
#   'quality',
#   'content',
#   'easy',
#   'need',
#   'keep',
#   'breaking',
#   'walls',
#   'social',
#   'anxiety',
#   'built'],
#  130: ['hate',
#   'going',
#   'vacation',
#   'parents',
#   'never',
#   'anything',
#   'want',
#   'never',
#   'tell',
#   'want',
#   'plus',
#   'one',
#   'talking',
#   'everyone',
#   'bc',
#   'speak',
#   'english',
#   'social',
#   'anxiety',
#   'handle'],
#  131: ['went',
#   'topman',
#   'get',
#   'brother',
#   'voucher',
#   'dead',
#   'like',
#   'no',
#   'one',
#   'whole',
#   'ass',
#   'social',
#   'anxiety',
#   'right',
#   'hate'],
#  132: ['even',
#   'didn',
#   'social',
#   'anxiety',
#   'still',
#   'introvert',
#   'much',
#   'hate',
#   'ppl',
#   'lol'],
#  133: ['implications',
#   'social',
#   'media',
#   'hate',
#   'mental',
#   'amp',
#   'emotional',
#   'wellbeing',
#   'anxiety',
#   'depression',
#   'withdrawn',
#   'nlp',
#   'practitioners',
#   'help',
#   '#nlp',
#   'kids',
#   '#socialmedia',
#   '#hate'],
#  134: ['even',
#   'explain',
#   'social',
#   'anxiety',
#   'like',
#   'physically',
#   'painful',
#   'draw',
#   'conversation',
#   'people',
#   'know',
#   'like',
#   'go',
#   'awayyyy',
#   'idk',
#   'might',
#   'hate',
#   'small',
#   'talk',
#   'pointless'],
#  135: ['social',
#   'media',
#   'break',
#   'must',
#   'days',
#   'amount',
#   'hate',
#   'abhorrence',
#   'get',
#   'ur',
#   'anxiety',
#   'amp',
#   'depression',
#   'level',
#   'high',
#   'important',
#   'social',
#   'media',
#   'one',
#   'best',
#   'thing',
#   'ever',
#   'happened',
#   'humanity',
#   'erased',
#   'boundaries',
#   'anyway',
#   'congratulations'],
#  136: ['hate', 'anxiety', 'attacks', 'always', 'ruins', 'social', 'skills'],
#  137: ['want',
#   'make',
#   'twitter',
#   'friends',
#   'socially',
#   'awkward',
#   'social',
#   'anxiety',
#   'hate',
#   'one',
#   'starts',
#   'conversation'],
#  138: ['hate',
#   'social',
#   'anxiety',
#   'kicks',
#   'like',
#   'honey',
#   'get',
#   'mad',
#   'text',
#   'text'],
#  139: ['hate', 'social', 'anxiety', 'fuck'],
#  140: ['social',
#   'anxiety',
#   'reason',
#   'probably',
#   'spend',
#   'new',
#   'year',
#   'eve',
#   'alone',
#   'really',
#   'hate',
#   'shit',
#   'detroys',
#   'day',
#   'day'],
#  141: ['anxiety',
#   'high',
#   'hate',
#   'holidays',
#   'bring',
#   'pain',
#   'keep',
#   'social',
#   'appearances',
#   'expectations',
#   'truthfully',
#   'not',
#   'right',
#   'headspace',
#   'currently',
#   'anyways',
#   'send',
#   'serotonin'],
#  142: ['hate',
#   'social',
#   'life',
#   'hate',
#   'not',
#   'friends',
#   'hate',
#   'no',
#   'trust',
#   'towards',
#   'people',
#   'hate',
#   'suspicious',
#   'whenever',
#   'someone',
#   'tries',
#   'nice',
#   'hate',
#   'social',
#   'anxiety',
#   'hate',
#   'trust',
#   'issue',
#   'hate',
#   'depression',
#   'hate',
#   'hate',
#   'everyone'],
#  143: ['hate',
#   'days',
#   'social',
#   'anxiety',
#   'bad',
#   'get',
#   'freaked',
#   'simple',
#   'encounters',
#   'others',
#   'not',
#   'expecting'],
#  144: ['hate', 'still', 'kinda', 'get', 'social', 'anxiety', 'serve'],
#  145: ['sort',
#   'hate',
#   'year',
#   'review',
#   'stuff',
#   'social',
#   'doesn',
#   'really',
#   'capture',
#   'happened',
#   'reality',
#   'feels',
#   'like',
#   'spent',
#   'crying',
#   'crying',
#   'lost',
#   'friends',
#   'work',
#   'politics',
#   'anxieties',
#   'never',
#   'pops',
#   'favorites',
#   'made',
#   'important'],
#  146: ['omg',
#   'eternal',
#   'goodbye',
#   'hate',
#   'social',
#   'anxiety',
#   'ready',
#   'leave',
#   'time',
#   'leave',
#   'not',
#   'minute',
#   'conversation',
#   'everyone',
#   'attended'],
#  147: ['meme',
#   'needs',
#   'know',
#   'hate',
#   'weddings',
#   'not',
#   'go',
#   'weddings',
#   'unless',
#   'home',
#   'year',
#   'year',
#   'nkelo',
#   'ila',
#   'tuye',
#   'kohango',
#   'ahawe',
#   'meme',
#   'antisocial',
#   'suffer',
#   'social',
#   'anxiety',
#   'also',
#   'not',
#   'like',
#   'people',
#   'no'],
#  148: ['message',
#   'ko',
#   'pala',
#   'sa',
#   'mga',
#   'tao',
#   'kaibigan',
#   'kamag',
#   'anak',
#   'na',
#   'kapag',
#   'meron',
#   'silang',
#   'na',
#   'encounter',
#   'na',
#   'nag',
#   'ssuffer',
#   'sa',
#   'ganto',
#   'depression',
#   'minsan',
#   'panga',
#   'severe',
#   'depression',
#   'social',
#   'anxiety',
#   'self',
#   'hate',
#   'low',
#   'self',
#   'esteem',
#   'kahit',
#   'ano',
#   'na',
#   'mag',
#   'llead',
#   'sakanila',
#   'ng',
#   'suicide',
#   'please',
#   'nag',
#   'mamakaawa',
#   'ako'],
#  149: ['add',
#   'introverted',
#   'not',
#   'mean',
#   'hate',
#   'people',
#   'extroverted',
#   'not',
#   'mean',
#   'loud',
#   'introverts',
#   'need',
#   'time',
#   'get',
#   'energy',
#   'back',
#   'still',
#   'enjoy',
#   'social',
#   'time',
#   'extroverts',
#   'get',
#   'energy',
#   'ppl',
#   'still',
#   'suffer',
#   'shyness',
#   'anxiety',
#   'xxx'],
#  150: ['implications',
#   'social',
#   'media',
#   'hate',
#   'mental',
#   'amp',
#   'emotional',
#   'wellbeing',
#   'anxiety',
#   'depression',
#   'withdrawn',
#   'nlp',
#   'kids',
#   'practitioners',
#   'help',
#   '#nlp',
#   'kids',
#   '#socialmedia',
#   '#hate'],
#  151: ['drunk', 'no', 'social', 'anxiety', 'hate'],
#  152: ['dont',
#   'hate',
#   'dislike',
#   'anyone',
#   'think',
#   'dont',
#   'like',
#   'definitely',
#   'not',
#   'case',
#   'severe',
#   'social',
#   'anxiety',
#   'sorry'],
#  153: ['love',
#   'social',
#   'seem',
#   'online',
#   'wish',
#   'irl',
#   'im',
#   'literally',
#   'exact',
#   'opposite',
#   'like',
#   'literally',
#   'get',
#   'scared',
#   'speak',
#   'multiple',
#   'reasons',
#   'social',
#   'anxiety',
#   'hate',
#   'sound',
#   'voice',
#   'think',
#   'others',
#   'hate',
#   'sound',
#   'voice'],
#  154: ['fun',
#   'fact',
#   'really',
#   'loud',
#   'outgoing',
#   'groups',
#   'shy',
#   'awkward',
#   'one',
#   'one',
#   'see',
#   'bubbly',
#   'group',
#   'cold',
#   'towards',
#   'dont',
#   'hate',
#   'inverted',
#   'social',
#   'anxiety'],
#  155: ['got',
#   'truly',
#   'hate',
#   'people',
#   'think',
#   'confusing',
#   'hatred',
#   'social',
#   'anxiety'],
#  156: ['hate',
#   'bad',
#   'social',
#   'anxiety',
#   'ppl',
#   'telling',
#   'ima',
#   'meeting',
#   'new',
#   'ppl',
#   'not',
#   'prepared',
#   'like',
#   'least',
#   'give',
#   'heads',
#   'anxiety',
#   'bad',
#   'literally',
#   'leave',
#   'get',
#   'car',
#   'get',
#   'sick',
#   'ugh',
#   'even',
#   'wanna',
#   'get'],
#  157: ['bp',
#   'apt',
#   'propanolol',
#   'started',
#   'explore',
#   'reasons',
#   'anxiety',
#   'gt',
#   'hate',
#   'miss',
#   'social',
#   'deteminants',
#   'health',
#   'sdoh',
#   'start',
#   'meds',
#   'bp',
#   'gt',
#   'occasion',
#   'epic',
#   'otherthan',
#   'current'],
#  158: ['anxiety', 'really', 'sucks', 'hate', 'people', 'social', 'situations'],
#  159: ['social',
#   'anxiety',
#   'sucks',
#   'eats',
#   'inside',
#   'hate',
#   'even',
#   'talk',
#   'someone',
#   'without',
#   'feeling',
#   'like',
#   'bother'],
#  160: ['depression',
#   'anxiety',
#   'doesnt',
#   'mean',
#   'lazy',
#   'anti',
#   'social',
#   'anxiety',
#   'makes',
#   'scared',
#   'af',
#   'worst',
#   'shit',
#   'gonna',
#   'happen',
#   'makes',
#   'depressed',
#   'dont',
#   'get',
#   'socialise',
#   'much',
#   'want',
#   'makes',
#   'anxious',
#   'people',
#   'hate'],
#  161: ['hate', 'social', 'anxiety'],
#  162: ['bitches',
#   'like',
#   'social',
#   'anxiety',
#   'hate',
#   'attention',
#   'go',
#   'eat',
#   'order',
#   'fajitas'],
#  163: ['hate',
#   'social',
#   'anxiety',
#   'trying',
#   'nice',
#   'outing',
#   'sister',
#   'mentally',
#   'take'],
#  164: ['hate', 'social', 'anxiety', 'kdnxisja', 'like'],
#  165: ['lot',
#   'fans',
#   'hate',
#   'mml',
#   'high',
#   'chance',
#   'hate',
#   'comments',
#   'contributed',
#   'social',
#   'anxiety',
#   'seen',
#   'effects',
#   'hate',
#   'comments',
#   'past',
#   'two',
#   'months',
#   'social',
#   'anxiety',
#   'plausible'],
#  166: ['love',
#   'chat',
#   'people',
#   'amp',
#   'see',
#   'day',
#   'goin',
#   'social',
#   'anxiety',
#   'says',
#   'hate'],
#  167: ['hate',
#   'self',
#   'checkouts',
#   'reason',
#   'social',
#   'anxiety',
#   'forces',
#   'use'],
#  168: ['battling',
#   'anxiety',
#   'evening',
#   'hate',
#   'social',
#   'situations',
#   'especially',
#   'around',
#   'family',
#   'make',
#   'feel',
#   'nervous',
#   'know',
#   'huge',
#   'argument',
#   'almost',
#   'always',
#   'happens',
#   'get',
#   'together'],
#  169: ['siempre',
#   'que',
#   'estoy',
#   'en',
#   'el',
#   'mall',
#   'sola',
#   'da',
#   'social',
#   'anxiety',
#   'hate'],
#  170: ['agree',
#   'usually',
#   'ask',
#   'people',
#   'go',
#   'hate',
#   'anxiety',
#   'comes',
#   'isolated',
#   'social',
#   'environments',
#   'learned',
#   'allow',
#   'exist',
#   'within',
#   'spaces',
#   'leave',
#   'immediately',
#   'feel',
#   'need'],
#  171: ['also',
#   'hate',
#   'ppl',
#   'try',
#   'compete',
#   'disorders',
#   'like',
#   'say',
#   'really',
#   'feel',
#   'like',
#   'going',
#   'eat',
#   'shannon',
#   'gotta',
#   'go',
#   'like',
#   'broke',
#   'literal',
#   'tears',
#   'inside',
#   'mcdonalds',
#   'play',
#   'pen',
#   'overwhelmed',
#   'result',
#   'social',
#   'anxiety',
#   'disorder'],
#  172: ['also',
#   'explain',
#   'another',
#   'post',
#   'apparently',
#   'selfish',
#   'social',
#   'anxiety',
#   'hate',
#   'small',
#   'talk',
#   'also',
#   'work',
#   'full',
#   'time',
#   'go',
#   'school',
#   'part',
#   'time',
#   'amp',
#   'obligations',
#   'waiting',
#   'min',
#   'line',
#   'due',
#   'super',
#   'slow',
#   'overly',
#   'chatty',
#   'cashier',
#   'not',
#   'option'],
#  173: ['lonely',
#   'depressed',
#   'idk',
#   'seem',
#   'really',
#   'find',
#   'one',
#   'woman',
#   'interested',
#   'social',
#   'anxiety',
#   'leave',
#   'house',
#   'much',
#   'see',
#   'point',
#   'life',
#   'anymore',
#   'failure',
#   'life',
#   'hate',
#   'wanna',
#   'die'],
#  174: ['love',
#   'dming',
#   'hate',
#   'force',
#   'social',
#   'anxiety',
#   'smile',
#   'wave',
#   'everyone',
#   'goodbye',
#   'goodgame',
#   'no',
#   'amount',
#   'telling',
#   'great',
#   'job',
#   'prevent',
#   'agonizing',
#   'things',
#   'wrong',
#   'could',
#   'done',
#   'better'],
#  175: ['hate', 'social', 'anxiety', 'much'],
#  176: ['really',
#   'slight',
#   'social',
#   'anxiety',
#   'like',
#   'hate',
#   'going',
#   'stores',
#   'especially',
#   'alone',
#   'real',
#   'mvp',
#   'shit'],
#  177: ['hate',
#   'christmas',
#   'part',
#   'commercialism',
#   'year',
#   'realize',
#   'social',
#   'anxiety',
#   'doesn',
#   'like',
#   'big',
#   'groups',
#   'people',
#   'especially',
#   'family',
#   'especially',
#   'formal',
#   'situations',
#   'hugs',
#   'christmas',
#   'tomorrow',
#   'feel'],
#  178: ['thank',
#   'saying',
#   'hate',
#   'things',
#   'severe',
#   'social',
#   'anxiety',
#   'whole',
#   'idea',
#   'spectacle',
#   'would',
#   'give',
#   'panic',
#   'attack'],
#  179: ['hate',
#   'social',
#   'anxiety',
#   'makes',
#   'feel',
#   'like',
#   'stop',
#   'texting',
#   'people',
#   'im',
#   'annoying'],
#  180: ['second',
#   'work',
#   'hate',
#   'socialising',
#   'like',
#   'wear',
#   'nice',
#   'dresses',
#   'social',
#   'anxiety',
#   'blows',
#   '#anxiety',
#   '#workdo',
#   '#christmas',
#   '#velvetdress',
#   '#mentalhealthawareness',
#   '#festivefuckery',
#   '#prettylittlething'],
#  181: ['hate', 'social', 'anxieties'],
#  182: ['man', 'hate', 'social', 'anxiety'],
#  183: ['even',
#   'anything',
#   'bad',
#   'literally',
#   'sleep',
#   'anxiety',
#   'shits',
#   'lmao',
#   'hate',
#   'social',
#   'anxiety'],
#  184: ['ok',
#   'see',
#   'thing',
#   'social',
#   'anxiety',
#   'hate',
#   'talking',
#   'really',
#   'political',
#   'topics',
#   'stresses',
#   'debate',
#   'others',
#   'think',
#   'civil',
#   'someone',
#   'group',
#   'best',
#   'walk',
#   'away',
#   'fighting',
#   'feeds',
#   'polarity',
#   'keeping'],
#  185: ['social', 'anxiety', 'strong', 'hate', 'ugh'],
#  186: ['not',
#   'sound',
#   'like',
#   'boomer',
#   'hate',
#   'loud',
#   'ass',
#   'kids',
#   'bus',
#   'smh',
#   'social',
#   'anxiety',
#   'like',
#   'age'],
#  187: ['shet',
#   'hate',
#   'monkey',
#   'app',
#   'maka',
#   'induce',
#   'ug',
#   'social',
#   'anxiety',
#   'ck',
#   'hahahahaha'],
#  188: ['social',
#   'anxiety',
#   'real',
#   'thing',
#   'still',
#   'hate',
#   'social',
#   'still',
#   'freak',
#   'hours',
#   'days',
#   'weeks',
#   'even',
#   'months',
#   'event',
#   'people',
#   'think',
#   'exaggerating',
#   'hurts'],
#  189: ['dead',
#   'ass',
#   'think',
#   'people',
#   'know',
#   'social',
#   'anxiety',
#   'means',
#   'hate',
#   'see'],
#  190: ['children',
#   'creating',
#   'society',
#   'hate',
#   'educated',
#   'serious',
#   'anxiety',
#   'social',
#   'skill',
#   'issues',
#   'teaching',
#   'people',
#   'look',
#   'everything',
#   'problem',
#   'society',
#   'become'],
#  191: ['really',
#   'hate',
#   'social',
#   'anxiety',
#   'gets',
#   'sometimes',
#   'really',
#   'convinces',
#   'no',
#   'one',
#   'likes',
#   'trying',
#   'work',
#   'confident',
#   'independent',
#   'no',
#   'matter',
#   'old',
#   'get',
#   'still',
#   'sticks',
#   'hits',
#   'least',
#   'expect',
#   'really',
#   'hate'],
#  192: ['feel',
#   'im',
#   'social',
#   'awkward',
#   'idk',
#   'im',
#   'close',
#   'anyone',
#   'people',
#   'already',
#   'gang',
#   'hate',
#   'anxiety'],
#  193: ['living',
#   'social',
#   'anxiety',
#   'not',
#   'easy',
#   'turns',
#   'normal',
#   'things',
#   'big',
#   'scary',
#   'event',
#   'hate'],
#  194: ['diagnosed',
#   'anxiety',
#   'probably',
#   'go',
#   'doctor',
#   'hate',
#   'much',
#   'think',
#   'social',
#   'anxiety',
#   'hate',
#   'talking',
#   'people',
#   'face',
#   'face',
#   'especially',
#   'higher'],
#  195: ['hate',
#   'social',
#   'anxiety',
#   'flare',
#   'ups',
#   'get',
#   'self',
#   'hating',
#   'towards',
#   'keep',
#   'trying',
#   'put',
#   'negative',
#   'hole'],
#  196: ['wow',
#   'step',
#   'outside',
#   'routine',
#   'try',
#   'social',
#   'get',
#   'around',
#   'people',
#   'forget',
#   'breathe',
#   'hate',
#   'anxiety'],
#  197: ['hate',
#   'living',
#   'social',
#   'anxiety',
#   'lonely',
#   'sorta',
#   'contradicting',
#   'want',
#   'friends',
#   'terrible',
#   'making',
#   'cheers'],
#  198: ['gonna',
#   'share',
#   'post',
#   'without',
#   'reacting',
#   'hate',
#   'kind',
#   'petty',
#   'level',
#   'social',
#   'anxiety'],
#  199: ['love',
#   'hate',
#   'amazon',
#   'replaced',
#   'malls',
#   'go',
#   'mall',
#   'getting',
#   'social',
#   'anxiety'],
#  200: ['social', 'anxiety', 'going', 'roof', 'void', 'space', 'right', 'hate'],
#  201: ['social',
#   'anxiety',
#   'party',
#   'one',
#   'hate',
#   'going',
#   'restaurants',
#   'packed',
#   'friday',
#   'nights'],
#  202: ['absolutely',
#   'hate',
#   'social',
#   'anxiety',
#   'even',
#   'say',
#   'hi',
#   'someone',
#   'see',
#   'public'],
#  203: ['honestly',
#   'hate',
#   'social',
#   'anxiety',
#   'doesn',
#   'mean',
#   'friends',
#   'wtfffff',
#   'believe',
#   'therapist',
#   'said'],
#  204: ['wanted',
#   'say',
#   'last',
#   'post',
#   'full',
#   'typos',
#   'texted',
#   'kinda',
#   'crush',
#   'know',
#   'annoying',
#   'anxiety',
#   'hate',
#   'social',
#   'crap'],
#  205: ['never',
#   'listen',
#   'people',
#   'think',
#   'omg',
#   'hate',
#   'talking',
#   'people',
#   'social',
#   'anxiety',
#   'omg',
#   'let',
#   'not',
#   'get',
#   'started',
#   'make',
#   'mad'],
#  206: ['#thankstocamila',
#   'person',
#   'taught',
#   'loving',
#   'best',
#   'friend',
#   'today',
#   'speak',
#   'people',
#   'without',
#   'thinking',
#   'social',
#   'anxiety',
#   'taught',
#   'love',
#   'not',
#   'give',
#   'anyone',
#   'hate'],
#  207: ['hate',
#   'desperately',
#   'want',
#   'talk',
#   'people',
#   'social',
#   'anxiety',
#   'stops'],
#  208: ['hate', 'social', 'anxiety', 'fucking', 'hate'],
#  209: ['mostly',
#   'feel',
#   'place',
#   'even',
#   'friends',
#   'not',
#   'blame',
#   'think',
#   'something',
#   'social',
#   'anxiety',
#   'fear',
#   'everybody',
#   'interact',
#   'eventually',
#   'grow',
#   'hate'],
#  210: ['everytime',
#   'mention',
#   'social',
#   'anxiety',
#   'anyone',
#   'get',
#   'laughed',
#   'genuinely',
#   'gives',
#   'panic',
#   'attacks',
#   'hate'],
#  211: ['social',
#   'anxiety',
#   'hate',
#   'attention',
#   'like',
#   'wear',
#   'things',
#   'like'],
#  212: ['social',
#   'anxiety',
#   'bitchhhh',
#   'really',
#   'want',
#   'go',
#   'things',
#   'comes',
#   'time',
#   'leave',
#   'anxiety',
#   'high',
#   'never',
#   'leave',
#   'house',
#   'unless',
#   'go',
#   'work',
#   'hate',
#   'not',
#   'productive'],
#  213: ['fucking',
#   'hate',
#   'social',
#   'media',
#   'used',
#   'compared',
#   'connected',
#   'generations',
#   'history',
#   'planet',
#   'also',
#   'highest',
#   'suicide',
#   'rates',
#   'linked',
#   'depression',
#   'anxiety',
#   'stress',
#   'lonliness',
#   'bullying',
#   'explain',
#   'one'],
#  214: ['weird',
#   'thing',
#   'mental',
#   'health',
#   'issues',
#   'year',
#   'made',
#   'sort',
#   'hate',
#   'alone',
#   'actually',
#   'want',
#   'people',
#   'around',
#   'problem',
#   'social',
#   'anxiety',
#   'part',
#   'problem',
#   'makes',
#   'hard',
#   'ask',
#   'people',
#   'hang',
#   'though'],
#  215: ['today', 'one', 'days', 'hate', 'social', 'anxiety'],
#  216: ['decided',
#   'go',
#   'boy',
#   'oh',
#   'boy',
#   'social',
#   'anxiety',
#   'fucked',
#   'bring',
#   'white',
#   'elephant',
#   'gift',
#   'suck',
#   'wrapping',
#   'hate',
#   'adulting'],
#  217: ['btw',
#   'hate',
#   'talking',
#   'everyone',
#   'always',
#   'bored',
#   'forcing',
#   'hesitant',
#   'like',
#   'drop',
#   'dead',
#   'altho',
#   'not',
#   'social',
#   'anxiety',
#   'hate',
#   'talking',
#   'even',
#   'tho',
#   'talkative',
#   'knew',
#   'lead',
#   'convo',
#   'like',
#   'whats',
#   'point',
#   'want',
#   'laugh',
#   'idk'],
#  218: ['swear',
#   'social',
#   'anxiety',
#   'comes',
#   'phone',
#   'calls',
#   'hate',
#   'know'],
#  219: ['also',
#   'went',
#   'christmas',
#   'shopping',
#   'today',
#   'hate',
#   'going',
#   'late',
#   'horrible',
#   'social',
#   'anxiety'],
#  220: ['want',
#   'make',
#   'documentary',
#   'called',
#   'secret',
#   'life',
#   'popular',
#   'furries',
#   'except',
#   'would',
#   'wind',
#   'short',
#   'film',
#   'people',
#   'suffering',
#   'heat',
#   'exhaustion',
#   'extreme',
#   'social',
#   'anxiety',
#   'read',
#   'hate',
#   'mail',
#   'death',
#   'threats',
#   'get',
#   'social',
#   'media'],
#  221: ['ive',
#   'dabbling',
#   'showing',
#   'face',
#   'often',
#   'terrifying',
#   'suffer',
#   'social',
#   'anxiety',
#   'still',
#   'hate',
#   'tinder',
#   'even',
#   'fucken',
#   'worse',
#   'insta',
#   'though'],
#  222: ['hate',
#   'dressing',
#   'fake',
#   'judged',
#   'feeling',
#   'absolutely',
#   'crippled',
#   'social',
#   'anxiety',
#   'god',
#   'absolutely',
#   'despise',
#   'process'],
#  223: ['relate', 'hard', 'kinda', 'hate', 'fuels', 'social', 'anxiety'],
#  224: ['hate',
#   'working',
#   'retail',
#   'right',
#   'social',
#   'anxiety',
#   'already',
#   'bad',
#   'nice',
#   'people'],
#  225: ['social',
#   'media',
#   'gives',
#   'anxiety',
#   'hate',
#   'checking',
#   'dms',
#   'sit',
#   'odd',
#   'number',
#   'feel',
#   'obligated',
#   'check'],
#  226: ['hate',
#   'every',
#   'time',
#   'wanna',
#   'go',
#   'ferdibert',
#   'discord',
#   'chat',
#   'maybe',
#   'make',
#   'online',
#   'friends',
#   'overwhelmed',
#   'anxiety',
#   'fear',
#   'rejection',
#   'end',
#   'not',
#   'anything',
#   'abandoned',
#   'friends',
#   'past',
#   'many',
#   'times',
#   'social',
#   'skills',
#   'crap'],
#  227: ['actually', 'hate', 'social', 'anxiety'],
#  228: ['thing',
#   'hate',
#   'social',
#   'anxiety',
#   'something',
#   'completely',
#   'aware',
#   'want',
#   'get',
#   'rid',
#   'cant',
#   'without',
#   'worst',
#   'enemy',
#   'mentally',
#   'blocking'],
#  229: ['social',
#   'anxiety',
#   'actual',
#   'hate',
#   'fire',
#   'fruit',
#   'decent',
#   'execution',
#   'games',
#   'seemingly',
#   'bottomless',
#   'hunger',
#   'ranked',
#   'everything'],
#  230: ['social',
#   'anxiety',
#   'many',
#   'situations',
#   'looked',
#   'exactly',
#   'tried',
#   'get',
#   'along',
#   'people',
#   'exactly',
#   'met',
#   'hell',
#   'hate',
#   'crowd',
#   'people',
#   'whose',
#   'eyes'],
#  231: ['wish',
#   'could',
#   'talk',
#   'social',
#   'anxiety',
#   'even',
#   'worse',
#   'online',
#   'want',
#   'get',
#   'better',
#   'many',
#   'friends',
#   'sometimes',
#   'feel',
#   'lonely',
#   'know',
#   'friends',
#   'love',
#   'alot',
#   'hate',
#   'feeling',
#   'anxious',
#   'al',
#   'time'],
#  232: ['hate',
#   'sister',
#   'tries',
#   'show',
#   'morally',
#   'right',
#   'wrong',
#   'bro',
#   'probably',
#   'one',
#   'reasons',
#   'social',
#   'anxiety'],
#  233: ['hate',
#   'performing',
#   'without',
#   'check',
#   'cuz',
#   'social',
#   'anxiety',
#   'facing',
#   'fears',
#   'wanna',
#   'get',
#   'compensated',
#   'new',
#   'years',
#   'might',
#   'exception'],
#  234: ['used',
#   'loud',
#   'ratchet',
#   'public',
#   'younger',
#   'got',
#   'social',
#   'anxiety',
#   'like',
#   'mf',
#   'hate',
#   'even',
#   'speaking'],
#  235: ['confused',
#   'assumed',
#   'cgp',
#   'grey',
#   'group',
#   'organization',
#   'tim',
#   'wrong',
#   'someone',
#   'wanting',
#   'make',
#   'someone',
#   'happy',
#   'hate',
#   'social',
#   'interaction',
#   'bad',
#   'anxiety',
#   'relish',
#   'great',
#   'engaging',
#   'conversations',
#   'not',
#   'good',
#   'starting'],
#  236: ['dude',
#   'literally',
#   'hate',
#   'telling',
#   'people',
#   'kind',
#   'social',
#   'media',
#   'lol',
#   'anxiety',
#   'make',
#   'scared',
#   'everything'],
#  237: ['hate',
#   'mom',
#   'makes',
#   'talk',
#   'strangers',
#   'instead',
#   'social',
#   'anxiety',
#   'inexistant'],
#  238: ['hate',
#   'social',
#   'anxiety',
#   'first',
#   'time',
#   'like',
#   'two',
#   'years',
#   'joy',
#   'good',
#   'job',
#   'lysander',
#   'days',
#   'without',
#   'randomly',
#   'ruining',
#   'things',
#   'no',
#   'reason'],
#  239: ['social',
#   'anxiety',
#   'charts',
#   'right',
#   'fucking',
#   'hate',
#   'school',
#   'good',
#   'thing',
#   'panic',
#   'attack',
#   'medication',
#   'take'],
#  240: ['social',
#   'anxiety',
#   'shitty',
#   'hate',
#   'spend',
#   'hours',
#   'debating',
#   'whether',
#   'go',
#   'eventually',
#   'exhaust',
#   'make',
#   'upset',
#   'never',
#   'gets',
#   'easier',
#   'lot',
#   'times',
#   'great',
#   'fun',
#   'difficult',
#   'get',
#   'confident'],
#  241: ['hate',
#   'hate',
#   'starbucks',
#   'worker',
#   'drive',
#   'thru',
#   'leans',
#   'window',
#   'makes',
#   'conversation',
#   'instead',
#   'letting',
#   'sit',
#   'silence',
#   'drink',
#   'ready',
#   'nice',
#   'sorry',
#   'bad',
#   'social',
#   'anxiety',
#   'hhhhhhhh'],
#  242: ['grinch',
#   'person',
#   'social',
#   'anxiety',
#   'bottled',
#   'hiding',
#   'facade',
#   'hate',
#   'pretending',
#   'mean',
#   'look',
#   'tough',
#   'grinch'],
#  243: ['strippers',
#   'tips',
#   'use',
#   'help',
#   'social',
#   'anxiety',
#   'working',
#   'starting',
#   'affect',
#   'money',
#   'no',
#   'no',
#   'drink',
#   'hate',
#   'drunk',
#   'work'],
#  244: ['also',
#   'someone',
#   'asked',
#   'coin',
#   'today',
#   'unemployed',
#   'shit',
#   'social',
#   'anxiety',
#   'made',
#   'give',
#   'knowing',
#   'could',
#   'given',
#   'less',
#   'money',
#   'probably',
#   'drugs',
#   'anyway',
#   'hate',
#   'like'],
#  245: ['need',
#   'read',
#   'emotions',
#   'understand',
#   'emotions',
#   'empathetic',
#   'self',
#   'regulatory',
#   'motivated',
#   'social',
#   'self',
#   'aware',
#   'influences',
#   'actions',
#   'fear',
#   'anxiety',
#   'love',
#   'hate'],
#  246: ['understand',
#   'people',
#   'struggle',
#   'anxiety',
#   'social',
#   'situations',
#   'type',
#   'things',
#   'not',
#   'create',
#   'unnecessary',
#   'hate'],
#  247: ['hate', 'havein', 'social', 'anxiety'],
#  248: ['drinking',
#   'coffee',
#   'seeing',
#   'guy',
#   'like',
#   'hot',
#   'popular',
#   'boys',
#   'social',
#   'media',
#   'anxiety',
#   'time',
#   'night',
#   'hate',
#   'feelings'],
#  249: ['playing',
#   'death',
#   'stranding',
#   'easy',
#   'bts',
#   'give',
#   'social',
#   'strand',
#   'anxiety',
#   'also',
#   'playing',
#   'mainly',
#   'delivery',
#   'part',
#   'not',
#   'weird',
#   'grey',
#   'scaled',
#   'sea',
#   'life',
#   'drama',
#   'tone',
#   'red',
#   'wrapping',
#   'sum',
#   'blonde',
#   'nonsense',
#   'hate',
#   'kidding',
#   'stan'],
#  250: ['hate', 'social', 'anxiety', 'thread'],
#  251: ['another',
#   'day',
#   'hate',
#   'means',
#   'one',
#   'day',
#   'love',
#   'fucking',
#   'social',
#   'anxiety'],
#  252: ['anti',
#   'social',
#   'coo',
#   'no',
#   'problems',
#   'part',
#   'anxiety',
#   'comes',
#   'meeting',
#   'new',
#   'people',
#   'hate'],
#  253: ['compensate',
#   'social',
#   'situations',
#   'simple',
#   'fact',
#   'hate',
#   'social',
#   'situations',
#   'filled',
#   'anxiety'],
#  254: ['went',
#   'see',
#   'frozen',
#   'woman',
#   'front',
#   'kept',
#   'taking',
#   'pictures',
#   'flash',
#   'may',
#   'incredible',
#   'social',
#   'anxiety',
#   'hate',
#   'conflict',
#   'th',
#   'time',
#   'yelled'],
#  255: ['thing',
#   'social',
#   'anxiety',
#   'make',
#   'mistake',
#   'even',
#   'minor',
#   'one',
#   'mind',
#   'like',
#   'activated',
#   'nuclear',
#   'weapon',
#   'ruined',
#   'think',
#   'people',
#   'hate',
#   'hate',
#   'feeling'],
#  256: ['man',
#   'hate',
#   'felt',
#   'sometimes',
#   'get',
#   'social',
#   'anxiety',
#   'reflection'],
#  257: ['hate',
#   'social',
#   'anxiety',
#   'everytime',
#   'go',
#   'give',
#   'upset',
#   'stomach',
#   'nervous'],
#  258: ['one',
#   'things',
#   'hate',
#   'abt',
#   'time',
#   'year',
#   'intensely',
#   'ups',
#   'social',
#   'anxiety',
#   'like',
#   'regression',
#   'type',
#   'shit',
#   'need',
#   'social',
#   'isolation',
#   'rn'],
#  259: ['pager',
#   'godsend',
#   'phone',
#   'either',
#   'constantly',
#   'charge',
#   'range',
#   'hospital',
#   'hate',
#   'phone',
#   'anyway',
#   'social',
#   'anxiety',
#   'throws',
#   'state',
#   'every',
#   'time',
#   'rings',
# ...
#   'anxiety',
#   'bad',
#   'hate',
#   'forced',
#   'talk',
#   'people',
#   'everyday',
#   'awkward',
#   'completely',
#   'understand',
#   'go',
#   'think'],
#  917: ['everyone', 'got', 'social', 'anxiety', 'hate'],
#  918: ['oh',
#   'people',
#   'actually',
#   'usually',
#   'fine',
#   'post',
#   'office',
#   'think',
#   'social',
#   'anxiety',
#   'like',
#   'hate',
#   'bothering',
#   'must',
#   'never',
#   'come',
#   'know',
#   'mean',
#   'lol'],
#  919: ['ive',
#   'evolved',
#   'saying',
#   'hate',
#   'people',
#   'emo',
#   'child',
#   'endless',
#   'social',
#   'anxiety',
#   'screaming'],
#  920: ['tf',
#   'gone',
#   'tell',
#   'shorty',
#   'got',
#   'social',
#   'anxiety',
#   'hate',
#   'people',
#   'damn',
#   'pigeon',
#   'something'],
#  921: ['social', 'anxiety', 'not', 'fun', 'fucking', 'hate'],
#  922: ['hate',
#   'asshole',
#   'social',
#   'anxiety',
#   'might',
#   'not',
#   'want',
#   'performer',
#   'summer',
#   'walker',
#   'canceled',
#   'tour',
#   'proves',
#   'social',
#   'anxiety',
#   'deeply',
#   'misunderstood',
#   'via'],
#  923: ['mfs',
#   'claim',
#   'everyday',
#   'crazy',
#   'depressed',
#   'bipolar',
#   'bad',
#   'anxiety',
#   'multiple',
#   'personalities',
#   'shxt',
#   'someone',
#   'really',
#   'social',
#   'anxiety',
#   'shows',
#   'hate'],
#  924: ['use',
#   'damn',
#   'internet',
#   'much',
#   'even',
#   'comprehend',
#   'social',
#   'anxiety',
#   'look',
#   'shit',
#   'putting',
#   'cents',
#   'reasons',
#   'hate',
#   'human',
#   'race',
#   'fucking',
#   'ignorant',
#   'ass',
#   'people'],
#  925: ['hate',
#   'people',
#   'bully',
#   'famous',
#   'doesn',
#   'mean',
#   'social',
#   'anxiety',
#   'like',
#   'people',
#   'make',
#   'sick'],
#  926: ['like',
#   'really',
#   'wish',
#   'could',
#   'figured',
#   'social',
#   'anxiety',
#   'last',
#   'fucking',
#   'semester',
#   'college',
#   'could',
#   'coordinated',
#   'sporadic',
#   'absences',
#   'like',
#   'send',
#   'collective',
#   'email',
#   'saying',
#   'hey',
#   'hate',
#   'class',
#   'hate',
#   'something',
#   'srry'],
#  927: ['love',
#   'cause',
#   'social',
#   'anxiety',
#   'hate',
#   'ordering',
#   'food',
#   'great'],
#  928: ['hate',
#   'people',
#   'pet',
#   'dog',
#   'without',
#   'asking',
#   'social',
#   'anxiety',
#   'blame',
#   'imagine',
#   'randos',
#   'coming',
#   'touching'],
#  929: ['hella',
#   'adorable',
#   'lot',
#   'ya',
#   'hate',
#   'awkward',
#   'social',
#   'anxiety',
#   'really',
#   'no',
#   'joke'],
#  930: ['social',
#   'media',
#   'causes',
#   'unnecessary',
#   'anxiety',
#   'question',
#   'ask',
#   'concern',
#   'speak',
#   'stop',
#   'subtweeting',
#   'talk',
#   'person',
#   'hate',
#   'seeing',
#   'people',
#   'struggle',
#   'social',
#   'media',
#   'post'],
#  931: ['literally',
#   'hate',
#   'gym',
#   'much',
#   'social',
#   'anxiety',
#   'fat',
#   'body',
#   'gonna',
#   'get',
#   'skinny'],
#  932: ['hate',
#   'summer',
#   'walker',
#   'receives',
#   'social',
#   'anxiety',
#   'wild',
#   'like',
#   'stfu',
#   'yall',
#   'know'],
#  933: ['would',
#   'like',
#   'share',
#   'accomplishment',
#   'may',
#   'know',
#   'social',
#   'anxiety',
#   'amp',
#   'today',
#   'first',
#   'time',
#   'ever',
#   'ate',
#   'usually',
#   'starve',
#   'rather',
#   'eat',
#   'bc',
#   'feel',
#   'like',
#   'ppl',
#   'would',
#   'give',
#   'looks',
#   'amp',
#   'hate',
#   'feeling',
#   'today',
#   'amp',
#   'im',
#   'proud'],
#  934: ['people',
#   'bad',
#   'social',
#   'anxiety',
#   'hate',
#   'tend',
#   'push',
#   'situations',
#   'forced',
#   'social',
#   'thinking',
#   'push',
#   'hard',
#   'enough',
#   'ok',
#   'realize',
#   'anxiety',
#   'worse',
#   'thought'],
#  935: ['makes',
#   'laugh',
#   'astros',
#   'fans',
#   'hate',
#   'much',
#   'yankee',
#   'fans',
#   'ones',
#   'threw',
#   'beer',
#   'fans',
#   'threw',
#   'stuff',
#   'players',
#   'field',
#   'taunted',
#   'one',
#   'pitchers',
#   'social',
#   'anxiety',
#   'depression',
#   'keep',
#   'talking'],
#  936: ['think',
#   'hardest',
#   'part',
#   'social',
#   'anxiety',
#   'mental',
#   'tug',
#   'war',
#   'talk',
#   'people',
#   'think',
#   'hate',
#   'uggghhh',
#   'shut',
#   'not',
#   'bother',
#   'people',
#   'presence'],
#  937: ['summer',
#   'walker',
#   'struggles',
#   'immensely',
#   'social',
#   'anxiety',
#   'tell',
#   'pictures',
#   'takes',
#   'performs',
#   'gotta',
#   'remember',
#   'human',
#   'hate',
#   'see',
#   'black',
#   'people',
#   'go',
#   'hard'],
#  938: ['believe',
#   'not',
#   'suffer',
#   'social',
#   'anxiety',
#   'rather',
#   'text',
#   'talk',
#   'person',
#   'phone',
#   'unless',
#   'comfortable',
#   'beyond',
#   'shy',
#   'amp',
#   'hate',
#   'holding',
#   'convo',
#   'break',
#   'sweating'],
#  939: ['summer',
#   'walker',
#   'opening',
#   'social',
#   'anxiety',
#   'getting',
#   'hate',
#   'makes',
#   'heart',
#   'hurt'],
#  940: ['maybe',
#   'yall',
#   'hatred',
#   'got',
#   'bad',
#   'rn',
#   'could',
#   'imagine',
#   'receiving',
#   'hate',
#   'hundreds',
#   'thousands',
#   'people',
#   'cant',
#   'compare',
#   'social',
#   'anxiety',
#   'anyone',
#   'know',
#   'exposure',
#   'two',
#   'completely',
#   'different',
#   'scales'],
#  941: ['sorry',
#   'not',
#   'model',
#   'body',
#   'builder',
#   'idc',
#   'people',
#   'explaining',
#   'social',
#   'anxiety',
#   'put',
#   'body',
#   'everywhere',
#   'internet',
#   'hate',
#   'break',
#   'ya',
#   'bitch'],
#  942: ['hate',
#   'school',
#   'much',
#   'social',
#   'anxiety',
#   'roof',
#   'day',
#   'long',
#   'actually',
#   'feel',
#   'like',
#   'gonna',
#   'throw',
#   'someone',
#   'accept',
#   'rn',
#   'wanna',
#   'cry'],
#  943: ['hate',
#   'people',
#   'talk',
#   'summer',
#   'walker',
#   'bad',
#   'way',
#   'understand',
#   'social',
#   'anxiety',
#   'people',
#   'always',
#   'pick',
#   'understand',
#   'amp',
#   'unfair',
#   'treat',
#   'someone',
#   'way',
#   'understand',
#   'like'],
#  944: ['everyone',
#   'twitter',
#   'like',
#   'social',
#   'anxiety',
#   'sometimes',
#   'worry',
#   'friends',
#   'secretly',
#   'hate',
#   'haha',
#   'cute',
#   'consider',
#   'friends',
#   'never',
#   'post',
#   'instagram',
#   'stories',
#   'birthday',
#   'know',
#   'hate'],
#  945: ['everyone',
#   'giving',
#   'summer',
#   'walker',
#   'hard',
#   'time',
#   'social',
#   'anxiety',
#   'goes',
#   'show',
#   'country',
#   'treats',
#   'mental',
#   'illness',
#   'never',
#   'seen',
#   'much',
#   'hate',
#   'girl',
#   'shy',
#   'pursuing',
#   'dreams'],
#  946: ['exactly',
#   'want',
#   'perform',
#   'act',
#   'broadway',
#   'hate',
#   'plays',
#   'book',
#   'tours',
#   'social',
#   'anxiety',
#   'consumer',
#   'pays',
#   'service',
#   'feels',
#   'stiffed',
#   'messed'],
#  947: ['people',
#   'picking',
#   'summer',
#   'walker',
#   'way',
#   'handle',
#   'social',
#   'anxiety',
#   'smh',
#   'hate',
#   'see'],
#  948: ['expexted',
#   'entertainment',
#   'industry',
#   'without',
#   'hate',
#   'went',
#   'entertainment',
#   'industry',
#   'knowing',
#   'damn',
#   'well',
#   'social',
#   'anxiety'],
#  949: ['hate',
#   'people',
#   'keep',
#   'coming',
#   'summer',
#   'walker',
#   'social',
#   'anxiety',
#   'get',
#   'life'],
#  950: ['extroverted',
#   'social',
#   'people',
#   'hate',
#   'introverts',
#   'people',
#   'social',
#   'anxiety',
#   'complete',
#   'shit'],
#  951: ['hate',
#   'summer',
#   'deals',
#   'social',
#   'anxiety',
#   'love',
#   'handles',
#   'best',
#   'abilities'],
#  952: ['hate',
#   'relationships',
#   'reason',
#   'plus',
#   'social',
#   'anxiety',
#   'always',
#   'end'],
#  953: ['sigh',
#   'remind',
#   'even',
#   'started',
#   'posting',
#   'artwork',
#   'anything',
#   'reminded',
#   'hate',
#   'social',
#   'media',
#   'sm',
#   'anxiety',
#   'enjoying',
#   'hahahaha'],
#  954: ['protect',
#   'woman',
#   'life',
#   'fucking',
#   'hate',
#   'people',
#   'go',
#   'people',
#   'social',
#   'anxiety'],
#  955: ['exactly', 'plus', 'said', 'social', 'anxiety', 'hate', 'sm'],
#  956: ['know',
#   'real',
#   'social',
#   'anxiety',
#   'hate',
#   'ever',
#   'say',
#   'person',
#   'respond',
#   'back',
#   'nigga',
#   'asked',
#   'first'],
#  957: ['want',
#   'depressed',
#   'anxious',
#   'not',
#   'every',
#   'emotion',
#   'true',
#   'mental',
#   'disorder',
#   'social',
#   'anxiety',
#   'hate',
#   'humans',
#   'true',
#   'anxiety',
#   'depression',
#   'work',
#   'hard',
#   'get'],
#  958: ['hate',
#   'small',
#   'talk',
#   'automatically',
#   'assume',
#   'think',
#   'far',
#   'elitist',
#   'amp',
#   'lofty',
#   'found',
#   'engaging',
#   'could',
#   'potentially',
#   'amazing',
#   'convo',
#   'sit',
#   'fuck',
#   'humble',
#   'supersilicious',
#   'self',
#   'amp',
#   'kind',
#   'unless',
#   'social',
#   'anxiety',
#   'case',
#   'sry'],
#  959: ['ok',
#   'summer',
#   'walker',
#   'tell',
#   'ppl',
#   'social',
#   'anxiety',
#   'like',
#   'around',
#   'ppl',
#   'soon',
#   'one',
#   'regular',
#   'like',
#   'say',
#   'slow',
#   'much',
#   'hate',
#   'internet'],
#  960: ['hate',
#   'social',
#   'anxiety',
#   'gets',
#   'way',
#   'like',
#   'setting',
#   'one',
#   'two',
#   'ppl',
#   'fine',
#   'group',
#   'setting',
#   'anxiety',
#   'kicks',
#   'tend',
#   'shut',
#   'isolate',
#   'conversation'],
#  961: ['hate',
#   'using',
#   'stripper',
#   'tactic',
#   'claim',
#   'doesn',
#   'social',
#   'anxiety',
#   'searched',
#   'definition',
#   'social',
#   'anxiety',
#   'google',
#   'doesn',
#   'mean',
#   'know',
#   'shit',
#   'stripping',
#   'small',
#   'club',
#   'different',
#   'performing',
#   'concert'],
#  962: ['people',
#   'dragging',
#   'summer',
#   'walker',
#   'social',
#   'anxiety',
#   'hate',
#   'icebreaker',
#   'introductions',
#   'group',
#   'settings'],
#  963: ['tired',
#   'seeing',
#   'niggas',
#   'come',
#   'trees',
#   'talking',
#   'summers',
#   'social',
#   'anxiety',
#   'writer',
#   'nervous',
#   'hate',
#   'yall',
#   'black',
#   'community',
#   'whole',
#   'sucks',
#   'blind',
#   'comes',
#   'mental',
#   'health'],
#  964: ['social',
#   'anxiety',
#   'hard',
#   'summer',
#   'walker',
#   'actually',
#   'tell',
#   'world',
#   'takes',
#   'strength',
#   'many',
#   'people',
#   'mental',
#   'issues',
#   'even',
#   'know',
#   'start',
#   'start',
#   'bash',
#   'people',
#   'hate',
#   'us',
#   'get',
#   'therapy',
#   '#soultrainawards'],
#  965: ['replies', 'awful', 'really', 'hate', 'somebody', 'social', 'anxiety'],
#  966: ['istg',
#   'foul',
#   'questioning',
#   'summer',
#   'walker',
#   'social',
#   'anxiety',
#   'clowning',
#   'anxiety',
#   'social',
#   'media',
#   'almost',
#   'nothing',
#   'worsen',
#   'talk',
#   'bad',
#   'ab',
#   'every',
#   'day',
#   'wonder',
#   'hate',
#   'stream',
#   'music',
#   'leave',
#   'shordy',
#   'alone',
#   'much'],
#  967: ['babe',
#   'comes',
#   'social',
#   'media',
#   'tell',
#   'everyone',
#   'anxiety',
#   'black',
#   'community',
#   'telling',
#   'not',
#   'overdoing',
#   'really',
#   'hate',
#   'see'],
#  968: ['hate',
#   'ppl',
#   'think',
#   'faking',
#   'speech',
#   'gave',
#   'soul',
#   'train',
#   'awards',
#   'no',
#   'doubt',
#   'social',
#   'anxiety',
#   'almost',
#   'bursted',
#   'tears'],
#  969: ['havin', 'social', 'anxiety', 'trash', 'hate'],
#  970: ['hate', 'around', 'many', 'people', 'social', 'anxiety'],
#  971: ['summer',
#   'walker',
#   'literally',
#   'opened',
#   'talked',
#   'social',
#   'anxiety',
#   'still',
#   'making',
#   'jokes',
#   'disgusting',
#   'idea',
#   'like',
#   'hate',
#   'people'],
#  972: ['hate',
#   'people',
#   'call',
#   'someone',
#   'social',
#   'anxiety',
#   'shy',
#   'bitch',
#   'existence',
#   'causes',
#   'us',
#   'panic',
#   'theres',
#   'nothing',
#   'cute'],
#  973: ['years',
#   'ago',
#   'wanted',
#   'go',
#   'school',
#   'meet',
#   'friends',
#   'go',
#   'home',
#   'play',
#   'kiddy',
#   'ps',
#   'games',
#   'hate',
#   'everything',
#   'everyone',
#   'regret',
#   'ever',
#   'talking',
#   'people',
#   'social',
#   'anxiety',
#   'trust',
#   'issues',
#   'come',
#   'crashing'],
#  974: ['hate',
#   'judging',
#   'social',
#   'anxiety',
#   'way',
#   'behave',
#   'fans',
#   'online',
#   'part',
#   'reason',
#   'anxiety',
#   'first',
#   'place',
#   'busy',
#   'trying',
#   'find',
#   'reason',
#   'tear',
#   'apart',
#   'instead',
#   'showing',
#   'basic',
#   'human',
#   'empathy',
#   'people',
#   'trash'],
#  975: ['hate',
#   'seeing',
#   'summer',
#   'walker',
#   'slander',
#   'feed',
#   'like',
#   'invalidating',
#   'social',
#   'anxiety',
#   'bitch',
#   'like',
#   'walk',
#   'fuckimg',
#   'mile',
#   'shoes'],
#  976: ['tryna',
#   'give',
#   'every',
#   'reason',
#   'world',
#   'summer',
#   'walker',
#   'social',
#   'anxiety',
#   'act',
#   'like',
#   'people',
#   'wanna',
#   'try',
#   'grow',
#   'certain',
#   'things',
#   'wanna',
#   'awkward',
#   'self',
#   'still',
#   'making',
#   'money',
#   'hate',
#   'everybody',
#   'mane'],
#  977: ['fact',
#   'people',
#   'really',
#   'think',
#   'summer',
#   'stripper',
#   'even',
#   'social',
#   'anxiety',
#   'hate',
#   'people'],
#  978: ['ugggghhhhh', 'hate', 'social', 'anxiety'],
#  979: ['ignorant',
#   'comes',
#   'summer',
#   'would',
#   'hate',
#   'mfs',
#   'child',
#   'severe',
#   'social',
#   'anxiety',
#   'let',
#   'see',
#   'funny'],
#  980: ['hate',
#   'dumb',
#   'ass',
#   'people',
#   'taking',
#   'someone',
#   'suffered',
#   'social',
#   'anxiety',
#   'trying',
#   'awkward'],
#  981: ['really',
#   'hate',
#   'everybody',
#   'keeps',
#   'saying',
#   'social',
#   'anxiety',
#   'sudden',
#   'didn',
#   'even',
#   'know',
#   'term',
#   'week',
#   'ago',
#   '#stfu'],
#  982: ['totally',
#   'relate',
#   'summer',
#   'walkers',
#   'social',
#   'anxiety',
#   'not',
#   'severe',
#   'definitely',
#   'hate',
#   'around',
#   'folks',
#   'know'],
#  983: ['hate',
#   'way',
#   'social',
#   'media',
#   'completely',
#   'made',
#   'fun',
#   'summer',
#   'walker',
#   'social',
#   'anxiety',
#   'praying',
#   'hope',
#   'amazing',
#   'therapist',
#   'beautiful',
#   'soul'],
#  984: ['hate',
#   'black',
#   'women',
#   'allowed',
#   'mental',
#   'health',
#   'issues',
#   'mocking',
#   'social',
#   'anxiety'],
#  985: ['makin',
#   'fun',
#   'summer',
#   'walker',
#   'social',
#   'anxiety',
#   'well',
#   'hate',
#   'see'],
#  986: ['open',
#   'struggles',
#   'social',
#   'anxiety',
#   'amp',
#   'difficulty',
#   'limelight',
#   'hate',
#   'real'],
#  987: ['hate',
#   'people',
#   'think',
#   'social',
#   'anxiety',
#   'shy',
#   'like',
#   'bitch',
#   'im',
#   'not',
#   'shy',
#   'im',
#   'legit',
#   'scared',
#   'irrational',
#   'phobia',
#   'fear',
#   'really',
#   'anxiety',
#   'essence'],
#  988: ['much',
#   'lmao',
#   'never',
#   'showed',
#   'doesnt',
#   'mean',
#   'wasnt',
#   'happening',
#   'social',
#   'media',
#   'alot',
#   'people',
#   'social',
#   'anxiety',
#   'dont',
#   'show',
#   'time',
#   'could',
#   'got',
#   'worst',
#   'blew',
#   'especially',
#   'hate',
#   'getting'],
#  989: ['people',
#   'belittling',
#   'summer',
#   'walker',
#   'social',
#   'anxiety',
#   'saying',
#   'faking',
#   'ones',
#   'tweet',
#   'black',
#   'people',
#   'needing',
#   'take',
#   'mental',
#   'health',
#   'seriously',
#   'gonna',
#   'better',
#   'parents',
#   'really',
#   'fucking',
#   'hate',
#   'see'],
#  990: ['ooouu',
#   'one',
#   'reasons',
#   'hate',
#   'social',
#   'anxiety',
#   'cuz',
#   'ppl',
#   'thibk',
#   'got',
#   'attitude',
#   'maaaan'],
#  991: ['hate',
#   'preach',
#   'abt',
#   'taking',
#   'mental',
#   'health',
#   'issues',
#   'srsly',
#   'knowing',
#   'social',
#   'anxiety',
#   'yall',
#   'make',
#   'fun',
#   'like',
#   'okay'],
#  992: ['mum',
#   'went',
#   'gossiped',
#   'dad',
#   'started',
#   'laughing',
#   'ugh',
#   'hate',
#   'social',
#   'anxiety',
#   'joke'],
#  993: ['hell',
#   'tf',
#   'not',
#   'hate',
#   'body',
#   'perform',
#   'like',
#   'cause',
#   'body',
#   'not',
#   'cause',
#   'social',
#   'anxiety'],
#  994: ['really',
#   'let',
#   'summer',
#   'breathe',
#   'deserves',
#   'none',
#   'bashing',
#   'hate',
#   'giving',
#   'dealing',
#   'social',
#   'anxiety',
#   'not',
#   'easy',
#   'even',
#   'brave',
#   'enough',
#   'come',
#   'home',
#   'fans',
#   'regardless',
#   'feels',
#   'amazing'],
#  995: ['man',
#   'person',
#   'social',
#   'anxiety',
#   'fucking',
#   'hate',
#   'going',
#   'best',
#   'buy',
#   'love',
#   'going',
#   'look',
#   'new',
#   'tech',
#   'know',
#   'job',
#   'wanna',
#   'shop',
#   'peace'],
#  996: ['really',
#   'hate',
#   'everyone',
#   'trying',
#   'drag',
#   'summer',
#   'walker',
#   '#mentalhealth',
#   'something',
#   'serious',
#   'truly',
#   'effect',
#   'someone',
#   'yet',
#   'want',
#   'drag',
#   'praise',
#   'fact',
#   'young',
#   'black',
#   'woman',
#   'social',
#   'anxiety',
#   'makes',
#   'great',
#   'music'],
#  997: ['hate',
#   'summer',
#   'walker',
#   'really',
#   'tryna',
#   'play',
#   'dumbass',
#   'social',
#   'anxiety',
#   'bs',
#   'gts'],
#  998: ['geographies',
#   'anxieties',
#   'topologies',
#   'hate',
#   'served',
#   'silver',
#   'platter',
#   'analyzing',
#   'political',
#   'economy',
#   'keri',
#   'hilson',
#   'knock',
#   'dessert',
#   'disaster',
#   'capitalism',
#   'rent',
#   'week',
#   'late',
#   'enclosure',
#   'eviction',
#   'fugitives',
#   'social',
#   'life',
#   'social',
#   'death',
#   'lmao'],
#  999: ['see',
#   'making',
#   'summer',
#   'walker',
#   'joke',
#   'tl',
#   'shit',
#   'high',
#   'key',
#   'weird',
#   'literally',
#   'told',
#   'world',
#   'social',
#   'anxiety',
#   'amp',
#   'socially',
#   'awkward',
#   'amp',
#   'making',
#   'joke',
#   'something',
#   'serious',
#   'hate']}

# %%
from nltk.tokenize.treebank import TreebankWordDetokenizer

# %%
TreebankWordDetokenizer().detokenize(tweets_clean_dict[1])
# Out:
# 'hate social anxiety omg'

# %%
detokenized_dict = {}
for key, items in tweets_clean_dict.items():
    detokenized_dict[key] = TreebankWordDetokenizer().detokenize(tweets_clean_dict[key])
# detokenized_dict

# %%
detokenized_dict[0]
# Out:
# 'sometimes really hate social anxiety'

# %%
detokenized_df = pd.DataFrame.from_dict(detokenized_dict, orient='index')

# %%
detokenized_df.head(10)
detokenized_df.rename(columns={0:'pre_processed'}, inplace=True)

# %%
from transformers import AutoModelForSequenceClassification
from transformers import TFAutoModelForSequenceClassification
from transformers import AutoTokenizer
import numpy as np
from scipy.special import softmax
import csv
import urllib.request

# %%
task1='sentiment'
MODEL1 = f"cardiffnlp/twitter-roberta-base-{task1}"
tokenizer1 = AutoTokenizer.from_pretrained(MODEL1)

task2='emotion'
MODEL2 = f"cardiffnlp/twitter-roberta-base-{task2}"
tokenizer2 = AutoTokenizer.from_pretrained(MODEL2)

task3='irony'
MODEL3 = f"cardiffnlp/twitter-roberta-base-{task3}"
tokenizer3 = AutoTokenizer.from_pretrained(MODEL3)

# %%
# download label mapping sentiment
mapping_link = f"https://raw.githubusercontent.com/cardiffnlp/tweeteval/main/datasets/{task1}/mapping.txt"
with urllib.request.urlopen(mapping_link) as f:
    html = f.read().decode('utf-8').split("\n")
    csvreader = csv.reader(html, delimiter='\t')
labels1 = [row[1] for row in csvreader if len(row) > 1]
labels1
# Out:
# ['negative', 'neutral', 'positive']

# %%
# download label mapping emotion
mapping_link = f"https://raw.githubusercontent.com/cardiffnlp/tweeteval/main/datasets/{task2}/mapping.txt"
with urllib.request.urlopen(mapping_link) as f:
    html = f.read().decode('utf-8').split("\n")
    csvreader = csv.reader(html, delimiter='\t')
labels2 = [row[1] for row in csvreader if len(row) > 1]
labels2
# Out:
# ['anger', 'joy', 'optimism', 'sadness']

# %%
# download label mapping irony
mapping_link = f"https://raw.githubusercontent.com/cardiffnlp/tweeteval/main/datasets/{task3}/mapping.txt"
with urllib.request.urlopen(mapping_link) as f:
    html = f.read().decode('utf-8').split("\n")
    csvreader = csv.reader(html, delimiter='\t')
labels3 = [row[1] for row in csvreader if len(row) > 1]
labels3
# Out:
# ['non_irony', 'irony']

# %%
model1 = TFAutoModelForSequenceClassification.from_pretrained(MODEL1)
model2 = TFAutoModelForSequenceClassification.from_pretrained(MODEL2)
model3 = TFAutoModelForSequenceClassification.from_pretrained(MODEL3)
# Out:
# All model checkpoint layers were used when initializing TFRobertaForSequenceClassification.
#
# All the layers of TFRobertaForSequenceClassification were initialized from the model checkpoint at cardiffnlp/twitter-roberta-base-sentiment.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFRobertaForSequenceClassification for predictions without further training.
# All model checkpoint layers were used when initializing TFRobertaForSequenceClassification.
#
# All the layers of TFRobertaForSequenceClassification were initialized from the model checkpoint at cardiffnlp/twitter-roberta-base-emotion.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFRobertaForSequenceClassification for predictions without further training.
# All model checkpoint layers were used when initializing TFRobertaForSequenceClassification.
#
# All the layers of TFRobertaForSequenceClassification were initialized from the model checkpoint at cardiffnlp/twitter-roberta-base-irony.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFRobertaForSequenceClassification for predictions without further training.

# %%
# this function return labels for sentiment
def return_labels1(text):
    encoded_input = tokenizer1(text, return_tensors='tf')
    output = model1(encoded_input)
    scores = output[0][0].numpy()
    scores = softmax(scores)
    ranking = np.argsort(scores)
    ranking = ranking[::-1]
    label1 = labels1[ranking[0]]
    return label1

# %%
# this function return labels for emotions
def return_labels2(text):
    encoded_input = tokenizer2(text, return_tensors='tf')
    output = model2(encoded_input)
    scores = output[0][0].numpy()
    scores = softmax(scores)
    ranking = np.argsort(scores)
    ranking = ranking[::-1]
    label2 = labels2[ranking[0]]
    return label2

# %%
# this function return labels for irony
def return_labels3(text):
    encoded_input = tokenizer3(text, return_tensors='tf')
    output = model3(encoded_input)
    scores = output[0][0].numpy()
    scores = softmax(scores)
    ranking = np.argsort(scores)
    ranking = ranking[::-1]
    label3 = labels3[ranking[0]]
    return label3

# %%
# this function return probabilities to analize how "sure" the model is
def return_prob1(text):
    encoded_input = tokenizer1(text, return_tensors='tf')
    output = model1(encoded_input)
    scores = output[0][0].numpy()
    scores = softmax(scores)
    ranking = np.argsort(scores)
    ranking = ranking[::-1]
    return np.sort(scores)[-1]

# %%
# this function return probabilities to analize how "sure" the model is
def return_prob2(text):
    encoded_input = tokenizer2(text, return_tensors='tf')
    output = model2(encoded_input)
    scores = output[0][0].numpy()
    scores = softmax(scores)
    ranking = np.argsort(scores)
    ranking = ranking[::-1]
    return np.sort(scores)[-1]

# %%
# this function return probabilities to analize how "sure" the model is
def return_prob3(text):
    encoded_input = tokenizer3(text, return_tensors='tf')
    output = model3(encoded_input)
    scores = output[0][0].numpy()
    scores = softmax(scores)
    ranking = np.argsort(scores)
    ranking = ranking[::-1]
    return np.sort(scores)[-1]

# %%
detokenized_df['label_sentiment'] = detokenized_df['pre_processed'].apply(lambda x: return_labels1(x))
detokenized_df['probability_sentiment'] = detokenized_df['pre_processed'].apply(lambda x: return_prob1(x))

detokenized_df['label_emotion'] = detokenized_df['pre_processed'].apply(lambda x: return_labels2(x))
detokenized_df['probability_emotion'] = detokenized_df['pre_processed'].apply(lambda x: return_prob2(x))

detokenized_df['label_irony'] = detokenized_df['pre_processed'].apply(lambda x: return_labels3(x))
detokenized_df['probability_irony'] = detokenized_df['pre_processed'].apply(lambda x: return_prob3(x))

detokenized_df
# Out:
#                                                                                                                                                                                                        pre_processed  \
# 0                                                                                                                                                                               sometimes really hate social anxiety
# 1                                                                                                                                                                                            hate social anxiety omg
# 2                                                                                                                                 social anxiety says stay home day nothing depression says idiot stay home day hate
# 3                                                                                                                                                space hour gone drunk pounding migraine social anxiety fucking hate
# 4                love leaving house lol jk fucking hate took quick jaunt town today lit fire today celebration #socialanxiety solid opportunities realizing within min paying #fuckit #goinghome #notworthanothermin
# ..                                                                                                                                                                                                               ...
# 995                                                                                                         man person social anxiety fucking hate going best buy love going look new tech know job wanna shop peace
# 996                                 really hate everyone trying drag summer walker #mentalhealth something serious truly effect someone yet want drag praise fact young black woman social anxiety makes great music
# 997                                                                                                                                               hate summer walker really tryna play dumbass social anxiety bs gts
# 998  geographies anxieties topologies hate served silver platter analyzing political economy keri hilson knock dessert disaster capitalism rent week late enclosure eviction fugitives social life social death lmao
# 999                                                             see making summer walker joke tl shit high key weird literally told world social anxiety amp socially awkward amp making joke something serious hate
#
#     label_sentiment  probability_sentiment label_emotion  probability_emotion  \
# 0          negative               0.966794       sadness             0.919926
# 1          negative               0.972935       sadness             0.920086
# 2          negative               0.902722       sadness             0.767700
# 3          negative               0.975444         anger             0.851755
# 4          negative               0.345962         anger             0.831793
# ..              ...                    ...           ...                  ...
# 995        negative               0.784583         anger             0.595983
# 996        negative               0.655295         anger             0.610953
# 997        negative               0.930655         anger             0.903912
# 998        negative               0.752642       sadness             0.744211
# 999        negative               0.959547         anger             0.801338
#
#     label_irony  probability_irony
# 0         irony           0.855944
# 1         irony           0.536289
# 2         irony           0.638162
# 3     non_irony           0.639590
# 4     non_irony           0.703963
# ..          ...                ...
# 995   non_irony           0.711266
# 996       irony           0.824386
# 997   non_irony           0.654283
# 998   non_irony           0.678233
# 999   non_irony           0.514762
#
# [1000 rows x 7 columns]

# %%
official_df = pd.concat([depression_df[['renderedContent']], detokenized_df], axis = 1)
official_df
# Out:
#                                                                                                                                                                                                                                                                                 renderedContent  \
# 0                                                                                                                                                                                                                                                     Sometimes I really hate my social anxiety
# 1                                                                                                                                                                                                                                                                 i hate social anxiety omg 😓😓😓
# 2                                                                                                                                                                   Social anxiety says "stay home all day and do nothing"\nBut depression says "idiot why do you stay home all day I hate you"
# 3                                                                                                                                                                                  In the space of an hour I've gone from drunk, to pounding migraine and social anxiety, I fucking hate myself
# 4    I love leaving the house (lol jk… fucking HATE it)\n\nTook a quick jaunt into town today and lit about $25-$30 on fire today in celebration of my #socialanxiety. Had a solid 2 opportunities after realizing it within 1 min of paying but.....\n#fuckit\n#goinghome\n#notworthanothermin
# ..                                                                                                                                                                                                                                                                                          ...
# 995                                                                                                            Man as a person with social anxiety I fucking hate going to Best Buy but I love going there to look at new tech. I KNOW THEY'RE DOING THEIR JOB BUT I JUST WANNA SHOP IN PEACE 😣
# 996                               i really hate how everyone is trying to drag summer walker. \n\n#MentalHealth is something serious and can truly effect someone and yet we want to drag her. \n\nHow about we praise the fact that a young black woman with social anxiety makes great music.
# 997                                                                                                                                                                                                             I hate summer walker 😭 she really tryna play that dumbass social anxiety bs gts
# 998  “geographies, anxieties and topologies of hate served on a silver platter ” analyzing the political economy of Keri Hilson’s”Knock You Down” dessert or disaster(capitalism)?\n Or\n“my rent about a week late” enclosure/eviction and the fugitives social life through social death LMAO
# 999                              I see that y’all are making summer Walker a joke all over my TL and that shit is high key weird. She literally told the world that she has social anxiety &amp; is socially awkward &amp; here y’all are making a joke out of something serious. I hate y’all.
#
#                                                                                                                                                                                                        pre_processed  \
# 0                                                                                                                                                                               sometimes really hate social anxiety
# 1                                                                                                                                                                                            hate social anxiety omg
# 2                                                                                                                                 social anxiety says stay home day nothing depression says idiot stay home day hate
# 3                                                                                                                                                space hour gone drunk pounding migraine social anxiety fucking hate
# 4                love leaving house lol jk fucking hate took quick jaunt town today lit fire today celebration #socialanxiety solid opportunities realizing within min paying #fuckit #goinghome #notworthanothermin
# ..                                                                                                                                                                                                               ...
# 995                                                                                                         man person social anxiety fucking hate going best buy love going look new tech know job wanna shop peace
# 996                                 really hate everyone trying drag summer walker #mentalhealth something serious truly effect someone yet want drag praise fact young black woman social anxiety makes great music
# 997                                                                                                                                               hate summer walker really tryna play dumbass social anxiety bs gts
# 998  geographies anxieties topologies hate served silver platter analyzing political economy keri hilson knock dessert disaster capitalism rent week late enclosure eviction fugitives social life social death lmao
# 999                                                             see making summer walker joke tl shit high key weird literally told world social anxiety amp socially awkward amp making joke something serious hate
#
#     label_sentiment  probability_sentiment label_emotion  probability_emotion  \
# 0          negative               0.966794       sadness             0.919926
# 1          negative               0.972935       sadness             0.920086
# 2          negative               0.902722       sadness             0.767700
# 3          negative               0.975444         anger             0.851755
# 4          negative               0.345962         anger             0.831793
# ..              ...                    ...           ...                  ...
# 995        negative               0.784583         anger             0.595983
# 996        negative               0.655295         anger             0.610953
# 997        negative               0.930655         anger             0.903912
# 998        negative               0.752642       sadness             0.744211
# 999        negative               0.959547         anger             0.801338
#
#     label_irony  probability_irony
# 0         irony           0.855944
# 1         irony           0.536289
# 2         irony           0.638162
# 3     non_irony           0.639590
# 4     non_irony           0.703963
# ..          ...                ...
# 995   non_irony           0.711266
# 996       irony           0.824386
# 997   non_irony           0.654283
# 998   non_irony           0.678233
# 999   non_irony           0.514762
#
# [1000 rows x 8 columns]

# %%
official_df.to_csv('./preprocessed_data/without_negations/anxiety_without_negations.csv', sep=',', index=False, encoding='utf-8-sig')

# %%
#official_df
