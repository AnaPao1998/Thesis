# %%
# Imports
import os
import pandas as pd

# %%
# Setting variables to be used in format string command below
#['contraladepresion', 'noestassolo'] lista para hashtags
# otra lista para search si no hay suficiente
tweet_count = 1000
text_query = "contraladepresion"
since_date = "2020-01-01"
until_date = "2021-01-01"

# Using OS library to call CLI commands in Python
os.system(f'snscrape --jsonl --max-results {tweet_count} --since {since_date} twitter-hashtag "{text_query} until:{until_date}"> text-query-tweets.json')
# Out:
# 0

# %%
# Reads the json generated from the CLI command above and creates a pandas dataframe
tweets_df1 = pd.read_json('text-query-tweets.json', lines=True)
# Displays first 5 entries from dataframe
tweets_df1.head()
# Out:
#                                                  url  \
# 0  https://twitter.com/GmezNapolen/status/1334224...
# 1  https://twitter.com/diegoberlin/status/1274673...
# 2  https://twitter.com/kalhy_deis/status/12521247...
# 3  https://twitter.com/danna_ediciones/status/122...
# 4  https://twitter.com/AgusDLeon/status/121723712...
#
#                        date  \
# 0 2020-12-02 19:54:05+00:00
# 1 2020-06-21 11:59:17+00:00
# 2 2020-04-20 06:39:49+00:00
# 3 2020-02-18 19:40:12+00:00
# 4 2020-01-15 00:08:40+00:00
#
#                                              content  \
# 0  Los abrazos cuando duran 20 segundo liberan do...
# 1  @shakira #dontbother #loveyourself #arcoiris #...
# 2  La salud mental no es un tema para menosprecia...
# 3  #Sí #MiReina #SomosMás #LaLuchq #ContraLaDepre...
# 4  #Frase Motiva a tu equipo a crecer, porque seg...
#
#                                      renderedContent                   id  \
# ...

# %%
tweets_df1
# Out:
#                                                   url  \
# 0   https://twitter.com/GmezNapolen/status/1334224...
# 1   https://twitter.com/diegoberlin/status/1274673...
# 2   https://twitter.com/kalhy_deis/status/12521247...
# 3   https://twitter.com/danna_ediciones/status/122...
# 4   https://twitter.com/AgusDLeon/status/121723712...
# 5   https://twitter.com/jdavidbol/status/121690132...
# 6   https://twitter.com/TuKble/status/121685216673...
# 7   https://twitter.com/katita048/status/121684661...
# 8   https://twitter.com/FEMUAC/status/121683283644...
# 9   https://twitter.com/Nextia_IT/status/121681223...
# 10  https://twitter.com/eguzmanp/status/1216731201...
#
#                         date  \
# 0  2020-12-02 19:54:05+00:00
# 1  2020-06-21 11:59:17+00:00
# 2  2020-04-20 06:39:49+00:00
# 3  2020-02-18 19:40:12+00:00
# 4  2020-01-15 00:08:40+00:00
# 5  2020-01-14 01:54:18+00:00
# 6  2020-01-13 22:38:59+00:00
# 7  2020-01-13 22:16:54+00:00
# 8  2020-01-13 21:22:10+00:00
# ...

# %%
list(tweets_df1['content'])
# Out:
# ['Los abrazos cuando duran 20 segundo liberan dopamina y es hermosa esa sensación 🤗 #contraladepresion',
#  '@shakira #dontbother #loveyourself #arcoiris #regenbogen #regenbogenfarben #csdberlin \n#DasLebenschmecktnachObst #Thaliafrutas #mdcthalia #nodepression #sindepresion #contraladepresion #levantate #stehauf… https://t.co/8HG9X6DuDP',
#  'La salud mental no es un tema para menospreciar, cuidemos de nuestro todo, cuerpo, corazon y mente~\n#saludmental #encasa #todosjuntos #UnidosSaldremosAdelante #contraelcovid19 #contraladepresion #noestassolo',
#  '#Sí #MiReina #SomosMás #LaLuchq #ContraLaDepresión es #MuyValiente\nSé lo que afrontas, así que te admiro por tener el valor de contarlo. Ese es el #Primer #GranPaso\n#RT para ayudar e una #Venezolana #Migrante #Linda #Valiente y #Fuerte por #Salir y por #Resistir la #Soledad https://t.co/5oKRt0f2lC',
#  '#Frase Motiva a tu equipo a crecer, porque seguramente tu crecerás con ellos 😉. #ContraLaDepresión #Puebla',
# ...

# %%
# Export dataframe into a CSV
tweets_df1.to_csv('depresion.csv', sep=',', index=False, encoding='utf-8-sig')

# %%
# Setting variables to be used in format string command below
tweet_count = 1000
text_query =
head()
# Out:
#                                                  url  \
# 0  https://twitter.com/pgescu/status/133169708590...
# 1  https://twitter.com/paulacetamol/status/132376...
# 2  https://twitter.com/howtolovecamila/status/132...
# 3  https://twitter.com/Rep_Artran/status/13200632...
# 4  https://twitter.com/Solmurz/status/13049812749...
#
#                        date  \
# 0 2020-11-25 20:31:41+00:00
# 1 2020-11-03 23:25:10+00:00
# 2 2020-10-31 12:52:50+00:00
# 3 2020-10-24 18:03:07+00:00
# 4 2020-09-13 03:12:35+00:00
#
#                                              content  \
# 0  Me diagnosticaron anhedonia y TEPT. Solo un vi...
# 1  me diagnosticaron tlp y un posible tept, no sé...
# 2  me diagnosticaron TEPT \nustedes que tienen po...
# 3  @ardillaaviadora No sé si lo he entendido.\nCu...
# 4  leí tengo miedo torero cuando me diagnosticaro...
#
#                                      renderedContent                   id  \
# ...

# %%
# Export dataframe into a CSV
tweets_df5.to_csv('estres_postraumatico2.csv', sep=',', index=False, encoding='utf-8-sig')

# %%
# Setting variables to be used in format string command below
tweet_count = 1000
text_query = "diagnosticaron ansiedad social"
since_date = "2020-01-01"
until_date = "2021-01-01"

# Using OS library to call CLI commands in Python
os.system('snscrape --jsonl --max-results {} --since {} twitter-search "{} until:{}"> text-query-tweets.json'.format(tweet_count, since_date, text_query, until_date))
# Out:
# 0

# %%
# Reads the json generated from the CLI command above and creates a pandas dataframe
tweets_df6 = pd.read_json('text-query-tweets.json', lines=True)
# Displays first 5 entries from dataframe
tweets_df6.head()
# Out:
#                                                  url  \
# 0  https://twitter.com/sonor0us/status/1344080857...
# 1  https://twitter.com/AgussTorrees/status/134320...
# 2  https://twitter.com/highdown131/status/1341212...
# 3  https://twitter.com/iAlinne/status/13367935840...
# 4  https://twitter.com/eternbelle/status/13339961...
#
#                        date  \
# 0 2020-12-30 00:40:22+00:00
# 1 2020-12-27 14:47:23+00:00
# 2 2020-12-22 02:41:12+00:00
# 3 2020-12-09 22:03:21+00:00
# 4 2020-12-02 04:47:19+00:00
#
#                                              content  \
# 0  sabéis lo acorralada que me sentía yo cuando m...
# 1  @Caron7e1 Hace algún tiempo me diagnosticaron ...
# 2  Hoy hace 4 años, cuando tenía 17, me diagnosti...
# 3  @AdriqnHF Ay qué buena onda.\nA mí me diagnost...
# 4  14) Antes de que mi papá falleciera, yo realme...
#
#                                      renderedContent                   id  \
# ...

# %%
# Export dataframe into a CSV
tweets_df6.to_csv('ansiedad_social.csv', sep=',', index=False, encoding='utf-8-sig')

# %%
# Setting variables to be used in format string command below
tweet_count = 1000
text_query = "tengo ansiedad social"
since_date = "2020-01-01"
until_date = "2021-01-01"

# Using OS library to call CLI commands in Python
os.system('snscrape --jsonl --max-results {} --since {} twitter-search "{} until:{}"> text-query-tweets.json'.format(tweet_count, since_date, text_query, until_date))
# Out:
# 0

# %%
# Reads the json generated from the CLI command above and creates a pandas dataframe
tweets_df7 = pd.read_json('text-query-tweets.json', lines=True)
# Displays first 5 entries from dataframe
tweets_df7.head()
# Out:
#                                                  url  \
# 0  https://twitter.com/SH0T0R0K1/status/134476944...
# 1  https://twitter.com/Candel_PV/status/134469477...
# 2  https://twitter.com/movedtousagibun/status/134...
# 3  https://twitter.com/loadlossantos/status/13446...
# 4  https://twitter.com/dxnisse24/status/134465896...
#
#                        date  \
# 0 2020-12-31 22:16:34+00:00
# 1 2020-12-31 17:19:53+00:00
# 2 2020-12-31 16:54:47+00:00
# 3 2020-12-31 16:18:49+00:00
# 4 2020-12-31 14:57:34+00:00
#
#                                              content  \
# 0  Por donde empezar? Cuando te conocí me daba al...
# 1  Che yo no la pasé tan mal en el 2020 capaz por...
# 2  Tengo ansiedad social pero Dios colaos delante...
# 3  dios jajsjsjs yo me tengo que anotar lo que te...
# 4  mí prima deja gimnasia artística y ahora cuand...
#
#                                      renderedContent                   id  \
# ...

# %%
# Export dataframe into a CSV
tweets_df7.to_csv('ansiedad_social2.csv', sep=',', index=False, encoding='utf-8-sig')

# %%
 for h in hastag_list:
        if len(keyword) > 0:
            output_name = f"{keyword.replace(' ', '_')}_{since.replace('-', '')}_{until.replace('-', '')}.txt"
            output_path = os.path.join(ROOT_DIR, 'scraped_tweet', dir_name, output_name)

            print(f'scraping tweets with keyword: "{keyword}" ...')
            try:
                os.system(
                    f'snscrape twitter-{keyword_user_search_param} "{keyword} since:{since} until:{until} lang:{lang}" > {output_path}')
            except Exception as err:
                print(f"SNSCRAPE ERROR: {err}")
