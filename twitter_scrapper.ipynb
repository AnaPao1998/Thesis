# %%
# Imports
import os
import pandas as pd

# %%
# Setting variables to be used in format string command below
tweet_count = 500
text_query = "bts"
since_date = "2020-12-24"
until_date = "2020-12-31"

# Using OS library to call CLI commands in Python
os.system('snscrape --jsonl --max-results {} --since {} twitter-search "{} until:{}"> text-query-tweets.json'.format(tweet_count, since_date, text_query, until_date))
# Out:
# 0

# %%
# Reads the json generated from the CLI command above and creates a pandas dataframe
tweets_df2 = pd.read_json('text-query-tweets.json', lines=True)

# Displays first 5 entries from dataframe
tweets_df2.head()
# Out:
#                                                  url  \
# 0  https://twitter.com/MYG0THIC/status/1344433082...
# 1  https://twitter.com/AM41017395/status/13444330...
# 2  https://twitter.com/io_y__/status/134443308115...
# 3  https://twitter.com/zeezeefarah2/status/134443...
# 4  https://twitter.com/jjkgoldenpjm/status/134443...
#
#                        date  \
# 0 2020-12-30 23:59:59+00:00
# 1 2020-12-30 23:59:59+00:00
# 2 2020-12-30 23:59:59+00:00
# 3 2020-12-30 23:59:59+00:00
# 4 2020-12-30 23:59:59+00:00
#
#                                              content  \
# 0      @btsbrasil_on @BTS_twt @galaxiejisoo @BTS_twt
# 1  @BTS_twt Happy birthday Tae :3 https://t.co/H6...
# 2  tag\n\n00''\n\n김태형 \n#ARMYさんと仲良くなりたい #ARMYと仲良く...
# 3  @wearepoweruk @BTS_twt @BTSRadioUK @BTS_ARMY @...
# 4  @RaysminStore @BTS_twt @Stigma_baby @BTS_twt h...
#
#                                      renderedContent                   id  \
# ...

# %%
tweets_df2.columns
# Out:
# Index(['url', 'date', 'content', 'renderedContent', 'id', 'user', 'outlinks',
#        'tcooutlinks', 'replyCount', 'retweetCount', 'likeCount', 'quoteCount',
#        'conversationId', 'lang', 'source', 'sourceUrl', 'sourceLabel', 'media',
#        'retweetedTweet', 'quotedTweet', 'mentionedUsers'],
#       dtype='object')

# %%
list(tweets_df2['content'])
# Out:
# ['@btsbrasil_on @BTS_twt @galaxiejisoo @BTS_twt',
#  '@BTS_twt Happy birthday Tae :3 https://t.co/H6ysGxoXrY',
#  "tag\n\n00''\n\n김태형 \n#ARMYさんと仲良くなりたい #ARMYと仲良くなりたい #armyいいねくれた人全員フォロー #ナムジャarmy #ヨジャarmy #bts https://t.co/MJm8KjfjtU",
#  '@wearepoweruk @BTS_twt @BTSRadioUK @BTS_ARMY @BTSUKUNITE @UKBTSARMATION @btslondoninfo @BANGTANUK @amidocumentary @BTSxIndiana Congrats BTS 🎉💜',
#  '@RaysminStore @BTS_twt @Stigma_baby @BTS_twt https://t.co/fAHryOHZlK',
#  '@miihsw kim seokjin\nI choose Map of the soul: 7 by @BTS_twt @bts_bighit for the Most loved English Album in the #GaanaUsersChoiceIcons',
#  '@armystruggIe @BTS_twt VÉI OKKKKKKKKKKKK',
#  '@BTS_UPDATES_GER Welche tags',
#  '@JOONSJJK 👉👉👉Please vote for bts they are in 2nd place and today is the final day\n https://t.co/XalIiBxoHR',
#  '@BTS_twt 보고싶어요  오늘도 ✨',
#  '@WFVOTING @BTS_twt Answer \nBARMY PELO BTS @BTS_twt',
# ...

# %%
list(tweets_df2['user'])
# Out:
# [{'username': 'MYG0THIC',
#   'displayname': '𝗮𝗯𝘆𝘀𝘀¹¹ rosie day!',
#   'id': 1278008029095608322,
#   'description': '',
#   'rawDescription': '',
#   'descriptionUrls': [],
#   'verified': False,
#   'created': '2020-06-30T16:50:42+00:00',
#   'followersCount': 1161,
#   'friendsCount': 1654,
#   'statusesCount': 33397,
#   'favouritesCount': 41348,
#   'listedCount': 12,
#   'mediaCount': 1090,
#   'location': 'all my love is gone.',
#   'protected': False,
#   'linkUrl': 'http://myg0thic.carrd.co',
#   'linkTcourl': 'https://t.co/dpxkFt47en',
#   'profileImageUrl': 'https://pbs.twimg.com/profile_images/1359128972165066753/xi6HRsI__normal.jpg',
#   'profileBannerUrl': 'https://pbs.twimg.com/profile_banners/1278008029095608322/1612378505',
#   'url': 'https://twitter.com/MYG0THIC'},
#  {'username': 'AM41017395',
#   'displayname': 'AM',
#   'id': 1211389213419028480,
#   'description': "I'm here for the memes.",
#   'rawDescription': "I'm here for the memes.",
# ...

# %%
# Setting variables to be used in format string command below
tweet_count = 500
text_query = "#bts"
since_date = "2020-12-24"
until_date = "2020-12-31"

# Using OS library to call CLI commands in Python
os.system('snscrape --jsonl --max-results {} --since {} twitter-hastag "{} until:{}"> text-query-tweets.json'.format(tweet_count, since_date, text_query, until_date))
# Out:
# 2

# %%
# Reads the json generated from the CLI command above and creates a pandas dataframe
tweets_df2 = pd.read_json('text-query-tweets.json', lines=True)

# Displays first 5 entries from dataframe
tweets_df2.head()
# Out:
# Empty DataFrame
# Columns: []
# Index: []
