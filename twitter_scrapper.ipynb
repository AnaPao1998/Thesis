# %%
# Imports
import os
import pandas as pd

# %%
# Setting variables to be used in format string command below
tweet_count = 1000
text_query = "diagnosticaron depresión"
since_date = "2020-01-01"
until_date = "2021-01-01"

# Using OS library to call CLI commands in Python
os.system('snscrape --jsonl --max-results {} --since {} twitter-search "{} until:{}"> text-query-tweets.json'.format(tweet_count, since_date, text_query, until_date))
# Out:
# 0

# %%
# Reads the json generated from the CLI command above and creates a pandas dataframe
tweets_df1 = pd.read_json('text-query-tweets.json', lines=True)
# Displays first 5 entries from dataframe
tweets_df1.head()
# Out:
#                                                  url  \
# 0  https://twitter.com/urtubiacst/status/13447642...
# 1  https://twitter.com/__L053R/status/13447523665...
# 2  https://twitter.com/gigif3/status/134474170898...
# 3  https://twitter.com/watercalories23/status/134...
# 4  https://twitter.com/iequis/status/134472437171...
#
#                        date  \
# 0 2020-12-31 21:55:51+00:00
# 1 2020-12-31 21:08:43+00:00
# 2 2020-12-31 20:26:22+00:00
# 3 2020-12-31 19:31:44+00:00
# 4 2020-12-31 19:17:28+00:00
#
#                                              content  \
# 0  @Pilarferfig1 @VioletadeCivil Amor eterno a la...
# 1  Diciembre: Diagnosticaron a mi hermana menor c...
# 2  Me diagnosticaron depresión, en el hospital ca...
# 3  Ayyy Dios ya superen a @sky_stars22 y a @chaya...
# 4  Lo peor de mi 2020:\n1. Fallecimiento de 3 fam...
#
#                                      renderedContent                   id  \
# 0  @Pilarferfig1 @VioletadeCivil Amor eterno a la...  1344764229996457987
# 1  Diciembre: Diagnosticaron a mi hermana menor c...  1344752366583767047
# 2  Me diagnosticaron depresión, en el hospital ca...  1344741708987305987
# 3  Ayyy Dios ya superen a @sky_stars22 y a @chaya...  1344727959924568064
# 4  Lo peor de mi 2020:\n1. Fallecimiento de 3 fam...  1344724371718483968
#
#                                                 user  \
# 0  {'username': 'urtubiacst', 'displayname': 'Gat...
# 1  {'username': '__L053R', 'displayname': 'ⓒ ⓐ ⓝ ...
# 2  {'username': 'gigif3', 'displayname': 'Gigis',...
# 3  {'username': 'watercalories23', 'displayname':...
# 4  {'username': 'iequis', 'displayname': 'Rellen'...
#
#                                             outlinks  \
# 0                                                 []
# 1                                                 []
# 2                                                 []
# 3  [https://twitter.com/econfessed/status/1344726...
# 4                                                 []
#
#                  tcooutlinks  replyCount  retweetCount  ...  quoteCount  \
# 0                         []           0             0  ...           0
# 1                         []           0             0  ...           0
# 2                         []           1             0  ...           0
# 3  [https://t.co/BJ0RohavGu]           3             0  ...           0
# 4                         []           1             0  ...           0
#
#         conversationId  lang  \
# 0  1344507990121050112    es
# 1  1344749472484618256    es
# 2  1344740638789693442    es
# 3  1344727959924568064    es
# 4  1344724371718483968    es
#
#                                               source  \
# 0  <a href="http://twitter.com/download/android" ...
# 1  <a href="http://twitter.com/download/iphone" r...
# 2  <a href="http://twitter.com/download/android" ...
# 3  <a href="http://twitter.com/download/iphone" r...
# 4  <a href="http://twitter.com/download/iphone" r...
#
#                              sourceUrl          sourceLabel media  \
# 0  http://twitter.com/download/android  Twitter for Android  None
# 1   http://twitter.com/download/iphone   Twitter for iPhone  None
# 2  http://twitter.com/download/android  Twitter for Android  None
# 3   http://twitter.com/download/iphone   Twitter for iPhone  None
# 4   http://twitter.com/download/iphone   Twitter for iPhone  None
#
#   retweetedTweet                                        quotedTweet  \
# 0            NaN                                               None
# 1            NaN                                               None
# 2            NaN                                               None
# 3            NaN  {'url': 'https://twitter.com/econfessed/status...
# 4            NaN                                               None
#
#                                       mentionedUsers
# 0  [{'username': 'Pilarferfig1', 'displayname': '...
# 1                                               None
# 2                                               None
# 3  [{'username': 'sky_stars22', 'displayname': 's...
# 4                                               None
#
# [5 rows x 21 columns]

# %%
# Export dataframe into a CSV
tweets_df1.to_csv('depresion.csv', sep=',', index=False)

# %%
# Setting variables to be used in format string command below
tweet_count = 1000
text_query = "diagnosticaron bipolaridad"
since_date = "2020-01-01"
until_date = "2021-01-01"

# Using OS library to call CLI commands in Python
os.system('snscrape --jsonl --max-results {} --since {} twitter-search "{} until:{}"> text-query-tweets.json'.format(tweet_count, since_date, text_query, until_date))
# Out:
# 0

# %%
# Reads the json generated from the CLI command above and creates a pandas dataframe
tweets_df2 = pd.read_json('text-query-tweets.json', lines=True)
# Displays first 5 entries from dataframe
tweets_df2.head()
# Out:
#                                                  url  \
# 0  https://twitter.com/HellFireDemon3/status/1344...
# 1  https://twitter.com/FrannyHorror13/status/1344...
# 2  https://twitter.com/Anxlx_saotome/status/13408...
# 3  https://twitter.com/fucktiamo/status/134051550...
# 4  https://twitter.com/_andreeaa_m/status/1340513...
#
#                        date  \
# 0 2020-12-31 23:24:25+00:00
# 1 2020-12-29 22:48:40+00:00
# 2 2020-12-21 00:39:23+00:00
# 3 2020-12-20 04:32:55+00:00
# 4 2020-12-20 04:24:08+00:00
#
#                                              content  \
# 0  Es en forma de perdon, me diagnosticaron Bipol...
# 1  En dos dias me diagnosticaron bipolaridad, tuv...
# 2  bueno pero comprendeme que me diagnosticaron b...
# 3  me diagnosticaron bipolaridad qué tal su tarde...
# 4  Me preguntan "Si tu Dios es tan bueno por qué ...
#
#                                      renderedContent                   id  \
# 0  Es en forma de perdon, me diagnosticaron Bipol...  1344786520130138112
# 1  En dos dias me diagnosticaron bipolaridad, tuv...  1344052745695801345
# 2  bueno pero comprendeme que me diagnosticaron b...  1340819116094074880
# 3  me diagnosticaron bipolaridad qué tal su tarde...  1340515501303361537
# 4  Me preguntan "Si tu Dios es tan bueno por qué ...  1340513291035152388
#
#                                                 user  \
# 0  {'username': 'HellFireDemon3', 'displayname': ...
# 1  {'username': 'FrannyHorror13', 'displayname': ...
# 2  {'username': 'Anxlx_saotome', 'displayname': '...
# 3  {'username': 'fucktiamo', 'displayname': 'andr...
# 4  {'username': '_andreeaa_m', 'displayname': 'Dj...
#
#                                             outlinks  \
# 0  [https://twitter.com/Little_Hunter_/status/134...
# 1                                                 []
# 2                                                 []
# 3                                                 []
# 4                                                 []
#
#                  tcooutlinks  replyCount  retweetCount  ...  quoteCount  \
# 0  [https://t.co/LCBoLSiplA]           0             0  ...           1
# 1                         []           0             0  ...           0
# 2                         []           0             0  ...           0
# 3                         []           1             0  ...           0
# 4                         []           2             0  ...           0
#
#         conversationId  lang  \
# 0  1344786520130138112    es
# 1  1344052745695801345    es
# 2  1340819116094074880    es
# 3  1340515501303361537    es
# 4  1340513291035152388    es
#
#                                               source  \
# 0  <a href="http://twitter.com/download/android" ...
# 1  <a href="http://twitter.com/download/android" ...
# 2  <a href="https://mobile.twitter.com" rel="nofo...
# 3  <a href="http://twitter.com/download/iphone" r...
# 4  <a href="http://twitter.com/download/android" ...
#
#                              sourceUrl          sourceLabel media  \
# 0  http://twitter.com/download/android  Twitter for Android  None
# 1  http://twitter.com/download/android  Twitter for Android  None
# 2           https://mobile.twitter.com      Twitter Web App  None
# 3   http://twitter.com/download/iphone   Twitter for iPhone  None
# 4  http://twitter.com/download/android  Twitter for Android  None
#
#   retweetedTweet                                        quotedTweet  \
# 0            NaN  {'url': 'https://twitter.com/Little_Hunter_/st...
# 1            NaN                                               None
# 2            NaN                                               None
# 3            NaN                                               None
# 4            NaN                                               None
#
#   mentionedUsers
# 0           None
# 1           None
# 2           None
# 3           None
# 4           None
#
# [5 rows x 21 columns]

# %%
# Export dataframe into a CSV
tweets_df2.to_csv('bipolaridad.csv', sep=',', index=False)

# %%
# Setting variables to be used in format string command below
tweet_count = 1000
text_query = "diagnosticaron trastorno de estrés postraumático"
since_date = "2020-01-01"
until_date = "2021-01-01"

# Using OS library to call CLI commands in Python
os.system('snscrape --jsonl --max-results {} --since {} twitter-search "{} until:{}"> text-query-tweets.json'.format(tweet_count, since_date, text_query, until_date))
# Out:
# 0

# %%
# Reads the json generated from the CLI command above and creates a pandas dataframe
tweets_df3 = pd.read_json('text-query-tweets.json', lines=True)
# Displays first 5 entries from dataframe
tweets_df3.head()
# Out:
#                                                  url  \
# 0  https://twitter.com/thelifeasdiana/status/1323...
# 1  https://twitter.com/c_lesV/status/131914705248...
# 2  https://twitter.com/Locarconio/status/12954300...
# 3  https://twitter.com/kein_salat/status/12530993...
# 4  https://twitter.com/liwamairin/status/12254596...
#
#                        date  \
# 0 2020-11-04 01:15:45+00:00
# 1 2020-10-22 05:22:20+00:00
# 2 2020-08-17 18:39:29+00:00
# 3 2020-04-22 23:12:22+00:00
# 4 2020-02-06 16:42:03+00:00
#
#                                              content  \
# 0  Justo hoy me diagnosticaron trastorno de estré...
# 1  @nadrosso En mi caso sí, cuando me diagnostica...
# 2  🔴 TW: Abuso sexual\n\n"Evan Rachel Wood descri...
# 3  @Nofofox Me diagnosticaron trastorno de estrés...
# 4  El año pasado acompañé a mi hermano a consulta...
#
#                                      renderedContent                   id  \
# 0  Justo hoy me diagnosticaron trastorno de estré...  1323796041372561411
# 1  @nadrosso En mi caso sí, cuando me diagnostica...  1319147052480286720
# 2  🔴 TW: Abuso sexual\n\n"Evan Rachel Wood descri...  1295430060724420608
# 3  @Nofofox Me diagnosticaron trastorno de estrés...  1253099353855725570
# 4  El año pasado acompañé a mi hermano a consulta...  1225459650868469765
#
#                                                 user  \
# 0  {'username': 'thelifeasdiana', 'displayname': ...
# 1  {'username': 'c_lesV', 'displayname': 'C.Les',...
# 2  {'username': 'Locarconio', 'displayname': 'Loc...
# 3  {'username': 'kein_salat', 'displayname': 'Mil...
# 4  {'username': 'liwamairin', 'displayname': 'Wal...
#
#                                             outlinks  \
# 0  [https://twitter.com/marenafzarie/status/12352...
# 1                                                 []
# 2  [https://twitter.com/fleshfondue/status/127070...
# 3                                                 []
# 4  [https://twitter.com/Persefone____/status/1225...
#
#                  tcooutlinks  replyCount  retweetCount  ...  quoteCount  \
# 0  [https://t.co/FPZo7M7oQl]           0             0  ...           0
# 1                         []           1             0  ...           0
# 2  [https://t.co/piMnpa7YOL]           0            50  ...           3
# 3                         []           1             0  ...           0
# 4  [https://t.co/tbASkE7nJv]           1             9  ...           0
#
#         conversationId  lang  \
# 0  1323796041372561411    es
# 1  1316544328802734083    es
# 2  1295430060724420608    es
# 3  1253092198851149828    es
# 4  1225459650868469765    es
#
#                                               source  \
# 0  <a href="http://twitter.com/download/iphone" r...
# 1  <a href="http://twitter.com/download/android" ...
# 2  <a href="http://twitter.com/download/android" ...
# 3  <a href="http://twitter.com/download/iphone" r...
# 4  <a href="http://twitter.com/download/android" ...
#
#                              sourceUrl          sourceLabel media  \
# 0   http://twitter.com/download/iphone   Twitter for iPhone   NaN
# 1  http://twitter.com/download/android  Twitter for Android   NaN
# 2  http://twitter.com/download/android  Twitter for Android   NaN
# 3   http://twitter.com/download/iphone   Twitter for iPhone   NaN
# 4  http://twitter.com/download/android  Twitter for Android   NaN
#
#    retweetedTweet                                        quotedTweet  \
# 0             NaN  {'url': 'https://twitter.com/marenafzarie/stat...
# 1             NaN                                               None
# 2             NaN  {'url': 'https://twitter.com/fleshfondue/statu...
# 3             NaN                                               None
# 4             NaN  {'url': 'https://twitter.com/Persefone____/sta...
#
#                                       mentionedUsers
# 0                                               None
# 1  [{'username': 'nadrosso', 'displayname': 'Nadi...
# 2                                               None
# 3  [{'username': 'Nofofox', 'displayname': 'El in...
# 4                                               None
#
# [5 rows x 21 columns]

# %%
# Export dataframe into a CSV
tweets_df3.to_csv('estres_postraumatico.csv', sep=',', index=False)

# %%
# Setting variables to be used in format string command below
tweet_count = 1000
text_query = "diagnosticaron ansiedad social"
since_date = "2020-01-01"
until_date = "2021-01-01"

# Using OS library to call CLI commands in Python
os.system('snscrape --jsonl --max-results {} --since {} twitter-search "{} until:{}"> text-query-tweets.json'.format(tweet_count, since_date, text_query, until_date))
# Out:
# 0

# %%
# Reads the json generated from the CLI command above and creates a pandas dataframe
tweets_df4 = pd.read_json('text-query-tweets.json', lines=True)
# Displays first 5 entries from dataframe
tweets_df4.head()
# Out:
#                                                  url  \
# 0  https://twitter.com/sonor0us/status/1344080857...
# 1  https://twitter.com/AgussTorrees/status/134320...
# 2  https://twitter.com/iT0GAMi/status/13421303401...
# 3  https://twitter.com/highdown131/status/1341212...
# 4  https://twitter.com/iAlinne/status/13367935840...
#
#                        date  \
# 0 2020-12-30 00:40:22+00:00
# 1 2020-12-27 14:47:23+00:00
# 2 2020-12-24 15:29:43+00:00
# 3 2020-12-22 02:41:12+00:00
# 4 2020-12-09 22:03:21+00:00
#
#                                              content  \
# 0  sabéis lo acorralada que me sentía yo cuando m...
# 1  @Caron7e1 Hace algún tiempo me diagnosticaron ...
# 2  @BXBYT3DDY_ https://t.co/oG0cXRL9RO este ES QH...
# 3  Hoy hace 4 años, cuando tenía 17, me diagnosti...
# 4  @AdriqnHF Ay qué buena onda.\nA mí me diagnost...
#
#                                      renderedContent                   id  \
# 0  sabéis lo acorralada que me sentía yo cuando m...  1344080857351540738
# 1  @Caron7e1 Hace algún tiempo me diagnosticaron ...  1343206851714940933
# 2  @BXBYT3DDY_ vm.tiktok.com/ZMJsfsnbt/ este ES Q...  1342130340102549505
# 3  Hoy hace 4 años, cuando tenía 17, me diagnosti...  1341212163457888266
# 4  @AdriqnHF Ay qué buena onda.\nA mí me diagnost...  1336793584012566532
#
#                                                 user  \
# 0  {'username': 'sonor0us', 'displayname': 'ABIER...
# 1  {'username': 'AgussTorrees', 'displayname': 'A...
# 2  {'username': 'iT0GAMi', 'displayname': 'oliver...
# 3  {'username': 'highdown131', 'displayname': 'hi...
# 4  {'username': 'iAlinne', 'displayname': 'D a r ...
#
#                              outlinks                tcooutlinks  replyCount  \
# 0                                  []                         []           0
# 1                                  []                         []           0
# 2  [https://vm.tiktok.com/ZMJsfsnbt/]  [https://t.co/oG0cXRL9RO]           1
# 3                                  []                         []           0
# 4                                  []                         []           0
#
#    retweetCount  ...  quoteCount       conversationId  lang  \
# 0             0  ...           0  1344079842480971776    es
# 1             0  ...           0  1343091442756018176    es
# 2             0  ...           0  1342081905223753729    es
# 3             0  ...           0  1341212163457888266    es
# 4             0  ...           0  1336361804486897664    es
#
#                                               source  \
# 0  <a href="http://twitter.com/download/android" ...
# 1  <a href="http://twitter.com/download/android" ...
# 2  <a href="http://twitter.com/download/iphone" r...
# 3  <a href="https://mobile.twitter.com" rel="nofo...
# 4  <a href="http://twitter.com/download/android" ...
#
#                              sourceUrl          sourceLabel media  \
# 0  http://twitter.com/download/android  Twitter for Android  None
# 1  http://twitter.com/download/android  Twitter for Android  None
# 2   http://twitter.com/download/iphone   Twitter for iPhone  None
# 3           https://mobile.twitter.com      Twitter Web App  None
# 4  http://twitter.com/download/android  Twitter for Android  None
#
#   retweetedTweet  quotedTweet  \
# 0            NaN         None
# 1            NaN         None
# 2            NaN         None
# 3            NaN         None
# 4            NaN         None
#
#                                       mentionedUsers
# 0                                               None
# 1  [{'username': 'Caron7e1', 'displayname': 'Caro...
# 2                                               None
# 3                                               None
# 4  [{'username': 'AdriqnHF', 'displayname': 'Adri...
#
# [5 rows x 21 columns]

# %%
# Export dataframe into a CSV
tweets_df4.to_csv('ansiedad_social.csv', sep=',', index=False)
